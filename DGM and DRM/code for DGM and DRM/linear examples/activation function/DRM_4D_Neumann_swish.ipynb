# %%
import torch
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import torch.nn as nn
from math import *

# %%
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor') # 设置浮点类型为 torch.float64

# %%
# 定义激活函数: swish(x)
def acti(x):
    return x*torch.sigmoid(x)

# %%
# 定义网络结构
class DeepRitzNet(torch.nn.Module):
    def __init__(self, input_width, layer_width):
        super(DeepRitzNet, self).__init__()
        self.linear_in = torch.nn.Linear(input_width, layer_width)
        self.linear1 = torch.nn.Linear(layer_width, layer_width)
        self.linear2 = torch.nn.Linear(layer_width, layer_width)
        self.linear3 = torch.nn.Linear(layer_width, layer_width)
        self.linear4 = torch.nn.Linear(layer_width, layer_width)
        self.linear5 = torch.nn.Linear(layer_width, layer_width)
        self.linear6 = torch.nn.Linear(layer_width, layer_width)
        self.linear_out = torch.nn.Linear(layer_width, 1)

    def forward(self, x):
        y = self.linear_in(x) # fully connect layer
        y = y + acti(self.linear2(acti(self.linear1(y)))) # residual block 1
        y = y + acti(self.linear4(acti(self.linear3(y)))) # residual block 2
        y = y + acti(self.linear6(acti(self.linear5(y)))) # residual block 3
        output = self.linear_out(y) # fully connect layer
        return output

# %%
dimension = 4

# %%
# exact solution
def u_ex(x):  
    x_temp = torch.cos(pi*x)
    u_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return u_x

# %%
def f(x):
    x_temp = torch.cos(pi*x)
    f_x = 2*pi**2*(x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return f_x

# %%
def DRM(x):
    u_hat = model(x)
    ux = torch.zeros(x.size()[0], dimension).cuda()  
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension).cuda()  
        dx[:, i] = torch.ones(x.size()[0])
        ux[:, i] = (model(x+step_size*dx) - model(x-step_size*dx))[:,0]/step_size/2
    uxsq = (torch.sum(ux**2, dim = 1)).reshape([x.size()[0], 1]) # dim = 1 按行求和
    f_temp = f(x)
    part_1 = torch.sum(0.5 * uxsq + 0.5*pi**2*u_hat**2 - f_temp*u_hat)/x.size()[0]
    
    Nb = 100
    xa1 = torch.rand(Nb, dimension).cuda()  
    xa1[:, 0] = torch.zeros(Nb)
    xa2 = torch.rand(Nb, dimension).cuda()  
    xa2[:, 0] = torch.ones(Nb)
    xb1 = torch.rand(Nb, dimension).cuda() 
    xb1[:, 1] = torch.zeros(Nb)
    xb2 = torch.rand(Nb, dimension).cuda() 
    xb2[:, 1] = torch.ones(Nb)
    xc1 = torch.rand(Nb, dimension).cuda() 
    xc1[:, 2] = torch.zeros(Nb)
    xc2 = torch.rand(Nb, dimension).cuda() 
    xc2[:, 2] = torch.ones(Nb)
    xd1 = torch.rand(Nb, dimension).cuda() 
    xd1[:, 3] = torch.zeros(Nb)
    xd2 = torch.rand(Nb, dimension).cuda() 
    xd2[:, 3] = torch.ones(Nb)
    dx1 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx1[:, 0] = torch.ones(xb1.size()[0])
    dx2 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx2[:, 1] = torch.ones(xb1.size()[0])
    dx3 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx3[:, 2] = torch.ones(xb1.size()[0])
    dx4 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx4[:, 3] = torch.ones(xb1.size()[0])
    uxa1 = (((model(xa1+step_size*dx1) - model(xa1-step_size*dx1))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxa2 = (((model(xa2+step_size*dx1) - model(xa2-step_size*dx1))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxb1 = (((model(xb1+step_size*dx2) - model(xb1-step_size*dx2))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxb2 = (((model(xb2+step_size*dx2) - model(xb2-step_size*dx2))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxc1 = (((model(xc1+step_size*dx3) - model(xc1-step_size*dx3))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxc2 = (((model(xc2+step_size*dx3) - model(xc2-step_size*dx3))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxd1 = (((model(xd1+step_size*dx4) - model(xd1-step_size*dx4))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxd2 = (((model(xd2+step_size*dx4) - model(xd2-step_size*dx4))/step_size/2 * (-1.0) - 0)**2).cuda() 
    
    part_2 = torch.sum((uxa1 + uxa2 + uxb1 + uxb2 + uxc1 + uxc2 + uxd1 + uxd2)[:,0])/xa1.size()[0]
    lambda1 = 1.0
    return part_1 + lambda1 * part_2 / 8

# %%
Data_size = 2000
def Gendata():
    x = torch.rand(Data_size, dimension)
    return x.cuda()

# %%
# 正态分布初始化参数
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = DeepRitzNet(dimension, 8)
model = initparam(model, 0.5)

# %%
device = torch.device("cuda:1" )
model.to(device)
# Out:
# DeepRitzNet(
#   (linear_in): Linear(in_features=4, out_features=8, bias=True)
#   (linear1): Linear(in_features=8, out_features=8, bias=True)
#   (linear2): Linear(in_features=8, out_features=8, bias=True)
#   (linear3): Linear(in_features=8, out_features=8, bias=True)
#   (linear4): Linear(in_features=8, out_features=8, bias=True)
#   (linear5): Linear(in_features=8, out_features=8, bias=True)
#   (linear6): Linear(in_features=8, out_features=8, bias=True)
#   (linear_out): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
import torch.optim as optim
import torch.nn as nn
import time

# %%
def relative_error():
    x = Gendata()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact )**2))/torch.sqrt(torch.sum((exact )**2))
    return value

# %%
traintime = 20000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = Gendata()
    x.requires_grad = True
    losses = DRM(x)
    losses.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", losses.detach())
        print("current relative error is: ", error.detach())
        np.save("DRM_relative_error_4D_Neumann_swish.npy", error_save)
np.save("DRM_relative_error_4D_Neumann_swish.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(2.8997, device='cuda:1')
# current relative error is:  tensor(1.1772, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(-5.9744, device='cuda:1')
# current relative error is:  tensor(0.8515, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(-13.7600, device='cuda:1')
# current relative error is:  tensor(0.4736, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(-14.8328, device='cuda:1')
# current relative error is:  tensor(0.3243, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(-15.6605, device='cuda:1')
# current relative error is:  tensor(0.2793, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(-16.2906, device='cuda:1')
# current relative error is:  tensor(0.2429, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(-14.9076, device='cuda:1')
# current relative error is:  tensor(0.2257, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(-17.1390, device='cuda:1')
# current relative error is:  tensor(0.2209, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(-17.3113, device='cuda:1')
# current relative error is:  tensor(0.2030, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(-17.6080, device='cuda:1')
# current relative error is:  tensor(0.2183, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(-17.1982, device='cuda:1')
# current relative error is:  tensor(0.1975, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(-15.3987, device='cuda:1')
# current relative error is:  tensor(0.1996, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(-17.6387, device='cuda:1')
# current relative error is:  tensor(0.1820, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(-17.5328, device='cuda:1')
# current relative error is:  tensor(0.1773, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(-18.2364, device='cuda:1')
# current relative error is:  tensor(0.1830, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(-19.5133, device='cuda:1')
# current relative error is:  tensor(0.1719, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(-16.2584, device='cuda:1')
# current relative error is:  tensor(0.1737, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(-17.6666, device='cuda:1')
# current relative error is:  tensor(0.1736, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(-19.3621, device='cuda:1')
# current relative error is:  tensor(0.1582, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(-18.6986, device='cuda:1')
# current relative error is:  tensor(0.1601, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(-18.2025, device='cuda:1')
# current relative error is:  tensor(0.1610, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(-18.3729, device='cuda:1')
# current relative error is:  tensor(0.1644, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(-18.8539, device='cuda:1')
# current relative error is:  tensor(0.1648, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(-19.8371, device='cuda:1')
# current relative error is:  tensor(0.1605, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(-17.9530, device='cuda:1')
# current relative error is:  tensor(0.1526, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(-17.2282, device='cuda:1')
# current relative error is:  tensor(0.1605, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(-18.2848, device='cuda:1')
# current relative error is:  tensor(0.1613, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(-17.9935, device='cuda:1')
# current relative error is:  tensor(0.1601, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(-18.8029, device='cuda:1')
# current relative error is:  tensor(0.1556, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(-16.8380, device='cuda:1')
# current relative error is:  tensor(0.1579, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(-18.0427, device='cuda:1')
# current relative error is:  tensor(0.1526, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(-18.2004, device='cuda:1')
# current relative error is:  tensor(0.1426, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(-19.5378, device='cuda:1')
# current relative error is:  tensor(0.1226, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(-19.6716, device='cuda:1')
# current relative error is:  tensor(0.0942, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(-20.5291, device='cuda:1')
# current relative error is:  tensor(0.0777, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(-19.3142, device='cuda:1')
# current relative error is:  tensor(0.0490, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(-19.9756, device='cuda:1')
# current relative error is:  tensor(0.0471, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(-18.8073, device='cuda:1')
# current relative error is:  tensor(0.0769, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(-19.0957, device='cuda:1')
# current relative error is:  tensor(0.0312, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(-20.6924, device='cuda:1')
# current relative error is:  tensor(0.0503, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(-20.8517, device='cuda:1')
# current relative error is:  tensor(0.0233, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(-18.8540, device='cuda:1')
# current relative error is:  tensor(0.0387, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(-19.4122, device='cuda:1')
# current relative error is:  tensor(0.0405, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(-20.5293, device='cuda:1')
# current relative error is:  tensor(0.0410, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(-18.2139, device='cuda:1')
# current relative error is:  tensor(0.0692, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(-19.6531, device='cuda:1')
# current relative error is:  tensor(0.0257, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(-19.1365, device='cuda:1')
# current relative error is:  tensor(0.0237, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(-19.4381, device='cuda:1')
# current relative error is:  tensor(0.0251, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(-20.1543, device='cuda:1')
# current relative error is:  tensor(0.0323, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(-19.8102, device='cuda:1')
# current relative error is:  tensor(0.0389, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(-19.3508, device='cuda:1')
# current relative error is:  tensor(0.0254, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(-20.9696, device='cuda:1')
# current relative error is:  tensor(0.0239, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(-19.5650, device='cuda:1')
# current relative error is:  tensor(0.0261, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(-18.4758, device='cuda:1')
# current relative error is:  tensor(0.0300, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(-18.8791, device='cuda:1')
# current relative error is:  tensor(0.0546, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(-19.8076, device='cuda:1')
# current relative error is:  tensor(0.0219, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(-21.5953, device='cuda:1')
# current relative error is:  tensor(0.0407, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(-19.8749, device='cuda:1')
# current relative error is:  tensor(0.0184, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(-20.2947, device='cuda:1')
# current relative error is:  tensor(0.0617, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(-20.6677, device='cuda:1')
# current relative error is:  tensor(0.0186, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(-19.4814, device='cuda:1')
# current relative error is:  tensor(0.0226, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(-19.8645, device='cuda:1')
# current relative error is:  tensor(0.0201, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(-18.1173, device='cuda:1')
# current relative error is:  tensor(0.0624, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(-17.6979, device='cuda:1')
# current relative error is:  tensor(0.0164, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(-19.6818, device='cuda:1')
# current relative error is:  tensor(0.0236, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(-20.3041, device='cuda:1')
# current relative error is:  tensor(0.0364, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(-19.3978, device='cuda:1')
# current relative error is:  tensor(0.0296, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(-22.4904, device='cuda:1')
# current relative error is:  tensor(0.0163, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(-21.6527, device='cuda:1')
# current relative error is:  tensor(0.0572, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(-19.7908, device='cuda:1')
# current relative error is:  tensor(0.0245, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(-19.9805, device='cuda:1')
# current relative error is:  tensor(0.0492, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(-19.6239, device='cuda:1')
# current relative error is:  tensor(0.0309, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(-19.4859, device='cuda:1')
# current relative error is:  tensor(0.0164, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(-18.4390, device='cuda:1')
# current relative error is:  tensor(0.0243, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(-18.4663, device='cuda:1')
# current relative error is:  tensor(0.0169, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(-18.7556, device='cuda:1')
# current relative error is:  tensor(0.0536, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(-18.8190, device='cuda:1')
# current relative error is:  tensor(0.0766, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(-19.6081, device='cuda:1')
# current relative error is:  tensor(0.0349, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(-18.7025, device='cuda:1')
# current relative error is:  tensor(0.0222, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(-19.5386, device='cuda:1')
# current relative error is:  tensor(0.0311, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(-20.5442, device='cuda:1')
# current relative error is:  tensor(0.0729, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(-19.2478, device='cuda:1')
# current relative error is:  tensor(0.0222, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(-19.6619, device='cuda:1')
# current relative error is:  tensor(0.0598, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(-21.1990, device='cuda:1')
# current relative error is:  tensor(0.0592, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(-21.0562, device='cuda:1')
# current relative error is:  tensor(0.0203, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(-20.3794, device='cuda:1')
# current relative error is:  tensor(0.0451, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(-17.4922, device='cuda:1')
# current relative error is:  tensor(0.0229, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(-19.7729, device='cuda:1')
# current relative error is:  tensor(0.0251, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(-20.2864, device='cuda:1')
# current relative error is:  tensor(0.0439, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(-18.7655, device='cuda:1')
# current relative error is:  tensor(0.0193, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(-21.4272, device='cuda:1')
# current relative error is:  tensor(0.0227, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(-19.3464, device='cuda:1')
# current relative error is:  tensor(0.0214, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(-20.0122, device='cuda:1')
# current relative error is:  tensor(0.0429, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(-19.4397, device='cuda:1')
# current relative error is:  tensor(0.0195, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(-20.1638, device='cuda:1')
# current relative error is:  tensor(0.0320, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(-20.3069, device='cuda:1')
# current relative error is:  tensor(0.0217, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(-17.8072, device='cuda:1')
# current relative error is:  tensor(0.0305, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(-19.6866, device='cuda:1')
# current relative error is:  tensor(0.0522, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(-19.5926, device='cuda:1')
# current relative error is:  tensor(0.0377, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(-19.1588, device='cuda:1')
# current relative error is:  tensor(0.0131, device='cuda:1')
# current epoch is:  5000
# current loss is:  tensor(-19.5311, device='cuda:1')
# current relative error is:  tensor(0.0184, device='cuda:1')
# current epoch is:  5050
# current loss is:  tensor(-19.0734, device='cuda:1')
# current relative error is:  tensor(0.0267, device='cuda:1')
# current epoch is:  5100
# current loss is:  tensor(-19.7976, device='cuda:1')
# current relative error is:  tensor(0.0198, device='cuda:1')
# current epoch is:  5150
# current loss is:  tensor(-20.0787, device='cuda:1')
# current relative error is:  tensor(0.0223, device='cuda:1')
# current epoch is:  5200
# current loss is:  tensor(-20.0139, device='cuda:1')
# current relative error is:  tensor(0.0258, device='cuda:1')
# current epoch is:  5250
# current loss is:  tensor(-19.3616, device='cuda:1')
# current relative error is:  tensor(0.0278, device='cuda:1')
# current epoch is:  5300
# current loss is:  tensor(-17.8374, device='cuda:1')
# current relative error is:  tensor(0.0345, device='cuda:1')
# current epoch is:  5350
# current loss is:  tensor(-19.0810, device='cuda:1')
# current relative error is:  tensor(0.0678, device='cuda:1')
# current epoch is:  5400
# current loss is:  tensor(-18.2879, device='cuda:1')
# current relative error is:  tensor(0.0141, device='cuda:1')
# current epoch is:  5450
# current loss is:  tensor(-19.6076, device='cuda:1')
# current relative error is:  tensor(0.0312, device='cuda:1')
# current epoch is:  5500
# current loss is:  tensor(-19.1599, device='cuda:1')
# current relative error is:  tensor(0.0191, device='cuda:1')
# current epoch is:  5550
# current loss is:  tensor(-19.3318, device='cuda:1')
# current relative error is:  tensor(0.0192, device='cuda:1')
# current epoch is:  5600
# current loss is:  tensor(-18.6630, device='cuda:1')
# current relative error is:  tensor(0.0298, device='cuda:1')
# current epoch is:  5650
# current loss is:  tensor(-19.7696, device='cuda:1')
# current relative error is:  tensor(0.0529, device='cuda:1')
# current epoch is:  5700
# current loss is:  tensor(-19.6407, device='cuda:1')
# current relative error is:  tensor(0.0187, device='cuda:1')
# current epoch is:  5750
# current loss is:  tensor(-19.6085, device='cuda:1')
# current relative error is:  tensor(0.0214, device='cuda:1')
# current epoch is:  5800
# current loss is:  tensor(-19.8738, device='cuda:1')
# current relative error is:  tensor(0.0258, device='cuda:1')
# current epoch is:  5850
# current loss is:  tensor(-18.4182, device='cuda:1')
# current relative error is:  tensor(0.0348, device='cuda:1')
# current epoch is:  5900
# current loss is:  tensor(-21.0804, device='cuda:1')
# current relative error is:  tensor(0.0142, device='cuda:1')
# current epoch is:  5950
# current loss is:  tensor(-19.8893, device='cuda:1')
# current relative error is:  tensor(0.0331, device='cuda:1')
# current epoch is:  6000
# current loss is:  tensor(-19.5486, device='cuda:1')
# current relative error is:  tensor(0.0188, device='cuda:1')
# current epoch is:  6050
# current loss is:  tensor(-19.7930, device='cuda:1')
# current relative error is:  tensor(0.0119, device='cuda:1')
# current epoch is:  6100
# current loss is:  tensor(-19.0608, device='cuda:1')
# current relative error is:  tensor(0.0238, device='cuda:1')
# current epoch is:  6150
# current loss is:  tensor(-19.9987, device='cuda:1')
# current relative error is:  tensor(0.0208, device='cuda:1')
# current epoch is:  6200
# current loss is:  tensor(-19.0718, device='cuda:1')
# current relative error is:  tensor(0.0405, device='cuda:1')
# current epoch is:  6250
# current loss is:  tensor(-20.5742, device='cuda:1')
# current relative error is:  tensor(0.0667, device='cuda:1')
# current epoch is:  6300
# current loss is:  tensor(-20.4218, device='cuda:1')
# current relative error is:  tensor(0.0293, device='cuda:1')
# current epoch is:  6350
# current loss is:  tensor(-19.3811, device='cuda:1')
# current relative error is:  tensor(0.0153, device='cuda:1')
# current epoch is:  6400
# current loss is:  tensor(-18.3430, device='cuda:1')
# current relative error is:  tensor(0.0155, device='cuda:1')
# current epoch is:  6450
# current loss is:  tensor(-19.7735, device='cuda:1')
# current relative error is:  tensor(0.0452, device='cuda:1')
# current epoch is:  6500
# current loss is:  tensor(-19.0048, device='cuda:1')
# current relative error is:  tensor(0.0306, device='cuda:1')
# current epoch is:  6550
# current loss is:  tensor(-20.4276, device='cuda:1')
# current relative error is:  tensor(0.0216, device='cuda:1')
# current epoch is:  6600
# current loss is:  tensor(-20.5480, device='cuda:1')
# current relative error is:  tensor(0.0133, device='cuda:1')
# current epoch is:  6650
# current loss is:  tensor(-19.5065, device='cuda:1')
# current relative error is:  tensor(0.0204, device='cuda:1')
# current epoch is:  6700
# current loss is:  tensor(-20.3387, device='cuda:1')
# current relative error is:  tensor(0.0373, device='cuda:1')
# current epoch is:  6750
# current loss is:  tensor(-21.1224, device='cuda:1')
# current relative error is:  tensor(0.0268, device='cuda:1')
# current epoch is:  6800
# current loss is:  tensor(-19.6039, device='cuda:1')
# current relative error is:  tensor(0.0314, device='cuda:1')
# current epoch is:  6850
# current loss is:  tensor(-19.5500, device='cuda:1')
# current relative error is:  tensor(0.0217, device='cuda:1')
# current epoch is:  6900
# current loss is:  tensor(-18.7446, device='cuda:1')
# current relative error is:  tensor(0.0576, device='cuda:1')
# current epoch is:  6950
# current loss is:  tensor(-20.0457, device='cuda:1')
# current relative error is:  tensor(0.0509, device='cuda:1')
# current epoch is:  7000
# current loss is:  tensor(-19.1924, device='cuda:1')
# current relative error is:  tensor(0.0120, device='cuda:1')
# current epoch is:  7050
# current loss is:  tensor(-18.9879, device='cuda:1')
# current relative error is:  tensor(0.0247, device='cuda:1')
# current epoch is:  7100
# current loss is:  tensor(-20.1398, device='cuda:1')
# current relative error is:  tensor(0.0297, device='cuda:1')
# current epoch is:  7150
# current loss is:  tensor(-21.2376, device='cuda:1')
# current relative error is:  tensor(0.0124, device='cuda:1')
# current epoch is:  7200
# current loss is:  tensor(-19.1210, device='cuda:1')
# current relative error is:  tensor(0.0106, device='cuda:1')
# current epoch is:  7250
# current loss is:  tensor(-17.6245, device='cuda:1')
# current relative error is:  tensor(0.0400, device='cuda:1')
# current epoch is:  7300
# current loss is:  tensor(-19.8059, device='cuda:1')
# current relative error is:  tensor(0.0173, device='cuda:1')
# current epoch is:  7350
# current loss is:  tensor(-20.1107, device='cuda:1')
# current relative error is:  tensor(0.1000, device='cuda:1')
# current epoch is:  7400
# current loss is:  tensor(-19.6455, device='cuda:1')
# current relative error is:  tensor(0.0577, device='cuda:1')
# current epoch is:  7450
# current loss is:  tensor(-19.2792, device='cuda:1')
# current relative error is:  tensor(0.0356, device='cuda:1')
# current epoch is:  7500
# current loss is:  tensor(-19.5065, device='cuda:1')
# current relative error is:  tensor(0.0496, device='cuda:1')
# current epoch is:  7550
# current loss is:  tensor(-17.5177, device='cuda:1')
# current relative error is:  tensor(0.0209, device='cuda:1')
# current epoch is:  7600
# current loss is:  tensor(-20.0196, device='cuda:1')
# current relative error is:  tensor(0.0141, device='cuda:1')
# current epoch is:  7650
# current loss is:  tensor(-20.2008, device='cuda:1')
# current relative error is:  tensor(0.0136, device='cuda:1')
# current epoch is:  7700
# current loss is:  tensor(-21.8058, device='cuda:1')
# current relative error is:  tensor(0.0381, device='cuda:1')
# current epoch is:  7750
# current loss is:  tensor(-18.3462, device='cuda:1')
# current relative error is:  tensor(0.0548, device='cuda:1')
# current epoch is:  7800
# current loss is:  tensor(-18.5349, device='cuda:1')
# current relative error is:  tensor(0.0213, device='cuda:1')
# current epoch is:  7850
# current loss is:  tensor(-19.0797, device='cuda:1')
# current relative error is:  tensor(0.0190, device='cuda:1')
# current epoch is:  7900
# current loss is:  tensor(-21.0894, device='cuda:1')
# current relative error is:  tensor(0.0193, device='cuda:1')
# current epoch is:  7950
# current loss is:  tensor(-19.1186, device='cuda:1')
# current relative error is:  tensor(0.0128, device='cuda:1')
# current epoch is:  8000
# current loss is:  tensor(-20.7389, device='cuda:1')
# current relative error is:  tensor(0.0218, device='cuda:1')
# current epoch is:  8050
# current loss is:  tensor(-19.1200, device='cuda:1')
# current relative error is:  tensor(0.0313, device='cuda:1')
# current epoch is:  8100
# current loss is:  tensor(-19.5963, device='cuda:1')
# current relative error is:  tensor(0.0421, device='cuda:1')
# current epoch is:  8150
# current loss is:  tensor(-20.5343, device='cuda:1')
# current relative error is:  tensor(0.0689, device='cuda:1')
# current epoch is:  8200
# current loss is:  tensor(-20.3273, device='cuda:1')
# current relative error is:  tensor(0.0381, device='cuda:1')
# current epoch is:  8250
# current loss is:  tensor(-19.7175, device='cuda:1')
# current relative error is:  tensor(0.0664, device='cuda:1')
# current epoch is:  8300
# current loss is:  tensor(-19.5133, device='cuda:1')
# current relative error is:  tensor(0.0205, device='cuda:1')
# current epoch is:  8350
# current loss is:  tensor(-19.6523, device='cuda:1')
# current relative error is:  tensor(0.0426, device='cuda:1')
# current epoch is:  8400
# current loss is:  tensor(-19.8967, device='cuda:1')
# current relative error is:  tensor(0.0571, device='cuda:1')
# current epoch is:  8450
# current loss is:  tensor(-18.9209, device='cuda:1')
# current relative error is:  tensor(0.0438, device='cuda:1')
# current epoch is:  8500
# current loss is:  tensor(-20.1884, device='cuda:1')
# current relative error is:  tensor(0.0311, device='cuda:1')
# current epoch is:  8550
# current loss is:  tensor(-19.1765, device='cuda:1')
# current relative error is:  tensor(0.0360, device='cuda:1')
# current epoch is:  8600
# current loss is:  tensor(-21.2816, device='cuda:1')
# current relative error is:  tensor(0.0202, device='cuda:1')
# current epoch is:  8650
# current loss is:  tensor(-19.3473, device='cuda:1')
# current relative error is:  tensor(0.0573, device='cuda:1')
# current epoch is:  8700
# current loss is:  tensor(-20.0135, device='cuda:1')
# current relative error is:  tensor(0.0131, device='cuda:1')
# current epoch is:  8750
# current loss is:  tensor(-17.7545, device='cuda:1')
# current relative error is:  tensor(0.0307, device='cuda:1')
# current epoch is:  8800
# current loss is:  tensor(-19.3611, device='cuda:1')
# current relative error is:  tensor(0.0210, device='cuda:1')
# current epoch is:  8850
# current loss is:  tensor(-19.8564, device='cuda:1')
# current relative error is:  tensor(0.0401, device='cuda:1')
# current epoch is:  8900
# current loss is:  tensor(-20.6242, device='cuda:1')
# current relative error is:  tensor(0.0188, device='cuda:1')
# current epoch is:  8950
# current loss is:  tensor(-18.0133, device='cuda:1')
# current relative error is:  tensor(0.0546, device='cuda:1')
# current epoch is:  9000
# current loss is:  tensor(-20.4007, device='cuda:1')
# current relative error is:  tensor(0.0258, device='cuda:1')
# current epoch is:  9050
# current loss is:  tensor(-20.2864, device='cuda:1')
# current relative error is:  tensor(0.0226, device='cuda:1')
# current epoch is:  9100
# current loss is:  tensor(-19.8741, device='cuda:1')
# current relative error is:  tensor(0.0325, device='cuda:1')
# current epoch is:  9150
# current loss is:  tensor(-21.0164, device='cuda:1')
# current relative error is:  tensor(0.0229, device='cuda:1')
# current epoch is:  9200
# current loss is:  tensor(-20.3438, device='cuda:1')
# current relative error is:  tensor(0.0297, device='cuda:1')
# current epoch is:  9250
# current loss is:  tensor(-20.3136, device='cuda:1')
# current relative error is:  tensor(0.0423, device='cuda:1')
# current epoch is:  9300
# current loss is:  tensor(-17.9258, device='cuda:1')
# current relative error is:  tensor(0.0297, device='cuda:1')
# current epoch is:  9350
# current loss is:  tensor(-21.0914, device='cuda:1')
# current relative error is:  tensor(0.0659, device='cuda:1')
# current epoch is:  9400
# current loss is:  tensor(-20.7298, device='cuda:1')
# current relative error is:  tensor(0.0144, device='cuda:1')
# current epoch is:  9450
# current loss is:  tensor(-18.2452, device='cuda:1')
# current relative error is:  tensor(0.0161, device='cuda:1')
# current epoch is:  9500
# current loss is:  tensor(-19.9520, device='cuda:1')
# current relative error is:  tensor(0.0392, device='cuda:1')
# current epoch is:  9550
# current loss is:  tensor(-20.5836, device='cuda:1')
# current relative error is:  tensor(0.0138, device='cuda:1')
# current epoch is:  9600
# current loss is:  tensor(-20.1426, device='cuda:1')
# current relative error is:  tensor(0.0162, device='cuda:1')
# current epoch is:  9650
# current loss is:  tensor(-20.9542, device='cuda:1')
# current relative error is:  tensor(0.0337, device='cuda:1')
# current epoch is:  9700
# current loss is:  tensor(-19.7672, device='cuda:1')
# current relative error is:  tensor(0.0141, device='cuda:1')
# current epoch is:  9750
# current loss is:  tensor(-18.7266, device='cuda:1')
# current relative error is:  tensor(0.0454, device='cuda:1')
# current epoch is:  9800
# current loss is:  tensor(-18.6458, device='cuda:1')
# current relative error is:  tensor(0.0189, device='cuda:1')
# current epoch is:  9850
# current loss is:  tensor(-19.7712, device='cuda:1')
# current relative error is:  tensor(0.0331, device='cuda:1')
# current epoch is:  9900
# current loss is:  tensor(-19.7442, device='cuda:1')
# current relative error is:  tensor(0.0295, device='cuda:1')
# current epoch is:  9950
# current loss is:  tensor(-19.7598, device='cuda:1')
# current relative error is:  tensor(0.0176, device='cuda:1')
# current epoch is:  10000
# current loss is:  tensor(-18.4964, device='cuda:1')
# current relative error is:  tensor(0.0143, device='cuda:1')
# current epoch is:  10050
# current loss is:  tensor(-17.8933, device='cuda:1')
# current relative error is:  tensor(0.0115, device='cuda:1')
# current epoch is:  10100
# current loss is:  tensor(-19.0829, device='cuda:1')
# current relative error is:  tensor(0.0127, device='cuda:1')
# current epoch is:  10150
# current loss is:  tensor(-19.7840, device='cuda:1')
# current relative error is:  tensor(0.0184, device='cuda:1')
# current epoch is:  10200
# current loss is:  tensor(-19.8850, device='cuda:1')
# current relative error is:  tensor(0.0175, device='cuda:1')
# current epoch is:  10250
# current loss is:  tensor(-20.0935, device='cuda:1')
# current relative error is:  tensor(0.0330, device='cuda:1')
# current epoch is:  10300
# current loss is:  tensor(-19.7705, device='cuda:1')
# current relative error is:  tensor(0.0611, device='cuda:1')
# current epoch is:  10350
# current loss is:  tensor(-20.2136, device='cuda:1')
# current relative error is:  tensor(0.0204, device='cuda:1')
# current epoch is:  10400
# current loss is:  tensor(-21.2190, device='cuda:1')
# current relative error is:  tensor(0.0374, device='cuda:1')
# current epoch is:  10450
# current loss is:  tensor(-18.9219, device='cuda:1')
# current relative error is:  tensor(0.0252, device='cuda:1')
# current epoch is:  10500
# current loss is:  tensor(-19.2599, device='cuda:1')
# current relative error is:  tensor(0.0450, device='cuda:1')
# current epoch is:  10550
# current loss is:  tensor(-20.2310, device='cuda:1')
# current relative error is:  tensor(0.0233, device='cuda:1')
# current epoch is:  10600
# current loss is:  tensor(-18.9276, device='cuda:1')
# current relative error is:  tensor(0.0528, device='cuda:1')
# current epoch is:  10650
# current loss is:  tensor(-20.5500, device='cuda:1')
# current relative error is:  tensor(0.0228, device='cuda:1')
# current epoch is:  10700
# current loss is:  tensor(-22.1381, device='cuda:1')
# current relative error is:  tensor(0.0493, device='cuda:1')
# current epoch is:  10750
# current loss is:  tensor(-17.9501, device='cuda:1')
# current relative error is:  tensor(0.0150, device='cuda:1')
# current epoch is:  10800
# current loss is:  tensor(-21.3770, device='cuda:1')
# current relative error is:  tensor(0.0377, device='cuda:1')
# current epoch is:  10850
# current loss is:  tensor(-17.5261, device='cuda:1')
# current relative error is:  tensor(0.0274, device='cuda:1')
# current epoch is:  10900
# current loss is:  tensor(-20.4656, device='cuda:1')
# current relative error is:  tensor(0.0199, device='cuda:1')
# current epoch is:  10950
# current loss is:  tensor(-19.8835, device='cuda:1')
# current relative error is:  tensor(0.0363, device='cuda:1')
# current epoch is:  11000
# current loss is:  tensor(-20.2286, device='cuda:1')
# current relative error is:  tensor(0.0458, device='cuda:1')
# current epoch is:  11050
# current loss is:  tensor(-19.2958, device='cuda:1')
# current relative error is:  tensor(0.0116, device='cuda:1')
# current epoch is:  11100
# current loss is:  tensor(-20.3640, device='cuda:1')
# current relative error is:  tensor(0.0130, device='cuda:1')
# current epoch is:  11150
# current loss is:  tensor(-19.0139, device='cuda:1')
# current relative error is:  tensor(0.0209, device='cuda:1')
# current epoch is:  11200
# current loss is:  tensor(-22.0337, device='cuda:1')
# current relative error is:  tensor(0.0488, device='cuda:1')
# current epoch is:  11250
# current loss is:  tensor(-19.1044, device='cuda:1')
# current relative error is:  tensor(0.0131, device='cuda:1')
# current epoch is:  11300
# current loss is:  tensor(-19.9224, device='cuda:1')
# current relative error is:  tensor(0.0247, device='cuda:1')
# current epoch is:  11350
# current loss is:  tensor(-19.1642, device='cuda:1')
# current relative error is:  tensor(0.0440, device='cuda:1')
# current epoch is:  11400
# current loss is:  tensor(-18.9181, device='cuda:1')
# current relative error is:  tensor(0.0554, device='cuda:1')
# current epoch is:  11450
# current loss is:  tensor(-19.8662, device='cuda:1')
# current relative error is:  tensor(0.0157, device='cuda:1')
# current epoch is:  11500
# current loss is:  tensor(-20.8594, device='cuda:1')
# current relative error is:  tensor(0.0078, device='cuda:1')
# current epoch is:  11550
# current loss is:  tensor(-19.3439, device='cuda:1')
# current relative error is:  tensor(0.0159, device='cuda:1')
# current epoch is:  11600
# current loss is:  tensor(-20.2022, device='cuda:1')
# current relative error is:  tensor(0.0278, device='cuda:1')
# current epoch is:  11650
# current loss is:  tensor(-19.1997, device='cuda:1')
# current relative error is:  tensor(0.0369, device='cuda:1')
# current epoch is:  11700
# current loss is:  tensor(-20.1664, device='cuda:1')
# current relative error is:  tensor(0.0382, device='cuda:1')
# current epoch is:  11750
# current loss is:  tensor(-18.5165, device='cuda:1')
# current relative error is:  tensor(0.0131, device='cuda:1')
# current epoch is:  11800
# current loss is:  tensor(-20.7421, device='cuda:1')
# current relative error is:  tensor(0.0588, device='cuda:1')
# current epoch is:  11850
# current loss is:  tensor(-19.2630, device='cuda:1')
# current relative error is:  tensor(0.0343, device='cuda:1')
# current epoch is:  11900
# current loss is:  tensor(-17.8739, device='cuda:1')
# current relative error is:  tensor(0.0166, device='cuda:1')
# current epoch is:  11950
# current loss is:  tensor(-20.0015, device='cuda:1')
# current relative error is:  tensor(0.0485, device='cuda:1')
# current epoch is:  12000
# current loss is:  tensor(-20.1661, device='cuda:1')
# current relative error is:  tensor(0.0547, device='cuda:1')
# current epoch is:  12050
# current loss is:  tensor(-19.6845, device='cuda:1')
# current relative error is:  tensor(0.0789, device='cuda:1')
# current epoch is:  12100
# current loss is:  tensor(-19.8512, device='cuda:1')
# current relative error is:  tensor(0.0311, device='cuda:1')
# current epoch is:  12150
# current loss is:  tensor(-20.9481, device='cuda:1')
# current relative error is:  tensor(0.0206, device='cuda:1')
# current epoch is:  12200
# current loss is:  tensor(-19.0191, device='cuda:1')
# current relative error is:  tensor(0.0107, device='cuda:1')
# current epoch is:  12250
# current loss is:  tensor(-20.2104, device='cuda:1')
# current relative error is:  tensor(0.0446, device='cuda:1')
# current epoch is:  12300
# current loss is:  tensor(-20.8842, device='cuda:1')
# current relative error is:  tensor(0.0428, device='cuda:1')
# current epoch is:  12350
# current loss is:  tensor(-20.5816, device='cuda:1')
# current relative error is:  tensor(0.0529, device='cuda:1')
# current epoch is:  12400
# current loss is:  tensor(-20.4399, device='cuda:1')
# current relative error is:  tensor(0.0336, device='cuda:1')
# current epoch is:  12450
# current loss is:  tensor(-18.9693, device='cuda:1')
# current relative error is:  tensor(0.0104, device='cuda:1')
# current epoch is:  12500
# current loss is:  tensor(-20.9447, device='cuda:1')
# current relative error is:  tensor(0.0469, device='cuda:1')
# current epoch is:  12550
# current loss is:  tensor(-18.7727, device='cuda:1')
# current relative error is:  tensor(0.0315, device='cuda:1')
# current epoch is:  12600
# current loss is:  tensor(-20.2164, device='cuda:1')
# current relative error is:  tensor(0.0385, device='cuda:1')
# current epoch is:  12650
# current loss is:  tensor(-20.6886, device='cuda:1')
# current relative error is:  tensor(0.0351, device='cuda:1')
# current epoch is:  12700
# current loss is:  tensor(-17.9079, device='cuda:1')
# current relative error is:  tensor(0.0234, device='cuda:1')
# current epoch is:  12750
# current loss is:  tensor(-19.2315, device='cuda:1')
# current relative error is:  tensor(0.0151, device='cuda:1')
# current epoch is:  12800
# current loss is:  tensor(-20.9820, device='cuda:1')
# current relative error is:  tensor(0.0495, device='cuda:1')
# current epoch is:  12850
# current loss is:  tensor(-19.9529, device='cuda:1')
# current relative error is:  tensor(0.0250, device='cuda:1')
# current epoch is:  12900
# current loss is:  tensor(-18.7608, device='cuda:1')
# current relative error is:  tensor(0.0163, device='cuda:1')
# current epoch is:  12950
# current loss is:  tensor(-19.8070, device='cuda:1')
# current relative error is:  tensor(0.0310, device='cuda:1')
# current epoch is:  13000
# current loss is:  tensor(-18.8421, device='cuda:1')
# current relative error is:  tensor(0.0192, device='cuda:1')
# current epoch is:  13050
# current loss is:  tensor(-19.1142, device='cuda:1')
# current relative error is:  tensor(0.0193, device='cuda:1')
# current epoch is:  13100
# current loss is:  tensor(-19.0679, device='cuda:1')
# current relative error is:  tensor(0.0155, device='cuda:1')
# current epoch is:  13150
# current loss is:  tensor(-18.8773, device='cuda:1')
# current relative error is:  tensor(0.0451, device='cuda:1')
# current epoch is:  13200
# current loss is:  tensor(-19.0613, device='cuda:1')
# current relative error is:  tensor(0.0154, device='cuda:1')
# current epoch is:  13250
# current loss is:  tensor(-20.1675, device='cuda:1')
# current relative error is:  tensor(0.0255, device='cuda:1')
# current epoch is:  13300
# current loss is:  tensor(-19.5279, device='cuda:1')
# current relative error is:  tensor(0.0411, device='cuda:1')
# current epoch is:  13350
# current loss is:  tensor(-18.6256, device='cuda:1')
# current relative error is:  tensor(0.0523, device='cuda:1')
# current epoch is:  13400
# current loss is:  tensor(-19.6301, device='cuda:1')
# current relative error is:  tensor(0.0372, device='cuda:1')
# current epoch is:  13450
# current loss is:  tensor(-20.5718, device='cuda:1')
# current relative error is:  tensor(0.0209, device='cuda:1')
# current epoch is:  13500
# current loss is:  tensor(-19.9103, device='cuda:1')
# current relative error is:  tensor(0.0469, device='cuda:1')
# current epoch is:  13550
# current loss is:  tensor(-20.5039, device='cuda:1')
# current relative error is:  tensor(0.0449, device='cuda:1')
# current epoch is:  13600
# current loss is:  tensor(-18.9683, device='cuda:1')
# current relative error is:  tensor(0.0147, device='cuda:1')
# current epoch is:  13650
# current loss is:  tensor(-19.0750, device='cuda:1')
# current relative error is:  tensor(0.0432, device='cuda:1')
# current epoch is:  13700
# current loss is:  tensor(-18.2451, device='cuda:1')
# current relative error is:  tensor(0.0237, device='cuda:1')
# current epoch is:  13750
# current loss is:  tensor(-18.6089, device='cuda:1')
# current relative error is:  tensor(0.0657, device='cuda:1')
# current epoch is:  13800
# current loss is:  tensor(-19.5109, device='cuda:1')
# current relative error is:  tensor(0.0495, device='cuda:1')
# current epoch is:  13850
# current loss is:  tensor(-19.5911, device='cuda:1')
# current relative error is:  tensor(0.0123, device='cuda:1')
# current epoch is:  13900
# current loss is:  tensor(-19.8885, device='cuda:1')
# current relative error is:  tensor(0.0162, device='cuda:1')
# current epoch is:  13950
# current loss is:  tensor(-19.9369, device='cuda:1')
# current relative error is:  tensor(0.0336, device='cuda:1')
# current epoch is:  14000
# current loss is:  tensor(-20.4995, device='cuda:1')
# current relative error is:  tensor(0.0329, device='cuda:1')
# current epoch is:  14050
# current loss is:  tensor(-18.8047, device='cuda:1')
# current relative error is:  tensor(0.0204, device='cuda:1')
# current epoch is:  14100
# current loss is:  tensor(-19.1685, device='cuda:1')
# current relative error is:  tensor(0.0455, device='cuda:1')
# current epoch is:  14150
# current loss is:  tensor(-19.3004, device='cuda:1')
# current relative error is:  tensor(0.0421, device='cuda:1')
# current epoch is:  14200
# current loss is:  tensor(-19.5390, device='cuda:1')
# current relative error is:  tensor(0.0342, device='cuda:1')
# current epoch is:  14250
# current loss is:  tensor(-18.9984, device='cuda:1')
# current relative error is:  tensor(0.0258, device='cuda:1')
# current epoch is:  14300
# current loss is:  tensor(-19.2558, device='cuda:1')
# current relative error is:  tensor(0.0162, device='cuda:1')
# current epoch is:  14350
# current loss is:  tensor(-20.6030, device='cuda:1')
# current relative error is:  tensor(0.0402, device='cuda:1')
# current epoch is:  14400
# current loss is:  tensor(-20.0227, device='cuda:1')
# current relative error is:  tensor(0.0212, device='cuda:1')
# current epoch is:  14450
# current loss is:  tensor(-18.8934, device='cuda:1')
# current relative error is:  tensor(0.0289, device='cuda:1')
# current epoch is:  14500
# current loss is:  tensor(-20.1161, device='cuda:1')
# current relative error is:  tensor(0.0221, device='cuda:1')
# current epoch is:  14550
# current loss is:  tensor(-19.6188, device='cuda:1')
# current relative error is:  tensor(0.0179, device='cuda:1')
# current epoch is:  14600
# current loss is:  tensor(-20.2447, device='cuda:1')
# current relative error is:  tensor(0.0138, device='cuda:1')
# current epoch is:  14650
# current loss is:  tensor(-21.4730, device='cuda:1')
# current relative error is:  tensor(0.0304, device='cuda:1')
# current epoch is:  14700
# current loss is:  tensor(-20.0074, device='cuda:1')
# current relative error is:  tensor(0.0444, device='cuda:1')
# current epoch is:  14750
# current loss is:  tensor(-19.9128, device='cuda:1')
# current relative error is:  tensor(0.0275, device='cuda:1')
# current epoch is:  14800
# current loss is:  tensor(-19.6141, device='cuda:1')
# current relative error is:  tensor(0.0189, device='cuda:1')
# current epoch is:  14850
# current loss is:  tensor(-20.5959, device='cuda:1')
# current relative error is:  tensor(0.0444, device='cuda:1')
# current epoch is:  14900
# current loss is:  tensor(-20.8063, device='cuda:1')
# current relative error is:  tensor(0.0416, device='cuda:1')
# current epoch is:  14950
# current loss is:  tensor(-20.8868, device='cuda:1')
# current relative error is:  tensor(0.0166, device='cuda:1')
# current epoch is:  15000
# current loss is:  tensor(-19.9039, device='cuda:1')
# current relative error is:  tensor(0.0258, device='cuda:1')
# current epoch is:  15050
# current loss is:  tensor(-19.4806, device='cuda:1')
# current relative error is:  tensor(0.0418, device='cuda:1')
# current epoch is:  15100
# current loss is:  tensor(-18.7708, device='cuda:1')
# current relative error is:  tensor(0.0152, device='cuda:1')
# current epoch is:  15150
# current loss is:  tensor(-19.7971, device='cuda:1')
# current relative error is:  tensor(0.0662, device='cuda:1')
# current epoch is:  15200
# current loss is:  tensor(-19.8926, device='cuda:1')
# current relative error is:  tensor(0.0155, device='cuda:1')
# current epoch is:  15250
# current loss is:  tensor(-19.4742, device='cuda:1')
# current relative error is:  tensor(0.0251, device='cuda:1')
# current epoch is:  15300
# current loss is:  tensor(-19.7026, device='cuda:1')
# current relative error is:  tensor(0.0217, device='cuda:1')
# current epoch is:  15350
# current loss is:  tensor(-19.6051, device='cuda:1')
# current relative error is:  tensor(0.0168, device='cuda:1')
# current epoch is:  15400
# current loss is:  tensor(-19.2266, device='cuda:1')
# current relative error is:  tensor(0.0191, device='cuda:1')
# current epoch is:  15450
# current loss is:  tensor(-18.1995, device='cuda:1')
# current relative error is:  tensor(0.0257, device='cuda:1')
# current epoch is:  15500
# current loss is:  tensor(-20.1945, device='cuda:1')
# current relative error is:  tensor(0.0274, device='cuda:1')
# current epoch is:  15550
# current loss is:  tensor(-18.4766, device='cuda:1')
# current relative error is:  tensor(0.0172, device='cuda:1')
# current epoch is:  15600
# current loss is:  tensor(-20.1371, device='cuda:1')
# current relative error is:  tensor(0.0179, device='cuda:1')
# current epoch is:  15650
# current loss is:  tensor(-19.3228, device='cuda:1')
# current relative error is:  tensor(0.0287, device='cuda:1')
# current epoch is:  15700
# current loss is:  tensor(-21.5520, device='cuda:1')
# current relative error is:  tensor(0.0643, device='cuda:1')
# current epoch is:  15750
# current loss is:  tensor(-18.9218, device='cuda:1')
# current relative error is:  tensor(0.0469, device='cuda:1')
# current epoch is:  15800
# current loss is:  tensor(-21.1249, device='cuda:1')
# current relative error is:  tensor(0.0403, device='cuda:1')
# current epoch is:  15850
# current loss is:  tensor(-21.1106, device='cuda:1')
# current relative error is:  tensor(0.0203, device='cuda:1')
# current epoch is:  15900
# current loss is:  tensor(-20.0479, device='cuda:1')
# current relative error is:  tensor(0.0478, device='cuda:1')
# current epoch is:  15950
# current loss is:  tensor(-19.2528, device='cuda:1')
# current relative error is:  tensor(0.0212, device='cuda:1')
# current epoch is:  16000
# current loss is:  tensor(-19.3196, device='cuda:1')
# current relative error is:  tensor(0.0179, device='cuda:1')
# current epoch is:  16050
# current loss is:  tensor(-19.5211, device='cuda:1')
# current relative error is:  tensor(0.0138, device='cuda:1')
# current epoch is:  16100
# current loss is:  tensor(-20.0800, device='cuda:1')
# current relative error is:  tensor(0.0189, device='cuda:1')
# current epoch is:  16150
# current loss is:  tensor(-20.8268, device='cuda:1')
# current relative error is:  tensor(0.0335, device='cuda:1')
# current epoch is:  16200
# current loss is:  tensor(-18.4862, device='cuda:1')
# current relative error is:  tensor(0.0147, device='cuda:1')
# current epoch is:  16250
# current loss is:  tensor(-20.7227, device='cuda:1')
# current relative error is:  tensor(0.0232, device='cuda:1')
# current epoch is:  16300
# current loss is:  tensor(-19.8265, device='cuda:1')
# current relative error is:  tensor(0.0121, device='cuda:1')
# current epoch is:  16350
# current loss is:  tensor(-18.2023, device='cuda:1')
# current relative error is:  tensor(0.0174, device='cuda:1')
# current epoch is:  16400
# current loss is:  tensor(-20.8212, device='cuda:1')
# current relative error is:  tensor(0.0112, device='cuda:1')
# current epoch is:  16450
# current loss is:  tensor(-19.3395, device='cuda:1')
# current relative error is:  tensor(0.0139, device='cuda:1')
# current epoch is:  16500
# current loss is:  tensor(-19.6177, device='cuda:1')
# current relative error is:  tensor(0.0224, device='cuda:1')
# current epoch is:  16550
# current loss is:  tensor(-21.5212, device='cuda:1')
# current relative error is:  tensor(0.0497, device='cuda:1')
# current epoch is:  16600
# current loss is:  tensor(-19.4436, device='cuda:1')
# current relative error is:  tensor(0.0298, device='cuda:1')
# current epoch is:  16650
# current loss is:  tensor(-20.6436, device='cuda:1')
# current relative error is:  tensor(0.0345, device='cuda:1')
# current epoch is:  16700
# current loss is:  tensor(-20.2340, device='cuda:1')
# current relative error is:  tensor(0.0239, device='cuda:1')
# current epoch is:  16750
# current loss is:  tensor(-19.8806, device='cuda:1')
# current relative error is:  tensor(0.0150, device='cuda:1')
# current epoch is:  16800
# current loss is:  tensor(-19.1631, device='cuda:1')
# current relative error is:  tensor(0.0249, device='cuda:1')
# current epoch is:  16850
# current loss is:  tensor(-19.8508, device='cuda:1')
# current relative error is:  tensor(0.0440, device='cuda:1')
# current epoch is:  16900
# current loss is:  tensor(-17.7416, device='cuda:1')
# current relative error is:  tensor(0.0274, device='cuda:1')
# current epoch is:  16950
# current loss is:  tensor(-18.2852, device='cuda:1')
# current relative error is:  tensor(0.0206, device='cuda:1')
# current epoch is:  17000
# current loss is:  tensor(-19.7609, device='cuda:1')
# current relative error is:  tensor(0.0295, device='cuda:1')
# current epoch is:  17050
# current loss is:  tensor(-19.9177, device='cuda:1')
# current relative error is:  tensor(0.0167, device='cuda:1')
# current epoch is:  17100
# current loss is:  tensor(-18.1724, device='cuda:1')
# current relative error is:  tensor(0.0500, device='cuda:1')
# current epoch is:  17150
# current loss is:  tensor(-18.6676, device='cuda:1')
# current relative error is:  tensor(0.0105, device='cuda:1')
# current epoch is:  17200
# current loss is:  tensor(-20.5305, device='cuda:1')
# current relative error is:  tensor(0.0399, device='cuda:1')
# current epoch is:  17250
# current loss is:  tensor(-20.1619, device='cuda:1')
# current relative error is:  tensor(0.0121, device='cuda:1')
# current epoch is:  17300
# current loss is:  tensor(-20.2541, device='cuda:1')
# current relative error is:  tensor(0.0387, device='cuda:1')
# current epoch is:  17350
# current loss is:  tensor(-17.1894, device='cuda:1')
# current relative error is:  tensor(0.0407, device='cuda:1')
# current epoch is:  17400
# current loss is:  tensor(-19.9382, device='cuda:1')
# current relative error is:  tensor(0.0218, device='cuda:1')
# current epoch is:  17450
# current loss is:  tensor(-22.3112, device='cuda:1')
# current relative error is:  tensor(0.0404, device='cuda:1')
# current epoch is:  17500
# current loss is:  tensor(-21.2755, device='cuda:1')
# current relative error is:  tensor(0.0532, device='cuda:1')
# current epoch is:  17550
# current loss is:  tensor(-20.4899, device='cuda:1')
# current relative error is:  tensor(0.0244, device='cuda:1')
# current epoch is:  17600
# current loss is:  tensor(-19.7842, device='cuda:1')
# current relative error is:  tensor(0.0090, device='cuda:1')
# current epoch is:  17650
# current loss is:  tensor(-21.1533, device='cuda:1')
# current relative error is:  tensor(0.0180, device='cuda:1')
# current epoch is:  17700
# current loss is:  tensor(-19.7724, device='cuda:1')
# current relative error is:  tensor(0.0332, device='cuda:1')
# current epoch is:  17750
# current loss is:  tensor(-18.6891, device='cuda:1')
# current relative error is:  tensor(0.0526, device='cuda:1')
# current epoch is:  17800
# current loss is:  tensor(-19.6049, device='cuda:1')
# current relative error is:  tensor(0.0425, device='cuda:1')
# current epoch is:  17850
# current loss is:  tensor(-19.7943, device='cuda:1')
# current relative error is:  tensor(0.0350, device='cuda:1')
# current epoch is:  17900
# current loss is:  tensor(-18.9431, device='cuda:1')
# current relative error is:  tensor(0.0358, device='cuda:1')
# current epoch is:  17950
# current loss is:  tensor(-19.2165, device='cuda:1')
# current relative error is:  tensor(0.0209, device='cuda:1')
# current epoch is:  18000
# current loss is:  tensor(-20.9980, device='cuda:1')
# current relative error is:  tensor(0.0555, device='cuda:1')
# current epoch is:  18050
# current loss is:  tensor(-21.1936, device='cuda:1')
# current relative error is:  tensor(0.0503, device='cuda:1')
# current epoch is:  18100
# current loss is:  tensor(-19.6878, device='cuda:1')
# current relative error is:  tensor(0.0531, device='cuda:1')
# current epoch is:  18150
# current loss is:  tensor(-20.2889, device='cuda:1')
# current relative error is:  tensor(0.0307, device='cuda:1')
# current epoch is:  18200
# current loss is:  tensor(-19.8736, device='cuda:1')
# current relative error is:  tensor(0.0118, device='cuda:1')
# current epoch is:  18250
# current loss is:  tensor(-19.6149, device='cuda:1')
# current relative error is:  tensor(0.0198, device='cuda:1')
# current epoch is:  18300
# current loss is:  tensor(-19.6102, device='cuda:1')
# current relative error is:  tensor(0.0130, device='cuda:1')
# current epoch is:  18350
# current loss is:  tensor(-18.7305, device='cuda:1')
# current relative error is:  tensor(0.0189, device='cuda:1')
# current epoch is:  18400
# current loss is:  tensor(-19.5310, device='cuda:1')
# current relative error is:  tensor(0.0713, device='cuda:1')
# current epoch is:  18450
# current loss is:  tensor(-18.4222, device='cuda:1')
# current relative error is:  tensor(0.0147, device='cuda:1')
# current epoch is:  18500
# current loss is:  tensor(-18.6917, device='cuda:1')
# current relative error is:  tensor(0.0147, device='cuda:1')
# current epoch is:  18550
# current loss is:  tensor(-18.6919, device='cuda:1')
# current relative error is:  tensor(0.0190, device='cuda:1')
# current epoch is:  18600
# current loss is:  tensor(-19.9571, device='cuda:1')
# current relative error is:  tensor(0.0102, device='cuda:1')
# current epoch is:  18650
# current loss is:  tensor(-19.6078, device='cuda:1')
# current relative error is:  tensor(0.0227, device='cuda:1')
# current epoch is:  18700
# current loss is:  tensor(-19.0899, device='cuda:1')
# current relative error is:  tensor(0.0234, device='cuda:1')
# current epoch is:  18750
# current loss is:  tensor(-18.5626, device='cuda:1')
# current relative error is:  tensor(0.0790, device='cuda:1')
# current epoch is:  18800
# current loss is:  tensor(-20.3609, device='cuda:1')
# current relative error is:  tensor(0.0733, device='cuda:1')
# current epoch is:  18850
# current loss is:  tensor(-20.0893, device='cuda:1')
# current relative error is:  tensor(0.0120, device='cuda:1')
# current epoch is:  18900
# current loss is:  tensor(-18.7941, device='cuda:1')
# current relative error is:  tensor(0.0262, device='cuda:1')
# current epoch is:  18950
# current loss is:  tensor(-18.5179, device='cuda:1')
# current relative error is:  tensor(0.0218, device='cuda:1')
# current epoch is:  19000
# current loss is:  tensor(-19.3491, device='cuda:1')
# current relative error is:  tensor(0.0398, device='cuda:1')
# current epoch is:  19050
# current loss is:  tensor(-20.7699, device='cuda:1')
# current relative error is:  tensor(0.0400, device='cuda:1')
# current epoch is:  19100
# current loss is:  tensor(-19.1899, device='cuda:1')
# current relative error is:  tensor(0.0243, device='cuda:1')
# current epoch is:  19150
# current loss is:  tensor(-18.3793, device='cuda:1')
# current relative error is:  tensor(0.0325, device='cuda:1')
# current epoch is:  19200
# current loss is:  tensor(-19.5936, device='cuda:1')
# current relative error is:  tensor(0.0124, device='cuda:1')
# current epoch is:  19250
# current loss is:  tensor(-17.6891, device='cuda:1')
# current relative error is:  tensor(0.0402, device='cuda:1')
# current epoch is:  19300
# current loss is:  tensor(-20.3755, device='cuda:1')
# current relative error is:  tensor(0.0246, device='cuda:1')
# current epoch is:  19350
# current loss is:  tensor(-20.4456, device='cuda:1')
# current relative error is:  tensor(0.0267, device='cuda:1')
# current epoch is:  19400
# current loss is:  tensor(-19.1198, device='cuda:1')
# current relative error is:  tensor(0.0155, device='cuda:1')
# current epoch is:  19450
# current loss is:  tensor(-19.9592, device='cuda:1')
# current relative error is:  tensor(0.0140, device='cuda:1')
# current epoch is:  19500
# current loss is:  tensor(-19.9992, device='cuda:1')
# current relative error is:  tensor(0.0256, device='cuda:1')
# current epoch is:  19550
# current loss is:  tensor(-20.4614, device='cuda:1')
# current relative error is:  tensor(0.0179, device='cuda:1')
# current epoch is:  19600
# current loss is:  tensor(-20.2029, device='cuda:1')
# current relative error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  19650
# current loss is:  tensor(-19.1500, device='cuda:1')
# current relative error is:  tensor(0.0115, device='cuda:1')
# current epoch is:  19700
# current loss is:  tensor(-19.6627, device='cuda:1')
# current relative error is:  tensor(0.0187, device='cuda:1')
# current epoch is:  19750
# current loss is:  tensor(-18.8080, device='cuda:1')
# current relative error is:  tensor(0.0312, device='cuda:1')
# current epoch is:  19800
# current loss is:  tensor(-19.6419, device='cuda:1')
# current relative error is:  tensor(0.0245, device='cuda:1')
# current epoch is:  19850
# current loss is:  tensor(-19.8454, device='cuda:1')
# current relative error is:  tensor(0.0169, device='cuda:1')
# current epoch is:  19900
# current loss is:  tensor(-19.2796, device='cuda:1')
# current relative error is:  tensor(0.0485, device='cuda:1')
# current epoch is:  19950
# current loss is:  tensor(-19.1866, device='cuda:1')
# current relative error is:  tensor(0.0567, device='cuda:1')
# total time is:  7263.204406738281 seconds
