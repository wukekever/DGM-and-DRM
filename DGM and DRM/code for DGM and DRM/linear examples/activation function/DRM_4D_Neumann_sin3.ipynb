# %%
import torch
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import torch.nn as nn
from math import *

# %%
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor') # 设置浮点类型为 torch.float64

# %%
# 定义激活函数: sin(x)**3
def acti(x):
    return (torch.sin(x))**3

# %%
# 定义网络结构
class DeepRitzNet(torch.nn.Module):
    def __init__(self, input_width, layer_width):
        super(DeepRitzNet, self).__init__()
        self.linear_in = torch.nn.Linear(input_width, layer_width)
        self.linear1 = torch.nn.Linear(layer_width, layer_width)
        self.linear2 = torch.nn.Linear(layer_width, layer_width)
        self.linear3 = torch.nn.Linear(layer_width, layer_width)
        self.linear4 = torch.nn.Linear(layer_width, layer_width)
        self.linear5 = torch.nn.Linear(layer_width, layer_width)
        self.linear6 = torch.nn.Linear(layer_width, layer_width)
        self.linear_out = torch.nn.Linear(layer_width, 1)

    def forward(self, x):
        y = self.linear_in(x) # fully connect layer
        y = y + acti(self.linear2(acti(self.linear1(y)))) # residual block 1
        y = y + acti(self.linear4(acti(self.linear3(y)))) # residual block 2
        y = y + acti(self.linear6(acti(self.linear5(y)))) # residual block 3
        output = self.linear_out(y) # fully connect layer
        return output

# %%
dimension = 4

# %%
# exact solution
def u_ex(x):  
    x_temp = torch.cos(pi*x)
    u_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return u_x

# %%
def f(x):
    x_temp = torch.cos(pi*x)
    f_x = 2*pi**2*(x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return f_x

# %%
def DRM(x):
    u_hat = model(x)
    ux = torch.zeros(x.size()[0], dimension).cuda()  
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension).cuda()  
        dx[:, i] = torch.ones(x.size()[0])
        ux[:, i] = (model(x+step_size*dx) - model(x-step_size*dx))[:,0]/step_size/2
    uxsq = (torch.sum(ux**2, dim = 1)).reshape([x.size()[0], 1]) # dim = 1 按行求和
    f_temp = f(x)
    part_1 = torch.sum(0.5 * uxsq + 0.5*pi**2*u_hat**2 - f_temp*u_hat)/x.size()[0]
    
    Nb = 100
    xa1 = torch.rand(Nb, dimension).cuda()  
    xa1[:, 0] = torch.zeros(Nb)
    xa2 = torch.rand(Nb, dimension).cuda()  
    xa2[:, 0] = torch.ones(Nb)
    xb1 = torch.rand(Nb, dimension).cuda() 
    xb1[:, 1] = torch.zeros(Nb)
    xb2 = torch.rand(Nb, dimension).cuda() 
    xb2[:, 1] = torch.ones(Nb)
    xc1 = torch.rand(Nb, dimension).cuda() 
    xc1[:, 2] = torch.zeros(Nb)
    xc2 = torch.rand(Nb, dimension).cuda() 
    xc2[:, 2] = torch.ones(Nb)
    xd1 = torch.rand(Nb, dimension).cuda() 
    xd1[:, 3] = torch.zeros(Nb)
    xd2 = torch.rand(Nb, dimension).cuda() 
    xd2[:, 3] = torch.ones(Nb)
    dx1 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx1[:, 0] = torch.ones(xb1.size()[0])
    dx2 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx2[:, 1] = torch.ones(xb1.size()[0])
    dx3 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx3[:, 2] = torch.ones(xb1.size()[0])
    dx4 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx4[:, 3] = torch.ones(xb1.size()[0])
    uxa1 = (((model(xa1+step_size*dx1) - model(xa1-step_size*dx1))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxa2 = (((model(xa2+step_size*dx1) - model(xa2-step_size*dx1))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxb1 = (((model(xb1+step_size*dx2) - model(xb1-step_size*dx2))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxb2 = (((model(xb2+step_size*dx2) - model(xb2-step_size*dx2))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxc1 = (((model(xc1+step_size*dx3) - model(xc1-step_size*dx3))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxc2 = (((model(xc2+step_size*dx3) - model(xc2-step_size*dx3))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxd1 = (((model(xd1+step_size*dx4) - model(xd1-step_size*dx4))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxd2 = (((model(xd2+step_size*dx4) - model(xd2-step_size*dx4))/step_size/2 * (-1.0) - 0)**2).cuda() 
    
    part_2 = torch.sum((uxa1 + uxa2 + uxb1 + uxb2 + uxc1 + uxc2 + uxd1 + uxd2)[:,0])/xa1.size()[0]
    lambda1 = 1.0
    return part_1 + lambda1 * part_2 / 8

# %%
Data_size = 2000
def Gendata():
    x = torch.rand(Data_size, dimension)
    return x.cuda()

# %%
# 正态分布初始化参数
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = DeepRitzNet(dimension, 8)
model = initparam(model, 0.5)

# %%
device = torch.device("cuda:1" )
model.to(device)
# Out:
# DeepRitzNet(
#   (linear_in): Linear(in_features=4, out_features=8, bias=True)
#   (linear1): Linear(in_features=8, out_features=8, bias=True)
#   (linear2): Linear(in_features=8, out_features=8, bias=True)
#   (linear3): Linear(in_features=8, out_features=8, bias=True)
#   (linear4): Linear(in_features=8, out_features=8, bias=True)
#   (linear5): Linear(in_features=8, out_features=8, bias=True)
#   (linear6): Linear(in_features=8, out_features=8, bias=True)
#   (linear_out): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
import torch.optim as optim
import torch.nn as nn
import time

# %%
def relative_error():
    x = Gendata()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact )**2))/torch.sqrt(torch.sum((exact )**2))
    return value

# %%
traintime = 20000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = Gendata()
    x.requires_grad = True
    losses = DRM(x)
    losses.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", losses.detach())
        print("current relative error is: ", error.detach())
        np.save("DRM_relative_error_4D_Neumann_sin3.npy", error_save)
np.save("DRM_relative_error_4D_Neumann_sin3.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(15.7868, device='cuda:1')
# current relative error is:  tensor(1.2868, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(-7.7463, device='cuda:1')
# current relative error is:  tensor(0.6613, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(-14.2455, device='cuda:1')
# current relative error is:  tensor(0.4301, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(-14.2143, device='cuda:1')
# current relative error is:  tensor(0.3143, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(-14.6000, device='cuda:1')
# current relative error is:  tensor(0.2810, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(-16.6626, device='cuda:1')
# current relative error is:  tensor(0.2484, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(-16.6115, device='cuda:1')
# current relative error is:  tensor(0.2261, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(-17.3489, device='cuda:1')
# current relative error is:  tensor(0.2125, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(-17.2826, device='cuda:1')
# current relative error is:  tensor(0.1834, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(-16.3054, device='cuda:1')
# current relative error is:  tensor(0.1617, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(-18.7670, device='cuda:1')
# current relative error is:  tensor(0.1449, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(-18.4950, device='cuda:1')
# current relative error is:  tensor(0.1276, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(-18.7520, device='cuda:1')
# current relative error is:  tensor(0.1125, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(-19.1328, device='cuda:1')
# current relative error is:  tensor(0.1044, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(-19.5740, device='cuda:1')
# current relative error is:  tensor(0.0930, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(-19.6643, device='cuda:1')
# current relative error is:  tensor(0.0793, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(-18.1578, device='cuda:1')
# current relative error is:  tensor(0.0741, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(-19.7737, device='cuda:1')
# current relative error is:  tensor(0.0609, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(-19.6259, device='cuda:1')
# current relative error is:  tensor(0.0651, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(-20.8378, device='cuda:1')
# current relative error is:  tensor(0.0579, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(-20.0061, device='cuda:1')
# current relative error is:  tensor(0.0551, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(-20.0184, device='cuda:1')
# current relative error is:  tensor(0.0499, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(-19.3038, device='cuda:1')
# current relative error is:  tensor(0.0438, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(-17.5963, device='cuda:1')
# current relative error is:  tensor(0.0589, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(-18.4358, device='cuda:1')
# current relative error is:  tensor(0.0386, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(-19.3956, device='cuda:1')
# current relative error is:  tensor(0.0455, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(-21.1227, device='cuda:1')
# current relative error is:  tensor(0.0399, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(-19.9952, device='cuda:1')
# current relative error is:  tensor(0.0445, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(-19.1964, device='cuda:1')
# current relative error is:  tensor(0.0351, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(-17.7480, device='cuda:1')
# current relative error is:  tensor(0.0310, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(-18.4464, device='cuda:1')
# current relative error is:  tensor(0.0341, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(-19.2321, device='cuda:1')
# current relative error is:  tensor(0.0422, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(-18.9604, device='cuda:1')
# current relative error is:  tensor(0.0441, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(-19.6320, device='cuda:1')
# current relative error is:  tensor(0.0324, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(-19.4052, device='cuda:1')
# current relative error is:  tensor(0.0326, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(-19.4050, device='cuda:1')
# current relative error is:  tensor(0.0301, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(-20.0698, device='cuda:1')
# current relative error is:  tensor(0.0312, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(-19.0077, device='cuda:1')
# current relative error is:  tensor(0.0409, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(-17.7198, device='cuda:1')
# current relative error is:  tensor(0.0327, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(-19.4623, device='cuda:1')
# current relative error is:  tensor(0.0378, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(-19.3586, device='cuda:1')
# current relative error is:  tensor(0.0305, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(-18.8714, device='cuda:1')
# current relative error is:  tensor(0.0492, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(-19.5984, device='cuda:1')
# current relative error is:  tensor(0.0531, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(-19.4584, device='cuda:1')
# current relative error is:  tensor(0.0236, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(-20.3516, device='cuda:1')
# current relative error is:  tensor(0.0579, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(-18.8161, device='cuda:1')
# current relative error is:  tensor(0.0562, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(-18.7092, device='cuda:1')
# current relative error is:  tensor(0.0275, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(-20.1281, device='cuda:1')
# current relative error is:  tensor(0.0427, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(-19.4461, device='cuda:1')
# current relative error is:  tensor(0.0235, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(-19.7396, device='cuda:1')
# current relative error is:  tensor(0.0215, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(-18.6105, device='cuda:1')
# current relative error is:  tensor(0.0424, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(-19.0488, device='cuda:1')
# current relative error is:  tensor(0.0407, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(-19.5601, device='cuda:1')
# current relative error is:  tensor(0.0208, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(-19.8462, device='cuda:1')
# current relative error is:  tensor(0.0291, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(-19.4332, device='cuda:1')
# current relative error is:  tensor(0.0363, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(-21.6928, device='cuda:1')
# current relative error is:  tensor(0.0435, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(-19.3279, device='cuda:1')
# current relative error is:  tensor(0.0296, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(-19.7687, device='cuda:1')
# current relative error is:  tensor(0.0208, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(-18.4435, device='cuda:1')
# current relative error is:  tensor(0.0358, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(-19.1879, device='cuda:1')
# current relative error is:  tensor(0.0269, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(-18.3340, device='cuda:1')
# current relative error is:  tensor(0.0205, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(-19.4592, device='cuda:1')
# current relative error is:  tensor(0.0519, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(-20.1282, device='cuda:1')
# current relative error is:  tensor(0.0330, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(-18.0262, device='cuda:1')
# current relative error is:  tensor(0.0242, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(-18.6876, device='cuda:1')
# current relative error is:  tensor(0.0291, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(-18.3260, device='cuda:1')
# current relative error is:  tensor(0.0244, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(-20.8104, device='cuda:1')
# current relative error is:  tensor(0.0420, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(-19.4810, device='cuda:1')
# current relative error is:  tensor(0.0579, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(-19.4621, device='cuda:1')
# current relative error is:  tensor(0.0297, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(-19.6829, device='cuda:1')
# current relative error is:  tensor(0.0590, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(-19.3339, device='cuda:1')
# current relative error is:  tensor(0.0257, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(-20.0752, device='cuda:1')
# current relative error is:  tensor(0.0196, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(-20.1479, device='cuda:1')
# current relative error is:  tensor(0.0512, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(-19.9424, device='cuda:1')
# current relative error is:  tensor(0.0198, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(-19.5212, device='cuda:1')
# current relative error is:  tensor(0.0206, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(-19.4926, device='cuda:1')
# current relative error is:  tensor(0.0218, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(-20.7511, device='cuda:1')
# current relative error is:  tensor(0.0482, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(-20.8738, device='cuda:1')
# current relative error is:  tensor(0.0354, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(-19.9482, device='cuda:1')
# current relative error is:  tensor(0.0269, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(-20.9134, device='cuda:1')
# current relative error is:  tensor(0.0208, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(-20.3016, device='cuda:1')
# current relative error is:  tensor(0.0174, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(-19.1282, device='cuda:1')
# current relative error is:  tensor(0.0314, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(-18.4920, device='cuda:1')
# current relative error is:  tensor(0.0237, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(-21.0161, device='cuda:1')
# current relative error is:  tensor(0.0254, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(-20.6484, device='cuda:1')
# current relative error is:  tensor(0.0220, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(-18.6741, device='cuda:1')
# current relative error is:  tensor(0.0633, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(-19.6251, device='cuda:1')
# current relative error is:  tensor(0.0320, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(-19.0553, device='cuda:1')
# current relative error is:  tensor(0.0161, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(-20.4309, device='cuda:1')
# current relative error is:  tensor(0.0181, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(-19.2351, device='cuda:1')
# current relative error is:  tensor(0.0312, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(-18.6202, device='cuda:1')
# current relative error is:  tensor(0.0667, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(-20.0531, device='cuda:1')
# current relative error is:  tensor(0.0372, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(-18.3512, device='cuda:1')
# current relative error is:  tensor(0.0425, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(-19.1100, device='cuda:1')
# current relative error is:  tensor(0.0249, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(-20.6666, device='cuda:1')
# current relative error is:  tensor(0.0451, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(-18.5466, device='cuda:1')
# current relative error is:  tensor(0.0529, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(-20.1887, device='cuda:1')
# current relative error is:  tensor(0.0271, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(-19.6862, device='cuda:1')
# current relative error is:  tensor(0.0278, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(-19.7209, device='cuda:1')
# current relative error is:  tensor(0.0175, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(-20.3539, device='cuda:1')
# current relative error is:  tensor(0.0194, device='cuda:1')
# current epoch is:  5000
# current loss is:  tensor(-20.6312, device='cuda:1')
# current relative error is:  tensor(0.0479, device='cuda:1')
# current epoch is:  5050
# current loss is:  tensor(-19.4355, device='cuda:1')
# current relative error is:  tensor(0.0292, device='cuda:1')
# current epoch is:  5100
# current loss is:  tensor(-18.3538, device='cuda:1')
# current relative error is:  tensor(0.0333, device='cuda:1')
# current epoch is:  5150
# current loss is:  tensor(-19.8935, device='cuda:1')
# current relative error is:  tensor(0.0848, device='cuda:1')
# current epoch is:  5200
# current loss is:  tensor(-18.6009, device='cuda:1')
# current relative error is:  tensor(0.0455, device='cuda:1')
# current epoch is:  5250
# current loss is:  tensor(-19.9275, device='cuda:1')
# current relative error is:  tensor(0.0358, device='cuda:1')
# current epoch is:  5300
# current loss is:  tensor(-20.1931, device='cuda:1')
# current relative error is:  tensor(0.0527, device='cuda:1')
# current epoch is:  5350
# current loss is:  tensor(-20.3404, device='cuda:1')
# current relative error is:  tensor(0.0274, device='cuda:1')
# current epoch is:  5400
# current loss is:  tensor(-20.6270, device='cuda:1')
# current relative error is:  tensor(0.0510, device='cuda:1')
# current epoch is:  5450
# current loss is:  tensor(-22.1644, device='cuda:1')
# current relative error is:  tensor(0.0205, device='cuda:1')
# current epoch is:  5500
# current loss is:  tensor(-21.1022, device='cuda:1')
# current relative error is:  tensor(0.0204, device='cuda:1')
# current epoch is:  5550
# current loss is:  tensor(-18.3069, device='cuda:1')
# current relative error is:  tensor(0.0528, device='cuda:1')
# current epoch is:  5600
# current loss is:  tensor(-20.9742, device='cuda:1')
# current relative error is:  tensor(0.0217, device='cuda:1')
# current epoch is:  5650
# current loss is:  tensor(-19.5967, device='cuda:1')
# current relative error is:  tensor(0.0173, device='cuda:1')
# current epoch is:  5700
# current loss is:  tensor(-20.1127, device='cuda:1')
# current relative error is:  tensor(0.0178, device='cuda:1')
# current epoch is:  5750
# current loss is:  tensor(-18.7475, device='cuda:1')
# current relative error is:  tensor(0.0319, device='cuda:1')
# current epoch is:  5800
# current loss is:  tensor(-20.2428, device='cuda:1')
# current relative error is:  tensor(0.0349, device='cuda:1')
# current epoch is:  5850
# current loss is:  tensor(-19.1179, device='cuda:1')
# current relative error is:  tensor(0.0309, device='cuda:1')
# current epoch is:  5900
# current loss is:  tensor(-20.4317, device='cuda:1')
# current relative error is:  tensor(0.0569, device='cuda:1')
# current epoch is:  5950
# current loss is:  tensor(-18.3225, device='cuda:1')
# current relative error is:  tensor(0.0239, device='cuda:1')
# current epoch is:  6000
# current loss is:  tensor(-18.7244, device='cuda:1')
# current relative error is:  tensor(0.0127, device='cuda:1')
# current epoch is:  6050
# current loss is:  tensor(-18.4645, device='cuda:1')
# current relative error is:  tensor(0.0516, device='cuda:1')
# current epoch is:  6100
# current loss is:  tensor(-19.8866, device='cuda:1')
# current relative error is:  tensor(0.0159, device='cuda:1')
# current epoch is:  6150
# current loss is:  tensor(-19.3422, device='cuda:1')
# current relative error is:  tensor(0.0368, device='cuda:1')
# current epoch is:  6200
# current loss is:  tensor(-18.3896, device='cuda:1')
# current relative error is:  tensor(0.0284, device='cuda:1')
# current epoch is:  6250
# current loss is:  tensor(-19.2929, device='cuda:1')
# current relative error is:  tensor(0.0695, device='cuda:1')
# current epoch is:  6300
# current loss is:  tensor(-19.4011, device='cuda:1')
# current relative error is:  tensor(0.0266, device='cuda:1')
# current epoch is:  6350
# current loss is:  tensor(-20.7060, device='cuda:1')
# current relative error is:  tensor(0.0133, device='cuda:1')
# current epoch is:  6400
# current loss is:  tensor(-21.1114, device='cuda:1')
# current relative error is:  tensor(0.0569, device='cuda:1')
# current epoch is:  6450
# current loss is:  tensor(-20.3891, device='cuda:1')
# current relative error is:  tensor(0.0218, device='cuda:1')
# current epoch is:  6500
# current loss is:  tensor(-20.9540, device='cuda:1')
# current relative error is:  tensor(0.0673, device='cuda:1')
# current epoch is:  6550
# current loss is:  tensor(-20.9709, device='cuda:1')
# current relative error is:  tensor(0.0207, device='cuda:1')
# current epoch is:  6600
# current loss is:  tensor(-19.3500, device='cuda:1')
# current relative error is:  tensor(0.0341, device='cuda:1')
# current epoch is:  6650
# current loss is:  tensor(-20.1834, device='cuda:1')
# current relative error is:  tensor(0.0268, device='cuda:1')
# current epoch is:  6700
# current loss is:  tensor(-19.7243, device='cuda:1')
# current relative error is:  tensor(0.0148, device='cuda:1')
# current epoch is:  6750
# current loss is:  tensor(-19.1864, device='cuda:1')
# current relative error is:  tensor(0.0266, device='cuda:1')
# current epoch is:  6800
# current loss is:  tensor(-18.1007, device='cuda:1')
# current relative error is:  tensor(0.0280, device='cuda:1')
# current epoch is:  6850
# current loss is:  tensor(-19.0967, device='cuda:1')
# current relative error is:  tensor(0.0167, device='cuda:1')
# current epoch is:  6900
# current loss is:  tensor(-20.0508, device='cuda:1')
# current relative error is:  tensor(0.0277, device='cuda:1')
# current epoch is:  6950
# current loss is:  tensor(-20.2307, device='cuda:1')
# current relative error is:  tensor(0.0233, device='cuda:1')
# current epoch is:  7000
# current loss is:  tensor(-20.3762, device='cuda:1')
# current relative error is:  tensor(0.0309, device='cuda:1')
# current epoch is:  7050
# current loss is:  tensor(-20.3072, device='cuda:1')
# current relative error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  7100
# current loss is:  tensor(-20.7970, device='cuda:1')
# current relative error is:  tensor(0.0446, device='cuda:1')
# current epoch is:  7150
# current loss is:  tensor(-19.4587, device='cuda:1')
# current relative error is:  tensor(0.0355, device='cuda:1')
# current epoch is:  7200
# current loss is:  tensor(-20.1402, device='cuda:1')
# current relative error is:  tensor(0.0169, device='cuda:1')
# current epoch is:  7250
# current loss is:  tensor(-19.3291, device='cuda:1')
# current relative error is:  tensor(0.0309, device='cuda:1')
# current epoch is:  7300
# current loss is:  tensor(-19.9056, device='cuda:1')
# current relative error is:  tensor(0.0198, device='cuda:1')
# current epoch is:  7350
# current loss is:  tensor(-19.8769, device='cuda:1')
# current relative error is:  tensor(0.0181, device='cuda:1')
# current epoch is:  7400
# current loss is:  tensor(-20.1386, device='cuda:1')
# current relative error is:  tensor(0.0201, device='cuda:1')
# current epoch is:  7450
# current loss is:  tensor(-20.5766, device='cuda:1')
# current relative error is:  tensor(0.0501, device='cuda:1')
# current epoch is:  7500
# current loss is:  tensor(-20.2655, device='cuda:1')
# current relative error is:  tensor(0.0142, device='cuda:1')
# current epoch is:  7550
# current loss is:  tensor(-19.2890, device='cuda:1')
# current relative error is:  tensor(0.0399, device='cuda:1')
# current epoch is:  7600
# current loss is:  tensor(-19.9585, device='cuda:1')
# current relative error is:  tensor(0.0267, device='cuda:1')
# current epoch is:  7650
# current loss is:  tensor(-20.0424, device='cuda:1')
# current relative error is:  tensor(0.0406, device='cuda:1')
# current epoch is:  7700
# current loss is:  tensor(-19.3619, device='cuda:1')
# current relative error is:  tensor(0.0136, device='cuda:1')
# current epoch is:  7750
# current loss is:  tensor(-20.3972, device='cuda:1')
# current relative error is:  tensor(0.0223, device='cuda:1')
# current epoch is:  7800
# current loss is:  tensor(-20.8707, device='cuda:1')
# current relative error is:  tensor(0.0443, device='cuda:1')
# current epoch is:  7850
# current loss is:  tensor(-20.7688, device='cuda:1')
# current relative error is:  tensor(0.0434, device='cuda:1')
# current epoch is:  7900
# current loss is:  tensor(-18.2452, device='cuda:1')
# current relative error is:  tensor(0.0267, device='cuda:1')
# current epoch is:  7950
# current loss is:  tensor(-20.6693, device='cuda:1')
# current relative error is:  tensor(0.0154, device='cuda:1')
# current epoch is:  8000
# current loss is:  tensor(-19.3686, device='cuda:1')
# current relative error is:  tensor(0.0380, device='cuda:1')
# current epoch is:  8050
# current loss is:  tensor(-18.3233, device='cuda:1')
# current relative error is:  tensor(0.0462, device='cuda:1')
# current epoch is:  8100
# current loss is:  tensor(-20.1086, device='cuda:1')
# current relative error is:  tensor(0.0176, device='cuda:1')
# current epoch is:  8150
# current loss is:  tensor(-20.1196, device='cuda:1')
# current relative error is:  tensor(0.0474, device='cuda:1')
# current epoch is:  8200
# current loss is:  tensor(-20.3981, device='cuda:1')
# current relative error is:  tensor(0.0326, device='cuda:1')
# current epoch is:  8250
# current loss is:  tensor(-19.3845, device='cuda:1')
# current relative error is:  tensor(0.0343, device='cuda:1')
# current epoch is:  8300
# current loss is:  tensor(-20.2447, device='cuda:1')
# current relative error is:  tensor(0.0499, device='cuda:1')
# current epoch is:  8350
# current loss is:  tensor(-19.6016, device='cuda:1')
# current relative error is:  tensor(0.0221, device='cuda:1')
# current epoch is:  8400
# current loss is:  tensor(-18.2936, device='cuda:1')
# current relative error is:  tensor(0.0179, device='cuda:1')
# current epoch is:  8450
# current loss is:  tensor(-19.7092, device='cuda:1')
# current relative error is:  tensor(0.0197, device='cuda:1')
# current epoch is:  8500
# current loss is:  tensor(-19.2412, device='cuda:1')
# current relative error is:  tensor(0.0236, device='cuda:1')
# current epoch is:  8550
# current loss is:  tensor(-19.7565, device='cuda:1')
# current relative error is:  tensor(0.0160, device='cuda:1')
# current epoch is:  8600
# current loss is:  tensor(-19.1611, device='cuda:1')
# current relative error is:  tensor(0.0341, device='cuda:1')
# current epoch is:  8650
# current loss is:  tensor(-20.2217, device='cuda:1')
# current relative error is:  tensor(0.0229, device='cuda:1')
# current epoch is:  8700
# current loss is:  tensor(-18.5620, device='cuda:1')
# current relative error is:  tensor(0.0276, device='cuda:1')
# current epoch is:  8750
# current loss is:  tensor(-19.7750, device='cuda:1')
# current relative error is:  tensor(0.0153, device='cuda:1')
# current epoch is:  8800
# current loss is:  tensor(-19.5439, device='cuda:1')
# current relative error is:  tensor(0.0160, device='cuda:1')
# current epoch is:  8850
# current loss is:  tensor(-18.1736, device='cuda:1')
# current relative error is:  tensor(0.0208, device='cuda:1')
# current epoch is:  8900
# current loss is:  tensor(-18.6702, device='cuda:1')
# current relative error is:  tensor(0.0419, device='cuda:1')
# current epoch is:  8950
# current loss is:  tensor(-21.1859, device='cuda:1')
# current relative error is:  tensor(0.0697, device='cuda:1')
# current epoch is:  9000
# current loss is:  tensor(-18.3422, device='cuda:1')
# current relative error is:  tensor(0.0565, device='cuda:1')
# current epoch is:  9050
# current loss is:  tensor(-19.6910, device='cuda:1')
# current relative error is:  tensor(0.0332, device='cuda:1')
# current epoch is:  9100
# current loss is:  tensor(-19.3318, device='cuda:1')
# current relative error is:  tensor(0.0136, device='cuda:1')
# current epoch is:  9150
# current loss is:  tensor(-20.2135, device='cuda:1')
# current relative error is:  tensor(0.0109, device='cuda:1')
# current epoch is:  9200
# current loss is:  tensor(-18.8397, device='cuda:1')
# current relative error is:  tensor(0.0182, device='cuda:1')
# current epoch is:  9250
# current loss is:  tensor(-19.1804, device='cuda:1')
# current relative error is:  tensor(0.0487, device='cuda:1')
# current epoch is:  9300
# current loss is:  tensor(-19.1115, device='cuda:1')
# current relative error is:  tensor(0.0512, device='cuda:1')
# current epoch is:  9350
# current loss is:  tensor(-18.7406, device='cuda:1')
# current relative error is:  tensor(0.0318, device='cuda:1')
# current epoch is:  9400
# current loss is:  tensor(-19.7751, device='cuda:1')
# current relative error is:  tensor(0.0461, device='cuda:1')
# current epoch is:  9450
# current loss is:  tensor(-20.8071, device='cuda:1')
# current relative error is:  tensor(0.0158, device='cuda:1')
# current epoch is:  9500
# current loss is:  tensor(-21.1816, device='cuda:1')
# current relative error is:  tensor(0.0142, device='cuda:1')
# current epoch is:  9550
# current loss is:  tensor(-18.7746, device='cuda:1')
# current relative error is:  tensor(0.0136, device='cuda:1')
# current epoch is:  9600
# current loss is:  tensor(-19.0538, device='cuda:1')
# current relative error is:  tensor(0.0385, device='cuda:1')
# current epoch is:  9650
# current loss is:  tensor(-20.0272, device='cuda:1')
# current relative error is:  tensor(0.0462, device='cuda:1')
# current epoch is:  9700
# current loss is:  tensor(-20.0461, device='cuda:1')
# current relative error is:  tensor(0.0165, device='cuda:1')
# current epoch is:  9750
# current loss is:  tensor(-20.4298, device='cuda:1')
# current relative error is:  tensor(0.0762, device='cuda:1')
# current epoch is:  9800
# current loss is:  tensor(-19.6639, device='cuda:1')
# current relative error is:  tensor(0.0222, device='cuda:1')
# current epoch is:  9850
# current loss is:  tensor(-19.5661, device='cuda:1')
# current relative error is:  tensor(0.0427, device='cuda:1')
# current epoch is:  9900
# current loss is:  tensor(-19.2909, device='cuda:1')
# current relative error is:  tensor(0.0346, device='cuda:1')
# current epoch is:  9950
# current loss is:  tensor(-19.4747, device='cuda:1')
# current relative error is:  tensor(0.0664, device='cuda:1')
# current epoch is:  10000
# current loss is:  tensor(-18.7868, device='cuda:1')
# current relative error is:  tensor(0.0248, device='cuda:1')
# current epoch is:  10050
# current loss is:  tensor(-20.4633, device='cuda:1')
# current relative error is:  tensor(0.0394, device='cuda:1')
# current epoch is:  10100
# current loss is:  tensor(-18.5424, device='cuda:1')
# current relative error is:  tensor(0.0119, device='cuda:1')
# current epoch is:  10150
# current loss is:  tensor(-19.0894, device='cuda:1')
# current relative error is:  tensor(0.0258, device='cuda:1')
# current epoch is:  10200
# current loss is:  tensor(-19.2996, device='cuda:1')
# current relative error is:  tensor(0.0449, device='cuda:1')
# current epoch is:  10250
# current loss is:  tensor(-19.5074, device='cuda:1')
# current relative error is:  tensor(0.0380, device='cuda:1')
# current epoch is:  10300
# current loss is:  tensor(-20.3336, device='cuda:1')
# current relative error is:  tensor(0.0154, device='cuda:1')
# current epoch is:  10350
# current loss is:  tensor(-19.8740, device='cuda:1')
# current relative error is:  tensor(0.0117, device='cuda:1')
# current epoch is:  10400
# current loss is:  tensor(-18.4651, device='cuda:1')
# current relative error is:  tensor(0.0393, device='cuda:1')
# current epoch is:  10450
# current loss is:  tensor(-20.5698, device='cuda:1')
# current relative error is:  tensor(0.0418, device='cuda:1')
# current epoch is:  10500
# current loss is:  tensor(-19.7589, device='cuda:1')
# current relative error is:  tensor(0.0166, device='cuda:1')
# current epoch is:  10550
# current loss is:  tensor(-19.1598, device='cuda:1')
# current relative error is:  tensor(0.0113, device='cuda:1')
# current epoch is:  10600
# current loss is:  tensor(-19.6946, device='cuda:1')
# current relative error is:  tensor(0.0221, device='cuda:1')
# current epoch is:  10650
# current loss is:  tensor(-18.5117, device='cuda:1')
# current relative error is:  tensor(0.0478, device='cuda:1')
# current epoch is:  10700
# current loss is:  tensor(-20.6615, device='cuda:1')
# current relative error is:  tensor(0.0328, device='cuda:1')
# current epoch is:  10750
# current loss is:  tensor(-18.8889, device='cuda:1')
# current relative error is:  tensor(0.0140, device='cuda:1')
# current epoch is:  10800
# current loss is:  tensor(-19.3012, device='cuda:1')
# current relative error is:  tensor(0.0625, device='cuda:1')
# current epoch is:  10850
# current loss is:  tensor(-19.0327, device='cuda:1')
# current relative error is:  tensor(0.0266, device='cuda:1')
# current epoch is:  10900
# current loss is:  tensor(-19.2788, device='cuda:1')
# current relative error is:  tensor(0.0121, device='cuda:1')
# current epoch is:  10950
# current loss is:  tensor(-19.5862, device='cuda:1')
# current relative error is:  tensor(0.0282, device='cuda:1')
# current epoch is:  11000
# current loss is:  tensor(-19.5067, device='cuda:1')
# current relative error is:  tensor(0.0205, device='cuda:1')
# current epoch is:  11050
# current loss is:  tensor(-21.0691, device='cuda:1')
# current relative error is:  tensor(0.0305, device='cuda:1')
# current epoch is:  11100
# current loss is:  tensor(-19.8269, device='cuda:1')
# current relative error is:  tensor(0.0281, device='cuda:1')
# current epoch is:  11150
# current loss is:  tensor(-19.6886, device='cuda:1')
# current relative error is:  tensor(0.0241, device='cuda:1')
# current epoch is:  11200
# current loss is:  tensor(-19.5348, device='cuda:1')
# current relative error is:  tensor(0.0127, device='cuda:1')
# current epoch is:  11250
# current loss is:  tensor(-20.4770, device='cuda:1')
# current relative error is:  tensor(0.0234, device='cuda:1')
# current epoch is:  11300
# current loss is:  tensor(-19.6600, device='cuda:1')
# current relative error is:  tensor(0.0527, device='cuda:1')
# current epoch is:  11350
# current loss is:  tensor(-19.6688, device='cuda:1')
# current relative error is:  tensor(0.0181, device='cuda:1')
# current epoch is:  11400
# current loss is:  tensor(-21.2024, device='cuda:1')
# current relative error is:  tensor(0.0528, device='cuda:1')
# current epoch is:  11450
# current loss is:  tensor(-21.2977, device='cuda:1')
# current relative error is:  tensor(0.0673, device='cuda:1')
# current epoch is:  11500
# current loss is:  tensor(-21.3104, device='cuda:1')
# current relative error is:  tensor(0.0714, device='cuda:1')
# current epoch is:  11550
# current loss is:  tensor(-18.8640, device='cuda:1')
# current relative error is:  tensor(0.0336, device='cuda:1')
# current epoch is:  11600
# current loss is:  tensor(-20.2107, device='cuda:1')
# current relative error is:  tensor(0.0235, device='cuda:1')
# current epoch is:  11650
# current loss is:  tensor(-18.1953, device='cuda:1')
# current relative error is:  tensor(0.0290, device='cuda:1')
# current epoch is:  11700
# current loss is:  tensor(-19.8624, device='cuda:1')
# current relative error is:  tensor(0.0264, device='cuda:1')
# current epoch is:  11750
# current loss is:  tensor(-20.6534, device='cuda:1')
# current relative error is:  tensor(0.0321, device='cuda:1')
# current epoch is:  11800
# current loss is:  tensor(-18.3815, device='cuda:1')
# current relative error is:  tensor(0.0394, device='cuda:1')
# current epoch is:  11850
# current loss is:  tensor(-19.2026, device='cuda:1')
# current relative error is:  tensor(0.0412, device='cuda:1')
# current epoch is:  11900
# current loss is:  tensor(-19.2620, device='cuda:1')
# current relative error is:  tensor(0.0121, device='cuda:1')
# current epoch is:  11950
# current loss is:  tensor(-19.7490, device='cuda:1')
# current relative error is:  tensor(0.0120, device='cuda:1')
# current epoch is:  12000
# current loss is:  tensor(-19.8610, device='cuda:1')
# current relative error is:  tensor(0.0563, device='cuda:1')
# current epoch is:  12050
# current loss is:  tensor(-19.5626, device='cuda:1')
# current relative error is:  tensor(0.0172, device='cuda:1')
# current epoch is:  12100
# current loss is:  tensor(-20.2750, device='cuda:1')
# current relative error is:  tensor(0.0110, device='cuda:1')
# current epoch is:  12150
# current loss is:  tensor(-18.6582, device='cuda:1')
# current relative error is:  tensor(0.0225, device='cuda:1')
# current epoch is:  12200
# current loss is:  tensor(-19.6001, device='cuda:1')
# current relative error is:  tensor(0.0235, device='cuda:1')
# current epoch is:  12250
# current loss is:  tensor(-20.7861, device='cuda:1')
# current relative error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  12300
# current loss is:  tensor(-19.3723, device='cuda:1')
# current relative error is:  tensor(0.0304, device='cuda:1')
# current epoch is:  12350
# current loss is:  tensor(-19.9872, device='cuda:1')
# current relative error is:  tensor(0.0379, device='cuda:1')
# current epoch is:  12400
# current loss is:  tensor(-19.7653, device='cuda:1')
# current relative error is:  tensor(0.0143, device='cuda:1')
# current epoch is:  12450
# current loss is:  tensor(-20.2110, device='cuda:1')
# current relative error is:  tensor(0.0420, device='cuda:1')
# current epoch is:  12500
# current loss is:  tensor(-19.6548, device='cuda:1')
# current relative error is:  tensor(0.0172, device='cuda:1')
# current epoch is:  12550
# current loss is:  tensor(-20.7960, device='cuda:1')
# current relative error is:  tensor(0.0241, device='cuda:1')
# current epoch is:  12600
# current loss is:  tensor(-19.9744, device='cuda:1')
# current relative error is:  tensor(0.0236, device='cuda:1')
# current epoch is:  12650
# current loss is:  tensor(-19.8783, device='cuda:1')
# current relative error is:  tensor(0.0396, device='cuda:1')
# current epoch is:  12700
# current loss is:  tensor(-19.1472, device='cuda:1')
# current relative error is:  tensor(0.0221, device='cuda:1')
# current epoch is:  12750
# current loss is:  tensor(-19.9870, device='cuda:1')
# current relative error is:  tensor(0.0246, device='cuda:1')
# current epoch is:  12800
# current loss is:  tensor(-20.5868, device='cuda:1')
# current relative error is:  tensor(0.0218, device='cuda:1')
# current epoch is:  12850
# current loss is:  tensor(-17.8328, device='cuda:1')
# current relative error is:  tensor(0.0425, device='cuda:1')
# current epoch is:  12900
# current loss is:  tensor(-20.1777, device='cuda:1')
# current relative error is:  tensor(0.0380, device='cuda:1')
# current epoch is:  12950
# current loss is:  tensor(-18.9430, device='cuda:1')
# current relative error is:  tensor(0.0349, device='cuda:1')
# current epoch is:  13000
# current loss is:  tensor(-20.1258, device='cuda:1')
# current relative error is:  tensor(0.0431, device='cuda:1')
# current epoch is:  13050
# current loss is:  tensor(-20.8694, device='cuda:1')
# current relative error is:  tensor(0.0308, device='cuda:1')
# current epoch is:  13100
# current loss is:  tensor(-19.6780, device='cuda:1')
# current relative error is:  tensor(0.0244, device='cuda:1')
# current epoch is:  13150
# current loss is:  tensor(-19.6544, device='cuda:1')
# current relative error is:  tensor(0.0242, device='cuda:1')
# current epoch is:  13200
# current loss is:  tensor(-19.3076, device='cuda:1')
# current relative error is:  tensor(0.0366, device='cuda:1')
# current epoch is:  13250
# current loss is:  tensor(-20.0492, device='cuda:1')
# current relative error is:  tensor(0.0509, device='cuda:1')
# current epoch is:  13300
# current loss is:  tensor(-19.4100, device='cuda:1')
# current relative error is:  tensor(0.0148, device='cuda:1')
# current epoch is:  13350
# current loss is:  tensor(-18.9139, device='cuda:1')
# current relative error is:  tensor(0.0604, device='cuda:1')
# current epoch is:  13400
# current loss is:  tensor(-20.6021, device='cuda:1')
# current relative error is:  tensor(0.0269, device='cuda:1')
# current epoch is:  13450
# current loss is:  tensor(-18.7754, device='cuda:1')
# current relative error is:  tensor(0.0360, device='cuda:1')
# current epoch is:  13500
# current loss is:  tensor(-19.8981, device='cuda:1')
# current relative error is:  tensor(0.0221, device='cuda:1')
# current epoch is:  13550
# current loss is:  tensor(-19.6495, device='cuda:1')
# current relative error is:  tensor(0.0329, device='cuda:1')
# current epoch is:  13600
# current loss is:  tensor(-19.0514, device='cuda:1')
# current relative error is:  tensor(0.0189, device='cuda:1')
# current epoch is:  13650
# current loss is:  tensor(-19.6784, device='cuda:1')
# current relative error is:  tensor(0.0231, device='cuda:1')
# current epoch is:  13700
# current loss is:  tensor(-21.0914, device='cuda:1')
# current relative error is:  tensor(0.0174, device='cuda:1')
# current epoch is:  13750
# current loss is:  tensor(-19.7036, device='cuda:1')
# current relative error is:  tensor(0.0158, device='cuda:1')
# current epoch is:  13800
# current loss is:  tensor(-19.7129, device='cuda:1')
# current relative error is:  tensor(0.0545, device='cuda:1')
# current epoch is:  13850
# current loss is:  tensor(-19.1636, device='cuda:1')
# current relative error is:  tensor(0.0280, device='cuda:1')
# current epoch is:  13900
# current loss is:  tensor(-18.0393, device='cuda:1')
# current relative error is:  tensor(0.0095, device='cuda:1')
# current epoch is:  13950
# current loss is:  tensor(-19.3134, device='cuda:1')
# current relative error is:  tensor(0.0245, device='cuda:1')
# current epoch is:  14000
# current loss is:  tensor(-20.6786, device='cuda:1')
# current relative error is:  tensor(0.0692, device='cuda:1')
# current epoch is:  14050
# current loss is:  tensor(-17.7266, device='cuda:1')
# current relative error is:  tensor(0.0155, device='cuda:1')
# current epoch is:  14100
# current loss is:  tensor(-19.8592, device='cuda:1')
# current relative error is:  tensor(0.0141, device='cuda:1')
# current epoch is:  14150
# current loss is:  tensor(-19.3600, device='cuda:1')
# current relative error is:  tensor(0.0179, device='cuda:1')
# current epoch is:  14200
# current loss is:  tensor(-20.4098, device='cuda:1')
# current relative error is:  tensor(0.0131, device='cuda:1')
# current epoch is:  14250
# current loss is:  tensor(-19.0960, device='cuda:1')
# current relative error is:  tensor(0.0144, device='cuda:1')
# current epoch is:  14300
# current loss is:  tensor(-20.2394, device='cuda:1')
# current relative error is:  tensor(0.0281, device='cuda:1')
# current epoch is:  14350
# current loss is:  tensor(-19.6572, device='cuda:1')
# current relative error is:  tensor(0.0099, device='cuda:1')
# current epoch is:  14400
# current loss is:  tensor(-19.3026, device='cuda:1')
# current relative error is:  tensor(0.0456, device='cuda:1')
# current epoch is:  14450
# current loss is:  tensor(-19.4303, device='cuda:1')
# current relative error is:  tensor(0.0165, device='cuda:1')
# current epoch is:  14500
# current loss is:  tensor(-19.1713, device='cuda:1')
# current relative error is:  tensor(0.0368, device='cuda:1')
# current epoch is:  14550
# current loss is:  tensor(-20.2328, device='cuda:1')
# current relative error is:  tensor(0.0251, device='cuda:1')
# current epoch is:  14600
# current loss is:  tensor(-21.0104, device='cuda:1')
# current relative error is:  tensor(0.0298, device='cuda:1')
# current epoch is:  14650
# current loss is:  tensor(-20.0677, device='cuda:1')
# current relative error is:  tensor(0.0566, device='cuda:1')
# current epoch is:  14700
# current loss is:  tensor(-17.5853, device='cuda:1')
# current relative error is:  tensor(0.0411, device='cuda:1')
# current epoch is:  14750
# current loss is:  tensor(-20.3992, device='cuda:1')
# current relative error is:  tensor(0.0128, device='cuda:1')
# current epoch is:  14800
# current loss is:  tensor(-20.6039, device='cuda:1')
# current relative error is:  tensor(0.0231, device='cuda:1')
# current epoch is:  14850
# current loss is:  tensor(-19.1784, device='cuda:1')
# current relative error is:  tensor(0.0365, device='cuda:1')
# current epoch is:  14900
# current loss is:  tensor(-20.1561, device='cuda:1')
# current relative error is:  tensor(0.0314, device='cuda:1')
# current epoch is:  14950
# current loss is:  tensor(-18.8909, device='cuda:1')
# current relative error is:  tensor(0.0149, device='cuda:1')
# current epoch is:  15000
# current loss is:  tensor(-19.4471, device='cuda:1')
# current relative error is:  tensor(0.0393, device='cuda:1')
# current epoch is:  15050
# current loss is:  tensor(-18.8868, device='cuda:1')
# current relative error is:  tensor(0.0110, device='cuda:1')
# current epoch is:  15100
# current loss is:  tensor(-19.5112, device='cuda:1')
# current relative error is:  tensor(0.0466, device='cuda:1')
# current epoch is:  15150
# current loss is:  tensor(-19.6347, device='cuda:1')
# current relative error is:  tensor(0.0250, device='cuda:1')
# current epoch is:  15200
# current loss is:  tensor(-19.0401, device='cuda:1')
# current relative error is:  tensor(0.0202, device='cuda:1')
# current epoch is:  15250
# current loss is:  tensor(-20.5857, device='cuda:1')
# current relative error is:  tensor(0.0177, device='cuda:1')
# current epoch is:  15300
# current loss is:  tensor(-18.8307, device='cuda:1')
# current relative error is:  tensor(0.0502, device='cuda:1')
# current epoch is:  15350
# current loss is:  tensor(-19.9184, device='cuda:1')
# current relative error is:  tensor(0.0333, device='cuda:1')
# current epoch is:  15400
# current loss is:  tensor(-20.3902, device='cuda:1')
# current relative error is:  tensor(0.0238, device='cuda:1')
# current epoch is:  15450
# current loss is:  tensor(-19.9329, device='cuda:1')
# current relative error is:  tensor(0.0125, device='cuda:1')
# current epoch is:  15500
# current loss is:  tensor(-18.3262, device='cuda:1')
# current relative error is:  tensor(0.0443, device='cuda:1')
# current epoch is:  15550
# current loss is:  tensor(-20.0690, device='cuda:1')
# current relative error is:  tensor(0.0444, device='cuda:1')
# current epoch is:  15600
# current loss is:  tensor(-20.6119, device='cuda:1')
# current relative error is:  tensor(0.0165, device='cuda:1')
# current epoch is:  15650
# current loss is:  tensor(-17.2799, device='cuda:1')
# current relative error is:  tensor(0.0429, device='cuda:1')
# current epoch is:  15700
# current loss is:  tensor(-19.5923, device='cuda:1')
# current relative error is:  tensor(0.0180, device='cuda:1')
# current epoch is:  15750
# current loss is:  tensor(-20.5128, device='cuda:1')
# current relative error is:  tensor(0.0382, device='cuda:1')
# current epoch is:  15800
# current loss is:  tensor(-18.6281, device='cuda:1')
# current relative error is:  tensor(0.0201, device='cuda:1')
# current epoch is:  15850
# current loss is:  tensor(-20.7747, device='cuda:1')
# current relative error is:  tensor(0.0200, device='cuda:1')
# current epoch is:  15900
# current loss is:  tensor(-19.8097, device='cuda:1')
# current relative error is:  tensor(0.0395, device='cuda:1')
# current epoch is:  15950
# current loss is:  tensor(-18.9823, device='cuda:1')
# current relative error is:  tensor(0.0349, device='cuda:1')
# current epoch is:  16000
# current loss is:  tensor(-18.8529, device='cuda:1')
# current relative error is:  tensor(0.0242, device='cuda:1')
# current epoch is:  16050
# current loss is:  tensor(-19.9806, device='cuda:1')
# current relative error is:  tensor(0.0191, device='cuda:1')
# current epoch is:  16100
# current loss is:  tensor(-20.2556, device='cuda:1')
# current relative error is:  tensor(0.0109, device='cuda:1')
# current epoch is:  16150
# current loss is:  tensor(-20.4376, device='cuda:1')
# current relative error is:  tensor(0.0606, device='cuda:1')
# current epoch is:  16200
# current loss is:  tensor(-19.2812, device='cuda:1')
# current relative error is:  tensor(0.0153, device='cuda:1')
# current epoch is:  16250
# current loss is:  tensor(-20.6485, device='cuda:1')
# current relative error is:  tensor(0.0123, device='cuda:1')
# current epoch is:  16300
# current loss is:  tensor(-18.6760, device='cuda:1')
# current relative error is:  tensor(0.0271, device='cuda:1')
# current epoch is:  16350
# current loss is:  tensor(-19.6439, device='cuda:1')
# current relative error is:  tensor(0.0147, device='cuda:1')
# current epoch is:  16400
# current loss is:  tensor(-19.6427, device='cuda:1')
# current relative error is:  tensor(0.0238, device='cuda:1')
# current epoch is:  16450
# current loss is:  tensor(-20.8793, device='cuda:1')
# current relative error is:  tensor(0.0216, device='cuda:1')
# current epoch is:  16500
# current loss is:  tensor(-20.3286, device='cuda:1')
# current relative error is:  tensor(0.0623, device='cuda:1')
# current epoch is:  16550
# current loss is:  tensor(-17.5149, device='cuda:1')
# current relative error is:  tensor(0.0169, device='cuda:1')
# current epoch is:  16600
# current loss is:  tensor(-19.4414, device='cuda:1')
# current relative error is:  tensor(0.0302, device='cuda:1')
# current epoch is:  16650
# current loss is:  tensor(-20.8366, device='cuda:1')
# current relative error is:  tensor(0.0119, device='cuda:1')
# current epoch is:  16700
# current loss is:  tensor(-20.1217, device='cuda:1')
# current relative error is:  tensor(0.0230, device='cuda:1')
# current epoch is:  16750
# current loss is:  tensor(-19.0493, device='cuda:1')
# current relative error is:  tensor(0.0243, device='cuda:1')
# current epoch is:  16800
# current loss is:  tensor(-21.3889, device='cuda:1')
# current relative error is:  tensor(0.0404, device='cuda:1')
# current epoch is:  16850
# current loss is:  tensor(-19.5892, device='cuda:1')
# current relative error is:  tensor(0.0655, device='cuda:1')
# current epoch is:  16900
# current loss is:  tensor(-19.4991, device='cuda:1')
# current relative error is:  tensor(0.0202, device='cuda:1')
# current epoch is:  16950
# current loss is:  tensor(-18.0009, device='cuda:1')
# current relative error is:  tensor(0.0134, device='cuda:1')
# current epoch is:  17000
# current loss is:  tensor(-18.9567, device='cuda:1')
# current relative error is:  tensor(0.0221, device='cuda:1')
# current epoch is:  17050
# current loss is:  tensor(-19.8432, device='cuda:1')
# current relative error is:  tensor(0.0167, device='cuda:1')
# current epoch is:  17100
# current loss is:  tensor(-19.5640, device='cuda:1')
# current relative error is:  tensor(0.0342, device='cuda:1')
# current epoch is:  17150
# current loss is:  tensor(-21.3925, device='cuda:1')
# current relative error is:  tensor(0.0111, device='cuda:1')
# current epoch is:  17200
# current loss is:  tensor(-19.4438, device='cuda:1')
# current relative error is:  tensor(0.0222, device='cuda:1')
# current epoch is:  17250
# current loss is:  tensor(-20.3868, device='cuda:1')
# current relative error is:  tensor(0.0368, device='cuda:1')
# current epoch is:  17300
# current loss is:  tensor(-20.5831, device='cuda:1')
# current relative error is:  tensor(0.0296, device='cuda:1')
# current epoch is:  17350
# current loss is:  tensor(-20.2021, device='cuda:1')
# current relative error is:  tensor(0.0246, device='cuda:1')
# current epoch is:  17400
# current loss is:  tensor(-18.0785, device='cuda:1')
# current relative error is:  tensor(0.0381, device='cuda:1')
# current epoch is:  17450
# current loss is:  tensor(-19.9063, device='cuda:1')
# current relative error is:  tensor(0.0320, device='cuda:1')
# current epoch is:  17500
# current loss is:  tensor(-19.7275, device='cuda:1')
# current relative error is:  tensor(0.0183, device='cuda:1')
# current epoch is:  17550
# current loss is:  tensor(-18.8979, device='cuda:1')
# current relative error is:  tensor(0.0227, device='cuda:1')
# current epoch is:  17600
# current loss is:  tensor(-20.3657, device='cuda:1')
# current relative error is:  tensor(0.0405, device='cuda:1')
# current epoch is:  17650
# current loss is:  tensor(-20.6808, device='cuda:1')
# current relative error is:  tensor(0.0256, device='cuda:1')
# current epoch is:  17700
# current loss is:  tensor(-21.5573, device='cuda:1')
# current relative error is:  tensor(0.0183, device='cuda:1')
# current epoch is:  17750
# current loss is:  tensor(-19.4217, device='cuda:1')
# current relative error is:  tensor(0.0232, device='cuda:1')
# current epoch is:  17800
# current loss is:  tensor(-20.3783, device='cuda:1')
# current relative error is:  tensor(0.0104, device='cuda:1')
# current epoch is:  17850
# current loss is:  tensor(-20.3368, device='cuda:1')
# current relative error is:  tensor(0.0141, device='cuda:1')
# current epoch is:  17900
# current loss is:  tensor(-19.0059, device='cuda:1')
# current relative error is:  tensor(0.0152, device='cuda:1')
# current epoch is:  17950
# current loss is:  tensor(-19.7250, device='cuda:1')
# current relative error is:  tensor(0.0279, device='cuda:1')
# current epoch is:  18000
# current loss is:  tensor(-19.4303, device='cuda:1')
# current relative error is:  tensor(0.0244, device='cuda:1')
# current epoch is:  18050
# current loss is:  tensor(-18.1639, device='cuda:1')
# current relative error is:  tensor(0.0239, device='cuda:1')
# current epoch is:  18100
# current loss is:  tensor(-19.1634, device='cuda:1')
# current relative error is:  tensor(0.0190, device='cuda:1')
# current epoch is:  18150
# current loss is:  tensor(-19.9236, device='cuda:1')
# current relative error is:  tensor(0.0520, device='cuda:1')
# current epoch is:  18200
# current loss is:  tensor(-19.7220, device='cuda:1')
# current relative error is:  tensor(0.0245, device='cuda:1')
# current epoch is:  18250
# current loss is:  tensor(-19.0434, device='cuda:1')
# current relative error is:  tensor(0.0216, device='cuda:1')
# current epoch is:  18300
# current loss is:  tensor(-20.6890, device='cuda:1')
# current relative error is:  tensor(0.0153, device='cuda:1')
# current epoch is:  18350
# current loss is:  tensor(-19.6651, device='cuda:1')
# current relative error is:  tensor(0.0147, device='cuda:1')
# current epoch is:  18400
# current loss is:  tensor(-19.6714, device='cuda:1')
# current relative error is:  tensor(0.0187, device='cuda:1')
# current epoch is:  18450
# current loss is:  tensor(-20.9080, device='cuda:1')
# current relative error is:  tensor(0.0237, device='cuda:1')
# current epoch is:  18500
# current loss is:  tensor(-18.9046, device='cuda:1')
# current relative error is:  tensor(0.0427, device='cuda:1')
# current epoch is:  18550
# current loss is:  tensor(-19.9129, device='cuda:1')
# current relative error is:  tensor(0.0145, device='cuda:1')
# current epoch is:  18600
# current loss is:  tensor(-19.5237, device='cuda:1')
# current relative error is:  tensor(0.0399, device='cuda:1')
# current epoch is:  18650
# current loss is:  tensor(-19.0023, device='cuda:1')
# current relative error is:  tensor(0.0413, device='cuda:1')
# current epoch is:  18700
# current loss is:  tensor(-20.0588, device='cuda:1')
# current relative error is:  tensor(0.0223, device='cuda:1')
# current epoch is:  18750
# current loss is:  tensor(-20.0427, device='cuda:1')
# current relative error is:  tensor(0.0313, device='cuda:1')
# current epoch is:  18800
# current loss is:  tensor(-20.7090, device='cuda:1')
# current relative error is:  tensor(0.0293, device='cuda:1')
# current epoch is:  18850
# current loss is:  tensor(-20.4387, device='cuda:1')
# current relative error is:  tensor(0.0121, device='cuda:1')
# current epoch is:  18900
# current loss is:  tensor(-19.8451, device='cuda:1')
# current relative error is:  tensor(0.0240, device='cuda:1')
# current epoch is:  18950
# current loss is:  tensor(-19.3864, device='cuda:1')
# current relative error is:  tensor(0.0176, device='cuda:1')
# current epoch is:  19000
# current loss is:  tensor(-18.9421, device='cuda:1')
# current relative error is:  tensor(0.0217, device='cuda:1')
# current epoch is:  19050
# current loss is:  tensor(-20.8930, device='cuda:1')
# current relative error is:  tensor(0.0171, device='cuda:1')
# current epoch is:  19100
# current loss is:  tensor(-19.3212, device='cuda:1')
# current relative error is:  tensor(0.0155, device='cuda:1')
# current epoch is:  19150
# current loss is:  tensor(-18.7780, device='cuda:1')
# current relative error is:  tensor(0.0212, device='cuda:1')
# current epoch is:  19200
# current loss is:  tensor(-20.3388, device='cuda:1')
# current relative error is:  tensor(0.0411, device='cuda:1')
# current epoch is:  19250
# current loss is:  tensor(-18.6539, device='cuda:1')
# current relative error is:  tensor(0.0317, device='cuda:1')
# current epoch is:  19300
# current loss is:  tensor(-18.6882, device='cuda:1')
# current relative error is:  tensor(0.0434, device='cuda:1')
# current epoch is:  19350
# current loss is:  tensor(-19.0479, device='cuda:1')
# current relative error is:  tensor(0.0217, device='cuda:1')
# current epoch is:  19400
# current loss is:  tensor(-19.2825, device='cuda:1')
# current relative error is:  tensor(0.0352, device='cuda:1')
# current epoch is:  19450
# current loss is:  tensor(-18.9629, device='cuda:1')
# current relative error is:  tensor(0.0316, device='cuda:1')
# current epoch is:  19500
# current loss is:  tensor(-19.3261, device='cuda:1')
# current relative error is:  tensor(0.0420, device='cuda:1')
# current epoch is:  19550
# current loss is:  tensor(-20.3740, device='cuda:1')
# current relative error is:  tensor(0.0159, device='cuda:1')
# current epoch is:  19600
# current loss is:  tensor(-19.2875, device='cuda:1')
# current relative error is:  tensor(0.0359, device='cuda:1')
# current epoch is:  19650
# current loss is:  tensor(-19.1413, device='cuda:1')
# current relative error is:  tensor(0.0296, device='cuda:1')
# current epoch is:  19700
# current loss is:  tensor(-19.3781, device='cuda:1')
# current relative error is:  tensor(0.0358, device='cuda:1')
# current epoch is:  19750
# current loss is:  tensor(-18.5537, device='cuda:1')
# current relative error is:  tensor(0.0240, device='cuda:1')
# current epoch is:  19800
# current loss is:  tensor(-18.2155, device='cuda:1')
# current relative error is:  tensor(0.0152, device='cuda:1')
# current epoch is:  19850
# current loss is:  tensor(-19.3884, device='cuda:1')
# current relative error is:  tensor(0.0245, device='cuda:1')
# current epoch is:  19900
# current loss is:  tensor(-20.2886, device='cuda:1')
# current relative error is:  tensor(0.0315, device='cuda:1')
# current epoch is:  19950
# current loss is:  tensor(-21.1638, device='cuda:1')
# current relative error is:  tensor(0.0110, device='cuda:1')
# total time is:  7717.518991470337 seconds
