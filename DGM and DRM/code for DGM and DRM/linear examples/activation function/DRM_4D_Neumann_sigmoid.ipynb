# %%
import torch
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import torch.nn as nn
from math import *

# %%
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor') # 设置浮点类型为 torch.float64

# %%
# 定义激活函数: sigmoid(x)
def acti(x):
    return torch.sigmoid(x)

# %%
# 定义网络结构
class DeepRitzNet(torch.nn.Module):
    def __init__(self, input_width, layer_width):
        super(DeepRitzNet, self).__init__()
        self.linear_in = torch.nn.Linear(input_width, layer_width)
        self.linear1 = torch.nn.Linear(layer_width, layer_width)
        self.linear2 = torch.nn.Linear(layer_width, layer_width)
        self.linear3 = torch.nn.Linear(layer_width, layer_width)
        self.linear4 = torch.nn.Linear(layer_width, layer_width)
        self.linear5 = torch.nn.Linear(layer_width, layer_width)
        self.linear6 = torch.nn.Linear(layer_width, layer_width)
        self.linear_out = torch.nn.Linear(layer_width, 1)

    def forward(self, x):
        y = self.linear_in(x) # fully connect layer
        y = y + acti(self.linear2(acti(self.linear1(y)))) # residual block 1
        y = y + acti(self.linear4(acti(self.linear3(y)))) # residual block 2
        y = y + acti(self.linear6(acti(self.linear5(y)))) # residual block 3
        output = self.linear_out(y) # fully connect layer
        return output

# %%
dimension = 4

# %%
# exact solution
def u_ex(x):  
    x_temp = torch.cos(pi*x)
    u_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return u_x

# %%
def f(x):
    x_temp = torch.cos(pi*x)
    f_x = 2*pi**2*(x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return f_x

# %%
def DRM(x):
    u_hat = model(x)
    ux = torch.zeros(x.size()[0], dimension).cuda()  
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension).cuda()  
        dx[:, i] = torch.ones(x.size()[0])
        ux[:, i] = (model(x+step_size*dx) - model(x-step_size*dx))[:,0]/step_size/2
    uxsq = (torch.sum(ux**2, dim = 1)).reshape([x.size()[0], 1]) # dim = 1 按行求和
    f_temp = f(x)
    part_1 = torch.sum(0.5 * uxsq + 0.5*pi**2*u_hat**2 - f_temp*u_hat)/x.size()[0]
    
    Nb = 100
    xa1 = torch.rand(Nb, dimension).cuda()  
    xa1[:, 0] = torch.zeros(Nb)
    xa2 = torch.rand(Nb, dimension).cuda()  
    xa2[:, 0] = torch.ones(Nb)
    xb1 = torch.rand(Nb, dimension).cuda() 
    xb1[:, 1] = torch.zeros(Nb)
    xb2 = torch.rand(Nb, dimension).cuda() 
    xb2[:, 1] = torch.ones(Nb)
    xc1 = torch.rand(Nb, dimension).cuda() 
    xc1[:, 2] = torch.zeros(Nb)
    xc2 = torch.rand(Nb, dimension).cuda() 
    xc2[:, 2] = torch.ones(Nb)
    xd1 = torch.rand(Nb, dimension).cuda() 
    xd1[:, 3] = torch.zeros(Nb)
    xd2 = torch.rand(Nb, dimension).cuda() 
    xd2[:, 3] = torch.ones(Nb)
    dx1 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx1[:, 0] = torch.ones(xb1.size()[0])
    dx2 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx2[:, 1] = torch.ones(xb1.size()[0])
    dx3 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx3[:, 2] = torch.ones(xb1.size()[0])
    dx4 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx4[:, 3] = torch.ones(xb1.size()[0])
    uxa1 = (((model(xa1+step_size*dx1) - model(xa1-step_size*dx1))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxa2 = (((model(xa2+step_size*dx1) - model(xa2-step_size*dx1))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxb1 = (((model(xb1+step_size*dx2) - model(xb1-step_size*dx2))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxb2 = (((model(xb2+step_size*dx2) - model(xb2-step_size*dx2))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxc1 = (((model(xc1+step_size*dx3) - model(xc1-step_size*dx3))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxc2 = (((model(xc2+step_size*dx3) - model(xc2-step_size*dx3))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxd1 = (((model(xd1+step_size*dx4) - model(xd1-step_size*dx4))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxd2 = (((model(xd2+step_size*dx4) - model(xd2-step_size*dx4))/step_size/2 * (-1.0) - 0)**2).cuda() 
    
    part_2 = torch.sum((uxa1 + uxa2 + uxb1 + uxb2 + uxc1 + uxc2 + uxd1 + uxd2)[:,0])/xa1.size()[0]
    lambda1 = 1.0
    return part_1 + lambda1 * part_2 / 8

# %%
Data_size = 2000
def Gendata():
    x = torch.rand(Data_size, dimension)
    return x.cuda()

# %%
# 正态分布初始化参数
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = DeepRitzNet(dimension, 8)
model = initparam(model, 0.5)

# %%
device = torch.device("cuda:1" )
model.to(device)
# Out:
# DeepRitzNet(
#   (linear_in): Linear(in_features=4, out_features=8, bias=True)
#   (linear1): Linear(in_features=8, out_features=8, bias=True)
#   (linear2): Linear(in_features=8, out_features=8, bias=True)
#   (linear3): Linear(in_features=8, out_features=8, bias=True)
#   (linear4): Linear(in_features=8, out_features=8, bias=True)
#   (linear5): Linear(in_features=8, out_features=8, bias=True)
#   (linear6): Linear(in_features=8, out_features=8, bias=True)
#   (linear_out): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
import torch.optim as optim
import torch.nn as nn
import time

# %%
def relative_error():
    x = Gendata()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact )**2))/torch.sqrt(torch.sum((exact )**2))
    return value

# %%
traintime = 20000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = Gendata()
    x.requires_grad = True
    losses = DRM(x)
    losses.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", losses.detach())
        print("current relative error is: ", error.detach())
        np.save("DRM_relative_error_4D_Neumann_sigmoid.npy", error_save)
np.save("DRM_relative_error_4D_Neumann_sigmoid.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(7.3256, device='cuda:1')
# current relative error is:  tensor(1.2887, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(-1.9906, device='cuda:1')
# current relative error is:  tensor(0.9210, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(-5.0115, device='cuda:1')
# current relative error is:  tensor(0.8403, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(-7.3142, device='cuda:1')
# current relative error is:  tensor(0.7632, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(-9.5036, device='cuda:1')
# current relative error is:  tensor(0.6617, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(-11.2292, device='cuda:1')
# current relative error is:  tensor(0.5701, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(-13.2863, device='cuda:1')
# current relative error is:  tensor(0.4478, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(-14.7639, device='cuda:1')
# current relative error is:  tensor(0.3603, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(-13.8858, device='cuda:1')
# current relative error is:  tensor(0.3107, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(-14.5115, device='cuda:1')
# current relative error is:  tensor(0.2987, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(-13.1797, device='cuda:1')
# current relative error is:  tensor(0.2929, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(-13.0702, device='cuda:1')
# current relative error is:  tensor(0.2899, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(-14.2464, device='cuda:1')
# current relative error is:  tensor(0.2845, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(-14.0912, device='cuda:1')
# current relative error is:  tensor(0.2800, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(-13.8657, device='cuda:1')
# current relative error is:  tensor(0.2773, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(-14.5032, device='cuda:1')
# current relative error is:  tensor(0.2747, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(-14.6295, device='cuda:1')
# current relative error is:  tensor(0.2718, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(-15.2938, device='cuda:1')
# current relative error is:  tensor(0.2701, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(-14.5218, device='cuda:1')
# current relative error is:  tensor(0.2615, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(-15.1673, device='cuda:1')
# current relative error is:  tensor(0.2598, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(-15.3147, device='cuda:1')
# current relative error is:  tensor(0.2540, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(-16.4918, device='cuda:1')
# current relative error is:  tensor(0.2415, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(-15.7289, device='cuda:1')
# current relative error is:  tensor(0.2341, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(-17.4404, device='cuda:1')
# current relative error is:  tensor(0.2300, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(-17.0602, device='cuda:1')
# current relative error is:  tensor(0.2248, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(-14.8884, device='cuda:1')
# current relative error is:  tensor(0.2205, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(-16.4974, device='cuda:1')
# current relative error is:  tensor(0.2167, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(-17.0751, device='cuda:1')
# current relative error is:  tensor(0.2109, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(-17.2197, device='cuda:1')
# current relative error is:  tensor(0.2064, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(-17.0650, device='cuda:1')
# current relative error is:  tensor(0.2072, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(-17.4934, device='cuda:1')
# current relative error is:  tensor(0.1956, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(-18.2429, device='cuda:1')
# current relative error is:  tensor(0.2011, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(-16.1586, device='cuda:1')
# current relative error is:  tensor(0.2041, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(-17.1930, device='cuda:1')
# current relative error is:  tensor(0.1980, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(-16.9505, device='cuda:1')
# current relative error is:  tensor(0.2027, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(-17.4005, device='cuda:1')
# current relative error is:  tensor(0.2011, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(-17.6133, device='cuda:1')
# current relative error is:  tensor(0.2017, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(-17.6965, device='cuda:1')
# current relative error is:  tensor(0.2082, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(-17.8079, device='cuda:1')
# current relative error is:  tensor(0.2033, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(-16.7249, device='cuda:1')
# current relative error is:  tensor(0.2024, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(-16.8424, device='cuda:1')
# current relative error is:  tensor(0.1971, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(-17.1738, device='cuda:1')
# current relative error is:  tensor(0.1978, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(-18.7994, device='cuda:1')
# current relative error is:  tensor(0.2002, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(-17.2318, device='cuda:1')
# current relative error is:  tensor(0.1979, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(-17.8185, device='cuda:1')
# current relative error is:  tensor(0.1964, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(-17.8306, device='cuda:1')
# current relative error is:  tensor(0.1937, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(-16.2056, device='cuda:1')
# current relative error is:  tensor(0.1929, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(-17.9737, device='cuda:1')
# current relative error is:  tensor(0.1872, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(-16.8322, device='cuda:1')
# current relative error is:  tensor(0.1803, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(-15.8750, device='cuda:1')
# current relative error is:  tensor(0.1897, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(-17.2087, device='cuda:1')
# current relative error is:  tensor(0.1809, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(-18.7662, device='cuda:1')
# current relative error is:  tensor(0.1847, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(-16.7164, device='cuda:1')
# current relative error is:  tensor(0.1750, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(-18.9549, device='cuda:1')
# current relative error is:  tensor(0.1762, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(-18.8719, device='cuda:1')
# current relative error is:  tensor(0.1718, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(-18.5769, device='cuda:1')
# current relative error is:  tensor(0.1695, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(-18.3455, device='cuda:1')
# current relative error is:  tensor(0.1684, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(-17.4837, device='cuda:1')
# current relative error is:  tensor(0.1743, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(-17.7061, device='cuda:1')
# current relative error is:  tensor(0.1686, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(-18.6158, device='cuda:1')
# current relative error is:  tensor(0.1687, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(-17.9397, device='cuda:1')
# current relative error is:  tensor(0.1730, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(-18.2430, device='cuda:1')
# current relative error is:  tensor(0.1613, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(-17.6868, device='cuda:1')
# current relative error is:  tensor(0.1654, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(-17.8587, device='cuda:1')
# current relative error is:  tensor(0.1629, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(-17.7588, device='cuda:1')
# current relative error is:  tensor(0.1658, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(-17.6395, device='cuda:1')
# current relative error is:  tensor(0.1635, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(-18.7209, device='cuda:1')
# current relative error is:  tensor(0.1697, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(-18.1676, device='cuda:1')
# current relative error is:  tensor(0.1614, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(-19.5155, device='cuda:1')
# current relative error is:  tensor(0.1557, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(-18.9623, device='cuda:1')
# current relative error is:  tensor(0.1595, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(-18.9491, device='cuda:1')
# current relative error is:  tensor(0.1625, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(-17.4961, device='cuda:1')
# current relative error is:  tensor(0.1635, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(-16.6569, device='cuda:1')
# current relative error is:  tensor(0.1654, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(-19.0175, device='cuda:1')
# current relative error is:  tensor(0.1610, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(-17.5704, device='cuda:1')
# current relative error is:  tensor(0.1571, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(-18.4791, device='cuda:1')
# current relative error is:  tensor(0.1642, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(-17.2731, device='cuda:1')
# current relative error is:  tensor(0.1605, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(-18.6855, device='cuda:1')
# current relative error is:  tensor(0.1634, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(-17.9231, device='cuda:1')
# current relative error is:  tensor(0.1605, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(-17.4822, device='cuda:1')
# current relative error is:  tensor(0.1571, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(-17.5914, device='cuda:1')
# current relative error is:  tensor(0.1623, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(-19.5641, device='cuda:1')
# current relative error is:  tensor(0.1582, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(-18.6857, device='cuda:1')
# current relative error is:  tensor(0.1582, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(-19.3826, device='cuda:1')
# current relative error is:  tensor(0.1564, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(-17.7841, device='cuda:1')
# current relative error is:  tensor(0.1567, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(-18.1613, device='cuda:1')
# current relative error is:  tensor(0.1609, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(-17.0006, device='cuda:1')
# current relative error is:  tensor(0.1607, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(-20.2440, device='cuda:1')
# current relative error is:  tensor(0.1617, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(-18.4437, device='cuda:1')
# current relative error is:  tensor(0.1605, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(-19.2087, device='cuda:1')
# current relative error is:  tensor(0.1576, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(-17.8959, device='cuda:1')
# current relative error is:  tensor(0.1545, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(-17.1280, device='cuda:1')
# current relative error is:  tensor(0.1591, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(-17.3570, device='cuda:1')
# current relative error is:  tensor(0.1622, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(-16.4028, device='cuda:1')
# current relative error is:  tensor(0.1556, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(-19.1673, device='cuda:1')
# current relative error is:  tensor(0.1584, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(-19.0199, device='cuda:1')
# current relative error is:  tensor(0.1567, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(-18.0730, device='cuda:1')
# current relative error is:  tensor(0.1558, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(-18.1168, device='cuda:1')
# current relative error is:  tensor(0.1580, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(-18.2397, device='cuda:1')
# current relative error is:  tensor(0.1590, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(-16.8998, device='cuda:1')
# current relative error is:  tensor(0.1573, device='cuda:1')
# current epoch is:  5000
# current loss is:  tensor(-17.9752, device='cuda:1')
# current relative error is:  tensor(0.1608, device='cuda:1')
# current epoch is:  5050
# current loss is:  tensor(-17.0169, device='cuda:1')
# current relative error is:  tensor(0.1577, device='cuda:1')
# current epoch is:  5100
# current loss is:  tensor(-18.0208, device='cuda:1')
# current relative error is:  tensor(0.1710, device='cuda:1')
# current epoch is:  5150
# current loss is:  tensor(-18.1070, device='cuda:1')
# current relative error is:  tensor(0.1551, device='cuda:1')
# current epoch is:  5200
# current loss is:  tensor(-19.2399, device='cuda:1')
# current relative error is:  tensor(0.1603, device='cuda:1')
# current epoch is:  5250
# current loss is:  tensor(-18.4693, device='cuda:1')
# current relative error is:  tensor(0.1568, device='cuda:1')
# current epoch is:  5300
# current loss is:  tensor(-17.5717, device='cuda:1')
# current relative error is:  tensor(0.1549, device='cuda:1')
# current epoch is:  5350
# current loss is:  tensor(-18.6667, device='cuda:1')
# current relative error is:  tensor(0.1570, device='cuda:1')
# current epoch is:  5400
# current loss is:  tensor(-17.7340, device='cuda:1')
# current relative error is:  tensor(0.1659, device='cuda:1')
# current epoch is:  5450
# current loss is:  tensor(-17.5124, device='cuda:1')
# current relative error is:  tensor(0.1602, device='cuda:1')
# current epoch is:  5500
# current loss is:  tensor(-16.4312, device='cuda:1')
# current relative error is:  tensor(0.1516, device='cuda:1')
# current epoch is:  5550
# current loss is:  tensor(-17.0170, device='cuda:1')
# current relative error is:  tensor(0.1623, device='cuda:1')
# current epoch is:  5600
# current loss is:  tensor(-17.6801, device='cuda:1')
# current relative error is:  tensor(0.1595, device='cuda:1')
# current epoch is:  5650
# current loss is:  tensor(-18.0495, device='cuda:1')
# current relative error is:  tensor(0.1567, device='cuda:1')
# current epoch is:  5700
# current loss is:  tensor(-17.8231, device='cuda:1')
# current relative error is:  tensor(0.1655, device='cuda:1')
# current epoch is:  5750
# current loss is:  tensor(-17.9143, device='cuda:1')
# current relative error is:  tensor(0.1564, device='cuda:1')
# current epoch is:  5800
# current loss is:  tensor(-16.8377, device='cuda:1')
# current relative error is:  tensor(0.1524, device='cuda:1')
# current epoch is:  5850
# current loss is:  tensor(-17.6891, device='cuda:1')
# current relative error is:  tensor(0.1571, device='cuda:1')
# current epoch is:  5900
# current loss is:  tensor(-17.2903, device='cuda:1')
# current relative error is:  tensor(0.1643, device='cuda:1')
# current epoch is:  5950
# current loss is:  tensor(-19.1245, device='cuda:1')
# current relative error is:  tensor(0.1579, device='cuda:1')
# current epoch is:  6000
# current loss is:  tensor(-17.4150, device='cuda:1')
# current relative error is:  tensor(0.1596, device='cuda:1')
# current epoch is:  6050
# current loss is:  tensor(-18.5006, device='cuda:1')
# current relative error is:  tensor(0.1585, device='cuda:1')
# current epoch is:  6100
# current loss is:  tensor(-16.9527, device='cuda:1')
# current relative error is:  tensor(0.1608, device='cuda:1')
# current epoch is:  6150
# current loss is:  tensor(-17.4664, device='cuda:1')
# current relative error is:  tensor(0.1661, device='cuda:1')
# current epoch is:  6200
# current loss is:  tensor(-18.1340, device='cuda:1')
# current relative error is:  tensor(0.1584, device='cuda:1')
# current epoch is:  6250
# current loss is:  tensor(-18.3410, device='cuda:1')
# current relative error is:  tensor(0.1582, device='cuda:1')
# current epoch is:  6300
# current loss is:  tensor(-17.4994, device='cuda:1')
# current relative error is:  tensor(0.1607, device='cuda:1')
# current epoch is:  6350
# current loss is:  tensor(-16.9819, device='cuda:1')
# current relative error is:  tensor(0.1557, device='cuda:1')
# current epoch is:  6400
# current loss is:  tensor(-18.5374, device='cuda:1')
# current relative error is:  tensor(0.1629, device='cuda:1')
# current epoch is:  6450
# current loss is:  tensor(-18.1808, device='cuda:1')
# current relative error is:  tensor(0.1630, device='cuda:1')
# current epoch is:  6500
# current loss is:  tensor(-17.5282, device='cuda:1')
# current relative error is:  tensor(0.1524, device='cuda:1')
# current epoch is:  6550
# current loss is:  tensor(-18.7920, device='cuda:1')
# current relative error is:  tensor(0.1584, device='cuda:1')
# current epoch is:  6600
# current loss is:  tensor(-18.4466, device='cuda:1')
# current relative error is:  tensor(0.1575, device='cuda:1')
# current epoch is:  6650
# current loss is:  tensor(-17.6228, device='cuda:1')
# current relative error is:  tensor(0.1565, device='cuda:1')
# current epoch is:  6700
# current loss is:  tensor(-16.9786, device='cuda:1')
# current relative error is:  tensor(0.1567, device='cuda:1')
# current epoch is:  6750
# current loss is:  tensor(-19.2582, device='cuda:1')
# current relative error is:  tensor(0.1574, device='cuda:1')
# current epoch is:  6800
# current loss is:  tensor(-17.5501, device='cuda:1')
# current relative error is:  tensor(0.1527, device='cuda:1')
# current epoch is:  6850
# current loss is:  tensor(-18.9410, device='cuda:1')
# current relative error is:  tensor(0.1521, device='cuda:1')
# current epoch is:  6900
# current loss is:  tensor(-17.6563, device='cuda:1')
# current relative error is:  tensor(0.1509, device='cuda:1')
# current epoch is:  6950
# current loss is:  tensor(-17.7957, device='cuda:1')
# current relative error is:  tensor(0.1484, device='cuda:1')
# current epoch is:  7000
# current loss is:  tensor(-17.8977, device='cuda:1')
# current relative error is:  tensor(0.1527, device='cuda:1')
# current epoch is:  7050
# current loss is:  tensor(-18.8523, device='cuda:1')
# current relative error is:  tensor(0.1484, device='cuda:1')
# current epoch is:  7100
# current loss is:  tensor(-18.4381, device='cuda:1')
# current relative error is:  tensor(0.1490, device='cuda:1')
# current epoch is:  7150
# current loss is:  tensor(-17.9896, device='cuda:1')
# current relative error is:  tensor(0.1440, device='cuda:1')
# current epoch is:  7200
# current loss is:  tensor(-17.9997, device='cuda:1')
# current relative error is:  tensor(0.1471, device='cuda:1')
# current epoch is:  7250
# current loss is:  tensor(-16.8815, device='cuda:1')
# current relative error is:  tensor(0.1332, device='cuda:1')
# current epoch is:  7300
# current loss is:  tensor(-18.0725, device='cuda:1')
# current relative error is:  tensor(0.1372, device='cuda:1')
# current epoch is:  7350
# current loss is:  tensor(-18.9073, device='cuda:1')
# current relative error is:  tensor(0.1321, device='cuda:1')
# current epoch is:  7400
# current loss is:  tensor(-19.2457, device='cuda:1')
# current relative error is:  tensor(0.1106, device='cuda:1')
# current epoch is:  7450
# current loss is:  tensor(-18.2676, device='cuda:1')
# current relative error is:  tensor(0.1095, device='cuda:1')
# current epoch is:  7500
# current loss is:  tensor(-17.6958, device='cuda:1')
# current relative error is:  tensor(0.0997, device='cuda:1')
# current epoch is:  7550
# current loss is:  tensor(-18.6958, device='cuda:1')
# current relative error is:  tensor(0.0832, device='cuda:1')
# current epoch is:  7600
# current loss is:  tensor(-19.9408, device='cuda:1')
# current relative error is:  tensor(0.0838, device='cuda:1')
# current epoch is:  7650
# current loss is:  tensor(-17.7505, device='cuda:1')
# current relative error is:  tensor(0.0678, device='cuda:1')
# current epoch is:  7700
# current loss is:  tensor(-18.8116, device='cuda:1')
# current relative error is:  tensor(0.0627, device='cuda:1')
# current epoch is:  7750
# current loss is:  tensor(-19.0327, device='cuda:1')
# current relative error is:  tensor(0.0752, device='cuda:1')
# current epoch is:  7800
# current loss is:  tensor(-18.5349, device='cuda:1')
# current relative error is:  tensor(0.0423, device='cuda:1')
# current epoch is:  7850
# current loss is:  tensor(-18.5393, device='cuda:1')
# current relative error is:  tensor(0.0521, device='cuda:1')
# current epoch is:  7900
# current loss is:  tensor(-19.4113, device='cuda:1')
# current relative error is:  tensor(0.0421, device='cuda:1')
# current epoch is:  7950
# current loss is:  tensor(-19.2767, device='cuda:1')
# current relative error is:  tensor(0.0486, device='cuda:1')
# current epoch is:  8000
# current loss is:  tensor(-19.3593, device='cuda:1')
# current relative error is:  tensor(0.0456, device='cuda:1')
# current epoch is:  8050
# current loss is:  tensor(-19.6195, device='cuda:1')
# current relative error is:  tensor(0.0408, device='cuda:1')
# current epoch is:  8100
# current loss is:  tensor(-19.9301, device='cuda:1')
# current relative error is:  tensor(0.0402, device='cuda:1')
# current epoch is:  8150
# current loss is:  tensor(-20.9379, device='cuda:1')
# current relative error is:  tensor(0.0568, device='cuda:1')
# current epoch is:  8200
# current loss is:  tensor(-20.2419, device='cuda:1')
# current relative error is:  tensor(0.0446, device='cuda:1')
# current epoch is:  8250
# current loss is:  tensor(-19.0267, device='cuda:1')
# current relative error is:  tensor(0.0353, device='cuda:1')
# current epoch is:  8300
# current loss is:  tensor(-19.5844, device='cuda:1')
# current relative error is:  tensor(0.0382, device='cuda:1')
# current epoch is:  8350
# current loss is:  tensor(-20.6779, device='cuda:1')
# current relative error is:  tensor(0.0770, device='cuda:1')
# current epoch is:  8400
# current loss is:  tensor(-20.4291, device='cuda:1')
# current relative error is:  tensor(0.0329, device='cuda:1')
# current epoch is:  8450
# current loss is:  tensor(-20.1024, device='cuda:1')
# current relative error is:  tensor(0.0305, device='cuda:1')
# current epoch is:  8500
# current loss is:  tensor(-19.0713, device='cuda:1')
# current relative error is:  tensor(0.0366, device='cuda:1')
# current epoch is:  8550
# current loss is:  tensor(-18.8719, device='cuda:1')
# current relative error is:  tensor(0.0364, device='cuda:1')
# current epoch is:  8600
# current loss is:  tensor(-19.0242, device='cuda:1')
# current relative error is:  tensor(0.0468, device='cuda:1')
# current epoch is:  8650
# current loss is:  tensor(-18.4081, device='cuda:1')
# current relative error is:  tensor(0.0311, device='cuda:1')
# current epoch is:  8700
# current loss is:  tensor(-19.4956, device='cuda:1')
# current relative error is:  tensor(0.0405, device='cuda:1')
# current epoch is:  8750
# current loss is:  tensor(-19.0643, device='cuda:1')
# current relative error is:  tensor(0.0294, device='cuda:1')
# current epoch is:  8800
# current loss is:  tensor(-18.1377, device='cuda:1')
# current relative error is:  tensor(0.0375, device='cuda:1')
# current epoch is:  8850
# current loss is:  tensor(-19.9261, device='cuda:1')
# current relative error is:  tensor(0.0753, device='cuda:1')
# current epoch is:  8900
# current loss is:  tensor(-17.8259, device='cuda:1')
# current relative error is:  tensor(0.0590, device='cuda:1')
# current epoch is:  8950
# current loss is:  tensor(-20.1335, device='cuda:1')
# current relative error is:  tensor(0.0409, device='cuda:1')
# current epoch is:  9000
# current loss is:  tensor(-19.6170, device='cuda:1')
# current relative error is:  tensor(0.0328, device='cuda:1')
# current epoch is:  9050
# current loss is:  tensor(-19.2292, device='cuda:1')
# current relative error is:  tensor(0.0347, device='cuda:1')
# current epoch is:  9100
# current loss is:  tensor(-21.1111, device='cuda:1')
# current relative error is:  tensor(0.0587, device='cuda:1')
# current epoch is:  9150
# current loss is:  tensor(-19.8100, device='cuda:1')
# current relative error is:  tensor(0.0269, device='cuda:1')
# current epoch is:  9200
# current loss is:  tensor(-18.2467, device='cuda:1')
# current relative error is:  tensor(0.0317, device='cuda:1')
# current epoch is:  9250
# current loss is:  tensor(-19.2054, device='cuda:1')
# current relative error is:  tensor(0.0361, device='cuda:1')
# current epoch is:  9300
# current loss is:  tensor(-20.2002, device='cuda:1')
# current relative error is:  tensor(0.0387, device='cuda:1')
# current epoch is:  9350
# current loss is:  tensor(-18.2629, device='cuda:1')
# current relative error is:  tensor(0.0387, device='cuda:1')
# current epoch is:  9400
# current loss is:  tensor(-20.2581, device='cuda:1')
# current relative error is:  tensor(0.0404, device='cuda:1')
# current epoch is:  9450
# current loss is:  tensor(-19.9077, device='cuda:1')
# current relative error is:  tensor(0.0369, device='cuda:1')
# current epoch is:  9500
# current loss is:  tensor(-20.7519, device='cuda:1')
# current relative error is:  tensor(0.0319, device='cuda:1')
# current epoch is:  9550
# current loss is:  tensor(-18.6757, device='cuda:1')
# current relative error is:  tensor(0.0467, device='cuda:1')
# current epoch is:  9600
# current loss is:  tensor(-19.6489, device='cuda:1')
# current relative error is:  tensor(0.0287, device='cuda:1')
# current epoch is:  9650
# current loss is:  tensor(-18.1308, device='cuda:1')
# current relative error is:  tensor(0.0341, device='cuda:1')
# current epoch is:  9700
# current loss is:  tensor(-18.9126, device='cuda:1')
# current relative error is:  tensor(0.0351, device='cuda:1')
# current epoch is:  9750
# current loss is:  tensor(-19.7221, device='cuda:1')
# current relative error is:  tensor(0.0312, device='cuda:1')
# current epoch is:  9800
# current loss is:  tensor(-21.1676, device='cuda:1')
# current relative error is:  tensor(0.0382, device='cuda:1')
# current epoch is:  9850
# current loss is:  tensor(-21.0080, device='cuda:1')
# current relative error is:  tensor(0.0252, device='cuda:1')
# current epoch is:  9900
# current loss is:  tensor(-19.8133, device='cuda:1')
# current relative error is:  tensor(0.0590, device='cuda:1')
# current epoch is:  9950
# current loss is:  tensor(-18.9362, device='cuda:1')
# current relative error is:  tensor(0.0279, device='cuda:1')
# current epoch is:  10000
# current loss is:  tensor(-19.6573, device='cuda:1')
# current relative error is:  tensor(0.0483, device='cuda:1')
# current epoch is:  10050
# current loss is:  tensor(-19.5119, device='cuda:1')
# current relative error is:  tensor(0.0269, device='cuda:1')
# current epoch is:  10100
# current loss is:  tensor(-19.2807, device='cuda:1')
# current relative error is:  tensor(0.0290, device='cuda:1')
# current epoch is:  10150
# current loss is:  tensor(-20.0335, device='cuda:1')
# current relative error is:  tensor(0.0445, device='cuda:1')
# current epoch is:  10200
# current loss is:  tensor(-19.7153, device='cuda:1')
# current relative error is:  tensor(0.0242, device='cuda:1')
# current epoch is:  10250
# current loss is:  tensor(-19.5762, device='cuda:1')
# current relative error is:  tensor(0.0440, device='cuda:1')
# current epoch is:  10300
# current loss is:  tensor(-18.5595, device='cuda:1')
# current relative error is:  tensor(0.0335, device='cuda:1')
# current epoch is:  10350
# current loss is:  tensor(-19.4390, device='cuda:1')
# current relative error is:  tensor(0.0286, device='cuda:1')
# current epoch is:  10400
# current loss is:  tensor(-20.6677, device='cuda:1')
# current relative error is:  tensor(0.0321, device='cuda:1')
# current epoch is:  10450
# current loss is:  tensor(-19.0085, device='cuda:1')
# current relative error is:  tensor(0.0228, device='cuda:1')
# current epoch is:  10500
# current loss is:  tensor(-20.1984, device='cuda:1')
# current relative error is:  tensor(0.0355, device='cuda:1')
# current epoch is:  10550
# current loss is:  tensor(-20.5573, device='cuda:1')
# current relative error is:  tensor(0.0246, device='cuda:1')
# current epoch is:  10600
# current loss is:  tensor(-19.5668, device='cuda:1')
# current relative error is:  tensor(0.0420, device='cuda:1')
# current epoch is:  10650
# current loss is:  tensor(-19.1436, device='cuda:1')
# current relative error is:  tensor(0.0258, device='cuda:1')
# current epoch is:  10700
# current loss is:  tensor(-19.1068, device='cuda:1')
# current relative error is:  tensor(0.0370, device='cuda:1')
# current epoch is:  10750
# current loss is:  tensor(-19.4473, device='cuda:1')
# current relative error is:  tensor(0.0232, device='cuda:1')
# current epoch is:  10800
# current loss is:  tensor(-19.8081, device='cuda:1')
# current relative error is:  tensor(0.0330, device='cuda:1')
# current epoch is:  10850
# current loss is:  tensor(-19.4157, device='cuda:1')
# current relative error is:  tensor(0.0544, device='cuda:1')
# current epoch is:  10900
# current loss is:  tensor(-21.6145, device='cuda:1')
# current relative error is:  tensor(0.0233, device='cuda:1')
# current epoch is:  10950
# current loss is:  tensor(-19.5664, device='cuda:1')
# current relative error is:  tensor(0.0251, device='cuda:1')
# current epoch is:  11000
# current loss is:  tensor(-20.3816, device='cuda:1')
# current relative error is:  tensor(0.0334, device='cuda:1')
# current epoch is:  11050
# current loss is:  tensor(-20.2213, device='cuda:1')
# current relative error is:  tensor(0.0345, device='cuda:1')
# current epoch is:  11100
# current loss is:  tensor(-18.9816, device='cuda:1')
# current relative error is:  tensor(0.0343, device='cuda:1')
# current epoch is:  11150
# current loss is:  tensor(-19.8377, device='cuda:1')
# current relative error is:  tensor(0.0757, device='cuda:1')
# current epoch is:  11200
# current loss is:  tensor(-19.1656, device='cuda:1')
# current relative error is:  tensor(0.0288, device='cuda:1')
# current epoch is:  11250
# current loss is:  tensor(-18.7946, device='cuda:1')
# current relative error is:  tensor(0.0348, device='cuda:1')
# current epoch is:  11300
# current loss is:  tensor(-20.6885, device='cuda:1')
# current relative error is:  tensor(0.0229, device='cuda:1')
# current epoch is:  11350
# current loss is:  tensor(-20.3653, device='cuda:1')
# current relative error is:  tensor(0.0299, device='cuda:1')
# current epoch is:  11400
# current loss is:  tensor(-19.5426, device='cuda:1')
# current relative error is:  tensor(0.0320, device='cuda:1')
# current epoch is:  11450
# current loss is:  tensor(-18.9575, device='cuda:1')
# current relative error is:  tensor(0.0254, device='cuda:1')
# current epoch is:  11500
# current loss is:  tensor(-20.3266, device='cuda:1')
# current relative error is:  tensor(0.0331, device='cuda:1')
# current epoch is:  11550
# current loss is:  tensor(-19.1520, device='cuda:1')
# current relative error is:  tensor(0.0245, device='cuda:1')
# current epoch is:  11600
# current loss is:  tensor(-19.8815, device='cuda:1')
# current relative error is:  tensor(0.0257, device='cuda:1')
# current epoch is:  11650
# current loss is:  tensor(-19.0465, device='cuda:1')
# current relative error is:  tensor(0.0248, device='cuda:1')
# current epoch is:  11700
# current loss is:  tensor(-19.6621, device='cuda:1')
# current relative error is:  tensor(0.0316, device='cuda:1')
# current epoch is:  11750
# current loss is:  tensor(-17.2099, device='cuda:1')
# current relative error is:  tensor(0.0586, device='cuda:1')
# current epoch is:  11800
# current loss is:  tensor(-18.4012, device='cuda:1')
# current relative error is:  tensor(0.0216, device='cuda:1')
# current epoch is:  11850
# current loss is:  tensor(-19.6352, device='cuda:1')
# current relative error is:  tensor(0.0496, device='cuda:1')
# current epoch is:  11900
# current loss is:  tensor(-20.9134, device='cuda:1')
# current relative error is:  tensor(0.0203, device='cuda:1')
# current epoch is:  11950
# current loss is:  tensor(-19.9624, device='cuda:1')
# current relative error is:  tensor(0.0295, device='cuda:1')
# current epoch is:  12000
# current loss is:  tensor(-19.6096, device='cuda:1')
# current relative error is:  tensor(0.0248, device='cuda:1')
# current epoch is:  12050
# current loss is:  tensor(-20.4751, device='cuda:1')
# current relative error is:  tensor(0.0238, device='cuda:1')
# current epoch is:  12100
# current loss is:  tensor(-19.6776, device='cuda:1')
# current relative error is:  tensor(0.0471, device='cuda:1')
# current epoch is:  12150
# current loss is:  tensor(-19.3246, device='cuda:1')
# current relative error is:  tensor(0.0486, device='cuda:1')
# current epoch is:  12200
# current loss is:  tensor(-21.1450, device='cuda:1')
# current relative error is:  tensor(0.0294, device='cuda:1')
# current epoch is:  12250
# current loss is:  tensor(-19.1474, device='cuda:1')
# current relative error is:  tensor(0.0214, device='cuda:1')
# current epoch is:  12300
# current loss is:  tensor(-19.9431, device='cuda:1')
# current relative error is:  tensor(0.0255, device='cuda:1')
# current epoch is:  12350
# current loss is:  tensor(-19.8555, device='cuda:1')
# current relative error is:  tensor(0.0253, device='cuda:1')
# current epoch is:  12400
# current loss is:  tensor(-18.9122, device='cuda:1')
# current relative error is:  tensor(0.0271, device='cuda:1')
# current epoch is:  12450
# current loss is:  tensor(-19.7136, device='cuda:1')
# current relative error is:  tensor(0.0227, device='cuda:1')
# current epoch is:  12500
# current loss is:  tensor(-19.7440, device='cuda:1')
# current relative error is:  tensor(0.0402, device='cuda:1')
# current epoch is:  12550
# current loss is:  tensor(-19.5334, device='cuda:1')
# current relative error is:  tensor(0.0222, device='cuda:1')
# current epoch is:  12600
# current loss is:  tensor(-19.8919, device='cuda:1')
# current relative error is:  tensor(0.0334, device='cuda:1')
# current epoch is:  12650
# current loss is:  tensor(-20.0429, device='cuda:1')
# current relative error is:  tensor(0.0213, device='cuda:1')
# current epoch is:  12700
# current loss is:  tensor(-19.7046, device='cuda:1')
# current relative error is:  tensor(0.0259, device='cuda:1')
# current epoch is:  12750
# current loss is:  tensor(-19.3835, device='cuda:1')
# current relative error is:  tensor(0.0256, device='cuda:1')
# current epoch is:  12800
# current loss is:  tensor(-19.5367, device='cuda:1')
# current relative error is:  tensor(0.0491, device='cuda:1')
# current epoch is:  12850
# current loss is:  tensor(-19.7877, device='cuda:1')
# current relative error is:  tensor(0.0199, device='cuda:1')
# current epoch is:  12900
# current loss is:  tensor(-20.2924, device='cuda:1')
# current relative error is:  tensor(0.0298, device='cuda:1')
# current epoch is:  12950
# current loss is:  tensor(-20.2641, device='cuda:1')
# current relative error is:  tensor(0.0233, device='cuda:1')
# current epoch is:  13000
# current loss is:  tensor(-20.0792, device='cuda:1')
# current relative error is:  tensor(0.0407, device='cuda:1')
# current epoch is:  13050
# current loss is:  tensor(-19.5237, device='cuda:1')
# current relative error is:  tensor(0.0296, device='cuda:1')
# current epoch is:  13100
# current loss is:  tensor(-19.5434, device='cuda:1')
# current relative error is:  tensor(0.0261, device='cuda:1')
# current epoch is:  13150
# current loss is:  tensor(-19.0164, device='cuda:1')
# current relative error is:  tensor(0.0210, device='cuda:1')
# current epoch is:  13200
# current loss is:  tensor(-20.6071, device='cuda:1')
# current relative error is:  tensor(0.0246, device='cuda:1')
# current epoch is:  13250
# current loss is:  tensor(-19.1667, device='cuda:1')
# current relative error is:  tensor(0.0288, device='cuda:1')
# current epoch is:  13300
# current loss is:  tensor(-18.5335, device='cuda:1')
# current relative error is:  tensor(0.0355, device='cuda:1')
# current epoch is:  13350
# current loss is:  tensor(-20.9931, device='cuda:1')
# current relative error is:  tensor(0.0256, device='cuda:1')
# current epoch is:  13400
# current loss is:  tensor(-19.7567, device='cuda:1')
# current relative error is:  tensor(0.0182, device='cuda:1')
# current epoch is:  13450
# current loss is:  tensor(-21.2945, device='cuda:1')
# current relative error is:  tensor(0.0194, device='cuda:1')
# current epoch is:  13500
# current loss is:  tensor(-19.5623, device='cuda:1')
# current relative error is:  tensor(0.0203, device='cuda:1')
# current epoch is:  13550
# current loss is:  tensor(-18.4251, device='cuda:1')
# current relative error is:  tensor(0.0263, device='cuda:1')
# current epoch is:  13600
# current loss is:  tensor(-19.7235, device='cuda:1')
# current relative error is:  tensor(0.0324, device='cuda:1')
# current epoch is:  13650
# current loss is:  tensor(-21.7475, device='cuda:1')
# current relative error is:  tensor(0.0313, device='cuda:1')
# current epoch is:  13700
# current loss is:  tensor(-19.6397, device='cuda:1')
# current relative error is:  tensor(0.0231, device='cuda:1')
# current epoch is:  13750
# current loss is:  tensor(-19.2299, device='cuda:1')
# current relative error is:  tensor(0.0281, device='cuda:1')
# current epoch is:  13800
# current loss is:  tensor(-19.3706, device='cuda:1')
# current relative error is:  tensor(0.0230, device='cuda:1')
# current epoch is:  13850
# current loss is:  tensor(-18.0922, device='cuda:1')
# current relative error is:  tensor(0.0265, device='cuda:1')
# current epoch is:  13900
# current loss is:  tensor(-19.0900, device='cuda:1')
# current relative error is:  tensor(0.0625, device='cuda:1')
# current epoch is:  13950
# current loss is:  tensor(-19.4107, device='cuda:1')
# current relative error is:  tensor(0.0178, device='cuda:1')
# current epoch is:  14000
# current loss is:  tensor(-19.5376, device='cuda:1')
# current relative error is:  tensor(0.0192, device='cuda:1')
# current epoch is:  14050
# current loss is:  tensor(-20.3290, device='cuda:1')
# current relative error is:  tensor(0.0198, device='cuda:1')
# current epoch is:  14100
# current loss is:  tensor(-18.6860, device='cuda:1')
# current relative error is:  tensor(0.0405, device='cuda:1')
# current epoch is:  14150
# current loss is:  tensor(-19.5122, device='cuda:1')
# current relative error is:  tensor(0.0281, device='cuda:1')
# current epoch is:  14200
# current loss is:  tensor(-19.6143, device='cuda:1')
# current relative error is:  tensor(0.0251, device='cuda:1')
# current epoch is:  14250
# current loss is:  tensor(-19.4803, device='cuda:1')
# current relative error is:  tensor(0.0273, device='cuda:1')
# current epoch is:  14300
# current loss is:  tensor(-19.0362, device='cuda:1')
# current relative error is:  tensor(0.0233, device='cuda:1')
# current epoch is:  14350
# current loss is:  tensor(-19.0877, device='cuda:1')
# current relative error is:  tensor(0.0376, device='cuda:1')
# current epoch is:  14400
# current loss is:  tensor(-19.6076, device='cuda:1')
# current relative error is:  tensor(0.0265, device='cuda:1')
# current epoch is:  14450
# current loss is:  tensor(-20.0248, device='cuda:1')
# current relative error is:  tensor(0.0279, device='cuda:1')
# current epoch is:  14500
# current loss is:  tensor(-21.3330, device='cuda:1')
# current relative error is:  tensor(0.0237, device='cuda:1')
# current epoch is:  14550
# current loss is:  tensor(-19.2557, device='cuda:1')
# current relative error is:  tensor(0.0377, device='cuda:1')
# current epoch is:  14600
# current loss is:  tensor(-19.2541, device='cuda:1')
# current relative error is:  tensor(0.0230, device='cuda:1')
# current epoch is:  14650
# current loss is:  tensor(-20.3211, device='cuda:1')
# current relative error is:  tensor(0.0333, device='cuda:1')
# current epoch is:  14700
# current loss is:  tensor(-19.0099, device='cuda:1')
# current relative error is:  tensor(0.0193, device='cuda:1')
# current epoch is:  14750
# current loss is:  tensor(-19.1314, device='cuda:1')
# current relative error is:  tensor(0.0211, device='cuda:1')
# current epoch is:  14800
# current loss is:  tensor(-18.7439, device='cuda:1')
# current relative error is:  tensor(0.0269, device='cuda:1')
# current epoch is:  14850
# current loss is:  tensor(-20.7165, device='cuda:1')
# current relative error is:  tensor(0.0248, device='cuda:1')
# current epoch is:  14900
# current loss is:  tensor(-19.7837, device='cuda:1')
# current relative error is:  tensor(0.0310, device='cuda:1')
# current epoch is:  14950
# current loss is:  tensor(-20.0462, device='cuda:1')
# current relative error is:  tensor(0.0216, device='cuda:1')
# current epoch is:  15000
# current loss is:  tensor(-19.5098, device='cuda:1')
# current relative error is:  tensor(0.0296, device='cuda:1')
# current epoch is:  15050
# current loss is:  tensor(-20.2344, device='cuda:1')
# current relative error is:  tensor(0.0258, device='cuda:1')
# current epoch is:  15100
# current loss is:  tensor(-21.0467, device='cuda:1')
# current relative error is:  tensor(0.0185, device='cuda:1')
# current epoch is:  15150
# current loss is:  tensor(-21.9814, device='cuda:1')
# current relative error is:  tensor(0.0207, device='cuda:1')
# current epoch is:  15200
# current loss is:  tensor(-20.3102, device='cuda:1')
# current relative error is:  tensor(0.0243, device='cuda:1')
# current epoch is:  15250
# current loss is:  tensor(-19.6077, device='cuda:1')
# current relative error is:  tensor(0.0274, device='cuda:1')
# current epoch is:  15300
# current loss is:  tensor(-20.0373, device='cuda:1')
# current relative error is:  tensor(0.0216, device='cuda:1')
# current epoch is:  15350
# current loss is:  tensor(-20.0506, device='cuda:1')
# current relative error is:  tensor(0.0182, device='cuda:1')
# current epoch is:  15400
# current loss is:  tensor(-20.0707, device='cuda:1')
# current relative error is:  tensor(0.0191, device='cuda:1')
# current epoch is:  15450
# current loss is:  tensor(-20.0538, device='cuda:1')
# current relative error is:  tensor(0.0539, device='cuda:1')
# current epoch is:  15500
# current loss is:  tensor(-20.6580, device='cuda:1')
# current relative error is:  tensor(0.0346, device='cuda:1')
# current epoch is:  15550
# current loss is:  tensor(-20.1094, device='cuda:1')
# current relative error is:  tensor(0.0164, device='cuda:1')
# current epoch is:  15600
# current loss is:  tensor(-20.8353, device='cuda:1')
# current relative error is:  tensor(0.0300, device='cuda:1')
# current epoch is:  15650
# current loss is:  tensor(-20.4748, device='cuda:1')
# current relative error is:  tensor(0.0295, device='cuda:1')
# current epoch is:  15700
# current loss is:  tensor(-19.9086, device='cuda:1')
# current relative error is:  tensor(0.0271, device='cuda:1')
# current epoch is:  15750
# current loss is:  tensor(-18.1395, device='cuda:1')
# current relative error is:  tensor(0.0393, device='cuda:1')
# current epoch is:  15800
# current loss is:  tensor(-19.0217, device='cuda:1')
# current relative error is:  tensor(0.0339, device='cuda:1')
# current epoch is:  15850
# current loss is:  tensor(-19.1769, device='cuda:1')
# current relative error is:  tensor(0.0157, device='cuda:1')
# current epoch is:  15900
# current loss is:  tensor(-21.2573, device='cuda:1')
# current relative error is:  tensor(0.0227, device='cuda:1')
# current epoch is:  15950
# current loss is:  tensor(-18.7554, device='cuda:1')
# current relative error is:  tensor(0.0480, device='cuda:1')
# current epoch is:  16000
# current loss is:  tensor(-20.9424, device='cuda:1')
# current relative error is:  tensor(0.0192, device='cuda:1')
# current epoch is:  16050
# current loss is:  tensor(-19.3792, device='cuda:1')
# current relative error is:  tensor(0.0224, device='cuda:1')
# current epoch is:  16100
# current loss is:  tensor(-19.4693, device='cuda:1')
# current relative error is:  tensor(0.0328, device='cuda:1')
# current epoch is:  16150
# current loss is:  tensor(-18.7020, device='cuda:1')
# current relative error is:  tensor(0.0194, device='cuda:1')
# current epoch is:  16200
# current loss is:  tensor(-18.8662, device='cuda:1')
# current relative error is:  tensor(0.0159, device='cuda:1')
# current epoch is:  16250
# current loss is:  tensor(-17.5413, device='cuda:1')
# current relative error is:  tensor(0.0169, device='cuda:1')
# current epoch is:  16300
# current loss is:  tensor(-20.3123, device='cuda:1')
# current relative error is:  tensor(0.0200, device='cuda:1')
# current epoch is:  16350
# current loss is:  tensor(-18.2089, device='cuda:1')
# current relative error is:  tensor(0.0464, device='cuda:1')
# current epoch is:  16400
# current loss is:  tensor(-20.0481, device='cuda:1')
# current relative error is:  tensor(0.0320, device='cuda:1')
# current epoch is:  16450
# current loss is:  tensor(-19.3330, device='cuda:1')
# current relative error is:  tensor(0.0162, device='cuda:1')
# current epoch is:  16500
# current loss is:  tensor(-20.1577, device='cuda:1')
# current relative error is:  tensor(0.0236, device='cuda:1')
# current epoch is:  16550
# current loss is:  tensor(-20.0479, device='cuda:1')
# current relative error is:  tensor(0.0275, device='cuda:1')
# current epoch is:  16600
# current loss is:  tensor(-20.1010, device='cuda:1')
# current relative error is:  tensor(0.0511, device='cuda:1')
# current epoch is:  16650
# current loss is:  tensor(-21.0459, device='cuda:1')
# current relative error is:  tensor(0.0199, device='cuda:1')
# current epoch is:  16700
# current loss is:  tensor(-19.9981, device='cuda:1')
# current relative error is:  tensor(0.0257, device='cuda:1')
# current epoch is:  16750
# current loss is:  tensor(-19.3749, device='cuda:1')
# current relative error is:  tensor(0.0192, device='cuda:1')
# current epoch is:  16800
# current loss is:  tensor(-17.7142, device='cuda:1')
# current relative error is:  tensor(0.0342, device='cuda:1')
# current epoch is:  16850
# current loss is:  tensor(-20.5432, device='cuda:1')
# current relative error is:  tensor(0.0189, device='cuda:1')
# current epoch is:  16900
# current loss is:  tensor(-19.4619, device='cuda:1')
# current relative error is:  tensor(0.0485, device='cuda:1')
# current epoch is:  16950
# current loss is:  tensor(-20.5784, device='cuda:1')
# current relative error is:  tensor(0.0205, device='cuda:1')
# current epoch is:  17000
# current loss is:  tensor(-18.8362, device='cuda:1')
# current relative error is:  tensor(0.0362, device='cuda:1')
# current epoch is:  17050
# current loss is:  tensor(-19.8448, device='cuda:1')
# current relative error is:  tensor(0.0298, device='cuda:1')
# current epoch is:  17100
# current loss is:  tensor(-18.0697, device='cuda:1')
# current relative error is:  tensor(0.0170, device='cuda:1')
# current epoch is:  17150
# current loss is:  tensor(-21.1730, device='cuda:1')
# current relative error is:  tensor(0.0215, device='cuda:1')
# current epoch is:  17200
# current loss is:  tensor(-19.6157, device='cuda:1')
# current relative error is:  tensor(0.0498, device='cuda:1')
# current epoch is:  17250
# current loss is:  tensor(-20.1124, device='cuda:1')
# current relative error is:  tensor(0.0447, device='cuda:1')
# current epoch is:  17300
# current loss is:  tensor(-20.3462, device='cuda:1')
# current relative error is:  tensor(0.0172, device='cuda:1')
# current epoch is:  17350
# current loss is:  tensor(-18.8539, device='cuda:1')
# current relative error is:  tensor(0.0571, device='cuda:1')
# current epoch is:  17400
# current loss is:  tensor(-18.8922, device='cuda:1')
# current relative error is:  tensor(0.0592, device='cuda:1')
# current epoch is:  17450
# current loss is:  tensor(-18.2308, device='cuda:1')
# current relative error is:  tensor(0.0270, device='cuda:1')
# current epoch is:  17500
# current loss is:  tensor(-21.1459, device='cuda:1')
# current relative error is:  tensor(0.0151, device='cuda:1')
# current epoch is:  17550
# current loss is:  tensor(-18.7347, device='cuda:1')
# current relative error is:  tensor(0.0176, device='cuda:1')
# current epoch is:  17600
# current loss is:  tensor(-18.8266, device='cuda:1')
# current relative error is:  tensor(0.0363, device='cuda:1')
# current epoch is:  17650
# current loss is:  tensor(-19.3272, device='cuda:1')
# current relative error is:  tensor(0.0200, device='cuda:1')
# current epoch is:  17700
# current loss is:  tensor(-19.3123, device='cuda:1')
# current relative error is:  tensor(0.0184, device='cuda:1')
# current epoch is:  17750
# current loss is:  tensor(-19.6413, device='cuda:1')
# current relative error is:  tensor(0.0373, device='cuda:1')
# current epoch is:  17800
# current loss is:  tensor(-19.7783, device='cuda:1')
# current relative error is:  tensor(0.0497, device='cuda:1')
# current epoch is:  17850
# current loss is:  tensor(-20.5665, device='cuda:1')
# current relative error is:  tensor(0.0198, device='cuda:1')
# current epoch is:  17900
# current loss is:  tensor(-21.1693, device='cuda:1')
# current relative error is:  tensor(0.0325, device='cuda:1')
# current epoch is:  17950
# current loss is:  tensor(-18.8004, device='cuda:1')
# current relative error is:  tensor(0.0227, device='cuda:1')
# current epoch is:  18000
# current loss is:  tensor(-19.1922, device='cuda:1')
# current relative error is:  tensor(0.0302, device='cuda:1')
# current epoch is:  18050
# current loss is:  tensor(-19.7381, device='cuda:1')
# current relative error is:  tensor(0.0732, device='cuda:1')
# current epoch is:  18100
# current loss is:  tensor(-19.7603, device='cuda:1')
# current relative error is:  tensor(0.0258, device='cuda:1')
# current epoch is:  18150
# current loss is:  tensor(-18.3970, device='cuda:1')
# current relative error is:  tensor(0.0370, device='cuda:1')
# current epoch is:  18200
# current loss is:  tensor(-20.1842, device='cuda:1')
# current relative error is:  tensor(0.0144, device='cuda:1')
# current epoch is:  18250
# current loss is:  tensor(-17.8751, device='cuda:1')
# current relative error is:  tensor(0.0231, device='cuda:1')
# current epoch is:  18300
# current loss is:  tensor(-21.0704, device='cuda:1')
# current relative error is:  tensor(0.0211, device='cuda:1')
# current epoch is:  18350
# current loss is:  tensor(-20.4351, device='cuda:1')
# current relative error is:  tensor(0.0365, device='cuda:1')
# current epoch is:  18400
# current loss is:  tensor(-19.8957, device='cuda:1')
# current relative error is:  tensor(0.0381, device='cuda:1')
# current epoch is:  18450
# current loss is:  tensor(-19.6319, device='cuda:1')
# current relative error is:  tensor(0.0522, device='cuda:1')
# current epoch is:  18500
# current loss is:  tensor(-18.2842, device='cuda:1')
# current relative error is:  tensor(0.0146, device='cuda:1')
# current epoch is:  18550
# current loss is:  tensor(-20.6594, device='cuda:1')
# current relative error is:  tensor(0.0414, device='cuda:1')
# current epoch is:  18600
# current loss is:  tensor(-20.5959, device='cuda:1')
# current relative error is:  tensor(0.0524, device='cuda:1')
# current epoch is:  18650
# current loss is:  tensor(-18.5219, device='cuda:1')
# current relative error is:  tensor(0.0316, device='cuda:1')
# current epoch is:  18700
# current loss is:  tensor(-20.0352, device='cuda:1')
# current relative error is:  tensor(0.0397, device='cuda:1')
# current epoch is:  18750
# current loss is:  tensor(-19.3051, device='cuda:1')
# current relative error is:  tensor(0.0434, device='cuda:1')
# current epoch is:  18800
# current loss is:  tensor(-19.5130, device='cuda:1')
# current relative error is:  tensor(0.0283, device='cuda:1')
# current epoch is:  18850
# current loss is:  tensor(-19.6262, device='cuda:1')
# current relative error is:  tensor(0.0397, device='cuda:1')
# current epoch is:  18900
# current loss is:  tensor(-18.8992, device='cuda:1')
# current relative error is:  tensor(0.0292, device='cuda:1')
# current epoch is:  18950
# current loss is:  tensor(-19.3401, device='cuda:1')
# current relative error is:  tensor(0.0143, device='cuda:1')
# current epoch is:  19000
# current loss is:  tensor(-20.8594, device='cuda:1')
# current relative error is:  tensor(0.0273, device='cuda:1')
# current epoch is:  19050
# current loss is:  tensor(-17.3583, device='cuda:1')
# current relative error is:  tensor(0.0166, device='cuda:1')
# current epoch is:  19100
# current loss is:  tensor(-20.1973, device='cuda:1')
# current relative error is:  tensor(0.0253, device='cuda:1')
# current epoch is:  19150
# current loss is:  tensor(-19.7265, device='cuda:1')
# current relative error is:  tensor(0.0181, device='cuda:1')
# current epoch is:  19200
# current loss is:  tensor(-20.7417, device='cuda:1')
# current relative error is:  tensor(0.0437, device='cuda:1')
# current epoch is:  19250
# current loss is:  tensor(-19.8431, device='cuda:1')
# current relative error is:  tensor(0.0174, device='cuda:1')
# current epoch is:  19300
# current loss is:  tensor(-19.8336, device='cuda:1')
# current relative error is:  tensor(0.0271, device='cuda:1')
# current epoch is:  19350
# current loss is:  tensor(-20.0240, device='cuda:1')
# current relative error is:  tensor(0.0301, device='cuda:1')
# current epoch is:  19400
# current loss is:  tensor(-18.7947, device='cuda:1')
# current relative error is:  tensor(0.0243, device='cuda:1')
# current epoch is:  19450
# current loss is:  tensor(-19.8549, device='cuda:1')
# current relative error is:  tensor(0.0348, device='cuda:1')
# current epoch is:  19500
# current loss is:  tensor(-20.1676, device='cuda:1')
# current relative error is:  tensor(0.0123, device='cuda:1')
# current epoch is:  19550
# current loss is:  tensor(-19.1515, device='cuda:1')
# current relative error is:  tensor(0.0864, device='cuda:1')
# current epoch is:  19600
# current loss is:  tensor(-20.9276, device='cuda:1')
# current relative error is:  tensor(0.0184, device='cuda:1')
# current epoch is:  19650
# current loss is:  tensor(-20.2684, device='cuda:1')
# current relative error is:  tensor(0.0141, device='cuda:1')
# current epoch is:  19700
# current loss is:  tensor(-20.5101, device='cuda:1')
# current relative error is:  tensor(0.0481, device='cuda:1')
# current epoch is:  19750
# current loss is:  tensor(-19.5282, device='cuda:1')
# current relative error is:  tensor(0.0159, device='cuda:1')
# current epoch is:  19800
# current loss is:  tensor(-19.4496, device='cuda:1')
# current relative error is:  tensor(0.0427, device='cuda:1')
# current epoch is:  19850
# current loss is:  tensor(-19.1702, device='cuda:1')
# current relative error is:  tensor(0.0137, device='cuda:1')
# current epoch is:  19900
# current loss is:  tensor(-20.5482, device='cuda:1')
# current relative error is:  tensor(0.0144, device='cuda:1')
# current epoch is:  19950
# current loss is:  tensor(-20.2211, device='cuda:1')
# current relative error is:  tensor(0.0136, device='cuda:1')
# total time is:  7117.994770050049 seconds
