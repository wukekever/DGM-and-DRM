# %%
import torch
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import torch.nn as nn
from math import *

# %%
torch.set_default_tensor_type('torch.DoubleTensor') # 设置浮点类型为 torch.float64

# %%
# 定义激活函数: swish(x)
def acti(x):
    return x*torch.sigmoid(x)

# %%
# 定义网络结构
class DeepRitzNet(torch.nn.Module):
    def __init__(self, input_width, layer_width):
        super(DeepRitzNet, self).__init__()
        self.linear_in = torch.nn.Linear(input_width, layer_width)
        self.linear1 = torch.nn.Linear(layer_width, layer_width)
        self.linear2 = torch.nn.Linear(layer_width, layer_width)
        self.linear3 = torch.nn.Linear(layer_width, layer_width)
        self.linear4 = torch.nn.Linear(layer_width, layer_width)
        self.linear5 = torch.nn.Linear(layer_width, layer_width)
        self.linear6 = torch.nn.Linear(layer_width, layer_width)
        self.linear_out = torch.nn.Linear(layer_width, 1)

    def forward(self, x):
        y = self.linear_in(x) # fully connect layer
        y = y + acti(self.linear2(acti(self.linear1(y)))) # residual block 1
        y = y + acti(self.linear4(acti(self.linear3(y)))) # residual block 2
        y = y + acti(self.linear6(acti(self.linear5(y)))) # residual block 3
        output = self.linear_out(y) # fully connect layer
        return output

# %%
dimension = 2

# %%
# exact solution
def u_ex(x):  
    x_temp = torch.cos(pi*x)
    u_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return u_x

# %%
def f(x):
    x_temp = torch.cos(pi*x)
    f_x = 2*pi**2*(x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return f_x

# %%
# Deep Ritz Method
def DRM(x):
    u_hat = model(x)
    # v = torch.ones(u_hat.shape)
    # ux = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = v, create_graph = True)[0]
    
    ux = torch.zeros(x.size()[0], dimension)
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension)
        dx[:, i] = torch.ones(x.size()[0])
        ux[:, i] = (model(x+step_size*dx) - model(x-step_size*dx))[:,0]/step_size/2
    uxsq = (torch.sum(ux**2, dim = 1)).reshape([x.size()[0], 1]) # dim = 1 按行求和
    f_temp = f(x)
    part_1 = torch.sum(0.5 * uxsq + 0.5*pi**2*u_hat**2 - f_temp*u_hat)/x.size()[0]
    
    Nb = 100
    xb1 = torch.rand(Nb, dimension)
    xb1[:, 0] = torch.zeros(Nb)
    xb2 = torch.rand(Nb, dimension)
    xb2[:, 0] = torch.ones(Nb)
    xb3 = torch.rand(Nb, dimension)
    xb3[:, 1] = torch.zeros(Nb)
    xb4 = torch.rand(Nb, dimension)
    xb4[:, 1] = torch.ones(Nb)
    dx1 = torch.zeros(xb1.size()[0], dimension)
    dx1[:, 0] = torch.ones(xb1.size()[0])
    uxb1 = ((model(xb1+step_size*dx1) - model(xb1-step_size*dx1))/step_size/2 * (1.0) - 0)**2
    uxb2 = ((model(xb2+step_size*dx1) - model(xb2-step_size*dx1))/step_size/2 * (-1.0) - 0)**2
    dx2 = torch.zeros(xb1.size()[0], dimension)
    dx2[:, 1] = torch.ones(xb1.size()[0])
    uxb3 = ((model(xb3+step_size*dx2) - model(xb3-step_size*dx2))/step_size/2 * (1.0) - 0)**2
    uxb4 = ((model(xb4+step_size*dx2) - model(xb4-step_size*dx2))/step_size/2 * (-1.0) - 0)**2
    part_2 = torch.sum((uxb1 + uxb2 + uxb3 + uxb4)[:,0])/xb1.size()[0]
    lambda1 = 100.0
    return part_1 + lambda1 * part_2 / 4

# %%
Data_size = 2000
def Gendata():
    x = torch.rand(Data_size, dimension)
    return x

# %%
# 正态分布初始化参数
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = DeepRitzNet(dimension, 4)
model = initparam(model, 0.5)

# %%
import torch.optim as optim
import torch.nn as nn
import time

# %%
def relative_error():
    x = Gendata()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact )**2))/torch.sqrt(torch.sum((exact )**2))
    return value

# %%
traintime = 10000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = Gendata()
    x.requires_grad = True
    losses = DRM(x)
    losses.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", losses.detach())
        print("current relative error is: ", error.detach())
        np.save("DRM_relative_error_2D_Neumann.npy", error_save)
np.save("DRM_relative_error_2D_Neumann.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(17.0821)
# current relative error is:  tensor(0.9031)
# current epoch is:  50
# current loss is:  tensor(5.2000)
# current relative error is:  tensor(0.9689)
# current epoch is:  100
# current loss is:  tensor(1.4700)
# current relative error is:  tensor(0.9850)
# current epoch is:  150
# current loss is:  tensor(0.1536)
# current relative error is:  tensor(0.9808)
# current epoch is:  200
# current loss is:  tensor(-0.0390)
# current relative error is:  tensor(0.9824)
# current epoch is:  250
# current loss is:  tensor(-0.1101)
# current relative error is:  tensor(0.9823)
# current epoch is:  300
# current loss is:  tensor(-0.1346)
# current relative error is:  tensor(0.9815)
# current epoch is:  350
# current loss is:  tensor(-0.1511)
# current relative error is:  tensor(0.9822)
# current epoch is:  400
# current loss is:  tensor(-0.1637)
# current relative error is:  tensor(0.9814)
# current epoch is:  450
# current loss is:  tensor(-0.1702)
# current relative error is:  tensor(0.9806)
# current epoch is:  500
# current loss is:  tensor(-0.2210)
# current relative error is:  tensor(0.9802)
# current epoch is:  550
# current loss is:  tensor(-0.2250)
# current relative error is:  tensor(0.9791)
# current epoch is:  600
# current loss is:  tensor(-0.2275)
# current relative error is:  tensor(0.9798)
# current epoch is:  650
# current loss is:  tensor(-0.2549)
# current relative error is:  tensor(0.9780)
# current epoch is:  700
# current loss is:  tensor(-0.2813)
# current relative error is:  tensor(0.9762)
# current epoch is:  750
# current loss is:  tensor(-0.3567)
# current relative error is:  tensor(0.9734)
# current epoch is:  800
# current loss is:  tensor(-0.4201)
# current relative error is:  tensor(0.9703)
# current epoch is:  850
# current loss is:  tensor(-0.5932)
# current relative error is:  tensor(0.9611)
# current epoch is:  900
# current loss is:  tensor(-0.9364)
# current relative error is:  tensor(0.9418)
# current epoch is:  950
# current loss is:  tensor(-1.7569)
# current relative error is:  tensor(0.8956)
# current epoch is:  1000
# current loss is:  tensor(-3.0366)
# current relative error is:  tensor(0.8245)
# current epoch is:  1050
# current loss is:  tensor(-4.1279)
# current relative error is:  tensor(0.7504)
# current epoch is:  1100
# current loss is:  tensor(-5.0374)
# current relative error is:  tensor(0.7052)
# current epoch is:  1150
# current loss is:  tensor(-4.8378)
# current relative error is:  tensor(0.7023)
# current epoch is:  1200
# current loss is:  tensor(-4.6347)
# current relative error is:  tensor(0.6961)
# current epoch is:  1250
# current loss is:  tensor(-5.0678)
# current relative error is:  tensor(0.6966)
# current epoch is:  1300
# current loss is:  tensor(-4.7522)
# current relative error is:  tensor(0.6883)
# current epoch is:  1350
# current loss is:  tensor(-5.0119)
# current relative error is:  tensor(0.6867)
# current epoch is:  1400
# current loss is:  tensor(-5.4124)
# current relative error is:  tensor(0.6915)
# current epoch is:  1450
# current loss is:  tensor(-5.1855)
# current relative error is:  tensor(0.6949)
# current epoch is:  1500
# current loss is:  tensor(-4.9240)
# current relative error is:  tensor(0.6938)
# current epoch is:  1550
# current loss is:  tensor(-5.2195)
# current relative error is:  tensor(0.6989)
# current epoch is:  1600
# current loss is:  tensor(-4.7083)
# current relative error is:  tensor(0.6968)
# current epoch is:  1650
# current loss is:  tensor(-5.1284)
# current relative error is:  tensor(0.6967)
# current epoch is:  1700
# current loss is:  tensor(-5.1529)
# current relative error is:  tensor(0.6871)
# current epoch is:  1750
# current loss is:  tensor(-4.9283)
# current relative error is:  tensor(0.6985)
# current epoch is:  1800
# current loss is:  tensor(-4.9860)
# current relative error is:  tensor(0.6921)
# current epoch is:  1850
# current loss is:  tensor(-5.4595)
# current relative error is:  tensor(0.6990)
# current epoch is:  1900
# current loss is:  tensor(-5.0404)
# current relative error is:  tensor(0.7046)
# current epoch is:  1950
# current loss is:  tensor(-4.9411)
# current relative error is:  tensor(0.6853)
# current epoch is:  2000
# current loss is:  tensor(-5.0299)
# current relative error is:  tensor(0.6984)
# current epoch is:  2050
# current loss is:  tensor(-4.8624)
# current relative error is:  tensor(0.6959)
# current epoch is:  2100
# current loss is:  tensor(-5.1646)
# current relative error is:  tensor(0.6996)
# current epoch is:  2150
# current loss is:  tensor(-4.8951)
# current relative error is:  tensor(0.6999)
# current epoch is:  2200
# current loss is:  tensor(-5.2845)
# current relative error is:  tensor(0.6991)
# current epoch is:  2250
# current loss is:  tensor(-4.9003)
# current relative error is:  tensor(0.7050)
# current epoch is:  2300
# current loss is:  tensor(-5.1490)
# current relative error is:  tensor(0.6996)
# current epoch is:  2350
# current loss is:  tensor(-5.0308)
# current relative error is:  tensor(0.7047)
# current epoch is:  2400
# current loss is:  tensor(-5.1348)
# current relative error is:  tensor(0.7083)
# current epoch is:  2450
# current loss is:  tensor(-5.1152)
# current relative error is:  tensor(0.7114)
# current epoch is:  2500
# current loss is:  tensor(-5.4512)
# current relative error is:  tensor(0.6969)
# current epoch is:  2550
# current loss is:  tensor(-5.2425)
# current relative error is:  tensor(0.6854)
# current epoch is:  2600
# current loss is:  tensor(-5.0854)
# current relative error is:  tensor(0.6925)
# current epoch is:  2650
# current loss is:  tensor(-5.0453)
# current relative error is:  tensor(0.7043)
# current epoch is:  2700
# current loss is:  tensor(-4.9866)
# current relative error is:  tensor(0.6957)
# current epoch is:  2750
# current loss is:  tensor(-4.5797)
# current relative error is:  tensor(0.7020)
# current epoch is:  2800
# current loss is:  tensor(-5.2851)
# current relative error is:  tensor(0.6919)
# current epoch is:  2850
# current loss is:  tensor(-5.3548)
# current relative error is:  tensor(0.6909)
# current epoch is:  2900
# current loss is:  tensor(-4.5725)
# current relative error is:  tensor(0.6878)
# current epoch is:  2950
# current loss is:  tensor(-5.2707)
# current relative error is:  tensor(0.6949)
# current epoch is:  3000
# current loss is:  tensor(-4.8799)
# current relative error is:  tensor(0.6967)
# current epoch is:  3050
# current loss is:  tensor(-5.1347)
# current relative error is:  tensor(0.7072)
# current epoch is:  3100
# current loss is:  tensor(-4.9056)
# current relative error is:  tensor(0.6889)
# current epoch is:  3150
# current loss is:  tensor(-4.7941)
# current relative error is:  tensor(0.6983)
# current epoch is:  3200
# current loss is:  tensor(-4.8187)
# current relative error is:  tensor(0.6869)
# current epoch is:  3250
# current loss is:  tensor(-4.7132)
# current relative error is:  tensor(0.6901)
# current epoch is:  3300
# current loss is:  tensor(-5.4847)
# current relative error is:  tensor(0.6946)
# current epoch is:  3350
# current loss is:  tensor(-4.9464)
# current relative error is:  tensor(0.6794)
# current epoch is:  3400
# current loss is:  tensor(-4.9921)
# current relative error is:  tensor(0.6780)
# current epoch is:  3450
# current loss is:  tensor(-5.1329)
# current relative error is:  tensor(0.6622)
# current epoch is:  3500
# current loss is:  tensor(-6.0276)
# current relative error is:  tensor(0.6245)
# current epoch is:  3550
# current loss is:  tensor(-6.5518)
# current relative error is:  tensor(0.5255)
# current epoch is:  3600
# current loss is:  tensor(-7.9326)
# current relative error is:  tensor(0.3445)
# current epoch is:  3650
# current loss is:  tensor(-8.8776)
# current relative error is:  tensor(0.2332)
# current epoch is:  3700
# current loss is:  tensor(-9.1876)
# current relative error is:  tensor(0.1942)
# current epoch is:  3750
# current loss is:  tensor(-8.9517)
# current relative error is:  tensor(0.1512)
# current epoch is:  3800
# current loss is:  tensor(-9.7681)
# current relative error is:  tensor(0.1285)
# current epoch is:  3850
# current loss is:  tensor(-9.0403)
# current relative error is:  tensor(0.1154)
# current epoch is:  3900
# current loss is:  tensor(-9.6225)
# current relative error is:  tensor(0.0964)
# current epoch is:  3950
# current loss is:  tensor(-9.7119)
# current relative error is:  tensor(0.0858)
# current epoch is:  4000
# current loss is:  tensor(-9.8233)
# current relative error is:  tensor(0.0835)
# current epoch is:  4050
# current loss is:  tensor(-9.5292)
# current relative error is:  tensor(0.0766)
# current epoch is:  4100
# current loss is:  tensor(-9.6930)
# current relative error is:  tensor(0.0728)
# current epoch is:  4150
# current loss is:  tensor(-9.8820)
# current relative error is:  tensor(0.0660)
# current epoch is:  4200
# current loss is:  tensor(-9.7434)
# current relative error is:  tensor(0.0622)
# current epoch is:  4250
# current loss is:  tensor(-9.7442)
# current relative error is:  tensor(0.0605)
# current epoch is:  4300
# current loss is:  tensor(-9.9111)
# current relative error is:  tensor(0.0581)
# current epoch is:  4350
# current loss is:  tensor(-9.9935)
# current relative error is:  tensor(0.0570)
# current epoch is:  4400
# current loss is:  tensor(-9.7802)
# current relative error is:  tensor(0.0524)
# current epoch is:  4450
# current loss is:  tensor(-10.4155)
# current relative error is:  tensor(0.0509)
# current epoch is:  4500
# current loss is:  tensor(-9.9908)
# current relative error is:  tensor(0.0452)
# current epoch is:  4550
# current loss is:  tensor(-9.2371)
# current relative error is:  tensor(0.0435)
# current epoch is:  4600
# current loss is:  tensor(-9.8550)
# current relative error is:  tensor(0.0429)
# current epoch is:  4650
# current loss is:  tensor(-10.4678)
# current relative error is:  tensor(0.0394)
# current epoch is:  4700
# current loss is:  tensor(-9.3825)
# current relative error is:  tensor(0.0386)
# current epoch is:  4750
# current loss is:  tensor(-9.7380)
# current relative error is:  tensor(0.0386)
# current epoch is:  4800
# current loss is:  tensor(-9.5508)
# current relative error is:  tensor(0.0353)
# current epoch is:  4850
# current loss is:  tensor(-9.8967)
# current relative error is:  tensor(0.0360)
# current epoch is:  4900
# current loss is:  tensor(-10.2047)
# current relative error is:  tensor(0.0328)
# current epoch is:  4950
# current loss is:  tensor(-9.5529)
# current relative error is:  tensor(0.0340)
# current epoch is:  5000
# current loss is:  tensor(-9.8479)
# current relative error is:  tensor(0.0309)
# current epoch is:  5050
# current loss is:  tensor(-9.6776)
# current relative error is:  tensor(0.0316)
# current epoch is:  5100
# current loss is:  tensor(-10.3602)
# current relative error is:  tensor(0.0295)
# current epoch is:  5150
# current loss is:  tensor(-9.6055)
# current relative error is:  tensor(0.0272)
# current epoch is:  5200
# current loss is:  tensor(-9.7211)
# current relative error is:  tensor(0.0258)
# current epoch is:  5250
# current loss is:  tensor(-8.9971)
# current relative error is:  tensor(0.0243)
# current epoch is:  5300
# current loss is:  tensor(-9.8336)
# current relative error is:  tensor(0.0243)
# current epoch is:  5350
# current loss is:  tensor(-10.0301)
# current relative error is:  tensor(0.0243)
# current epoch is:  5400
# current loss is:  tensor(-9.9989)
# current relative error is:  tensor(0.0249)
# current epoch is:  5450
# current loss is:  tensor(-10.4183)
# current relative error is:  tensor(0.0227)
# current epoch is:  5500
# current loss is:  tensor(-9.4887)
# current relative error is:  tensor(0.0238)
# current epoch is:  5550
# current loss is:  tensor(-9.3664)
# current relative error is:  tensor(0.0317)
# current epoch is:  5600
# current loss is:  tensor(-9.5525)
# current relative error is:  tensor(0.0213)
# current epoch is:  5650
# current loss is:  tensor(-10.2894)
# current relative error is:  tensor(0.0196)
# current epoch is:  5700
# current loss is:  tensor(-9.9743)
# current relative error is:  tensor(0.0205)
# current epoch is:  5750
# current loss is:  tensor(-9.6134)
# current relative error is:  tensor(0.0219)
# current epoch is:  5800
# current loss is:  tensor(-9.5050)
# current relative error is:  tensor(0.0187)
# current epoch is:  5850
# current loss is:  tensor(-10.0914)
# current relative error is:  tensor(0.0187)
# current epoch is:  5900
# current loss is:  tensor(-9.8367)
# current relative error is:  tensor(0.0196)
# current epoch is:  5950
# current loss is:  tensor(-9.1037)
# current relative error is:  tensor(0.0169)
# current epoch is:  6000
# current loss is:  tensor(-9.8124)
# current relative error is:  tensor(0.0213)
# current epoch is:  6050
# current loss is:  tensor(-10.1817)
# current relative error is:  tensor(0.0180)
# current epoch is:  6100
# current loss is:  tensor(-9.4864)
# current relative error is:  tensor(0.0145)
# current epoch is:  6150
# current loss is:  tensor(-9.7293)
# current relative error is:  tensor(0.0168)
# current epoch is:  6200
# current loss is:  tensor(-9.8196)
# current relative error is:  tensor(0.0167)
# current epoch is:  6250
# current loss is:  tensor(-9.8066)
# current relative error is:  tensor(0.0198)
# current epoch is:  6300
# current loss is:  tensor(-9.7247)
# current relative error is:  tensor(0.0136)
# current epoch is:  6350
# current loss is:  tensor(-9.8372)
# current relative error is:  tensor(0.0143)
# current epoch is:  6400
# current loss is:  tensor(-10.0635)
# current relative error is:  tensor(0.0177)
# current epoch is:  6450
# current loss is:  tensor(-10.9513)
# current relative error is:  tensor(0.0145)
# current epoch is:  6500
# current loss is:  tensor(-10.5911)
# current relative error is:  tensor(0.0222)
# current epoch is:  6550
# current loss is:  tensor(-10.0660)
# current relative error is:  tensor(0.0166)
# current epoch is:  6600
# current loss is:  tensor(-9.5256)
# current relative error is:  tensor(0.0134)
# current epoch is:  6650
# current loss is:  tensor(-9.3248)
# current relative error is:  tensor(0.0228)
# current epoch is:  6700
# current loss is:  tensor(-10.3150)
# current relative error is:  tensor(0.0147)
# current epoch is:  6750
# current loss is:  tensor(-9.2065)
# current relative error is:  tensor(0.0193)
# current epoch is:  6800
# current loss is:  tensor(-9.6772)
# current relative error is:  tensor(0.0245)
# current epoch is:  6850
# current loss is:  tensor(-9.3478)
# current relative error is:  tensor(0.0149)
# current epoch is:  6900
# current loss is:  tensor(-9.4048)
# current relative error is:  tensor(0.0127)
# current epoch is:  6950
# current loss is:  tensor(-9.7734)
# current relative error is:  tensor(0.0132)
# current epoch is:  7000
# current loss is:  tensor(-10.2096)
# current relative error is:  tensor(0.0122)
# current epoch is:  7050
# current loss is:  tensor(-10.0564)
# current relative error is:  tensor(0.0117)
# current epoch is:  7100
# current loss is:  tensor(-10.5128)
# current relative error is:  tensor(0.0110)
# current epoch is:  7150
# current loss is:  tensor(-9.9690)
# current relative error is:  tensor(0.0206)
# current epoch is:  7200
# current loss is:  tensor(-9.4447)
# current relative error is:  tensor(0.0108)
# current epoch is:  7250
# current loss is:  tensor(-9.2296)
# current relative error is:  tensor(0.0166)
# current epoch is:  7300
# current loss is:  tensor(-9.8981)
# current relative error is:  tensor(0.0092)
# current epoch is:  7350
# current loss is:  tensor(-9.9553)
# current relative error is:  tensor(0.0121)
# current epoch is:  7400
# current loss is:  tensor(-10.2724)
# current relative error is:  tensor(0.0083)
# current epoch is:  7450
# current loss is:  tensor(-9.5555)
# current relative error is:  tensor(0.0279)
# current epoch is:  7500
# current loss is:  tensor(-8.8940)
# current relative error is:  tensor(0.0142)
# current epoch is:  7550
# current loss is:  tensor(-9.2837)
# current relative error is:  tensor(0.0170)
# current epoch is:  7600
# current loss is:  tensor(-9.1036)
# current relative error is:  tensor(0.0161)
# current epoch is:  7650
# current loss is:  tensor(-10.1790)
# current relative error is:  tensor(0.0104)
# current epoch is:  7700
# current loss is:  tensor(-10.0736)
# current relative error is:  tensor(0.0154)
# current epoch is:  7750
# current loss is:  tensor(-9.7623)
# current relative error is:  tensor(0.0111)
# current epoch is:  7800
# current loss is:  tensor(-10.8229)
# current relative error is:  tensor(0.0116)
# current epoch is:  7850
# current loss is:  tensor(-9.6321)
# current relative error is:  tensor(0.0104)
# current epoch is:  7900
# current loss is:  tensor(-10.2035)
# current relative error is:  tensor(0.0098)
# current epoch is:  7950
# current loss is:  tensor(-10.3981)
# current relative error is:  tensor(0.0124)
# current epoch is:  8000
# current loss is:  tensor(-9.5772)
# current relative error is:  tensor(0.0130)
# current epoch is:  8050
# current loss is:  tensor(-9.2118)
# current relative error is:  tensor(0.0109)
# current epoch is:  8100
# current loss is:  tensor(-10.1654)
# current relative error is:  tensor(0.0113)
# current epoch is:  8150
# current loss is:  tensor(-9.9539)
# current relative error is:  tensor(0.0086)
# current epoch is:  8200
# current loss is:  tensor(-10.9081)
# current relative error is:  tensor(0.0090)
# current epoch is:  8250
# current loss is:  tensor(-9.4266)
# current relative error is:  tensor(0.0123)
# current epoch is:  8300
# current loss is:  tensor(-9.4523)
# current relative error is:  tensor(0.0152)
# current epoch is:  8350
# current loss is:  tensor(-10.3338)
# current relative error is:  tensor(0.0139)
# current epoch is:  8400
# current loss is:  tensor(-9.2774)
# current relative error is:  tensor(0.0093)
# current epoch is:  8450
# current loss is:  tensor(-10.2367)
# current relative error is:  tensor(0.0108)
# current epoch is:  8500
# current loss is:  tensor(-10.1101)
# current relative error is:  tensor(0.0072)
# current epoch is:  8550
# current loss is:  tensor(-9.5322)
# current relative error is:  tensor(0.0096)
# current epoch is:  8600
# current loss is:  tensor(-9.7183)
# current relative error is:  tensor(0.0169)
# current epoch is:  8650
# current loss is:  tensor(-9.9079)
# current relative error is:  tensor(0.0113)
# current epoch is:  8700
# current loss is:  tensor(-8.9406)
# current relative error is:  tensor(0.0198)
# current epoch is:  8750
# current loss is:  tensor(-9.6527)
# current relative error is:  tensor(0.0138)
# current epoch is:  8800
# current loss is:  tensor(-10.2699)
# current relative error is:  tensor(0.0111)
# current epoch is:  8850
# current loss is:  tensor(-9.9012)
# current relative error is:  tensor(0.0099)
# current epoch is:  8900
# current loss is:  tensor(-9.4602)
# current relative error is:  tensor(0.0096)
# current epoch is:  8950
# current loss is:  tensor(-9.6807)
# current relative error is:  tensor(0.0082)
# current epoch is:  9000
# current loss is:  tensor(-9.3296)
# current relative error is:  tensor(0.0087)
# current epoch is:  9050
# current loss is:  tensor(-9.2201)
# current relative error is:  tensor(0.0125)
# current epoch is:  9100
# current loss is:  tensor(-9.9697)
# current relative error is:  tensor(0.0140)
# current epoch is:  9150
# current loss is:  tensor(-9.7606)
# current relative error is:  tensor(0.0116)
# current epoch is:  9200
# current loss is:  tensor(-9.8664)
# current relative error is:  tensor(0.0183)
# current epoch is:  9250
# current loss is:  tensor(-9.7914)
# current relative error is:  tensor(0.0133)
# current epoch is:  9300
# current loss is:  tensor(-10.4856)
# current relative error is:  tensor(0.0070)
# current epoch is:  9350
# current loss is:  tensor(-10.2730)
# current relative error is:  tensor(0.0182)
# current epoch is:  9400
# current loss is:  tensor(-9.6262)
# current relative error is:  tensor(0.0083)
# current epoch is:  9450
# current loss is:  tensor(-9.7630)
# current relative error is:  tensor(0.0135)
# current epoch is:  9500
# current loss is:  tensor(-9.9540)
# current relative error is:  tensor(0.0166)
# current epoch is:  9550
# current loss is:  tensor(-9.4389)
# current relative error is:  tensor(0.0160)
# current epoch is:  9600
# current loss is:  tensor(-9.5739)
# current relative error is:  tensor(0.0088)
# current epoch is:  9650
# current loss is:  tensor(-9.7732)
# current relative error is:  tensor(0.0116)
# current epoch is:  9700
# current loss is:  tensor(-10.3224)
# current relative error is:  tensor(0.0204)
# current epoch is:  9750
# current loss is:  tensor(-10.7137)
# current relative error is:  tensor(0.0218)
# current epoch is:  9800
# current loss is:  tensor(-10.1355)
# current relative error is:  tensor(0.0120)
# current epoch is:  9850
# current loss is:  tensor(-9.7450)
# current relative error is:  tensor(0.0125)
# current epoch is:  9900
# current loss is:  tensor(-9.8025)
# current relative error is:  tensor(0.0178)
# current epoch is:  9950
# current loss is:  tensor(-9.8268)
# current relative error is:  tensor(0.0078)
# total time is:  929.6760766506195 seconds

# %%
x_test = torch.rand(2, 10)
torch.abs(model(x) - u_ex(x))
# Out:
# tensor([[0.0086],
#         [0.0015],
#         [0.0065],
#         ...,
#         [0.0056],
#         [0.0076],
#         [0.0032]], grad_fn=<AbsBackward>)
