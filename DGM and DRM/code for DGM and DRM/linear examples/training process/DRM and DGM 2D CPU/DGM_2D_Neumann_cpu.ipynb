# %%
import torch
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import torch.nn as nn
from math import *

# %%
torch.set_default_tensor_type('torch.DoubleTensor') # 设置浮点类型为 torch.float64

# %%
# 定义激活函数: swish(x)
def acti(x):
    return x*torch.sigmoid(x)

# %%
# 定义网络结构
class DeepRitzNet(torch.nn.Module):
    def __init__(self, input_width, layer_width):
        super(DeepRitzNet, self).__init__()
        self.linear_in = torch.nn.Linear(input_width, layer_width)
        self.linear1 = torch.nn.Linear(layer_width, layer_width)
        self.linear2 = torch.nn.Linear(layer_width, layer_width)
        self.linear3 = torch.nn.Linear(layer_width, layer_width)
        self.linear4 = torch.nn.Linear(layer_width, layer_width)
        self.linear5 = torch.nn.Linear(layer_width, layer_width)
        self.linear6 = torch.nn.Linear(layer_width, layer_width)
        self.linear_out = torch.nn.Linear(layer_width, 1)

    def forward(self, x):
        y = self.linear_in(x) # fully connect layer
        y = y + acti(self.linear2(acti(self.linear1(y)))) # residual block 1
        y = y + acti(self.linear4(acti(self.linear3(y)))) # residual block 2
        y = y + acti(self.linear6(acti(self.linear5(y)))) # residual block 3
        output = self.linear_out(y) # fully connect layer
        return output

# %%
dimension = 2

# %%
# exact solution
def u_ex(x):  
    x_temp = torch.cos(pi*x)
    u_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return u_x

# %%
def f(x):
    x_temp = torch.cos(pi*x)
    f_x = 2*pi**2*(x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return f_x

# %%
# Deep Ritz Method
def DRM(x):
    u_hat = model(x)
    # v = torch.ones(u_hat.shape)
    # ux = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = v, create_graph = True)[0]
    
    uxx = torch.zeros(x.size()[0], dimension)
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension)
        dx[:, i] = torch.ones(x.size()[0])
        uxx[:, i] = (model(x+step_size*dx) - 2*model(x) + model(x-step_size*dx))[:,0]/step_size**2
    laplace_u = (torch.sum(uxx, dim = 1)).reshape([x.size()[0], 1]) # dim = 1 按行求和
    f_temp = f(x)
    part_1 = torch.sum((-laplace_u + pi**2*u_hat - f_temp)**2)/x.size()[0]
    
    Nb = 100
    xb1 = torch.rand(Nb, dimension)
    xb1[:, 0] = torch.zeros(Nb)
    xb2 = torch.rand(Nb, dimension)
    xb2[:, 0] = torch.ones(Nb)
    xb3 = torch.rand(Nb, dimension)
    xb3[:, 1] = torch.zeros(Nb)
    xb4 = torch.rand(Nb, dimension)
    xb4[:, 1] = torch.ones(Nb)
    dx1 = torch.zeros(xb1.size()[0], dimension)
    dx1[:, 0] = torch.ones(xb1.size()[0])
    uxb1 = ((model(xb1+step_size*dx1) - model(xb1-step_size*dx1))/step_size/2 * (1.0) - 0)**2
    uxb2 = ((model(xb2+step_size*dx1) - model(xb2-step_size*dx1))/step_size/2 * (-1.0) - 0)**2
    dx2 = torch.zeros(xb1.size()[0], dimension)
    dx2[:, 1] = torch.ones(xb1.size()[0])
    uxb3 = ((model(xb3+step_size*dx2) - model(xb3-step_size*dx2))/step_size/2 * (1.0) - 0)**2
    uxb4 = ((model(xb4+step_size*dx2) - model(xb4-step_size*dx2))/step_size/2 * (-1.0) - 0)**2
    part_2 = torch.sum((uxb1 + uxb2 + uxb3 + uxb4)[:,0])/xb1.size()[0]
    lambda1 = 100.0
    return part_1 + lambda1 * part_2 / 4

# %%
Data_size = 2000
def Gendata():
    x = torch.rand(Data_size, dimension)
    return x

# %%
# 正态分布初始化参数
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = DeepRitzNet(dimension, 4)
model = initparam(model, 0.5)

# %%
import torch.optim as optim
import torch.nn as nn
import time

# %%
def relative_error():
    x = Gendata()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact )**2))/torch.sqrt(torch.sum((exact )**2))
    return value

# %%
traintime = 10000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = Gendata()
    x.requires_grad = True
    losses = DRM(x)
    losses.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", losses.detach())
        print("current relative error is: ", error.detach())
        np.save("DGM_relative_error_2D_Neumann.npy", error_save)
np.save("DGM_relative_error_2D_Neumann.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(435.8747)
# current relative error is:  tensor(1.0965)
# current epoch is:  50
# current loss is:  tensor(397.5710)
# current relative error is:  tensor(1.0511)
# current epoch is:  100
# current loss is:  tensor(373.5429)
# current relative error is:  tensor(0.9834)
# current epoch is:  150
# current loss is:  tensor(358.8594)
# current relative error is:  tensor(0.9090)
# current epoch is:  200
# current loss is:  tensor(326.2984)
# current relative error is:  tensor(0.7631)
# current epoch is:  250
# current loss is:  tensor(189.9325)
# current relative error is:  tensor(0.5148)
# current epoch is:  300
# current loss is:  tensor(170.6434)
# current relative error is:  tensor(0.4393)
# current epoch is:  350
# current loss is:  tensor(138.8032)
# current relative error is:  tensor(0.3891)
# current epoch is:  400
# current loss is:  tensor(56.1708)
# current relative error is:  tensor(0.2342)
# current epoch is:  450
# current loss is:  tensor(35.6711)
# current relative error is:  tensor(0.1365)
# current epoch is:  500
# current loss is:  tensor(28.9897)
# current relative error is:  tensor(0.1060)
# current epoch is:  550
# current loss is:  tensor(26.4863)
# current relative error is:  tensor(0.0900)
# current epoch is:  600
# current loss is:  tensor(21.5744)
# current relative error is:  tensor(0.0802)
# current epoch is:  650
# current loss is:  tensor(20.6265)
# current relative error is:  tensor(0.0681)
# current epoch is:  700
# current loss is:  tensor(16.9381)
# current relative error is:  tensor(0.0586)
# current epoch is:  750
# current loss is:  tensor(14.0638)
# current relative error is:  tensor(0.0522)
# current epoch is:  800
# current loss is:  tensor(12.6050)
# current relative error is:  tensor(0.0424)
# current epoch is:  850
# current loss is:  tensor(10.7287)
# current relative error is:  tensor(0.0399)
# current epoch is:  900
# current loss is:  tensor(8.4982)
# current relative error is:  tensor(0.0338)
# current epoch is:  950
# current loss is:  tensor(7.5878)
# current relative error is:  tensor(0.0289)
# current epoch is:  1000
# current loss is:  tensor(6.1006)
# current relative error is:  tensor(0.0255)
# current epoch is:  1050
# current loss is:  tensor(5.4476)
# current relative error is:  tensor(0.0215)
# current epoch is:  1100
# current loss is:  tensor(4.8870)
# current relative error is:  tensor(0.0182)
# current epoch is:  1150
# current loss is:  tensor(3.8805)
# current relative error is:  tensor(0.0179)
# current epoch is:  1200
# current loss is:  tensor(3.5536)
# current relative error is:  tensor(0.0143)
# current epoch is:  1250
# current loss is:  tensor(2.7126)
# current relative error is:  tensor(0.0151)
# current epoch is:  1300
# current loss is:  tensor(2.3567)
# current relative error is:  tensor(0.0119)
# current epoch is:  1350
# current loss is:  tensor(1.8962)
# current relative error is:  tensor(0.0104)
# current epoch is:  1400
# current loss is:  tensor(1.8606)
# current relative error is:  tensor(0.0089)
# current epoch is:  1450
# current loss is:  tensor(1.3856)
# current relative error is:  tensor(0.0083)
# current epoch is:  1500
# current loss is:  tensor(1.2783)
# current relative error is:  tensor(0.0084)
# current epoch is:  1550
# current loss is:  tensor(1.2054)
# current relative error is:  tensor(0.0078)
# current epoch is:  1600
# current loss is:  tensor(1.0546)
# current relative error is:  tensor(0.0072)
# current epoch is:  1650
# current loss is:  tensor(0.9926)
# current relative error is:  tensor(0.0070)
# current epoch is:  1700
# current loss is:  tensor(0.9523)
# current relative error is:  tensor(0.0059)
# current epoch is:  1750
# current loss is:  tensor(0.8691)
# current relative error is:  tensor(0.0068)
# current epoch is:  1800
# current loss is:  tensor(0.8701)
# current relative error is:  tensor(0.0058)
# current epoch is:  1850
# current loss is:  tensor(0.7031)
# current relative error is:  tensor(0.0063)
# current epoch is:  1900
# current loss is:  tensor(0.6559)
# current relative error is:  tensor(0.0064)
# current epoch is:  1950
# current loss is:  tensor(0.7167)
# current relative error is:  tensor(0.0053)
# current epoch is:  2000
# current loss is:  tensor(0.6358)
# current relative error is:  tensor(0.0047)
# current epoch is:  2050
# current loss is:  tensor(0.6307)
# current relative error is:  tensor(0.0055)
# current epoch is:  2100
# current loss is:  tensor(0.5893)
# current relative error is:  tensor(0.0053)
# current epoch is:  2150
# current loss is:  tensor(0.5529)
# current relative error is:  tensor(0.0045)
# current epoch is:  2200
# current loss is:  tensor(0.4815)
# current relative error is:  tensor(0.0053)
# current epoch is:  2250
# current loss is:  tensor(0.5226)
# current relative error is:  tensor(0.0057)
# current relative error is:  tensor(0.0011)
# current epoch is:  5450
# current loss is:  tensor(0.0450)
# current relative error is:  tensor(0.0012)
# current epoch is:  5500
# current loss is:  tensor(0.0451)
# current relative error is:  tensor(0.0018)
# current epoch is:  5550
# current loss is:  tensor(0.0429)
# current relative error is:  tensor(0.0018)
# current epoch is:  5600
# current loss is:  tensor(0.0425)
# current relative error is:  tensor(0.0033)
# current epoch is:  5650
# current loss is:  tensor(0.0413)
# current relative error is:  tensor(0.0014)
# current epoch is:  5700
# current loss is:  tensor(0.0382)
# current relative error is:  tensor(0.0017)
# current epoch is:  5750
# current loss is:  tensor(0.0406)
# current relative error is:  tensor(0.0011)
# current epoch is:  5800
# current loss is:  tensor(0.0406)
# current relative error is:  tensor(0.0013)
# current epoch is:  5850
# current loss is:  tensor(0.0355)
# current relative error is:  tensor(0.0010)
# current epoch is:  5900
# current loss is:  tensor(0.0352)
# current relative error is:  tensor(0.0013)
# current epoch is:  5950
# current loss is:  tensor(0.0387)
# current relative error is:  tensor(0.0011)
# current epoch is:  6000
# current loss is:  tensor(0.0316)
# current relative error is:  tensor(0.0012)
# current epoch is:  6050
# current loss is:  tensor(0.0295)
# current relative error is:  tensor(0.0019)
# current epoch is:  6100
# current loss is:  tensor(0.0308)
# current relative error is:  tensor(0.0017)
# current epoch is:  6150
# current loss is:  tensor(0.0274)
# current relative error is:  tensor(0.0027)
# current epoch is:  6200
# current loss is:  tensor(0.0284)
# current relative error is:  tensor(0.0014)
# current epoch is:  6250
# current loss is:  tensor(0.0276)
# current relative error is:  tensor(0.0032)
# current epoch is:  6300
# current loss is:  tensor(0.0285)
# current relative error is:  tensor(0.0011)
# current epoch is:  6350
# current loss is:  tensor(0.0253)
# current relative error is:  tensor(0.0013)
# current epoch is:  6400
# current loss is:  tensor(0.0244)
# current relative error is:  tensor(0.0011)
# current epoch is:  6450
# current loss is:  tensor(0.0249)
# current relative error is:  tensor(0.0010)
# current epoch is:  6500
# current loss is:  tensor(0.0256)
# current relative error is:  tensor(0.0009)
# current epoch is:  6550
# current loss is:  tensor(0.0248)
# current relative error is:  tensor(0.0022)
# current epoch is:  6600
# current loss is:  tensor(0.0223)
# current relative error is:  tensor(0.0013)
# current epoch is:  6650
# current loss is:  tensor(0.0225)
# current relative error is:  tensor(0.0017)
# current epoch is:  6700
# current loss is:  tensor(0.0240)
# current relative error is:  tensor(0.0012)
# current epoch is:  6750
# current loss is:  tensor(0.0227)
# current relative error is:  tensor(0.0008)
# current epoch is:  6800
# current loss is:  tensor(0.0200)
# current relative error is:  tensor(0.0009)
# current epoch is:  6850
# current loss is:  tensor(0.0208)
# current relative error is:  tensor(0.0028)
# current epoch is:  6900
# current loss is:  tensor(0.0222)
# current relative error is:  tensor(0.0010)
# current epoch is:  6950
# current loss is:  tensor(0.0175)
# current relative error is:  tensor(0.0008)
# current epoch is:  7000
# current loss is:  tensor(0.0169)
# current relative error is:  tensor(0.0010)
# current epoch is:  7050
# current loss is:  tensor(0.0171)
# current relative error is:  tensor(0.0008)
# current epoch is:  7100
# current loss is:  tensor(0.0181)
# current relative error is:  tensor(0.0007)
# current epoch is:  7150
# current loss is:  tensor(0.0175)
# current relative error is:  tensor(0.0023)
# current epoch is:  7200
# current loss is:  tensor(0.0182)
# current relative error is:  tensor(0.0016)
# current epoch is:  7250
# current loss is:  tensor(0.0165)
# current relative error is:  tensor(0.0019)
# current epoch is:  7300
# current loss is:  tensor(0.0154)
# current relative error is:  tensor(0.0014)
# current epoch is:  7350
# current loss is:  tensor(0.0156)
# current relative error is:  tensor(0.0010)
# current epoch is:  7400
# current loss is:  tensor(0.0145)
# current relative error is:  tensor(0.0015)
# current epoch is:  7450
# current loss is:  tensor(0.0155)
# current relative error is:  tensor(0.0021)
# current epoch is:  7500
# current loss is:  tensor(0.0134)
# current relative error is:  tensor(0.0010)
# current epoch is:  7550
# current loss is:  tensor(0.0164)
# current relative error is:  tensor(0.0010)
# current epoch is:  7600
# current loss is:  tensor(0.0132)
# current relative error is:  tensor(0.0010)
# current epoch is:  7650
# current loss is:  tensor(0.0149)
# current relative error is:  tensor(0.0032)
# current epoch is:  7700
# current loss is:  tensor(0.0149)
# current relative error is:  tensor(0.0022)
# current epoch is:  7750
# current loss is:  tensor(0.0137)
# current relative error is:  tensor(0.0030)
# current epoch is:  7800
# current loss is:  tensor(0.0128)
# current relative error is:  tensor(0.0009)
# current epoch is:  7850
# current loss is:  tensor(0.0125)
# current relative error is:  tensor(0.0023)
# current epoch is:  7900
# current loss is:  tensor(0.0115)
# current relative error is:  tensor(0.0012)
# current epoch is:  7950
# current loss is:  tensor(0.0140)
# current relative error is:  tensor(0.0016)
# current epoch is:  8000
# current loss is:  tensor(0.0108)
# current relative error is:  tensor(0.0007)
# current epoch is:  8050
# current loss is:  tensor(0.0129)
# current relative error is:  tensor(0.0008)
# current epoch is:  8100
# current loss is:  tensor(0.0101)
# current relative error is:  tensor(0.0008)
# current epoch is:  8150
# current loss is:  tensor(0.0097)
# current relative error is:  tensor(0.0007)
# current epoch is:  8200
# current loss is:  tensor(0.0103)
# current relative error is:  tensor(0.0007)
# current epoch is:  8250
# current loss is:  tensor(0.0107)
# current relative error is:  tensor(0.0011)
# current epoch is:  8300
# current loss is:  tensor(0.0103)
# current relative error is:  tensor(0.0018)
# current epoch is:  8350
# current loss is:  tensor(0.0095)
# current relative error is:  tensor(0.0007)
# current epoch is:  8400
# current loss is:  tensor(0.0093)
# current relative error is:  tensor(0.0013)
# current epoch is:  8450
# current loss is:  tensor(0.0139)
# current relative error is:  tensor(0.0013)
# current epoch is:  8500
# current loss is:  tensor(0.0097)
# current relative error is:  tensor(0.0013)
# current epoch is:  8550
# current loss is:  tensor(0.0113)
# current relative error is:  tensor(0.0014)
# current epoch is:  8600
# current loss is:  tensor(0.0106)
# current relative error is:  tensor(0.0009)
# current epoch is:  8650
# current loss is:  tensor(0.0083)
# current relative error is:  tensor(0.0014)
# current epoch is:  8700
# current loss is:  tensor(0.0089)
# current relative error is:  tensor(0.0006)
# current epoch is:  8750
# current loss is:  tensor(0.0082)
# current relative error is:  tensor(0.0014)
# current epoch is:  8800
# current loss is:  tensor(0.0094)
# current relative error is:  tensor(0.0017)
# current epoch is:  8850
# current loss is:  tensor(0.0085)
# current relative error is:  tensor(0.0005)
# current epoch is:  8900
# current loss is:  tensor(0.0089)
# current relative error is:  tensor(0.0021)
# current epoch is:  8950
# current loss is:  tensor(0.0081)
# current relative error is:  tensor(0.0013)
# current epoch is:  9000
# current loss is:  tensor(0.0083)
# current relative error is:  tensor(0.0013)
# current epoch is:  9050
# current loss is:  tensor(0.0111)
# current relative error is:  tensor(0.0018)
# current epoch is:  9100
# current loss is:  tensor(0.0073)
# current relative error is:  tensor(0.0009)
# current epoch is:  9150
# current loss is:  tensor(0.0083)
# current relative error is:  tensor(0.0019)
# current epoch is:  9200
# current loss is:  tensor(0.0077)
# current relative error is:  tensor(0.0008)
# current epoch is:  9250
# current loss is:  tensor(0.0077)
# current relative error is:  tensor(0.0023)
# current epoch is:  9300
# current loss is:  tensor(0.0080)
# current relative error is:  tensor(0.0008)
# current epoch is:  9350
# current loss is:  tensor(0.0102)
# current relative error is:  tensor(0.0013)
# current epoch is:  9400
# current loss is:  tensor(0.0064)
# current relative error is:  tensor(0.0005)
# current epoch is:  9450
# current loss is:  tensor(0.0086)
# current relative error is:  tensor(0.0021)
# current epoch is:  9500
# current loss is:  tensor(0.0070)
# current relative error is:  tensor(0.0013)
# current epoch is:  9550
# current loss is:  tensor(0.0072)
# current relative error is:  tensor(0.0011)
# current epoch is:  9600
# current loss is:  tensor(0.0069)
# current relative error is:  tensor(0.0008)
# current epoch is:  9650
# current loss is:  tensor(0.0067)
# current relative error is:  tensor(0.0006)
# current epoch is:  9700
# current loss is:  tensor(0.0092)
# current relative error is:  tensor(0.0031)
# current epoch is:  9750
# current loss is:  tensor(0.0062)
# current relative error is:  tensor(0.0005)
# current epoch is:  9800
# current loss is:  tensor(0.0059)
# current relative error is:  tensor(0.0007)
# current epoch is:  9850
# current loss is:  tensor(0.0068)
# current relative error is:  tensor(0.0008)
# current epoch is:  9900
# current loss is:  tensor(0.0064)
# current relative error is:  tensor(0.0011)
# current epoch is:  9950
# current loss is:  tensor(0.0057)
# current relative error is:  tensor(0.0020)
# total time is:  1122.4178318977356 seconds

# %%
x_test = torch.rand(2, 10)
torch.abs(model(x) - u_ex(x))
# Out:
# tensor([[0.0024],
#         [0.0023],
#         [0.0022],
#         ...,
#         [0.0025],
#         [0.0027],
#         [0.0021]], grad_fn=<AbsBackward>)
