# %%
import torch
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import torch.nn as nn
from math import *

# %%
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor') # 设置浮点类型为 torch.float64

# %%
# 定义激活函数: swish(x)
def acti(x):
    return x*torch.sigmoid(x)

# %%
# 定义网络结构
class DeepRitzNet(torch.nn.Module):
    def __init__(self, input_width, layer_width):
        super(DeepRitzNet, self).__init__()
        self.linear_in = torch.nn.Linear(input_width, layer_width)
        self.linear1 = torch.nn.Linear(layer_width, layer_width)
        self.linear2 = torch.nn.Linear(layer_width, layer_width)
        self.linear3 = torch.nn.Linear(layer_width, layer_width)
        self.linear4 = torch.nn.Linear(layer_width, layer_width)
        self.linear5 = torch.nn.Linear(layer_width, layer_width)
        self.linear6 = torch.nn.Linear(layer_width, layer_width)
        self.linear_out = torch.nn.Linear(layer_width, 1)

    def forward(self, x):
        y = self.linear_in(x) # fully connect layer
        y = y + acti(self.linear2(acti(self.linear1(y)))) # residual block 1
        y = y + acti(self.linear4(acti(self.linear3(y)))) # residual block 2
        y = y + acti(self.linear6(acti(self.linear5(y)))) # residual block 3
        output = self.linear_out(y) # fully connect layer
        return output

# %%
dimension = 16

# %%
# exact solution
def u_ex(x):  
    x_temp = torch.cos(pi*x)
    u_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return u_x

# %%
def f(x):
    x_temp = torch.cos(pi*x)
    f_x = 2*pi**2*(x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return f_x

# %%
def DRM(x):
    u_hat = model(x)
    ux = torch.zeros(x.size()[0], dimension).cuda()  
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension).cuda()  
        dx[:, i] = torch.ones(x.size()[0])
        ux[:, i] = (model(x+step_size*dx) - model(x-step_size*dx))[:,0]/step_size/2
    uxsq = (torch.sum(ux**2, dim = 1)).reshape([x.size()[0], 1]) # dim = 1 按行求和
    f_temp = f(x)
    part_1 = torch.sum(0.5 * uxsq + 0.5*pi**2*u_hat**2 - f_temp*u_hat)/x.size()[0]
     
    Nb = 100
    xa1 = torch.rand(Nb, dimension).cuda()  
    xa1[:, 0] = torch.zeros(Nb)
    xa2 = torch.rand(Nb, dimension).cuda()  
    xa2[:, 0] = torch.ones(Nb)
    xb1 = torch.rand(Nb, dimension).cuda() 
    xb1[:, 1] = torch.zeros(Nb)
    xb2 = torch.rand(Nb, dimension).cuda() 
    xb2[:, 1] = torch.ones(Nb)
    xc1 = torch.rand(Nb, dimension).cuda() 
    xc1[:, 2] = torch.zeros(Nb)
    xc2 = torch.rand(Nb, dimension).cuda() 
    xc2[:, 2] = torch.ones(Nb)
    xd1 = torch.rand(Nb, dimension).cuda() 
    xd1[:, 3] = torch.zeros(Nb)
    xd2 = torch.rand(Nb, dimension).cuda() 
    xd2[:, 3] = torch.ones(Nb)
    xe1 = torch.rand(Nb, dimension).cuda()  
    xe1[:, 4] = torch.zeros(Nb)
    xe2 = torch.rand(Nb, dimension).cuda()  
    xe2[:, 4] = torch.ones(Nb)
    xf1 = torch.rand(Nb, dimension).cuda() 
    xf1[:, 5] = torch.zeros(Nb)
    xf2 = torch.rand(Nb, dimension).cuda() 
    xf2[:, 5] = torch.ones(Nb)
    xg1 = torch.rand(Nb, dimension).cuda() 
    xg1[:, 6] = torch.zeros(Nb)
    xg2 = torch.rand(Nb, dimension).cuda() 
    xg2[:, 6] = torch.ones(Nb)
    xh1 = torch.rand(Nb, dimension).cuda() 
    xh1[:, 7] = torch.zeros(Nb)
    xh2 = torch.rand(Nb, dimension).cuda() 
    xh2[:, 7] = torch.ones(Nb)
    xi1 = torch.rand(Nb, dimension).cuda()  
    xi1[:, 8] = torch.zeros(Nb)
    xi2 = torch.rand(Nb, dimension).cuda()  
    xi2[:, 8] = torch.ones(Nb)
    xj1 = torch.rand(Nb, dimension).cuda() 
    xj1[:, 9] = torch.zeros(Nb)
    xj2 = torch.rand(Nb, dimension).cuda() 
    xj2[:, 9] = torch.ones(Nb)
    xk1 = torch.rand(Nb, dimension).cuda() 
    xk1[:, 10] = torch.zeros(Nb)
    xk2 = torch.rand(Nb, dimension).cuda() 
    xk2[:, 10] = torch.ones(Nb)
    xl1 = torch.rand(Nb, dimension).cuda() 
    xl1[:, 11] = torch.zeros(Nb)
    xl2 = torch.rand(Nb, dimension).cuda() 
    xl2[:, 11] = torch.ones(Nb)
    xm1 = torch.rand(Nb, dimension).cuda()  
    xm1[:, 12] = torch.zeros(Nb)
    xm2 = torch.rand(Nb, dimension).cuda()  
    xm2[:, 12] = torch.ones(Nb)
    xn1 = torch.rand(Nb, dimension).cuda() 
    xn1[:, 13] = torch.zeros(Nb)
    xn2 = torch.rand(Nb, dimension).cuda() 
    xn2[:, 13] = torch.ones(Nb)
    xo1 = torch.rand(Nb, dimension).cuda() 
    xo1[:, 14] = torch.zeros(Nb)
    xo2 = torch.rand(Nb, dimension).cuda() 
    xo2[:, 14] = torch.ones(Nb)
    xp1 = torch.rand(Nb, dimension).cuda() 
    xp1[:, 15] = torch.zeros(Nb)
    xp2 = torch.rand(Nb, dimension).cuda() 
    xp2[:, 15] = torch.ones(Nb)
    
    dx1 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx1[:, 0] = torch.ones(xb1.size()[0])
    dx2 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx2[:, 1] = torch.ones(xb1.size()[0])
    dx3 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx3[:, 2] = torch.ones(xb1.size()[0])
    dx4 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx4[:, 3] = torch.ones(xb1.size()[0])
    dx5 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx5[:, 4] = torch.ones(xb1.size()[0])
    dx6 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx6[:, 5] = torch.ones(xb1.size()[0])
    dx7 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx7[:, 6] = torch.ones(xb1.size()[0])
    dx8 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx8[:, 7] = torch.ones(xb1.size()[0])
    dx9 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx9[:, 8] = torch.ones(xb1.size()[0])
    dx10 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx10[:, 9] = torch.ones(xb1.size()[0])
    dx11 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx11[:, 10] = torch.ones(xb1.size()[0])
    dx12 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx12[:, 11] = torch.ones(xb1.size()[0])
    dx13 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx13[:, 12] = torch.ones(xb1.size()[0])
    dx14 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx14[:, 13] = torch.ones(xb1.size()[0])
    dx15 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx15[:, 14] = torch.ones(xb1.size()[0])
    dx16 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx16[:, 15] = torch.ones(xb1.size()[0])
    
    uxa1 = (((model(xa1+step_size*dx1) - model(xa1-step_size*dx1))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxa2 = (((model(xa2+step_size*dx1) - model(xa2-step_size*dx1))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxb1 = (((model(xb1+step_size*dx2) - model(xb1-step_size*dx2))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxb2 = (((model(xb2+step_size*dx2) - model(xb2-step_size*dx2))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxc1 = (((model(xc1+step_size*dx3) - model(xc1-step_size*dx3))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxc2 = (((model(xc2+step_size*dx3) - model(xc2-step_size*dx3))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxd1 = (((model(xd1+step_size*dx4) - model(xd1-step_size*dx4))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxd2 = (((model(xd2+step_size*dx4) - model(xd2-step_size*dx4))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxe1 = (((model(xe1+step_size*dx5) - model(xe1-step_size*dx5))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxe2 = (((model(xe2+step_size*dx5) - model(xe2-step_size*dx5))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxf1 = (((model(xf1+step_size*dx6) - model(xf1-step_size*dx6))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxf2 = (((model(xf2+step_size*dx6) - model(xf2-step_size*dx6))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxg1 = (((model(xg1+step_size*dx7) - model(xg1-step_size*dx7))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxg2 = (((model(xg2+step_size*dx7) - model(xg2-step_size*dx7))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxh1 = (((model(xh1+step_size*dx8) - model(xh1-step_size*dx8))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxh2 = (((model(xh2+step_size*dx8) - model(xh2-step_size*dx8))/step_size/2 * (-1.0) - 0)**2).cuda()
    uxi1 = (((model(xi1+step_size*dx9) - model(xi1-step_size*dx9))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxi2 = (((model(xi2+step_size*dx9) - model(xi2-step_size*dx9))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxj1 = (((model(xj1+step_size*dx10) - model(xj1-step_size*dx10))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxj2 = (((model(xj2+step_size*dx10) - model(xj2-step_size*dx10))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxk1 = (((model(xk1+step_size*dx11) - model(xk1-step_size*dx11))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxk2 = (((model(xk2+step_size*dx11) - model(xk2-step_size*dx11))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxl1 = (((model(xl1+step_size*dx12) - model(xl1-step_size*dx12))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxl2 = (((model(xl2+step_size*dx12) - model(xl2-step_size*dx12))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxm1 = (((model(xm1+step_size*dx13) - model(xm1-step_size*dx13))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxm2 = (((model(xm2+step_size*dx13) - model(xm2-step_size*dx13))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxn1 = (((model(xn1+step_size*dx14) - model(xn1-step_size*dx14))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxn2 = (((model(xn2+step_size*dx14) - model(xn2-step_size*dx14))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxo1 = (((model(xo1+step_size*dx15) - model(xo1-step_size*dx15))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxo2 = (((model(xo2+step_size*dx15) - model(xo2-step_size*dx15))/step_size/2 * (-1.0) - 0)**2).cuda() 
    uxp1 = (((model(xp1+step_size*dx16) - model(xp1-step_size*dx16))/step_size/2 * (1.0) - 0)**2).cuda() 
    uxp2 = (((model(xp2+step_size*dx16) - model(xp2-step_size*dx16))/step_size/2 * (-1.0) - 0)**2).cuda()
    
    part_2 = torch.sum((uxa1 + uxa2 + uxb1 + uxb2 + uxc1 + uxc2 + uxd1 + uxd2 + uxe1 + uxe2 + uxf1 + uxf2 + uxg1 + uxg2 + uxh1 + uxh2 + uxi1 + uxi2 + uxj1 + uxj2 + uxk1 + uxk2 + uxl1 + uxl2 + uxm1 + uxm2 + uxn1 + uxn2 + uxo1 + uxo2 + uxp1 + uxp2)[:,0])/xa1.size()[0]
    lambda1 = 1.0
    return part_1 + lambda1 * part_2 / 32

# %%
Data_size = 2000
def Gendata():
    x = torch.rand(Data_size, dimension)
    return x.cuda()

# %%
# 正态分布初始化参数
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = DeepRitzNet(dimension, 32)
model = initparam(model, 0.5)

# %%
device = torch.device("cuda:1" )
model.to(device)
# Out:
# DeepRitzNet(
#   (linear_in): Linear(in_features=16, out_features=32, bias=True)
#   (linear1): Linear(in_features=32, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=32, bias=True)
#   (linear3): Linear(in_features=32, out_features=32, bias=True)
#   (linear4): Linear(in_features=32, out_features=32, bias=True)
#   (linear5): Linear(in_features=32, out_features=32, bias=True)
#   (linear6): Linear(in_features=32, out_features=32, bias=True)
#   (linear_out): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
import torch.optim as optim
import torch.nn as nn
import time

# %%
def relative_error():
    x = Gendata()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
traintime = 100000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = Gendata()
    x.requires_grad = True
    losses = DRM(x)
    losses.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", losses.detach())
        print("current relative error is: ", error.detach())
        np.save("DRM_relative_error_16D_Neumann.npy", error_save)
np.save("DRM_relative_error_16D_Neumann.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(362579.0609, device='cuda:1')
# current relative error is:  tensor(72.5181, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(7749.2028, device='cuda:1')
# current relative error is:  tensor(5.1041, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(3022.1504, device='cuda:1')
# current relative error is:  tensor(3.4535, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(1873.1061, device='cuda:1')
# current relative error is:  tensor(2.7727, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(1189.9542, device='cuda:1')
# current relative error is:  tensor(2.2614, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(812.9861, device='cuda:1')
# current relative error is:  tensor(1.8161, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(595.7685, device='cuda:1')
# current relative error is:  tensor(1.6206, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(393.7835, device='cuda:1')
# current relative error is:  tensor(1.4682, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(284.9895, device='cuda:1')
# current relative error is:  tensor(1.3502, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(207.4428, device='cuda:1')
# current relative error is:  tensor(1.2199, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(165.0503, device='cuda:1')
# current relative error is:  tensor(1.1670, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(110.7584, device='cuda:1')
# current relative error is:  tensor(1.0748, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(92.0932, device='cuda:1')
# current relative error is:  tensor(1.0328, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(67.5447, device='cuda:1')
# current relative error is:  tensor(0.9745, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(55.6497, device='cuda:1')
# current relative error is:  tensor(0.9331, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(40.3164, device='cuda:1')
# current relative error is:  tensor(0.9262, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(35.5436, device='cuda:1')
# current relative error is:  tensor(0.8726, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(25.1557, device='cuda:1')
# current relative error is:  tensor(0.8535, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(18.2285, device='cuda:1')
# current relative error is:  tensor(0.7995, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(4.0286, device='cuda:1')
# current relative error is:  tensor(0.7906, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(6.5971, device='cuda:1')
# current relative error is:  tensor(0.7940, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(-1.1625, device='cuda:1')
# current relative error is:  tensor(0.7622, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(-12.1055, device='cuda:1')
# current relative error is:  tensor(0.7310, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(-15.0435, device='cuda:1')
# current relative error is:  tensor(0.7106, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(-17.9143, device='cuda:1')
# current relative error is:  tensor(0.7166, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(-19.0946, device='cuda:1')
# current relative error is:  tensor(0.6766, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(-24.0232, device='cuda:1')
# current relative error is:  tensor(0.6711, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(-26.8239, device='cuda:1')
# current relative error is:  tensor(0.6583, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(-28.5101, device='cuda:1')
# current relative error is:  tensor(0.6085, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(-34.4460, device='cuda:1')
# current relative error is:  tensor(0.6227, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(-34.3392, device='cuda:1')
# current relative error is:  tensor(0.5874, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(-41.1376, device='cuda:1')
# current relative error is:  tensor(0.5914, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(-35.0982, device='cuda:1')
# current relative error is:  tensor(0.5625, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(-46.6280, device='cuda:1')
# current relative error is:  tensor(0.5828, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(-39.4852, device='cuda:1')
# current relative error is:  tensor(0.5480, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(-45.4339, device='cuda:1')
# current relative error is:  tensor(0.5369, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(-41.6224, device='cuda:1')
# current relative error is:  tensor(0.5515, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(-44.3360, device='cuda:1')
# current relative error is:  tensor(0.5049, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(-50.0066, device='cuda:1')
# current relative error is:  tensor(0.4951, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(-51.1068, device='cuda:1')
# current relative error is:  tensor(0.4993, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(-49.3482, device='cuda:1')
# current relative error is:  tensor(0.4906, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(-48.8306, device='cuda:1')
# current relative error is:  tensor(0.4600, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(-56.9387, device='cuda:1')
# current relative error is:  tensor(0.4463, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(-51.2421, device='cuda:1')
# current relative error is:  tensor(0.4454, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(-56.8498, device='cuda:1')
# current relative error is:  tensor(0.4114, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(-53.3640, device='cuda:1')
# current relative error is:  tensor(0.4340, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(-52.8233, device='cuda:1')
# current relative error is:  tensor(0.4167, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(-49.4974, device='cuda:1')
# current relative error is:  tensor(0.3945, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(-55.8554, device='cuda:1')
# current relative error is:  tensor(0.4185, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(-54.5528, device='cuda:1')
# current relative error is:  tensor(0.4655, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(-56.1313, device='cuda:1')
# current relative error is:  tensor(0.3902, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(-56.6422, device='cuda:1')
# current relative error is:  tensor(0.3553, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(-63.4083, device='cuda:1')
# current relative error is:  tensor(0.3489, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(-60.9198, device='cuda:1')
# current relative error is:  tensor(0.3434, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(-60.0303, device='cuda:1')
# current relative error is:  tensor(0.3556, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(-63.6985, device='cuda:1')
# current relative error is:  tensor(0.3166, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(-55.8621, device='cuda:1')
# current relative error is:  tensor(0.3548, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(-65.1716, device='cuda:1')
# current relative error is:  tensor(0.3108, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(-64.5740, device='cuda:1')
# current relative error is:  tensor(0.3669, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(-59.9720, device='cuda:1')
# current relative error is:  tensor(0.2916, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(-56.7644, device='cuda:1')
# current relative error is:  tensor(0.2992, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(-58.6061, device='cuda:1')
# current relative error is:  tensor(0.2838, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(-57.6187, device='cuda:1')
# current relative error is:  tensor(0.2738, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(-60.0810, device='cuda:1')
# current relative error is:  tensor(0.3058, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(-55.6813, device='cuda:1')
# current relative error is:  tensor(0.3073, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(-60.8209, device='cuda:1')
# current relative error is:  tensor(0.2915, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(-60.3331, device='cuda:1')
# current relative error is:  tensor(0.3091, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(-66.2921, device='cuda:1')
# current relative error is:  tensor(0.2606, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(-57.2883, device='cuda:1')
# current relative error is:  tensor(0.3175, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(-56.3017, device='cuda:1')
# current relative error is:  tensor(0.2447, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(-57.1602, device='cuda:1')
# current relative error is:  tensor(0.2767, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(-58.2125, device='cuda:1')
# current relative error is:  tensor(0.2649, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(-70.2282, device='cuda:1')
# current relative error is:  tensor(0.2657, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(-66.2464, device='cuda:1')
# current relative error is:  tensor(0.2353, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(-62.1808, device='cuda:1')
# current relative error is:  tensor(0.2431, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(-56.4610, device='cuda:1')
# current relative error is:  tensor(0.3851, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(-58.9852, device='cuda:1')
# current relative error is:  tensor(0.2431, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(-61.2290, device='cuda:1')
# current relative error is:  tensor(0.2497, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(-62.9449, device='cuda:1')
# current relative error is:  tensor(0.2502, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(-64.3502, device='cuda:1')
# current relative error is:  tensor(0.2536, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(-61.8736, device='cuda:1')
# current relative error is:  tensor(0.2350, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(-60.2921, device='cuda:1')
# current relative error is:  tensor(0.2885, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(-62.5545, device='cuda:1')
# current relative error is:  tensor(0.3591, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(-62.1487, device='cuda:1')
# current relative error is:  tensor(0.2447, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(-63.2694, device='cuda:1')
# current relative error is:  tensor(0.5132, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(-62.4202, device='cuda:1')
# current relative error is:  tensor(0.3907, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(-67.9935, device='cuda:1')
# current relative error is:  tensor(0.2857, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(-63.3485, device='cuda:1')
# current relative error is:  tensor(0.2182, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(-65.6513, device='cuda:1')
# current relative error is:  tensor(0.3216, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(-65.4857, device='cuda:1')
# current relative error is:  tensor(0.2798, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(-64.1527, device='cuda:1')
# current relative error is:  tensor(0.2521, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(-64.7912, device='cuda:1')
# current relative error is:  tensor(0.2185, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(-70.0859, device='cuda:1')
# current relative error is:  tensor(0.2143, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(-63.7385, device='cuda:1')
# current relative error is:  tensor(0.2094, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(-67.3301, device='cuda:1')
# current relative error is:  tensor(0.2701, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(-66.5829, device='cuda:1')
# current relative error is:  tensor(0.2034, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(-53.9847, device='cuda:1')
# current relative error is:  tensor(0.4516, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(-64.1302, device='cuda:1')
# current relative error is:  tensor(0.4618, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(-72.2671, device='cuda:1')
# current relative error is:  tensor(0.3514, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(-60.8459, device='cuda:1')
# current relative error is:  tensor(0.2277, device='cuda:1')
# current epoch is:  5000
# current loss is:  tensor(-64.5931, device='cuda:1')
# current relative error is:  tensor(0.2563, device='cuda:1')
# current epoch is:  5050
# current loss is:  tensor(-65.9240, device='cuda:1')
# current relative error is:  tensor(0.3431, device='cuda:1')
# current epoch is:  5100
# current loss is:  tensor(-60.2675, device='cuda:1')
# current relative error is:  tensor(0.2560, device='cuda:1')
# current epoch is:  5150
# current loss is:  tensor(-65.2051, device='cuda:1')
# current relative error is:  tensor(0.2267, device='cuda:1')
# current epoch is:  5200
# current loss is:  tensor(-65.7606, device='cuda:1')
# current relative error is:  tensor(0.2129, device='cuda:1')
# current epoch is:  5250
# current loss is:  tensor(-63.7333, device='cuda:1')
# current relative error is:  tensor(0.2124, device='cuda:1')
# current epoch is:  5300
# current loss is:  tensor(-57.3922, device='cuda:1')
# current relative error is:  tensor(0.2432, device='cuda:1')
# current epoch is:  5350
# current loss is:  tensor(-68.2859, device='cuda:1')
# current relative error is:  tensor(0.3190, device='cuda:1')
# current epoch is:  5400
# current loss is:  tensor(-63.8012, device='cuda:1')
# current relative error is:  tensor(0.2269, device='cuda:1')
# current epoch is:  5450
# current loss is:  tensor(-64.8870, device='cuda:1')
# current relative error is:  tensor(0.2108, device='cuda:1')
# current epoch is:  5500
# current loss is:  tensor(-65.6455, device='cuda:1')
# current relative error is:  tensor(0.2098, device='cuda:1')
# current epoch is:  5550
# current loss is:  tensor(-59.3694, device='cuda:1')
# current relative error is:  tensor(0.2197, device='cuda:1')
# current epoch is:  5600
# current loss is:  tensor(-61.0636, device='cuda:1')
# current relative error is:  tensor(0.2895, device='cuda:1')
# current epoch is:  5650
# current loss is:  tensor(-67.7359, device='cuda:1')
# current relative error is:  tensor(0.3125, device='cuda:1')
# current epoch is:  5700
# current loss is:  tensor(-63.5824, device='cuda:1')
# current relative error is:  tensor(0.4001, device='cuda:1')
# current epoch is:  5750
# current loss is:  tensor(-54.5603, device='cuda:1')
# current relative error is:  tensor(0.2990, device='cuda:1')
# current epoch is:  5800
# current loss is:  tensor(-53.3744, device='cuda:1')
# current relative error is:  tensor(0.2200, device='cuda:1')
# current epoch is:  5850
# current loss is:  tensor(-57.3821, device='cuda:1')
# current relative error is:  tensor(0.2258, device='cuda:1')
# current epoch is:  5900
# current loss is:  tensor(-60.0462, device='cuda:1')
# current relative error is:  tensor(0.4396, device='cuda:1')
# current epoch is:  5950
# current loss is:  tensor(-60.9648, device='cuda:1')
# current relative error is:  tensor(0.3412, device='cuda:1')
# current epoch is:  6000
# current loss is:  tensor(-58.7104, device='cuda:1')
# current relative error is:  tensor(0.4647, device='cuda:1')
# current epoch is:  6050
# current loss is:  tensor(-61.6915, device='cuda:1')
# current relative error is:  tensor(0.4754, device='cuda:1')
# current epoch is:  6100
# current loss is:  tensor(-65.4747, device='cuda:1')
# current relative error is:  tensor(0.4836, device='cuda:1')
# current epoch is:  6150
# current loss is:  tensor(-64.1159, device='cuda:1')
# current relative error is:  tensor(0.2325, device='cuda:1')
# current epoch is:  6200
# current loss is:  tensor(-67.3980, device='cuda:1')
# current relative error is:  tensor(0.2045, device='cuda:1')
# current epoch is:  6250
# current loss is:  tensor(-60.0925, device='cuda:1')
# current relative error is:  tensor(0.2049, device='cuda:1')
# current epoch is:  6300
# current loss is:  tensor(-61.3176, device='cuda:1')
# current relative error is:  tensor(0.4454, device='cuda:1')
# current epoch is:  6350
# current loss is:  tensor(-67.5180, device='cuda:1')
# current relative error is:  tensor(0.2032, device='cuda:1')
# current epoch is:  6400
# current loss is:  tensor(-68.9658, device='cuda:1')
# current relative error is:  tensor(0.2124, device='cuda:1')
# current epoch is:  6450
# current loss is:  tensor(-36.3430, device='cuda:1')
# current relative error is:  tensor(0.3978, device='cuda:1')
# current epoch is:  6500
# current loss is:  tensor(-71.6885, device='cuda:1')
# current relative error is:  tensor(0.2225, device='cuda:1')
# current epoch is:  6550
# current loss is:  tensor(-58.9926, device='cuda:1')
# current relative error is:  tensor(0.2046, device='cuda:1')
# current epoch is:  6600
# current loss is:  tensor(-60.8651, device='cuda:1')
# current relative error is:  tensor(0.3298, device='cuda:1')
# current epoch is:  6650
# current loss is:  tensor(-68.8577, device='cuda:1')
# current relative error is:  tensor(0.2243, device='cuda:1')
# current epoch is:  6700
# current loss is:  tensor(-62.7188, device='cuda:1')
# current relative error is:  tensor(0.2430, device='cuda:1')
# current epoch is:  6750
# current loss is:  tensor(-61.3359, device='cuda:1')
# current relative error is:  tensor(0.2148, device='cuda:1')
# current epoch is:  6800
# current loss is:  tensor(-58.5180, device='cuda:1')
# current relative error is:  tensor(0.3672, device='cuda:1')
# current epoch is:  6850
# current loss is:  tensor(-61.3860, device='cuda:1')
# current relative error is:  tensor(0.2028, device='cuda:1')
# current epoch is:  6900
# current loss is:  tensor(-71.9327, device='cuda:1')
# current relative error is:  tensor(0.3294, device='cuda:1')
# current epoch is:  6950
# current loss is:  tensor(-64.5925, device='cuda:1')
# current relative error is:  tensor(0.2564, device='cuda:1')
# current epoch is:  7000
# current loss is:  tensor(-63.0833, device='cuda:1')
# current relative error is:  tensor(0.2029, device='cuda:1')
# current epoch is:  7050
# current loss is:  tensor(-64.5867, device='cuda:1')
# current relative error is:  tensor(0.1995, device='cuda:1')
# current epoch is:  7100
# current loss is:  tensor(-61.0095, device='cuda:1')
# current relative error is:  tensor(0.3488, device='cuda:1')
# current epoch is:  7150
# current loss is:  tensor(-69.1920, device='cuda:1')
# current relative error is:  tensor(0.2172, device='cuda:1')
# current epoch is:  7200
# current loss is:  tensor(-62.1672, device='cuda:1')
# current relative error is:  tensor(0.2572, device='cuda:1')
# current epoch is:  7250
# current loss is:  tensor(-58.0270, device='cuda:1')
# current relative error is:  tensor(0.3786, device='cuda:1')
# current epoch is:  7300
# current loss is:  tensor(-67.4645, device='cuda:1')
# current relative error is:  tensor(0.3664, device='cuda:1')
# current epoch is:  7350
# current loss is:  tensor(-65.8708, device='cuda:1')
# current relative error is:  tensor(0.3615, device='cuda:1')
# current epoch is:  7400
# current loss is:  tensor(-75.6707, device='cuda:1')
# current relative error is:  tensor(0.4032, device='cuda:1')
# current epoch is:  7450
# current loss is:  tensor(-66.3547, device='cuda:1')
# current relative error is:  tensor(0.2636, device='cuda:1')
# current epoch is:  7500
# current loss is:  tensor(-50.0715, device='cuda:1')
# current relative error is:  tensor(0.4305, device='cuda:1')
# current epoch is:  7550
# current loss is:  tensor(-67.8350, device='cuda:1')
# current relative error is:  tensor(0.2045, device='cuda:1')
# current epoch is:  7600
# current loss is:  tensor(-64.8298, device='cuda:1')
# current relative error is:  tensor(0.2681, device='cuda:1')
# current epoch is:  7650
# current loss is:  tensor(-68.6815, device='cuda:1')
# current relative error is:  tensor(0.4079, device='cuda:1')
# current epoch is:  7700
# current loss is:  tensor(-67.0404, device='cuda:1')
# current relative error is:  tensor(0.2173, device='cuda:1')
# current epoch is:  7750
# current loss is:  tensor(-62.9301, device='cuda:1')
# current relative error is:  tensor(0.3316, device='cuda:1')
# current epoch is:  7800
# current loss is:  tensor(-62.9239, device='cuda:1')
# current relative error is:  tensor(0.4059, device='cuda:1')
# current epoch is:  7850
# current loss is:  tensor(-57.0339, device='cuda:1')
# current relative error is:  tensor(0.4987, device='cuda:1')
# current epoch is:  7900
# current loss is:  tensor(-67.0812, device='cuda:1')
# current relative error is:  tensor(0.2009, device='cuda:1')
# current epoch is:  7950
# current loss is:  tensor(-64.9238, device='cuda:1')
# current relative error is:  tensor(0.1967, device='cuda:1')
# current epoch is:  8000
# current loss is:  tensor(-61.1392, device='cuda:1')
# current relative error is:  tensor(0.1999, device='cuda:1')
# current epoch is:  8050
# current loss is:  tensor(-64.2638, device='cuda:1')
# current relative error is:  tensor(0.3531, device='cuda:1')
# current epoch is:  8100
# current loss is:  tensor(-67.7347, device='cuda:1')
# current relative error is:  tensor(0.1970, device='cuda:1')
# current epoch is:  8150
# current loss is:  tensor(-63.4036, device='cuda:1')
# current relative error is:  tensor(0.2273, device='cuda:1')
# current epoch is:  8200
# current loss is:  tensor(-65.1942, device='cuda:1')
# current relative error is:  tensor(0.1899, device='cuda:1')
# current epoch is:  8250
# current loss is:  tensor(-71.4533, device='cuda:1')
# current relative error is:  tensor(0.3185, device='cuda:1')
# current epoch is:  8300
# current loss is:  tensor(-67.7046, device='cuda:1')
# current relative error is:  tensor(0.1906, device='cuda:1')
# current epoch is:  8350
# current loss is:  tensor(-66.7024, device='cuda:1')
# current relative error is:  tensor(0.2222, device='cuda:1')
# current epoch is:  8400
# current loss is:  tensor(-67.7604, device='cuda:1')
# current relative error is:  tensor(0.2379, device='cuda:1')
# current epoch is:  8450
# current loss is:  tensor(-68.1804, device='cuda:1')
# current relative error is:  tensor(0.2601, device='cuda:1')
# current epoch is:  8500
# current loss is:  tensor(-68.6802, device='cuda:1')
# current relative error is:  tensor(0.2237, device='cuda:1')
# current epoch is:  8550
# current loss is:  tensor(-66.3997, device='cuda:1')
# current relative error is:  tensor(0.2788, device='cuda:1')
# current epoch is:  8600
# current loss is:  tensor(-64.7029, device='cuda:1')
# current relative error is:  tensor(0.2404, device='cuda:1')
# current epoch is:  8650
# current loss is:  tensor(-66.1822, device='cuda:1')
# current relative error is:  tensor(0.2213, device='cuda:1')
# current epoch is:  8700
# current loss is:  tensor(-71.3856, device='cuda:1')
# current relative error is:  tensor(0.1974, device='cuda:1')
# current epoch is:  8750
# current loss is:  tensor(-62.9157, device='cuda:1')
# current relative error is:  tensor(0.2562, device='cuda:1')
# current epoch is:  8800
# current loss is:  tensor(-63.4245, device='cuda:1')
# current relative error is:  tensor(0.2063, device='cuda:1')
# current epoch is:  8850
# current loss is:  tensor(-67.7196, device='cuda:1')
# current relative error is:  tensor(0.1874, device='cuda:1')
# current epoch is:  8900
# current loss is:  tensor(-62.5183, device='cuda:1')
# current relative error is:  tensor(0.2589, device='cuda:1')
# current epoch is:  8950
# current loss is:  tensor(-67.1569, device='cuda:1')
# current relative error is:  tensor(0.1877, device='cuda:1')
# current epoch is:  9000
# current loss is:  tensor(-64.3349, device='cuda:1')
# current relative error is:  tensor(0.2437, device='cuda:1')
# current epoch is:  9050
# current loss is:  tensor(-71.1109, device='cuda:1')
# current relative error is:  tensor(0.3220, device='cuda:1')
# current epoch is:  9100
# current loss is:  tensor(-60.5975, device='cuda:1')
# current relative error is:  tensor(0.3059, device='cuda:1')
# current epoch is:  9150
# current loss is:  tensor(-63.1602, device='cuda:1')
# current relative error is:  tensor(0.2156, device='cuda:1')
# current epoch is:  9200
# current loss is:  tensor(-56.4517, device='cuda:1')
# current relative error is:  tensor(0.3471, device='cuda:1')
# current epoch is:  9250
# current loss is:  tensor(-62.5291, device='cuda:1')
# current relative error is:  tensor(0.1960, device='cuda:1')
# current epoch is:  9300
# current loss is:  tensor(-65.3968, device='cuda:1')
# current relative error is:  tensor(0.2046, device='cuda:1')
# current epoch is:  9350
# current loss is:  tensor(-68.4350, device='cuda:1')
# current relative error is:  tensor(0.2652, device='cuda:1')
# current epoch is:  9400
# current loss is:  tensor(-63.5118, device='cuda:1')
# current relative error is:  tensor(0.2767, device='cuda:1')
# current epoch is:  9450
# current loss is:  tensor(-63.3408, device='cuda:1')
# current relative error is:  tensor(0.4104, device='cuda:1')
# current epoch is:  9500
# current loss is:  tensor(-69.0293, device='cuda:1')
# current relative error is:  tensor(0.2188, device='cuda:1')
# current epoch is:  9550
# current loss is:  tensor(-65.3536, device='cuda:1')
# current relative error is:  tensor(0.3370, device='cuda:1')
# current epoch is:  9600
# current loss is:  tensor(-61.2066, device='cuda:1')
# current relative error is:  tensor(0.2138, device='cuda:1')
# current epoch is:  9650
# current loss is:  tensor(-67.5141, device='cuda:1')
# current relative error is:  tensor(0.2065, device='cuda:1')
# current epoch is:  9700
# current loss is:  tensor(-67.6302, device='cuda:1')
# current relative error is:  tensor(0.3656, device='cuda:1')
# current epoch is:  9750
# current loss is:  tensor(-69.2058, device='cuda:1')
# current relative error is:  tensor(0.1850, device='cuda:1')
# current epoch is:  9800
# current loss is:  tensor(-57.3933, device='cuda:1')
# current relative error is:  tensor(0.2303, device='cuda:1')
# current epoch is:  9850
# current loss is:  tensor(-62.2286, device='cuda:1')
# current relative error is:  tensor(0.3917, device='cuda:1')
# current epoch is:  9900
# current loss is:  tensor(-63.3177, device='cuda:1')
# current relative error is:  tensor(0.2150, device='cuda:1')
# current epoch is:  9950
# current loss is:  tensor(-69.6543, device='cuda:1')
# current relative error is:  tensor(0.2483, device='cuda:1')
# current epoch is:  10000
# current loss is:  tensor(-70.9186, device='cuda:1')
# current relative error is:  tensor(0.2979, device='cuda:1')
# current epoch is:  10050
# current loss is:  tensor(-61.7067, device='cuda:1')
# current relative error is:  tensor(0.2642, device='cuda:1')
# current epoch is:  10100
# current loss is:  tensor(-70.5130, device='cuda:1')
# current relative error is:  tensor(0.1896, device='cuda:1')
# current epoch is:  10150
# current loss is:  tensor(-66.6250, device='cuda:1')
# current relative error is:  tensor(0.2912, device='cuda:1')
# current epoch is:  10200
# current loss is:  tensor(-62.6573, device='cuda:1')
# current relative error is:  tensor(0.1904, device='cuda:1')
# current epoch is:  10250
# current loss is:  tensor(-61.9558, device='cuda:1')
# current relative error is:  tensor(0.2109, device='cuda:1')
# current epoch is:  10300
# current loss is:  tensor(-70.5318, device='cuda:1')
# current relative error is:  tensor(0.1772, device='cuda:1')
# current epoch is:  10350
# current loss is:  tensor(-62.2958, device='cuda:1')
# current relative error is:  tensor(0.2117, device='cuda:1')
# current epoch is:  10400
# current loss is:  tensor(-65.0185, device='cuda:1')
# current relative error is:  tensor(0.2504, device='cuda:1')
# current epoch is:  10450
# current loss is:  tensor(-67.8741, device='cuda:1')
# current relative error is:  tensor(0.1959, device='cuda:1')
# current epoch is:  10500
# current loss is:  tensor(-69.9510, device='cuda:1')
# current relative error is:  tensor(0.1813, device='cuda:1')
# current epoch is:  10550
# current loss is:  tensor(-63.4630, device='cuda:1')
# current relative error is:  tensor(0.2577, device='cuda:1')
# current epoch is:  10600
# current loss is:  tensor(-65.6189, device='cuda:1')
# current relative error is:  tensor(0.2120, device='cuda:1')
# current epoch is:  10650
# current loss is:  tensor(-70.4529, device='cuda:1')
# current relative error is:  tensor(0.2130, device='cuda:1')
# current epoch is:  10700
# current loss is:  tensor(-62.9033, device='cuda:1')
# current relative error is:  tensor(0.3167, device='cuda:1')
# current epoch is:  10750
# current loss is:  tensor(-66.2034, device='cuda:1')
# current relative error is:  tensor(0.2056, device='cuda:1')
# current epoch is:  10800
# current loss is:  tensor(-71.4702, device='cuda:1')
# current relative error is:  tensor(0.2584, device='cuda:1')
# current epoch is:  10850
# current loss is:  tensor(-67.9606, device='cuda:1')
# current relative error is:  tensor(0.1930, device='cuda:1')
# current epoch is:  10900
# current loss is:  tensor(-72.8312, device='cuda:1')
# current relative error is:  tensor(0.1783, device='cuda:1')
# current epoch is:  10950
# current loss is:  tensor(-62.4517, device='cuda:1')
# current relative error is:  tensor(0.2685, device='cuda:1')
# current epoch is:  11000
# current loss is:  tensor(-67.4529, device='cuda:1')
# current relative error is:  tensor(0.1811, device='cuda:1')
# current epoch is:  11050
# current loss is:  tensor(-70.9710, device='cuda:1')
# current relative error is:  tensor(0.1773, device='cuda:1')
# current epoch is:  11100
# current loss is:  tensor(-68.1810, device='cuda:1')
# current relative error is:  tensor(0.2142, device='cuda:1')
# current epoch is:  11150
# current loss is:  tensor(-64.6120, device='cuda:1')
# current relative error is:  tensor(0.1829, device='cuda:1')
# current epoch is:  11200
# current loss is:  tensor(-59.7258, device='cuda:1')
# current relative error is:  tensor(0.3641, device='cuda:1')
# current epoch is:  11250
# current loss is:  tensor(-73.8827, device='cuda:1')
# current relative error is:  tensor(0.2939, device='cuda:1')
# current epoch is:  11300
# current loss is:  tensor(-63.4877, device='cuda:1')
# current relative error is:  tensor(0.1742, device='cuda:1')
# current epoch is:  11350
# current loss is:  tensor(-64.6640, device='cuda:1')
# current relative error is:  tensor(0.2209, device='cuda:1')
# current epoch is:  11400
# current loss is:  tensor(-70.4537, device='cuda:1')
# current relative error is:  tensor(0.3312, device='cuda:1')
# current epoch is:  11450
# current loss is:  tensor(-73.3580, device='cuda:1')
# current relative error is:  tensor(0.1774, device='cuda:1')
# current epoch is:  11500
# current loss is:  tensor(-75.4495, device='cuda:1')
# current relative error is:  tensor(0.2084, device='cuda:1')
# current epoch is:  11550
# current loss is:  tensor(-66.7763, device='cuda:1')
# current relative error is:  tensor(0.1768, device='cuda:1')
# current epoch is:  11600
# current loss is:  tensor(-62.7631, device='cuda:1')
# current relative error is:  tensor(0.3134, device='cuda:1')
# current epoch is:  11650
# current loss is:  tensor(-63.7206, device='cuda:1')
# current relative error is:  tensor(0.2637, device='cuda:1')
# current epoch is:  11700
# current loss is:  tensor(-69.9657, device='cuda:1')
# current relative error is:  tensor(0.1702, device='cuda:1')
# current epoch is:  11750
# current loss is:  tensor(-67.8218, device='cuda:1')
# current relative error is:  tensor(0.2116, device='cuda:1')
# current epoch is:  11800
# current loss is:  tensor(-67.7657, device='cuda:1')
# current relative error is:  tensor(0.1866, device='cuda:1')
# current epoch is:  11850
# current loss is:  tensor(-69.7930, device='cuda:1')
# current relative error is:  tensor(0.2330, device='cuda:1')
# current epoch is:  11900
# current loss is:  tensor(-62.3567, device='cuda:1')
# current relative error is:  tensor(0.2044, device='cuda:1')
# current epoch is:  11950
# current loss is:  tensor(-66.5096, device='cuda:1')
# current relative error is:  tensor(0.1720, device='cuda:1')
# current epoch is:  12000
# current loss is:  tensor(-68.0338, device='cuda:1')
# current relative error is:  tensor(0.1904, device='cuda:1')
# current epoch is:  12050
# current loss is:  tensor(-68.2403, device='cuda:1')
# current relative error is:  tensor(0.3263, device='cuda:1')
# current epoch is:  12100
# current loss is:  tensor(-68.1283, device='cuda:1')
# current relative error is:  tensor(0.1688, device='cuda:1')
# current epoch is:  12150
# current loss is:  tensor(-68.2780, device='cuda:1')
# current relative error is:  tensor(0.1987, device='cuda:1')
# current epoch is:  12200
# current loss is:  tensor(-70.4848, device='cuda:1')
# current relative error is:  tensor(0.1876, device='cuda:1')
# current epoch is:  12250
# current loss is:  tensor(-62.7017, device='cuda:1')
# current relative error is:  tensor(0.1682, device='cuda:1')
# current epoch is:  12300
# current loss is:  tensor(-61.3126, device='cuda:1')
# current relative error is:  tensor(0.2437, device='cuda:1')
# current epoch is:  12350
# current loss is:  tensor(-70.5383, device='cuda:1')
# current relative error is:  tensor(0.1746, device='cuda:1')
# current epoch is:  12400
# current loss is:  tensor(-60.4658, device='cuda:1')
# current relative error is:  tensor(0.2498, device='cuda:1')
# current epoch is:  12450
# current loss is:  tensor(-73.7064, device='cuda:1')
# current relative error is:  tensor(0.1670, device='cuda:1')
# current epoch is:  12500
# current loss is:  tensor(-71.8931, device='cuda:1')
# current relative error is:  tensor(0.1617, device='cuda:1')
# current epoch is:  12550
# current loss is:  tensor(-72.7072, device='cuda:1')
# current relative error is:  tensor(0.2054, device='cuda:1')
# current epoch is:  12600
# current loss is:  tensor(-67.2882, device='cuda:1')
# current relative error is:  tensor(0.1928, device='cuda:1')
# current epoch is:  12650
# current loss is:  tensor(-68.8700, device='cuda:1')
# current relative error is:  tensor(0.1716, device='cuda:1')
# current epoch is:  12700
# current loss is:  tensor(-67.6892, device='cuda:1')
# current relative error is:  tensor(0.1595, device='cuda:1')
# current epoch is:  12750
# current loss is:  tensor(-69.5301, device='cuda:1')
# current relative error is:  tensor(0.1824, device='cuda:1')
# current epoch is:  12800
# current loss is:  tensor(-65.9755, device='cuda:1')
# current relative error is:  tensor(0.1628, device='cuda:1')
# current epoch is:  12850
# current loss is:  tensor(-67.5806, device='cuda:1')
# current relative error is:  tensor(0.1608, device='cuda:1')
# current epoch is:  12900
# current loss is:  tensor(-69.1399, device='cuda:1')
# current relative error is:  tensor(0.2054, device='cuda:1')
# current epoch is:  12950
# current loss is:  tensor(-68.0600, device='cuda:1')
# current relative error is:  tensor(0.2561, device='cuda:1')
# current epoch is:  13000
# current loss is:  tensor(-69.4275, device='cuda:1')
# current relative error is:  tensor(0.1722, device='cuda:1')
# current epoch is:  13050
# current loss is:  tensor(-72.1409, device='cuda:1')
# current relative error is:  tensor(0.2656, device='cuda:1')
# current epoch is:  13100
# current loss is:  tensor(-68.5669, device='cuda:1')
# current relative error is:  tensor(0.1838, device='cuda:1')
# current epoch is:  13150
# current loss is:  tensor(-64.9255, device='cuda:1')
# current relative error is:  tensor(0.1756, device='cuda:1')
# current epoch is:  13200
# current loss is:  tensor(-67.1519, device='cuda:1')
# current relative error is:  tensor(0.2342, device='cuda:1')
# current epoch is:  13250
# current loss is:  tensor(-72.0065, device='cuda:1')
# current relative error is:  tensor(0.1688, device='cuda:1')
# current epoch is:  13300
# current loss is:  tensor(-64.6041, device='cuda:1')
# current relative error is:  tensor(0.2998, device='cuda:1')
# current epoch is:  13350
# current loss is:  tensor(-68.6145, device='cuda:1')
# current relative error is:  tensor(0.1606, device='cuda:1')
# current epoch is:  13400
# current loss is:  tensor(-70.3746, device='cuda:1')
# current relative error is:  tensor(0.1569, device='cuda:1')
# current epoch is:  13450
# current loss is:  tensor(-66.5319, device='cuda:1')
# current relative error is:  tensor(0.2487, device='cuda:1')
# current epoch is:  13500
# current loss is:  tensor(-72.1523, device='cuda:1')
# current relative error is:  tensor(0.2701, device='cuda:1')
# current epoch is:  13550
# current loss is:  tensor(-73.7141, device='cuda:1')
# current relative error is:  tensor(0.1601, device='cuda:1')
# current epoch is:  13600
# current loss is:  tensor(-73.7702, device='cuda:1')
# current relative error is:  tensor(0.1757, device='cuda:1')
# current epoch is:  13650
# current loss is:  tensor(-65.2952, device='cuda:1')
# current relative error is:  tensor(0.2835, device='cuda:1')
# current epoch is:  13700
# current loss is:  tensor(-71.1995, device='cuda:1')
# current relative error is:  tensor(0.1584, device='cuda:1')
# current epoch is:  13750
# current loss is:  tensor(-69.0784, device='cuda:1')
# current relative error is:  tensor(0.2163, device='cuda:1')
# current epoch is:  13800
# current loss is:  tensor(-68.4657, device='cuda:1')
# current relative error is:  tensor(0.1533, device='cuda:1')
# current epoch is:  13850
# current loss is:  tensor(-72.0401, device='cuda:1')
# current relative error is:  tensor(0.2040, device='cuda:1')
# current epoch is:  13900
# current loss is:  tensor(-70.2161, device='cuda:1')
# current relative error is:  tensor(0.1525, device='cuda:1')
# current epoch is:  13950
# current loss is:  tensor(-57.7937, device='cuda:1')
# current relative error is:  tensor(0.2268, device='cuda:1')
# current epoch is:  14000
# current loss is:  tensor(-67.1601, device='cuda:1')
# current relative error is:  tensor(0.1514, device='cuda:1')
# current epoch is:  14050
# current loss is:  tensor(-73.8067, device='cuda:1')
# current relative error is:  tensor(0.1499, device='cuda:1')
# current epoch is:  14100
# current loss is:  tensor(-67.8342, device='cuda:1')
# current relative error is:  tensor(0.1532, device='cuda:1')
# current epoch is:  14150
# current loss is:  tensor(-71.6823, device='cuda:1')
# current relative error is:  tensor(0.1760, device='cuda:1')
# current epoch is:  14200
# current loss is:  tensor(-71.0272, device='cuda:1')
# current relative error is:  tensor(0.1721, device='cuda:1')
# current epoch is:  14250
# current loss is:  tensor(-67.6569, device='cuda:1')
# current relative error is:  tensor(0.1537, device='cuda:1')
# current epoch is:  14300
# current loss is:  tensor(-67.9223, device='cuda:1')
# current relative error is:  tensor(0.1476, device='cuda:1')
# current epoch is:  14350
# current loss is:  tensor(-75.3720, device='cuda:1')
# current relative error is:  tensor(0.1603, device='cuda:1')
# current epoch is:  14400
# current loss is:  tensor(-74.2647, device='cuda:1')
# current relative error is:  tensor(0.1674, device='cuda:1')
# current epoch is:  14450
# current loss is:  tensor(-67.6853, device='cuda:1')
# current relative error is:  tensor(0.2472, device='cuda:1')
# current epoch is:  14500
# current loss is:  tensor(-74.8255, device='cuda:1')
# current relative error is:  tensor(0.1404, device='cuda:1')
# current epoch is:  14550
# current loss is:  tensor(-72.3906, device='cuda:1')
# current relative error is:  tensor(0.1903, device='cuda:1')
# current epoch is:  14600
# current loss is:  tensor(-66.2226, device='cuda:1')
# current relative error is:  tensor(0.1422, device='cuda:1')
# current epoch is:  14650
# current loss is:  tensor(-73.4795, device='cuda:1')
# current relative error is:  tensor(0.2197, device='cuda:1')
# current epoch is:  14700
# current loss is:  tensor(-72.9368, device='cuda:1')
# current relative error is:  tensor(0.1400, device='cuda:1')
# current epoch is:  14750
# current loss is:  tensor(-71.8559, device='cuda:1')
# current relative error is:  tensor(0.2501, device='cuda:1')
# current epoch is:  14800
# current loss is:  tensor(-68.6135, device='cuda:1')
# current relative error is:  tensor(0.1976, device='cuda:1')
# current epoch is:  14850
# current loss is:  tensor(-73.2687, device='cuda:1')
# current relative error is:  tensor(0.3359, device='cuda:1')
# current epoch is:  14900
# current loss is:  tensor(-70.3006, device='cuda:1')
# current relative error is:  tensor(0.2197, device='cuda:1')
# current epoch is:  14950
# current loss is:  tensor(-72.7393, device='cuda:1')
# current relative error is:  tensor(0.1835, device='cuda:1')
# current epoch is:  15000
# current loss is:  tensor(-73.2479, device='cuda:1')
# current relative error is:  tensor(0.1708, device='cuda:1')
# current epoch is:  15050
# current loss is:  tensor(-76.2285, device='cuda:1')
# current relative error is:  tensor(0.1517, device='cuda:1')
# current epoch is:  15100
# current loss is:  tensor(-71.3951, device='cuda:1')
# current relative error is:  tensor(0.1384, device='cuda:1')
# current epoch is:  15150
# current loss is:  tensor(-68.3936, device='cuda:1')
# current relative error is:  tensor(0.1542, device='cuda:1')
# current epoch is:  15200
# current loss is:  tensor(-70.5006, device='cuda:1')
# current relative error is:  tensor(0.1759, device='cuda:1')
# current epoch is:  15250
# current loss is:  tensor(-70.9299, device='cuda:1')
# current relative error is:  tensor(0.1395, device='cuda:1')
# current epoch is:  15300
# current loss is:  tensor(-70.2717, device='cuda:1')
# current relative error is:  tensor(0.1739, device='cuda:1')
# current epoch is:  15350
# current loss is:  tensor(-67.1000, device='cuda:1')
# current relative error is:  tensor(0.1501, device='cuda:1')
# current epoch is:  15400
# current loss is:  tensor(-73.5329, device='cuda:1')
# current relative error is:  tensor(0.1256, device='cuda:1')
# current epoch is:  15450
# current loss is:  tensor(-72.6250, device='cuda:1')
# current relative error is:  tensor(0.2079, device='cuda:1')
# current epoch is:  15500
# current loss is:  tensor(-73.1313, device='cuda:1')
# current relative error is:  tensor(0.1297, device='cuda:1')
# current epoch is:  15550
# current loss is:  tensor(-72.1341, device='cuda:1')
# current relative error is:  tensor(0.1773, device='cuda:1')
# current epoch is:  15600
# current loss is:  tensor(-73.0303, device='cuda:1')
# current relative error is:  tensor(0.1356, device='cuda:1')
# current epoch is:  15650
# current loss is:  tensor(-74.0229, device='cuda:1')
# current relative error is:  tensor(0.1243, device='cuda:1')
# current epoch is:  15700
# current loss is:  tensor(-71.5511, device='cuda:1')
# current relative error is:  tensor(0.2466, device='cuda:1')
# current epoch is:  15750
# current loss is:  tensor(-72.9036, device='cuda:1')
# current relative error is:  tensor(0.1501, device='cuda:1')
# current epoch is:  15800
# current loss is:  tensor(-74.5386, device='cuda:1')
# current relative error is:  tensor(0.1335, device='cuda:1')
# current epoch is:  15850
# current loss is:  tensor(-73.3184, device='cuda:1')
# current relative error is:  tensor(0.1197, device='cuda:1')
# current epoch is:  15900
# current loss is:  tensor(-70.2331, device='cuda:1')
# current relative error is:  tensor(0.1859, device='cuda:1')
# current epoch is:  15950
# current loss is:  tensor(-77.6069, device='cuda:1')
# current relative error is:  tensor(0.1839, device='cuda:1')
# current epoch is:  16000
# current loss is:  tensor(-79.0729, device='cuda:1')
# current relative error is:  tensor(0.1357, device='cuda:1')
# current epoch is:  16050
# current loss is:  tensor(-73.0888, device='cuda:1')
# current relative error is:  tensor(0.1181, device='cuda:1')
# current epoch is:  16100
# current loss is:  tensor(-72.0796, device='cuda:1')
# current relative error is:  tensor(0.1618, device='cuda:1')
# current epoch is:  16150
# current loss is:  tensor(-76.5286, device='cuda:1')
# current relative error is:  tensor(0.1918, device='cuda:1')
# current epoch is:  16200
# current loss is:  tensor(-85.8229, device='cuda:1')
# current relative error is:  tensor(0.1675, device='cuda:1')
# current epoch is:  16250
# current loss is:  tensor(-75.3593, device='cuda:1')
# current relative error is:  tensor(0.1364, device='cuda:1')
# current epoch is:  16300
# current loss is:  tensor(-72.8807, device='cuda:1')
# current relative error is:  tensor(0.1224, device='cuda:1')
# current epoch is:  16350
# current loss is:  tensor(-68.5538, device='cuda:1')
# current relative error is:  tensor(0.1267, device='cuda:1')
# current epoch is:  16400
# current loss is:  tensor(-73.5926, device='cuda:1')
# current relative error is:  tensor(0.1138, device='cuda:1')
# current epoch is:  16450
# current loss is:  tensor(-72.5789, device='cuda:1')
# current relative error is:  tensor(0.1549, device='cuda:1')
# current epoch is:  16500
# current loss is:  tensor(-76.4715, device='cuda:1')
# current relative error is:  tensor(0.1645, device='cuda:1')
# current epoch is:  16550
# current loss is:  tensor(-73.2708, device='cuda:1')
# current relative error is:  tensor(0.1825, device='cuda:1')
# current epoch is:  16600
# current loss is:  tensor(-72.7691, device='cuda:1')
# current relative error is:  tensor(0.1218, device='cuda:1')
# current epoch is:  16650
# current loss is:  tensor(-75.9633, device='cuda:1')
# current relative error is:  tensor(0.2020, device='cuda:1')
# current epoch is:  16700
# current loss is:  tensor(-75.7140, device='cuda:1')
# current relative error is:  tensor(0.0996, device='cuda:1')
# current epoch is:  16750
# current loss is:  tensor(-68.7775, device='cuda:1')
# current relative error is:  tensor(0.1256, device='cuda:1')
# current epoch is:  16800
# current loss is:  tensor(-80.6522, device='cuda:1')
# current relative error is:  tensor(0.1551, device='cuda:1')
# current epoch is:  16850
# current loss is:  tensor(-74.0845, device='cuda:1')
# current relative error is:  tensor(0.1307, device='cuda:1')
# current epoch is:  16900
# current loss is:  tensor(-73.8045, device='cuda:1')
# current relative error is:  tensor(0.1348, device='cuda:1')
# current epoch is:  16950
# current loss is:  tensor(-73.8392, device='cuda:1')
# current relative error is:  tensor(0.1581, device='cuda:1')
# current epoch is:  17000
# current loss is:  tensor(-76.6924, device='cuda:1')
# current relative error is:  tensor(0.1718, device='cuda:1')
# current epoch is:  17050
# current loss is:  tensor(-80.0953, device='cuda:1')
# current relative error is:  tensor(0.1595, device='cuda:1')
# current epoch is:  17100
# current loss is:  tensor(-76.2455, device='cuda:1')
# current relative error is:  tensor(0.1311, device='cuda:1')
# current epoch is:  17150
# current loss is:  tensor(-66.0084, device='cuda:1')
# current relative error is:  tensor(0.2090, device='cuda:1')
# current epoch is:  17200
# current loss is:  tensor(-75.2897, device='cuda:1')
# current relative error is:  tensor(0.1758, device='cuda:1')
# current epoch is:  17250
# current loss is:  tensor(-74.4548, device='cuda:1')
# current relative error is:  tensor(0.2085, device='cuda:1')
# current epoch is:  17300
# current loss is:  tensor(-75.7929, device='cuda:1')
# current relative error is:  tensor(0.2839, device='cuda:1')
# current epoch is:  17350
# current loss is:  tensor(-74.0345, device='cuda:1')
# current relative error is:  tensor(0.1663, device='cuda:1')
# current epoch is:  17400
# current loss is:  tensor(-76.8873, device='cuda:1')
# current relative error is:  tensor(0.1373, device='cuda:1')
# current epoch is:  17450
# current loss is:  tensor(-75.3261, device='cuda:1')
# current relative error is:  tensor(0.1994, device='cuda:1')
# current epoch is:  17500
# current loss is:  tensor(-75.4177, device='cuda:1')
# current relative error is:  tensor(0.1151, device='cuda:1')
# current epoch is:  17550
# current loss is:  tensor(-74.1526, device='cuda:1')
# current relative error is:  tensor(0.1256, device='cuda:1')
# ...
# current relative error is:  tensor(0.0453, device='cuda:1')
# current epoch is:  94200
# current loss is:  tensor(-80.7991, device='cuda:1')
# current relative error is:  tensor(0.0267, device='cuda:1')
# current epoch is:  94250
# current loss is:  tensor(-90.7184, device='cuda:1')
# current relative error is:  tensor(0.0500, device='cuda:1')
# current epoch is:  94300
# current loss is:  tensor(-74.7453, device='cuda:1')
# current relative error is:  tensor(0.0417, device='cuda:1')
# current epoch is:  94350
# current loss is:  tensor(-75.5854, device='cuda:1')
# current relative error is:  tensor(0.0684, device='cuda:1')
# current epoch is:  94400
# current loss is:  tensor(-79.7534, device='cuda:1')
# current relative error is:  tensor(0.0336, device='cuda:1')
# current epoch is:  94450
# current loss is:  tensor(-86.7832, device='cuda:1')
# current relative error is:  tensor(0.0356, device='cuda:1')
# current epoch is:  94500
# current loss is:  tensor(-75.0747, device='cuda:1')
# current relative error is:  tensor(0.0325, device='cuda:1')
# current epoch is:  94550
# current loss is:  tensor(-85.8399, device='cuda:1')
# current relative error is:  tensor(0.0274, device='cuda:1')
# current epoch is:  94600
# current loss is:  tensor(-78.1799, device='cuda:1')
# current relative error is:  tensor(0.0405, device='cuda:1')
# current epoch is:  94650
# current loss is:  tensor(-74.7819, device='cuda:1')
# current relative error is:  tensor(0.0868, device='cuda:1')
# current epoch is:  94700
# current loss is:  tensor(-77.4577, device='cuda:1')
# current relative error is:  tensor(0.0298, device='cuda:1')
# current epoch is:  94750
# current loss is:  tensor(-79.1339, device='cuda:1')
# current relative error is:  tensor(0.0410, device='cuda:1')
# current epoch is:  94800
# current loss is:  tensor(-80.1435, device='cuda:1')
# current relative error is:  tensor(0.0282, device='cuda:1')
# current epoch is:  94850
# current loss is:  tensor(-74.4288, device='cuda:1')
# current relative error is:  tensor(0.0535, device='cuda:1')
# current epoch is:  94900
# current loss is:  tensor(-81.6574, device='cuda:1')
# current relative error is:  tensor(0.0302, device='cuda:1')
# current epoch is:  94950
# current loss is:  tensor(-79.4059, device='cuda:1')
# current relative error is:  tensor(0.1201, device='cuda:1')
# current epoch is:  95000
# current loss is:  tensor(-84.4707, device='cuda:1')
# current relative error is:  tensor(0.0295, device='cuda:1')
# current epoch is:  95050
# current loss is:  tensor(-81.4760, device='cuda:1')
# current relative error is:  tensor(0.0307, device='cuda:1')
# current epoch is:  95100
# current loss is:  tensor(-77.3335, device='cuda:1')
# current relative error is:  tensor(0.0284, device='cuda:1')
# current epoch is:  95150
# current loss is:  tensor(-84.4984, device='cuda:1')
# current relative error is:  tensor(0.0385, device='cuda:1')
# current epoch is:  95200
# current loss is:  tensor(-80.7644, device='cuda:1')
# current relative error is:  tensor(0.0363, device='cuda:1')
# current epoch is:  95250
# current loss is:  tensor(-75.0936, device='cuda:1')
# current relative error is:  tensor(0.0711, device='cuda:1')
# current epoch is:  95300
# current loss is:  tensor(-76.2239, device='cuda:1')
# current relative error is:  tensor(0.0512, device='cuda:1')
# current epoch is:  95350
# current loss is:  tensor(-83.8415, device='cuda:1')
# current relative error is:  tensor(0.0427, device='cuda:1')
# current epoch is:  95400
# current loss is:  tensor(-77.8721, device='cuda:1')
# current relative error is:  tensor(0.0981, device='cuda:1')
# current epoch is:  95450
# current loss is:  tensor(-84.1320, device='cuda:1')
# current relative error is:  tensor(0.0381, device='cuda:1')
# current epoch is:  95500
# current loss is:  tensor(-76.1161, device='cuda:1')
# current relative error is:  tensor(0.0338, device='cuda:1')
# current epoch is:  95550
# current loss is:  tensor(-76.2227, device='cuda:1')
# current relative error is:  tensor(0.0478, device='cuda:1')
# current epoch is:  95600
# current loss is:  tensor(-75.8644, device='cuda:1')
# current relative error is:  tensor(0.0429, device='cuda:1')
# current epoch is:  95650
# current loss is:  tensor(-77.9267, device='cuda:1')
# current relative error is:  tensor(0.0398, device='cuda:1')
# current epoch is:  95700
# current loss is:  tensor(-79.2916, device='cuda:1')
# current relative error is:  tensor(0.0262, device='cuda:1')
# current epoch is:  95750
# current loss is:  tensor(-80.0728, device='cuda:1')
# current relative error is:  tensor(0.0314, device='cuda:1')
# current epoch is:  95800
# current loss is:  tensor(-78.5049, device='cuda:1')
# current relative error is:  tensor(0.0296, device='cuda:1')
# current epoch is:  95850
# current loss is:  tensor(-71.3574, device='cuda:1')
# current relative error is:  tensor(0.0798, device='cuda:1')
# current epoch is:  95900
# current loss is:  tensor(-80.1223, device='cuda:1')
# current relative error is:  tensor(0.0303, device='cuda:1')
# current epoch is:  95950
# current loss is:  tensor(-83.3594, device='cuda:1')
# current relative error is:  tensor(0.0541, device='cuda:1')
# current epoch is:  96000
# current loss is:  tensor(-77.9171, device='cuda:1')
# current relative error is:  tensor(0.0592, device='cuda:1')
# current epoch is:  96050
# current loss is:  tensor(-77.5130, device='cuda:1')
# current relative error is:  tensor(0.0450, device='cuda:1')
# current epoch is:  96100
# current loss is:  tensor(-79.5634, device='cuda:1')
# current relative error is:  tensor(0.0269, device='cuda:1')
# current epoch is:  96150
# current loss is:  tensor(-78.4863, device='cuda:1')
# current relative error is:  tensor(0.0317, device='cuda:1')
# current epoch is:  96200
# current loss is:  tensor(-78.6151, device='cuda:1')
# current relative error is:  tensor(0.0839, device='cuda:1')
# current epoch is:  96250
# current loss is:  tensor(-81.0763, device='cuda:1')
# current relative error is:  tensor(0.0323, device='cuda:1')
# current epoch is:  96300
# current loss is:  tensor(-76.7682, device='cuda:1')
# current relative error is:  tensor(0.0352, device='cuda:1')
# current epoch is:  96350
# current loss is:  tensor(-78.3867, device='cuda:1')
# current relative error is:  tensor(0.0321, device='cuda:1')
# current epoch is:  96400
# current loss is:  tensor(-74.5031, device='cuda:1')
# current relative error is:  tensor(0.0659, device='cuda:1')
# current epoch is:  96450
# current loss is:  tensor(-83.2452, device='cuda:1')
# current relative error is:  tensor(0.0454, device='cuda:1')
# current epoch is:  96500
# current loss is:  tensor(-80.2463, device='cuda:1')
# current relative error is:  tensor(0.0959, device='cuda:1')
# current epoch is:  96550
# current loss is:  tensor(-80.7077, device='cuda:1')
# current relative error is:  tensor(0.0308, device='cuda:1')
# current epoch is:  96600
# current loss is:  tensor(-79.5773, device='cuda:1')
# current relative error is:  tensor(0.0420, device='cuda:1')
# current epoch is:  96650
# current loss is:  tensor(-82.8232, device='cuda:1')
# current relative error is:  tensor(0.0407, device='cuda:1')
# current epoch is:  96700
# current loss is:  tensor(-73.3494, device='cuda:1')
# current relative error is:  tensor(0.0337, device='cuda:1')
# current epoch is:  96750
# current loss is:  tensor(-76.8445, device='cuda:1')
# current relative error is:  tensor(0.0658, device='cuda:1')
# current epoch is:  96800
# current loss is:  tensor(-75.1448, device='cuda:1')
# current relative error is:  tensor(0.0743, device='cuda:1')
# current epoch is:  96850
# current loss is:  tensor(-79.9949, device='cuda:1')
# current relative error is:  tensor(0.0293, device='cuda:1')
# current epoch is:  96900
# current loss is:  tensor(-85.2676, device='cuda:1')
# current relative error is:  tensor(0.0646, device='cuda:1')
# current epoch is:  96950
# current loss is:  tensor(-78.2190, device='cuda:1')
# current relative error is:  tensor(0.0558, device='cuda:1')
# current epoch is:  97000
# current loss is:  tensor(-78.8635, device='cuda:1')
# current relative error is:  tensor(0.0254, device='cuda:1')
# current epoch is:  97050
# current loss is:  tensor(-77.2037, device='cuda:1')
# current relative error is:  tensor(0.0671, device='cuda:1')
# current epoch is:  97100
# current loss is:  tensor(-82.4278, device='cuda:1')
# current relative error is:  tensor(0.0559, device='cuda:1')
# current epoch is:  97150
# current loss is:  tensor(-75.8072, device='cuda:1')
# current relative error is:  tensor(0.0381, device='cuda:1')
# current epoch is:  97200
# current loss is:  tensor(-79.2143, device='cuda:1')
# current relative error is:  tensor(0.0494, device='cuda:1')
# current epoch is:  97250
# current loss is:  tensor(-72.8815, device='cuda:1')
# current relative error is:  tensor(0.0470, device='cuda:1')
# current epoch is:  97300
# current loss is:  tensor(-80.9543, device='cuda:1')
# current relative error is:  tensor(0.0934, device='cuda:1')
# current epoch is:  97350
# current loss is:  tensor(-75.3564, device='cuda:1')
# current relative error is:  tensor(0.0275, device='cuda:1')
# current epoch is:  97400
# current loss is:  tensor(-81.4668, device='cuda:1')
# current relative error is:  tensor(0.0267, device='cuda:1')
# current epoch is:  97450
# current loss is:  tensor(-83.5573, device='cuda:1')
# current relative error is:  tensor(0.0543, device='cuda:1')
# current epoch is:  97500
# current loss is:  tensor(-78.6654, device='cuda:1')
# current relative error is:  tensor(0.0397, device='cuda:1')
# current epoch is:  97550
# current loss is:  tensor(-77.3507, device='cuda:1')
# current relative error is:  tensor(0.0364, device='cuda:1')
# current epoch is:  97600
# current loss is:  tensor(-81.0630, device='cuda:1')
# current relative error is:  tensor(0.0519, device='cuda:1')
# current epoch is:  97650
# current loss is:  tensor(-75.0591, device='cuda:1')
# current relative error is:  tensor(0.0540, device='cuda:1')
# current epoch is:  97700
# current loss is:  tensor(-74.4143, device='cuda:1')
# current relative error is:  tensor(0.0315, device='cuda:1')
# current epoch is:  97750
# current loss is:  tensor(-79.2616, device='cuda:1')
# current relative error is:  tensor(0.0469, device='cuda:1')
# current epoch is:  97800
# current loss is:  tensor(-78.5067, device='cuda:1')
# current relative error is:  tensor(0.0419, device='cuda:1')
# current epoch is:  97850
# current loss is:  tensor(-81.2914, device='cuda:1')
# current relative error is:  tensor(0.0963, device='cuda:1')
# current epoch is:  97900
# current loss is:  tensor(-75.8086, device='cuda:1')
# current relative error is:  tensor(0.0484, device='cuda:1')
# current epoch is:  97950
# current loss is:  tensor(-80.8325, device='cuda:1')
# current relative error is:  tensor(0.0399, device='cuda:1')
# current epoch is:  98000
# current loss is:  tensor(-78.0253, device='cuda:1')
# current relative error is:  tensor(0.1034, device='cuda:1')
# current epoch is:  98050
# current loss is:  tensor(-73.4980, device='cuda:1')
# current relative error is:  tensor(0.0832, device='cuda:1')
# current epoch is:  98100
# current loss is:  tensor(-83.9897, device='cuda:1')
# current relative error is:  tensor(0.0411, device='cuda:1')
# current epoch is:  98150
# current loss is:  tensor(-74.1894, device='cuda:1')
# current relative error is:  tensor(0.0357, device='cuda:1')
# current epoch is:  98200
# current loss is:  tensor(-78.4083, device='cuda:1')
# current relative error is:  tensor(0.0691, device='cuda:1')
# current epoch is:  98250
# current loss is:  tensor(-79.5907, device='cuda:1')
# current relative error is:  tensor(0.0272, device='cuda:1')
# current epoch is:  98300
# current loss is:  tensor(-79.5480, device='cuda:1')
# current relative error is:  tensor(0.0477, device='cuda:1')
# current epoch is:  98350
# current loss is:  tensor(-72.3307, device='cuda:1')
# current relative error is:  tensor(0.0382, device='cuda:1')
# current epoch is:  98400
# current loss is:  tensor(-74.2781, device='cuda:1')
# current relative error is:  tensor(0.0334, device='cuda:1')
# current epoch is:  98450
# current loss is:  tensor(-80.0360, device='cuda:1')
# current relative error is:  tensor(0.0390, device='cuda:1')
# current epoch is:  98500
# current loss is:  tensor(-83.2311, device='cuda:1')
# current relative error is:  tensor(0.0388, device='cuda:1')
# current epoch is:  98550
# current loss is:  tensor(-79.6060, device='cuda:1')
# current relative error is:  tensor(0.0435, device='cuda:1')
# current epoch is:  98600
# current loss is:  tensor(-74.8546, device='cuda:1')
# current relative error is:  tensor(0.0710, device='cuda:1')
# current epoch is:  98650
# current loss is:  tensor(-77.3125, device='cuda:1')
# current relative error is:  tensor(0.0263, device='cuda:1')
# current epoch is:  98700
# current loss is:  tensor(-75.3486, device='cuda:1')
# current relative error is:  tensor(0.0824, device='cuda:1')
# current epoch is:  98750
# current loss is:  tensor(-87.2171, device='cuda:1')
# current relative error is:  tensor(0.0680, device='cuda:1')
# current epoch is:  98800
# current loss is:  tensor(-73.2812, device='cuda:1')
# current relative error is:  tensor(0.0292, device='cuda:1')
# current epoch is:  98850
# current loss is:  tensor(-76.5603, device='cuda:1')
# current relative error is:  tensor(0.0238, device='cuda:1')
# current epoch is:  98900
# current loss is:  tensor(-79.0630, device='cuda:1')
# current relative error is:  tensor(0.0373, device='cuda:1')
# current epoch is:  98950
# current loss is:  tensor(-77.3956, device='cuda:1')
# current relative error is:  tensor(0.0450, device='cuda:1')
# current epoch is:  99000
# current loss is:  tensor(-76.7975, device='cuda:1')
# current relative error is:  tensor(0.0249, device='cuda:1')
# current epoch is:  99050
# current loss is:  tensor(-78.3841, device='cuda:1')
# current relative error is:  tensor(0.0735, device='cuda:1')
# current epoch is:  99100
# current loss is:  tensor(-85.1345, device='cuda:1')
# current relative error is:  tensor(0.0249, device='cuda:1')
# current epoch is:  99150
# current loss is:  tensor(-81.1327, device='cuda:1')
# current relative error is:  tensor(0.0592, device='cuda:1')
# current epoch is:  99200
# current loss is:  tensor(-76.8657, device='cuda:1')
# current relative error is:  tensor(0.0334, device='cuda:1')
# current epoch is:  99250
# current loss is:  tensor(-79.6294, device='cuda:1')
# current relative error is:  tensor(0.0579, device='cuda:1')
# current epoch is:  99300
# current loss is:  tensor(-83.1914, device='cuda:1')
# current relative error is:  tensor(0.0594, device='cuda:1')
# current epoch is:  99350
# current loss is:  tensor(-86.0420, device='cuda:1')
# current relative error is:  tensor(0.0874, device='cuda:1')
# current epoch is:  99400
# current loss is:  tensor(-79.2990, device='cuda:1')
# current relative error is:  tensor(0.0874, device='cuda:1')
# current epoch is:  99450
# current loss is:  tensor(-84.6617, device='cuda:1')
# current relative error is:  tensor(0.1373, device='cuda:1')
# current epoch is:  99500
# current loss is:  tensor(-81.4503, device='cuda:1')
# current relative error is:  tensor(0.0321, device='cuda:1')
# current epoch is:  99550
# current loss is:  tensor(-78.0083, device='cuda:1')
# current relative error is:  tensor(0.0363, device='cuda:1')
# current epoch is:  99600
# current loss is:  tensor(-72.1961, device='cuda:1')
# current relative error is:  tensor(0.0615, device='cuda:1')
# current epoch is:  99650
# current loss is:  tensor(-79.8059, device='cuda:1')
# current relative error is:  tensor(0.0278, device='cuda:1')
# current epoch is:  99700
# current loss is:  tensor(-73.3731, device='cuda:1')
# current relative error is:  tensor(0.0848, device='cuda:1')
# current epoch is:  99750
# current loss is:  tensor(-73.2130, device='cuda:1')
# current relative error is:  tensor(0.0546, device='cuda:1')
# current epoch is:  99800
# current loss is:  tensor(-81.4563, device='cuda:1')
# current relative error is:  tensor(0.0343, device='cuda:1')
# current epoch is:  99850
# current loss is:  tensor(-69.1048, device='cuda:1')
# current relative error is:  tensor(0.0365, device='cuda:1')
# current epoch is:  99900
# current loss is:  tensor(-78.9395, device='cuda:1')
# current relative error is:  tensor(0.0608, device='cuda:1')
# current epoch is:  99950
# current loss is:  tensor(-82.5328, device='cuda:1')
# current relative error is:  tensor(0.0368, device='cuda:1')
# total time is:  46402.699214696884 seconds
