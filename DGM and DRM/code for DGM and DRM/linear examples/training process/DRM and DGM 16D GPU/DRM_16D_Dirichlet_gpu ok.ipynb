# %%
import torch
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import torch.nn as nn
from math import *

# %%
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor') # 设置浮点类型为 torch.float64

# %%
# 定义激活函数: swish(x)
def acti(x):
    return x*torch.sigmoid(x)

# %%
# 定义网络结构
class DeepRitzNet(torch.nn.Module):
    def __init__(self, input_width, layer_width):
        super(DeepRitzNet, self).__init__()
        self.linear_in = torch.nn.Linear(input_width, layer_width)
        self.linear1 = torch.nn.Linear(layer_width, layer_width)
        self.linear2 = torch.nn.Linear(layer_width, layer_width)
        self.linear3 = torch.nn.Linear(layer_width, layer_width)
        self.linear4 = torch.nn.Linear(layer_width, layer_width)
        self.linear5 = torch.nn.Linear(layer_width, layer_width)
        self.linear6 = torch.nn.Linear(layer_width, layer_width)
        self.linear_out = torch.nn.Linear(layer_width, 1)

    def forward(self, x):
        y = self.linear_in(x) # fully connect layer
        y = y + acti(self.linear2(acti(self.linear1(y)))) # residual block 1
        y = y + acti(self.linear4(acti(self.linear3(y)))) # residual block 2
        y = y + acti(self.linear6(acti(self.linear5(y)))) # residual block 3
        output = self.linear_out(y) # fully connect layer
        return output

# %%
dimension = 16

# %%
# exact solution
def u_ex(x):  
    x_temp = torch.cos(pi*x)
    u_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return u_x

# %%
def f(x):
    x_temp = torch.cos(pi*x)
    f_x = 2*pi**2*(x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return f_x

# %%
def DRM(x):
    u_hat = model(x)
    ux = torch.zeros(x.size()[0], dimension).cuda()
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension).cuda()
        dx[:, i] = torch.ones(x.size()[0])
        ux[:, i] = (model(x+step_size*dx) - model(x-step_size*dx))[:,0]/step_size/2
    uxsq = (torch.sum(ux**2, dim = 1)).reshape([x.size()[0], 1]) # dim = 1 按行求和
    f_temp = f(x)
    part_1 = torch.sum(0.5 * uxsq + 0.5*pi**2*u_hat**2 - f_temp*u_hat)/x.size()[0]
    
    Nb = 100
    xa1 = torch.rand(Nb, dimension).cuda()  
    xa1[:, 0] = torch.zeros(Nb)
    xa2 = torch.rand(Nb, dimension).cuda()  
    xa2[:, 0] = torch.ones(Nb)
    xb1 = torch.rand(Nb, dimension).cuda() 
    xb1[:, 1] = torch.zeros(Nb)
    xb2 = torch.rand(Nb, dimension).cuda() 
    xb2[:, 1] = torch.ones(Nb)
    xc1 = torch.rand(Nb, dimension).cuda() 
    xc1[:, 2] = torch.zeros(Nb)
    xc2 = torch.rand(Nb, dimension).cuda() 
    xc2[:, 2] = torch.ones(Nb)
    xd1 = torch.rand(Nb, dimension).cuda() 
    xd1[:, 3] = torch.zeros(Nb)
    xd2 = torch.rand(Nb, dimension).cuda() 
    xd2[:, 3] = torch.ones(Nb)
    xe1 = torch.rand(Nb, dimension).cuda()  
    xe1[:, 4] = torch.zeros(Nb)
    xe2 = torch.rand(Nb, dimension).cuda()  
    xe2[:, 4] = torch.ones(Nb)
    xf1 = torch.rand(Nb, dimension).cuda() 
    xf1[:, 5] = torch.zeros(Nb)
    xf2 = torch.rand(Nb, dimension).cuda() 
    xf2[:, 5] = torch.ones(Nb)
    xg1 = torch.rand(Nb, dimension).cuda() 
    xg1[:, 6] = torch.zeros(Nb)
    xg2 = torch.rand(Nb, dimension).cuda() 
    xg2[:, 6] = torch.ones(Nb)
    xh1 = torch.rand(Nb, dimension).cuda() 
    xh1[:, 7] = torch.zeros(Nb)
    xh2 = torch.rand(Nb, dimension).cuda() 
    xh2[:, 7] = torch.ones(Nb)
    xi1 = torch.rand(Nb, dimension).cuda()  
    xi1[:, 8] = torch.zeros(Nb)
    xi2 = torch.rand(Nb, dimension).cuda()  
    xi2[:, 8] = torch.ones(Nb)
    xj1 = torch.rand(Nb, dimension).cuda() 
    xj1[:, 9] = torch.zeros(Nb)
    xj2 = torch.rand(Nb, dimension).cuda() 
    xj2[:, 9] = torch.ones(Nb)
    xk1 = torch.rand(Nb, dimension).cuda() 
    xk1[:, 10] = torch.zeros(Nb)
    xk2 = torch.rand(Nb, dimension).cuda() 
    xk2[:, 10] = torch.ones(Nb)
    xl1 = torch.rand(Nb, dimension).cuda() 
    xl1[:, 11] = torch.zeros(Nb)
    xl2 = torch.rand(Nb, dimension).cuda() 
    xl2[:, 11] = torch.ones(Nb)
    xm1 = torch.rand(Nb, dimension).cuda()  
    xm1[:, 12] = torch.zeros(Nb)
    xm2 = torch.rand(Nb, dimension).cuda()  
    xm2[:, 12] = torch.ones(Nb)
    xn1 = torch.rand(Nb, dimension).cuda() 
    xn1[:, 13] = torch.zeros(Nb)
    xn2 = torch.rand(Nb, dimension).cuda() 
    xn2[:, 13] = torch.ones(Nb)
    xo1 = torch.rand(Nb, dimension).cuda() 
    xo1[:, 14] = torch.zeros(Nb)
    xo2 = torch.rand(Nb, dimension).cuda() 
    xo2[:, 14] = torch.ones(Nb)
    xp1 = torch.rand(Nb, dimension).cuda() 
    xp1[:, 15] = torch.zeros(Nb)
    xp2 = torch.rand(Nb, dimension).cuda() 
    xp2[:, 15] = torch.ones(Nb)
    
    sa1 = (torch.sum((model(xa1)-u_ex(xa1))**2)/xa1.size()[0]).cuda() 
    sa2 = (torch.sum((model(xa2)-u_ex(xa2))**2)/xa1.size()[0]).cuda()  
    sb1 = (torch.sum((model(xb1)-u_ex(xb1))**2)/xa1.size()[0]).cuda()  
    sb2 = (torch.sum((model(xb2)-u_ex(xb2))**2)/xa1.size()[0]).cuda() 
    sc1 = (torch.sum((model(xc1)-u_ex(xc1))**2)/xa1.size()[0]).cuda()  
    sc2 = (torch.sum((model(xc2)-u_ex(xc2))**2)/xa1.size()[0]).cuda() 
    sd1 = (torch.sum((model(xd1)-u_ex(xd1))**2)/xa1.size()[0]).cuda()  
    sd2 = (torch.sum((model(xd2)-u_ex(xd2))**2)/xa1.size()[0]).cuda() 
    se1 = (torch.sum((model(xe1)-u_ex(xe1))**2)/xa1.size()[0]).cuda() 
    se2 = (torch.sum((model(xe2)-u_ex(xe2))**2)/xa1.size()[0]).cuda()  
    sf1 = (torch.sum((model(xf1)-u_ex(xf1))**2)/xa1.size()[0]).cuda()  
    sf2 = (torch.sum((model(xf2)-u_ex(xf2))**2)/xa1.size()[0]).cuda() 
    sg1 = (torch.sum((model(xg1)-u_ex(xg1))**2)/xa1.size()[0]).cuda()  
    sg2 = (torch.sum((model(xg2)-u_ex(xg2))**2)/xa1.size()[0]).cuda() 
    sh1 = (torch.sum((model(xh1)-u_ex(xh1))**2)/xa1.size()[0]).cuda()  
    sh2 = (torch.sum((model(xh2)-u_ex(xh2))**2)/xa1.size()[0]).cuda()
    si1 = (torch.sum((model(xi1)-u_ex(xi1))**2)/xa1.size()[0]).cuda() 
    si2 = (torch.sum((model(xi2)-u_ex(xi2))**2)/xa1.size()[0]).cuda()  
    sj1 = (torch.sum((model(xj1)-u_ex(xj1))**2)/xa1.size()[0]).cuda()  
    sj2 = (torch.sum((model(xj2)-u_ex(xj2))**2)/xa1.size()[0]).cuda() 
    sk1 = (torch.sum((model(xk1)-u_ex(xk1))**2)/xa1.size()[0]).cuda()  
    sk2 = (torch.sum((model(xk2)-u_ex(xk2))**2)/xa1.size()[0]).cuda() 
    sl1 = (torch.sum((model(xl1)-u_ex(xl1))**2)/xa1.size()[0]).cuda()  
    sl2 = (torch.sum((model(xl2)-u_ex(xl2))**2)/xa1.size()[0]).cuda() 
    sm1 = (torch.sum((model(xm1)-u_ex(xm1))**2)/xa1.size()[0]).cuda() 
    sm2 = (torch.sum((model(xm2)-u_ex(xm2))**2)/xa1.size()[0]).cuda()  
    sn1 = (torch.sum((model(xn1)-u_ex(xn1))**2)/xa1.size()[0]).cuda()  
    sn2 = (torch.sum((model(xn2)-u_ex(xn2))**2)/xa1.size()[0]).cuda() 
    so1 = (torch.sum((model(xo1)-u_ex(xo1))**2)/xa1.size()[0]).cuda()  
    so2 = (torch.sum((model(xo2)-u_ex(xo2))**2)/xa1.size()[0]).cuda() 
    sp1 = (torch.sum((model(xp1)-u_ex(xp1))**2)/xa1.size()[0]).cuda()  
    sp2 = (torch.sum((model(xp2)-u_ex(xp2))**2)/xa1.size()[0]).cuda()
    
    part_2 = sa1 + sa2 + sb1 + sb2 + sc1 + sc2 + sd1 + sd2 + se1 + se2 + sf1 + sf2 + sg1 + sg2 + sh1 + sh2 + si1 + si2 + sj1 + sj2 + sk1 + sk2 + sl1 + sl2 + sm1 + sm2 + sn1 + sn2 + so1 + so2 + sp1 + sp2
    
    lambda1 = 100.0
    return part_1 + lambda1 * part_2 / 32

# %%
Data_size = 2000
def Gendata():
    x = torch.rand(Data_size, dimension)
    return x.cuda()

# %%
# 正态分布初始化参数
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = DeepRitzNet(dimension, 32)
model = initparam(model, 0.5)

# %%
device = torch.device("cuda:1" )
model.to(device)
# Out:
# DeepRitzNet(
#   (linear_in): Linear(in_features=16, out_features=32, bias=True)
#   (linear1): Linear(in_features=32, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=32, bias=True)
#   (linear3): Linear(in_features=32, out_features=32, bias=True)
#   (linear4): Linear(in_features=32, out_features=32, bias=True)
#   (linear5): Linear(in_features=32, out_features=32, bias=True)
#   (linear6): Linear(in_features=32, out_features=32, bias=True)
#   (linear_out): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
import torch.optim as optim
import torch.nn as nn
import time

# %%
def relative_error():
    x = Gendata()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
traintime = 100000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = Gendata()
    x.requires_grad = True
    losses = DRM(x)
    losses.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", losses.detach())
        print("current relative error is: ", error.detach())
        np.save("DRM_relative_error_16D_Dirichlet.npy", error_save)
np.save("DRM_relative_error_16D_Dirichlet.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(3348489.1440, device='cuda:1')
# current relative error is:  tensor(54.7438, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(60899.0425, device='cuda:1')
# current relative error is:  tensor(6.8291, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(26286.1007, device='cuda:1')
# current relative error is:  tensor(4.5317, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(17501.9980, device='cuda:1')
# current relative error is:  tensor(3.5263, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(12767.6523, device='cuda:1')
# current relative error is:  tensor(3.0775, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(9512.5114, device='cuda:1')
# current relative error is:  tensor(2.7049, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(8416.5941, device='cuda:1')
# current relative error is:  tensor(2.4580, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(6550.7584, device='cuda:1')
# current relative error is:  tensor(2.2332, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(5406.9034, device='cuda:1')
# current relative error is:  tensor(2.1026, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(4729.8025, device='cuda:1')
# current relative error is:  tensor(1.8818, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(4094.1153, device='cuda:1')
# current relative error is:  tensor(1.8252, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(3665.0222, device='cuda:1')
# current relative error is:  tensor(1.6443, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(3222.8404, device='cuda:1')
# current relative error is:  tensor(1.5568, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(2787.4474, device='cuda:1')
# current relative error is:  tensor(1.5199, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(2542.1636, device='cuda:1')
# current relative error is:  tensor(1.3829, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(2324.6314, device='cuda:1')
# current relative error is:  tensor(1.3070, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(2066.4087, device='cuda:1')
# current relative error is:  tensor(1.3070, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(1879.4529, device='cuda:1')
# current relative error is:  tensor(1.2076, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(1615.7694, device='cuda:1')
# current relative error is:  tensor(1.1564, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(1457.1341, device='cuda:1')
# current relative error is:  tensor(1.1131, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(1363.6546, device='cuda:1')
# current relative error is:  tensor(1.0760, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(1216.7636, device='cuda:1')
# current relative error is:  tensor(0.9934, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(1099.1821, device='cuda:1')
# current relative error is:  tensor(0.9261, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(1045.7740, device='cuda:1')
# current relative error is:  tensor(0.9248, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(922.1926, device='cuda:1')
# current relative error is:  tensor(0.8750, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(847.4162, device='cuda:1')
# current relative error is:  tensor(0.8693, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(795.0308, device='cuda:1')
# current relative error is:  tensor(0.7363, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(699.2657, device='cuda:1')
# current relative error is:  tensor(0.7809, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(637.9273, device='cuda:1')
# current relative error is:  tensor(0.7693, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(584.4049, device='cuda:1')
# current relative error is:  tensor(0.7046, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(553.0859, device='cuda:1')
# current relative error is:  tensor(0.6727, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(494.1275, device='cuda:1')
# current relative error is:  tensor(0.6518, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(454.6337, device='cuda:1')
# current relative error is:  tensor(0.6260, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(410.3795, device='cuda:1')
# current relative error is:  tensor(0.5891, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(368.1740, device='cuda:1')
# current relative error is:  tensor(0.5805, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(341.6207, device='cuda:1')
# current relative error is:  tensor(0.5389, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(313.5577, device='cuda:1')
# current relative error is:  tensor(0.5281, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(284.2024, device='cuda:1')
# current relative error is:  tensor(0.5113, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(255.4572, device='cuda:1')
# current relative error is:  tensor(0.5203, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(253.6353, device='cuda:1')
# current relative error is:  tensor(0.4657, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(224.2215, device='cuda:1')
# current relative error is:  tensor(0.4670, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(192.1091, device='cuda:1')
# current relative error is:  tensor(0.4325, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(172.3089, device='cuda:1')
# current relative error is:  tensor(0.4395, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(162.1122, device='cuda:1')
# current relative error is:  tensor(0.3996, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(144.5760, device='cuda:1')
# current relative error is:  tensor(0.3830, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(126.5807, device='cuda:1')
# current relative error is:  tensor(0.3869, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(113.5981, device='cuda:1')
# current relative error is:  tensor(0.3753, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(81.1121, device='cuda:1')
# current relative error is:  tensor(0.3274, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(88.1963, device='cuda:1')
# current relative error is:  tensor(0.3144, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(59.7035, device='cuda:1')
# current relative error is:  tensor(0.3355, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(52.6623, device='cuda:1')
# current relative error is:  tensor(0.3145, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(50.3978, device='cuda:1')
# current relative error is:  tensor(0.3014, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(38.1520, device='cuda:1')
# current relative error is:  tensor(0.2842, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(35.0043, device='cuda:1')
# current relative error is:  tensor(0.2786, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(22.5414, device='cuda:1')
# current relative error is:  tensor(0.2738, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(33.3912, device='cuda:1')
# current relative error is:  tensor(0.2648, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(11.3525, device='cuda:1')
# current relative error is:  tensor(0.2588, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(20.1481, device='cuda:1')
# current relative error is:  tensor(0.2480, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(7.1585, device='cuda:1')
# current relative error is:  tensor(0.2615, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(2.7297, device='cuda:1')
# current relative error is:  tensor(0.2426, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(-2.1876, device='cuda:1')
# current relative error is:  tensor(0.2402, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(4.7586, device='cuda:1')
# current relative error is:  tensor(0.2319, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(-3.5325, device='cuda:1')
# current relative error is:  tensor(0.2496, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(-5.7942, device='cuda:1')
# current relative error is:  tensor(0.2180, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(-14.5376, device='cuda:1')
# current relative error is:  tensor(0.2190, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(-17.6762, device='cuda:1')
# current relative error is:  tensor(0.2166, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(-21.8847, device='cuda:1')
# current relative error is:  tensor(0.2158, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(-14.8232, device='cuda:1')
# current relative error is:  tensor(0.2258, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(-12.0814, device='cuda:1')
# current relative error is:  tensor(0.2023, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(-27.9919, device='cuda:1')
# current relative error is:  tensor(0.1995, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(-21.4307, device='cuda:1')
# current relative error is:  tensor(0.1893, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(-14.4509, device='cuda:1')
# current relative error is:  tensor(0.2067, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(-31.9884, device='cuda:1')
# current relative error is:  tensor(0.2063, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(-25.3613, device='cuda:1')
# current relative error is:  tensor(0.1984, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(-24.0535, device='cuda:1')
# current relative error is:  tensor(0.1895, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(-23.9496, device='cuda:1')
# current relative error is:  tensor(0.1999, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(-30.8752, device='cuda:1')
# current relative error is:  tensor(0.1916, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(-29.6943, device='cuda:1')
# current relative error is:  tensor(0.1796, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(-27.4663, device='cuda:1')
# current relative error is:  tensor(0.1879, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(-31.2165, device='cuda:1')
# current relative error is:  tensor(0.1771, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(-35.0332, device='cuda:1')
# current relative error is:  tensor(0.1792, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(-23.7615, device='cuda:1')
# current relative error is:  tensor(0.1985, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(-36.7347, device='cuda:1')
# current relative error is:  tensor(0.1874, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(-39.8104, device='cuda:1')
# current relative error is:  tensor(0.1795, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(-24.4747, device='cuda:1')
# current relative error is:  tensor(0.1794, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(-36.1284, device='cuda:1')
# current relative error is:  tensor(0.1825, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(-35.0446, device='cuda:1')
# current relative error is:  tensor(0.1872, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(-38.9617, device='cuda:1')
# current relative error is:  tensor(0.1734, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(-36.9274, device='cuda:1')
# current relative error is:  tensor(0.1755, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(-35.0172, device='cuda:1')
# current relative error is:  tensor(0.1701, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(-28.1416, device='cuda:1')
# current relative error is:  tensor(0.2117, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(-46.5905, device='cuda:1')
# current relative error is:  tensor(0.1661, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(-41.8383, device='cuda:1')
# current relative error is:  tensor(0.1712, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(-37.2976, device='cuda:1')
# current relative error is:  tensor(0.1600, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(-9.0705, device='cuda:1')
# current relative error is:  tensor(0.2393, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(-44.7540, device='cuda:1')
# current relative error is:  tensor(0.1666, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(-28.2981, device='cuda:1')
# current relative error is:  tensor(0.1582, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(-34.1950, device='cuda:1')
# current relative error is:  tensor(0.1622, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(-44.3783, device='cuda:1')
# current relative error is:  tensor(0.1619, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(-34.6129, device='cuda:1')
# current relative error is:  tensor(0.1967, device='cuda:1')
# current epoch is:  5000
# current loss is:  tensor(-36.0313, device='cuda:1')
# current relative error is:  tensor(0.1918, device='cuda:1')
# current epoch is:  5050
# current loss is:  tensor(-39.8864, device='cuda:1')
# current relative error is:  tensor(0.1514, device='cuda:1')
# current epoch is:  5100
# current loss is:  tensor(8.0114, device='cuda:1')
# current relative error is:  tensor(0.2696, device='cuda:1')
# current epoch is:  5150
# current loss is:  tensor(-47.5303, device='cuda:1')
# current relative error is:  tensor(0.1609, device='cuda:1')
# current epoch is:  5200
# current loss is:  tensor(-45.3295, device='cuda:1')
# current relative error is:  tensor(0.1520, device='cuda:1')
# current epoch is:  5250
# current loss is:  tensor(-37.1758, device='cuda:1')
# current relative error is:  tensor(0.1757, device='cuda:1')
# current epoch is:  5300
# current loss is:  tensor(-40.3786, device='cuda:1')
# current relative error is:  tensor(0.1607, device='cuda:1')
# current epoch is:  5350
# current loss is:  tensor(-45.0774, device='cuda:1')
# current relative error is:  tensor(0.1477, device='cuda:1')
# current epoch is:  5400
# current loss is:  tensor(-44.1233, device='cuda:1')
# current relative error is:  tensor(0.1655, device='cuda:1')
# current epoch is:  5450
# current loss is:  tensor(-43.3853, device='cuda:1')
# current relative error is:  tensor(0.1514, device='cuda:1')
# current epoch is:  5500
# current loss is:  tensor(-36.8031, device='cuda:1')
# current relative error is:  tensor(0.1501, device='cuda:1')
# current epoch is:  5550
# current loss is:  tensor(-56.9041, device='cuda:1')
# current relative error is:  tensor(0.1552, device='cuda:1')
# current epoch is:  5600
# current loss is:  tensor(-18.1232, device='cuda:1')
# current relative error is:  tensor(0.2598, device='cuda:1')
# current epoch is:  5650
# current loss is:  tensor(-45.5553, device='cuda:1')
# current relative error is:  tensor(0.1748, device='cuda:1')
# current epoch is:  5700
# current loss is:  tensor(-37.7504, device='cuda:1')
# current relative error is:  tensor(0.1663, device='cuda:1')
# current epoch is:  5750
# current loss is:  tensor(-43.5264, device='cuda:1')
# current relative error is:  tensor(0.1574, device='cuda:1')
# current epoch is:  5800
# current loss is:  tensor(-48.1306, device='cuda:1')
# current relative error is:  tensor(0.1449, device='cuda:1')
# current epoch is:  5850
# current loss is:  tensor(9.6920, device='cuda:1')
# current relative error is:  tensor(0.2655, device='cuda:1')
# current epoch is:  5900
# current loss is:  tensor(-50.1129, device='cuda:1')
# current relative error is:  tensor(0.1494, device='cuda:1')
# current epoch is:  5950
# current loss is:  tensor(-49.5977, device='cuda:1')
# current relative error is:  tensor(0.1495, device='cuda:1')
# current epoch is:  6000
# current loss is:  tensor(-53.1534, device='cuda:1')
# current relative error is:  tensor(0.1530, device='cuda:1')
# current epoch is:  6050
# current loss is:  tensor(-45.1279, device='cuda:1')
# current relative error is:  tensor(0.1651, device='cuda:1')
# current epoch is:  6100
# current loss is:  tensor(-16.2594, device='cuda:1')
# current relative error is:  tensor(0.2139, device='cuda:1')
# current epoch is:  6150
# current loss is:  tensor(-33.3464, device='cuda:1')
# current relative error is:  tensor(0.1873, device='cuda:1')
# current epoch is:  6200
# current loss is:  tensor(-47.2727, device='cuda:1')
# current relative error is:  tensor(0.1728, device='cuda:1')
# current epoch is:  6250
# current loss is:  tensor(-44.5577, device='cuda:1')
# current relative error is:  tensor(0.1480, device='cuda:1')
# current epoch is:  6300
# current loss is:  tensor(-46.3486, device='cuda:1')
# current relative error is:  tensor(0.1509, device='cuda:1')
# current epoch is:  6350
# current loss is:  tensor(-42.0418, device='cuda:1')
# current relative error is:  tensor(0.1609, device='cuda:1')
# current epoch is:  6400
# current loss is:  tensor(-39.8676, device='cuda:1')
# current relative error is:  tensor(0.1600, device='cuda:1')
# current epoch is:  6450
# current loss is:  tensor(-41.7607, device='cuda:1')
# current relative error is:  tensor(0.1500, device='cuda:1')
# current epoch is:  6500
# current loss is:  tensor(-45.3747, device='cuda:1')
# current relative error is:  tensor(0.1486, device='cuda:1')
# current epoch is:  6550
# current loss is:  tensor(-47.4195, device='cuda:1')
# current relative error is:  tensor(0.1429, device='cuda:1')
# current epoch is:  6600
# current loss is:  tensor(-41.3728, device='cuda:1')
# current relative error is:  tensor(0.1476, device='cuda:1')
# current epoch is:  6650
# current loss is:  tensor(-27.6663, device='cuda:1')
# current relative error is:  tensor(0.1827, device='cuda:1')
# current epoch is:  6700
# current loss is:  tensor(105.0201, device='cuda:1')
# current relative error is:  tensor(0.4992, device='cuda:1')
# current epoch is:  6750
# current loss is:  tensor(-45.1152, device='cuda:1')
# current relative error is:  tensor(0.1416, device='cuda:1')
# current epoch is:  6800
# current loss is:  tensor(-49.6621, device='cuda:1')
# current relative error is:  tensor(0.1400, device='cuda:1')
# current epoch is:  6850
# current loss is:  tensor(-40.1321, device='cuda:1')
# current relative error is:  tensor(0.1828, device='cuda:1')
# current epoch is:  6900
# current loss is:  tensor(-39.0289, device='cuda:1')
# current relative error is:  tensor(0.1966, device='cuda:1')
# current epoch is:  6950
# current loss is:  tensor(-47.5758, device='cuda:1')
# current relative error is:  tensor(0.1537, device='cuda:1')
# current epoch is:  7000
# current loss is:  tensor(-47.6212, device='cuda:1')
# current relative error is:  tensor(0.1458, device='cuda:1')
# current epoch is:  7050
# current loss is:  tensor(-48.6183, device='cuda:1')
# current relative error is:  tensor(0.1523, device='cuda:1')
# current epoch is:  7100
# current loss is:  tensor(-18.9274, device='cuda:1')
# current relative error is:  tensor(0.1542, device='cuda:1')
# current epoch is:  7150
# current loss is:  tensor(-50.7988, device='cuda:1')
# current relative error is:  tensor(0.1407, device='cuda:1')
# current epoch is:  7200
# current loss is:  tensor(-50.8746, device='cuda:1')
# current relative error is:  tensor(0.1552, device='cuda:1')
# current epoch is:  7250
# current loss is:  tensor(-57.6939, device='cuda:1')
# current relative error is:  tensor(0.1377, device='cuda:1')
# current epoch is:  7300
# current loss is:  tensor(-50.9173, device='cuda:1')
# current relative error is:  tensor(0.1405, device='cuda:1')
# current epoch is:  7350
# current loss is:  tensor(-35.7702, device='cuda:1')
# current relative error is:  tensor(0.1644, device='cuda:1')
# current epoch is:  7400
# current loss is:  tensor(-36.1893, device='cuda:1')
# current relative error is:  tensor(0.1728, device='cuda:1')
# current epoch is:  7450
# current loss is:  tensor(-49.4896, device='cuda:1')
# current relative error is:  tensor(0.1462, device='cuda:1')
# current epoch is:  7500
# current loss is:  tensor(-46.3236, device='cuda:1')
# current relative error is:  tensor(0.1448, device='cuda:1')
# current epoch is:  7550
# current loss is:  tensor(-34.7476, device='cuda:1')
# current relative error is:  tensor(0.1800, device='cuda:1')
# current epoch is:  7600
# current loss is:  tensor(-50.0207, device='cuda:1')
# current relative error is:  tensor(0.1488, device='cuda:1')
# current epoch is:  7650
# current loss is:  tensor(-51.7336, device='cuda:1')
# current relative error is:  tensor(0.2056, device='cuda:1')
# current epoch is:  7700
# current loss is:  tensor(-53.0227, device='cuda:1')
# current relative error is:  tensor(0.1389, device='cuda:1')
# current epoch is:  7750
# current loss is:  tensor(-48.7230, device='cuda:1')
# current relative error is:  tensor(0.1473, device='cuda:1')
# current epoch is:  7800
# current loss is:  tensor(-43.7683, device='cuda:1')
# current relative error is:  tensor(0.1683, device='cuda:1')
# current epoch is:  7850
# current loss is:  tensor(-52.2190, device='cuda:1')
# current relative error is:  tensor(0.1365, device='cuda:1')
# current epoch is:  7900
# current loss is:  tensor(-53.0277, device='cuda:1')
# current relative error is:  tensor(0.1365, device='cuda:1')
# current epoch is:  7950
# current loss is:  tensor(-21.0856, device='cuda:1')
# current relative error is:  tensor(0.2368, device='cuda:1')
# current epoch is:  8000
# current loss is:  tensor(-44.0213, device='cuda:1')
# current relative error is:  tensor(0.1400, device='cuda:1')
# current epoch is:  8050
# current loss is:  tensor(-49.7631, device='cuda:1')
# current relative error is:  tensor(0.1475, device='cuda:1')
# current epoch is:  8100
# current loss is:  tensor(-56.8570, device='cuda:1')
# current relative error is:  tensor(0.1479, device='cuda:1')
# current epoch is:  8150
# current loss is:  tensor(-46.8357, device='cuda:1')
# current relative error is:  tensor(0.1371, device='cuda:1')
# current epoch is:  8200
# current loss is:  tensor(-51.5593, device='cuda:1')
# current relative error is:  tensor(0.1367, device='cuda:1')
# current epoch is:  8250
# current loss is:  tensor(-47.6278, device='cuda:1')
# current relative error is:  tensor(0.1393, device='cuda:1')
# current epoch is:  8300
# current loss is:  tensor(-53.9225, device='cuda:1')
# current relative error is:  tensor(0.1369, device='cuda:1')
# current epoch is:  8350
# current loss is:  tensor(-53.0244, device='cuda:1')
# current relative error is:  tensor(0.1565, device='cuda:1')
# current epoch is:  8400
# current loss is:  tensor(-50.5880, device='cuda:1')
# current relative error is:  tensor(0.1414, device='cuda:1')
# current epoch is:  8450
# current loss is:  tensor(31.9761, device='cuda:1')
# current relative error is:  tensor(0.3747, device='cuda:1')
# current epoch is:  8500
# current loss is:  tensor(-40.7944, device='cuda:1')
# current relative error is:  tensor(0.1702, device='cuda:1')
# current epoch is:  8550
# current loss is:  tensor(-46.2274, device='cuda:1')
# current relative error is:  tensor(0.1397, device='cuda:1')
# current epoch is:  8600
# current loss is:  tensor(-49.0977, device='cuda:1')
# current relative error is:  tensor(0.1417, device='cuda:1')
# current epoch is:  8650
# current loss is:  tensor(-40.1454, device='cuda:1')
# current relative error is:  tensor(0.1908, device='cuda:1')
# current epoch is:  8700
# current loss is:  tensor(-28.4576, device='cuda:1')
# current relative error is:  tensor(0.2195, device='cuda:1')
# current epoch is:  8750
# current loss is:  tensor(-34.1479, device='cuda:1')
# current relative error is:  tensor(0.1864, device='cuda:1')
# current epoch is:  8800
# current loss is:  tensor(-42.1928, device='cuda:1')
# current relative error is:  tensor(0.1861, device='cuda:1')
# current epoch is:  8850
# current loss is:  tensor(-51.8883, device='cuda:1')
# current relative error is:  tensor(0.1457, device='cuda:1')
# current epoch is:  8900
# current loss is:  tensor(-49.4044, device='cuda:1')
# current relative error is:  tensor(0.1284, device='cuda:1')
# current epoch is:  8950
# current loss is:  tensor(-52.3529, device='cuda:1')
# current relative error is:  tensor(0.1486, device='cuda:1')
# current epoch is:  9000
# current loss is:  tensor(-52.1173, device='cuda:1')
# current relative error is:  tensor(0.1355, device='cuda:1')
# current epoch is:  9050
# current loss is:  tensor(-49.5487, device='cuda:1')
# current relative error is:  tensor(0.1344, device='cuda:1')
# current epoch is:  9100
# current loss is:  tensor(-55.7967, device='cuda:1')
# current relative error is:  tensor(0.1424, device='cuda:1')
# current epoch is:  9150
# current loss is:  tensor(-41.4524, device='cuda:1')
# current relative error is:  tensor(0.1474, device='cuda:1')
# current epoch is:  9200
# current loss is:  tensor(25.5759, device='cuda:1')
# current relative error is:  tensor(0.3383, device='cuda:1')
# current epoch is:  9250
# current loss is:  tensor(-56.3555, device='cuda:1')
# current relative error is:  tensor(0.1325, device='cuda:1')
# current epoch is:  9300
# current loss is:  tensor(-49.3293, device='cuda:1')
# current relative error is:  tensor(0.1370, device='cuda:1')
# current epoch is:  9350
# current loss is:  tensor(-18.4525, device='cuda:1')
# current relative error is:  tensor(0.2316, device='cuda:1')
# current epoch is:  9400
# current loss is:  tensor(-9.9028, device='cuda:1')
# current relative error is:  tensor(0.2538, device='cuda:1')
# current epoch is:  9450
# current loss is:  tensor(-37.4677, device='cuda:1')
# current relative error is:  tensor(0.1912, device='cuda:1')
# current epoch is:  9500
# current loss is:  tensor(-46.3772, device='cuda:1')
# current relative error is:  tensor(0.1437, device='cuda:1')
# current epoch is:  9550
# current loss is:  tensor(-44.0263, device='cuda:1')
# current relative error is:  tensor(0.2081, device='cuda:1')
# current epoch is:  9600
# current loss is:  tensor(-52.1383, device='cuda:1')
# current relative error is:  tensor(0.1420, device='cuda:1')
# current epoch is:  9650
# current loss is:  tensor(-35.7634, device='cuda:1')
# current relative error is:  tensor(0.2018, device='cuda:1')
# current epoch is:  9700
# current loss is:  tensor(-56.8691, device='cuda:1')
# current relative error is:  tensor(0.1339, device='cuda:1')
# current epoch is:  9750
# current loss is:  tensor(-48.7654, device='cuda:1')
# current relative error is:  tensor(0.1423, device='cuda:1')
# current epoch is:  9800
# current loss is:  tensor(-51.8818, device='cuda:1')
# current relative error is:  tensor(0.1506, device='cuda:1')
# current epoch is:  9850
# current loss is:  tensor(-45.2226, device='cuda:1')
# current relative error is:  tensor(0.1326, device='cuda:1')
# current epoch is:  9900
# current loss is:  tensor(-53.1007, device='cuda:1')
# current relative error is:  tensor(0.1320, device='cuda:1')
# current epoch is:  9950
# current loss is:  tensor(-47.9764, device='cuda:1')
# current relative error is:  tensor(0.1502, device='cuda:1')
# current epoch is:  10000
# current loss is:  tensor(-12.2122, device='cuda:1')
# current relative error is:  tensor(0.2240, device='cuda:1')
# current epoch is:  10050
# current loss is:  tensor(-48.2735, device='cuda:1')
# current relative error is:  tensor(0.1343, device='cuda:1')
# current epoch is:  10100
# current loss is:  tensor(-52.0002, device='cuda:1')
# current relative error is:  tensor(0.1737, device='cuda:1')
# current epoch is:  10150
# current loss is:  tensor(-55.9715, device='cuda:1')
# current relative error is:  tensor(0.1317, device='cuda:1')
# current epoch is:  10200
# current loss is:  tensor(-51.7359, device='cuda:1')
# current relative error is:  tensor(0.1299, device='cuda:1')
# current epoch is:  10250
# current loss is:  tensor(-46.9209, device='cuda:1')
# current relative error is:  tensor(0.1456, device='cuda:1')
# current epoch is:  10300
# current loss is:  tensor(-38.7645, device='cuda:1')
# current relative error is:  tensor(0.1636, device='cuda:1')
# current epoch is:  10350
# current loss is:  tensor(-49.9677, device='cuda:1')
# current relative error is:  tensor(0.1349, device='cuda:1')
# current epoch is:  10400
# current loss is:  tensor(-53.2557, device='cuda:1')
# current relative error is:  tensor(0.1319, device='cuda:1')
# current epoch is:  10450
# current loss is:  tensor(-15.0646, device='cuda:1')
# current relative error is:  tensor(0.2600, device='cuda:1')
# current epoch is:  10500
# current loss is:  tensor(-50.9353, device='cuda:1')
# current relative error is:  tensor(0.1616, device='cuda:1')
# current epoch is:  10550
# current loss is:  tensor(-44.3998, device='cuda:1')
# current relative error is:  tensor(0.1608, device='cuda:1')
# current epoch is:  10600
# current loss is:  tensor(-53.3586, device='cuda:1')
# current relative error is:  tensor(0.1249, device='cuda:1')
# current epoch is:  10650
# current loss is:  tensor(-50.6672, device='cuda:1')
# current relative error is:  tensor(0.1366, device='cuda:1')
# current epoch is:  10700
# current loss is:  tensor(-53.6485, device='cuda:1')
# current relative error is:  tensor(0.1345, device='cuda:1')
# current epoch is:  10750
# current loss is:  tensor(-48.8732, device='cuda:1')
# current relative error is:  tensor(0.1374, device='cuda:1')
# current epoch is:  10800
# current loss is:  tensor(3.0412, device='cuda:1')
# current relative error is:  tensor(0.2656, device='cuda:1')
# current epoch is:  10850
# current loss is:  tensor(-53.2707, device='cuda:1')
# current relative error is:  tensor(0.1318, device='cuda:1')
# current epoch is:  10900
# current loss is:  tensor(-47.7855, device='cuda:1')
# current relative error is:  tensor(0.1541, device='cuda:1')
# current epoch is:  10950
# current loss is:  tensor(-54.0757, device='cuda:1')
# current relative error is:  tensor(0.1307, device='cuda:1')
# current epoch is:  11000
# current loss is:  tensor(-52.8619, device='cuda:1')
# current relative error is:  tensor(0.1344, device='cuda:1')
# current epoch is:  11050
# current loss is:  tensor(-55.2725, device='cuda:1')
# current relative error is:  tensor(0.1294, device='cuda:1')
# current epoch is:  11100
# current loss is:  tensor(-54.2361, device='cuda:1')
# current relative error is:  tensor(0.1428, device='cuda:1')
# current epoch is:  11150
# current loss is:  tensor(-55.1840, device='cuda:1')
# current relative error is:  tensor(0.1317, device='cuda:1')
# current epoch is:  11200
# current loss is:  tensor(-51.3419, device='cuda:1')
# current relative error is:  tensor(0.1328, device='cuda:1')
# current epoch is:  11250
# current loss is:  tensor(-13.1454, device='cuda:1')
# current relative error is:  tensor(0.3113, device='cuda:1')
# current epoch is:  11300
# current loss is:  tensor(-51.0977, device='cuda:1')
# current relative error is:  tensor(0.1264, device='cuda:1')
# current epoch is:  11350
# current loss is:  tensor(-49.5559, device='cuda:1')
# current relative error is:  tensor(0.1283, device='cuda:1')
# current epoch is:  11400
# current loss is:  tensor(-56.6621, device='cuda:1')
# current relative error is:  tensor(0.1294, device='cuda:1')
# current epoch is:  11450
# current loss is:  tensor(-53.3749, device='cuda:1')
# current relative error is:  tensor(0.1433, device='cuda:1')
# current epoch is:  11500
# current loss is:  tensor(-49.6944, device='cuda:1')
# current relative error is:  tensor(0.1487, device='cuda:1')
# current epoch is:  11550
# current loss is:  tensor(-42.6016, device='cuda:1')
# current relative error is:  tensor(0.1365, device='cuda:1')
# current epoch is:  11600
# current loss is:  tensor(-54.8522, device='cuda:1')
# current relative error is:  tensor(0.1253, device='cuda:1')
# current epoch is:  11650
# current loss is:  tensor(-57.4669, device='cuda:1')
# current relative error is:  tensor(0.1458, device='cuda:1')
# current epoch is:  11700
# current loss is:  tensor(-45.5544, device='cuda:1')
# current relative error is:  tensor(0.1346, device='cuda:1')
# current epoch is:  11750
# current loss is:  tensor(-46.9895, device='cuda:1')
# current relative error is:  tensor(0.1594, device='cuda:1')
# current epoch is:  11800
# current loss is:  tensor(-39.0556, device='cuda:1')
# current relative error is:  tensor(0.1527, device='cuda:1')
# current epoch is:  11850
# current loss is:  tensor(-52.9080, device='cuda:1')
# current relative error is:  tensor(0.1306, device='cuda:1')
# current epoch is:  11900
# current loss is:  tensor(-14.2580, device='cuda:1')
# current relative error is:  tensor(0.1917, device='cuda:1')
# current epoch is:  11950
# current loss is:  tensor(-52.9244, device='cuda:1')
# current relative error is:  tensor(0.1346, device='cuda:1')
# current epoch is:  12000
# current loss is:  tensor(-60.5793, device='cuda:1')
# current relative error is:  tensor(0.1346, device='cuda:1')
# current epoch is:  12050
# current loss is:  tensor(-52.1243, device='cuda:1')
# current relative error is:  tensor(0.1509, device='cuda:1')
# current epoch is:  12100
# current loss is:  tensor(-53.0469, device='cuda:1')
# current relative error is:  tensor(0.1258, device='cuda:1')
# current epoch is:  12150
# current loss is:  tensor(-52.6024, device='cuda:1')
# current relative error is:  tensor(0.1235, device='cuda:1')
# current epoch is:  12200
# current loss is:  tensor(-52.2405, device='cuda:1')
# current relative error is:  tensor(0.1501, device='cuda:1')
# current epoch is:  12250
# current loss is:  tensor(-53.4943, device='cuda:1')
# current relative error is:  tensor(0.1386, device='cuda:1')
# current epoch is:  12300
# current loss is:  tensor(-49.8562, device='cuda:1')
# current relative error is:  tensor(0.1314, device='cuda:1')
# current epoch is:  12350
# current loss is:  tensor(-51.5696, device='cuda:1')
# current relative error is:  tensor(0.1564, device='cuda:1')
# current epoch is:  12400
# current loss is:  tensor(-51.5960, device='cuda:1')
# current relative error is:  tensor(0.1298, device='cuda:1')
# current epoch is:  12450
# current loss is:  tensor(-54.1599, device='cuda:1')
# current relative error is:  tensor(0.1231, device='cuda:1')
# current epoch is:  12500
# current loss is:  tensor(-46.4165, device='cuda:1')
# current relative error is:  tensor(0.1553, device='cuda:1')
# current epoch is:  12550
# current loss is:  tensor(-44.9547, device='cuda:1')
# current relative error is:  tensor(0.1569, device='cuda:1')
# current epoch is:  12600
# current loss is:  tensor(-52.6905, device='cuda:1')
# current relative error is:  tensor(0.1234, device='cuda:1')
# current epoch is:  12650
# current loss is:  tensor(-50.5324, device='cuda:1')
# current relative error is:  tensor(0.1367, device='cuda:1')
# current epoch is:  12700
# current loss is:  tensor(-49.4036, device='cuda:1')
# current relative error is:  tensor(0.1420, device='cuda:1')
# current epoch is:  12750
# current loss is:  tensor(-50.9781, device='cuda:1')
# current relative error is:  tensor(0.1820, device='cuda:1')
# current epoch is:  12800
# current loss is:  tensor(-54.5935, device='cuda:1')
# current relative error is:  tensor(0.1254, device='cuda:1')
# current epoch is:  12850
# current loss is:  tensor(-49.9865, device='cuda:1')
# current relative error is:  tensor(0.1236, device='cuda:1')
# current epoch is:  12900
# current loss is:  tensor(-50.4324, device='cuda:1')
# current relative error is:  tensor(0.1238, device='cuda:1')
# current epoch is:  12950
# current loss is:  tensor(-48.2258, device='cuda:1')
# current relative error is:  tensor(0.1424, device='cuda:1')
# current epoch is:  13000
# current loss is:  tensor(-53.7692, device='cuda:1')
# current relative error is:  tensor(0.1271, device='cuda:1')
# current epoch is:  13050
# current loss is:  tensor(-49.4741, device='cuda:1')
# current relative error is:  tensor(0.1359, device='cuda:1')
# current epoch is:  13100
# current loss is:  tensor(-57.6135, device='cuda:1')
# current relative error is:  tensor(0.1224, device='cuda:1')
# current epoch is:  13150
# current loss is:  tensor(-53.3180, device='cuda:1')
# current relative error is:  tensor(0.1240, device='cuda:1')
# current epoch is:  13200
# current loss is:  tensor(-61.8968, device='cuda:1')
# current relative error is:  tensor(0.1307, device='cuda:1')
# current epoch is:  13250
# current loss is:  tensor(-44.2564, device='cuda:1')
# current relative error is:  tensor(0.1771, device='cuda:1')
# current epoch is:  13300
# current loss is:  tensor(-51.2913, device='cuda:1')
# current relative error is:  tensor(0.1344, device='cuda:1')
# current epoch is:  13350
# current loss is:  tensor(-55.3684, device='cuda:1')
# current relative error is:  tensor(0.1206, device='cuda:1')
# current epoch is:  13400
# current loss is:  tensor(-60.3604, device='cuda:1')
# current relative error is:  tensor(0.1223, device='cuda:1')
# current epoch is:  13450
# current loss is:  tensor(-52.8726, device='cuda:1')
# current relative error is:  tensor(0.1357, device='cuda:1')
# current epoch is:  13500
# current loss is:  tensor(-56.3262, device='cuda:1')
# current relative error is:  tensor(0.1216, device='cuda:1')
# current epoch is:  13550
# current loss is:  tensor(-58.1979, device='cuda:1')
# current relative error is:  tensor(0.1265, device='cuda:1')
# current epoch is:  13600
# current loss is:  tensor(-56.7727, device='cuda:1')
# current relative error is:  tensor(0.1223, device='cuda:1')
# current epoch is:  13650
# current loss is:  tensor(-52.1724, device='cuda:1')
# current relative error is:  tensor(0.1242, device='cuda:1')
# current epoch is:  13700
# current loss is:  tensor(-57.4373, device='cuda:1')
# current relative error is:  tensor(0.1260, device='cuda:1')
# current epoch is:  13750
# current loss is:  tensor(-51.7515, device='cuda:1')
# current relative error is:  tensor(0.1285, device='cuda:1')
# current epoch is:  13800
# current loss is:  tensor(-60.3820, device='cuda:1')
# current relative error is:  tensor(0.1318, device='cuda:1')
# current epoch is:  13850
# current loss is:  tensor(-55.3355, device='cuda:1')
# current relative error is:  tensor(0.1264, device='cuda:1')
# current epoch is:  13900
# current loss is:  tensor(-45.2657, device='cuda:1')
# current relative error is:  tensor(0.1527, device='cuda:1')
# current epoch is:  13950
# current loss is:  tensor(-53.1590, device='cuda:1')
# current relative error is:  tensor(0.1308, device='cuda:1')
# current epoch is:  14000
# current loss is:  tensor(-56.0403, device='cuda:1')
# current relative error is:  tensor(0.1320, device='cuda:1')
# current epoch is:  14050
# current loss is:  tensor(-51.0243, device='cuda:1')
# current relative error is:  tensor(0.1474, device='cuda:1')
# current epoch is:  14100
# current loss is:  tensor(-53.6008, device='cuda:1')
# current relative error is:  tensor(0.1316, device='cuda:1')
# current epoch is:  14150
# current loss is:  tensor(-53.1054, device='cuda:1')
# current relative error is:  tensor(0.1406, device='cuda:1')
# current epoch is:  14200
# current loss is:  tensor(-45.0532, device='cuda:1')
# current relative error is:  tensor(0.1328, device='cuda:1')
# current epoch is:  14250
# current loss is:  tensor(-52.0423, device='cuda:1')
# current relative error is:  tensor(0.1291, device='cuda:1')
# current epoch is:  14300
# current loss is:  tensor(-50.4707, device='cuda:1')
# current relative error is:  tensor(0.1408, device='cuda:1')
# current epoch is:  14350
# current loss is:  tensor(-56.8214, device='cuda:1')
# current relative error is:  tensor(0.1244, device='cuda:1')
# current epoch is:  14400
# current loss is:  tensor(-55.8304, device='cuda:1')
# current relative error is:  tensor(0.1232, device='cuda:1')
# current epoch is:  14450
# current loss is:  tensor(-58.6164, device='cuda:1')
# current relative error is:  tensor(0.1274, device='cuda:1')
# current epoch is:  14500
# current loss is:  tensor(-59.1688, device='cuda:1')
# current relative error is:  tensor(0.1355, device='cuda:1')
# current epoch is:  14550
# current loss is:  tensor(-49.5063, device='cuda:1')
# current relative error is:  tensor(0.1454, device='cuda:1')
# current epoch is:  14600
# current loss is:  tensor(-54.6261, device='cuda:1')
# current relative error is:  tensor(0.1524, device='cuda:1')
# current epoch is:  14650
# current loss is:  tensor(-56.4246, device='cuda:1')
# current relative error is:  tensor(0.1215, device='cuda:1')
# current epoch is:  14700
# current loss is:  tensor(-51.6483, device='cuda:1')
# current relative error is:  tensor(0.1279, device='cuda:1')
# current epoch is:  14750
# current loss is:  tensor(-45.7225, device='cuda:1')
# current relative error is:  tensor(0.1205, device='cuda:1')
# current epoch is:  14800
# current loss is:  tensor(-54.7200, device='cuda:1')
# current relative error is:  tensor(0.1548, device='cuda:1')
# current epoch is:  14850
# current loss is:  tensor(-24.7259, device='cuda:1')
# current relative error is:  tensor(0.2332, device='cuda:1')
# current epoch is:  14900
# current loss is:  tensor(-50.4630, device='cuda:1')
# current relative error is:  tensor(0.1213, device='cuda:1')
# current epoch is:  14950
# current loss is:  tensor(-51.7157, device='cuda:1')
# current relative error is:  tensor(0.1295, device='cuda:1')
# current epoch is:  15000
# current loss is:  tensor(-47.4719, device='cuda:1')
# current relative error is:  tensor(0.1296, device='cuda:1')
# current epoch is:  15050
# current loss is:  tensor(-49.0715, device='cuda:1')
# current relative error is:  tensor(0.1230, device='cuda:1')
# current epoch is:  15100
# current loss is:  tensor(-54.4466, device='cuda:1')
# current relative error is:  tensor(0.1234, device='cuda:1')
# current epoch is:  15150
# current loss is:  tensor(-45.5599, device='cuda:1')
# current relative error is:  tensor(0.1544, device='cuda:1')
# current epoch is:  15200
# current loss is:  tensor(-53.4849, device='cuda:1')
# current relative error is:  tensor(0.1502, device='cuda:1')
# current epoch is:  15250
# current loss is:  tensor(-57.0522, device='cuda:1')
# current relative error is:  tensor(0.1222, device='cuda:1')
# current epoch is:  15300
# current loss is:  tensor(-57.9971, device='cuda:1')
# current relative error is:  tensor(0.1212, device='cuda:1')
# current epoch is:  15350
# current loss is:  tensor(-52.5145, device='cuda:1')
# current relative error is:  tensor(0.1205, device='cuda:1')
# current epoch is:  15400
# current loss is:  tensor(-51.5594, device='cuda:1')
# current relative error is:  tensor(0.1290, device='cuda:1')
# current epoch is:  15450
# current loss is:  tensor(-56.5674, device='cuda:1')
# current relative error is:  tensor(0.1359, device='cuda:1')
# current epoch is:  15500
# current loss is:  tensor(-54.6207, device='cuda:1')
# current relative error is:  tensor(0.1197, device='cuda:1')
# current epoch is:  15550
# current loss is:  tensor(-55.1040, device='cuda:1')
# current relative error is:  tensor(0.1245, device='cuda:1')
# current epoch is:  15600
# current loss is:  tensor(-61.3812, device='cuda:1')
# current relative error is:  tensor(0.1395, device='cuda:1')
# current epoch is:  15650
# current loss is:  tensor(-55.0332, device='cuda:1')
# current relative error is:  tensor(0.1251, device='cuda:1')
# current epoch is:  15700
# current loss is:  tensor(-59.7904, device='cuda:1')
# current relative error is:  tensor(0.1245, device='cuda:1')
# current epoch is:  15750
# current loss is:  tensor(-57.1152, device='cuda:1')
# current relative error is:  tensor(0.1179, device='cuda:1')
# current epoch is:  15800
# current loss is:  tensor(-50.8108, device='cuda:1')
# current relative error is:  tensor(0.1869, device='cuda:1')
# current epoch is:  15850
# current loss is:  tensor(-46.0065, device='cuda:1')
# current relative error is:  tensor(0.1348, device='cuda:1')
# current epoch is:  15900
# current loss is:  tensor(-57.9116, device='cuda:1')
# current relative error is:  tensor(0.1212, device='cuda:1')
# current epoch is:  15950
# current loss is:  tensor(-51.8599, device='cuda:1')
# current relative error is:  tensor(0.1312, device='cuda:1')
# current epoch is:  16000
# current loss is:  tensor(-56.5186, device='cuda:1')
# current relative error is:  tensor(0.1126, device='cuda:1')
# current epoch is:  16050
# current loss is:  tensor(-56.1737, device='cuda:1')
# current relative error is:  tensor(0.1345, device='cuda:1')
# current epoch is:  16100
# current loss is:  tensor(-55.1704, device='cuda:1')
# current relative error is:  tensor(0.1289, device='cuda:1')
# current epoch is:  16150
# current loss is:  tensor(-53.4473, device='cuda:1')
# current relative error is:  tensor(0.1313, device='cuda:1')
# current epoch is:  16200
# current loss is:  tensor(-60.5151, device='cuda:1')
# current relative error is:  tensor(0.1260, device='cuda:1')
# current epoch is:  16250
# current loss is:  tensor(-60.8960, device='cuda:1')
# current relative error is:  tensor(0.1333, device='cuda:1')
# current epoch is:  16300
# current loss is:  tensor(-54.7352, device='cuda:1')
# current relative error is:  tensor(0.1190, device='cuda:1')
# current epoch is:  16350
# current loss is:  tensor(-50.9336, device='cuda:1')
# current relative error is:  tensor(0.1459, device='cuda:1')
# current epoch is:  16400
# current loss is:  tensor(-58.5358, device='cuda:1')
# current relative error is:  tensor(0.1161, device='cuda:1')
# current epoch is:  16450
# current loss is:  tensor(-58.7748, device='cuda:1')
# current relative error is:  tensor(0.1179, device='cuda:1')
# current epoch is:  16500
# current loss is:  tensor(-13.4631, device='cuda:1')
# current relative error is:  tensor(0.2642, device='cuda:1')
# current epoch is:  16550
# current loss is:  tensor(-61.3048, device='cuda:1')
# current relative error is:  tensor(0.1119, device='cuda:1')
# current epoch is:  16600
# current loss is:  tensor(-54.3786, device='cuda:1')
# current relative error is:  tensor(0.1156, device='cuda:1')
# current epoch is:  16650
# current loss is:  tensor(-52.8482, device='cuda:1')
# current relative error is:  tensor(0.1474, device='cuda:1')
# current epoch is:  16700
# current loss is:  tensor(-50.6595, device='cuda:1')
# current relative error is:  tensor(0.1423, device='cuda:1')
# current epoch is:  16750
# current loss is:  tensor(-46.9373, device='cuda:1')
# current relative error is:  tensor(0.1254, device='cuda:1')
# current epoch is:  16800
# current loss is:  tensor(-59.6221, device='cuda:1')
# current relative error is:  tensor(0.1106, device='cuda:1')
# current epoch is:  16850
# current loss is:  tensor(-54.4262, device='cuda:1')
# current relative error is:  tensor(0.1349, device='cuda:1')
# current epoch is:  16900
# current loss is:  tensor(-62.0518, device='cuda:1')
# current relative error is:  tensor(0.1212, device='cuda:1')
# current epoch is:  16950
# current loss is:  tensor(-61.4924, device='cuda:1')
# current relative error is:  tensor(0.1170, device='cuda:1')
# current epoch is:  17000
# current loss is:  tensor(-55.1157, device='cuda:1')
# current relative error is:  tensor(0.1203, device='cuda:1')
# current epoch is:  17050
# current loss is:  tensor(-42.1448, device='cuda:1')
# current relative error is:  tensor(0.1681, device='cuda:1')
# current epoch is:  17100
# current loss is:  tensor(-57.5843, device='cuda:1')
# current relative error is:  tensor(0.1134, device='cuda:1')
# current epoch is:  17150
# current loss is:  tensor(-57.0829, device='cuda:1')
# current relative error is:  tensor(0.1093, device='cuda:1')
# current epoch is:  17200
# current loss is:  tensor(-57.2029, device='cuda:1')
# current relative error is:  tensor(0.1327, device='cuda:1')
# current epoch is:  17250
# current loss is:  tensor(-51.2219, device='cuda:1')
# current relative error is:  tensor(0.1114, device='cuda:1')
# current epoch is:  17300
# current loss is:  tensor(-44.6807, device='cuda:1')
# current relative error is:  tensor(0.1584, device='cuda:1')
# current epoch is:  17350
# current loss is:  tensor(-55.3069, device='cuda:1')
# current relative error is:  tensor(0.1210, device='cuda:1')
# current epoch is:  17400
# current loss is:  tensor(-64.2477, device='cuda:1')
# current relative error is:  tensor(0.1157, device='cuda:1')
# current epoch is:  17450
# current loss is:  tensor(-55.2897, device='cuda:1')
# current relative error is:  tensor(0.1343, device='cuda:1')
# current epoch is:  17500
# current loss is:  tensor(-58.2340, device='cuda:1')
# current relative error is:  tensor(0.1049, device='cuda:1')
# current epoch is:  17550
# current loss is:  tensor(-64.0122, device='cuda:1')
# ...
# current relative error is:  tensor(0.0300, device='cuda:1')
# current epoch is:  94200
# current loss is:  tensor(-77.7591, device='cuda:1')
# current relative error is:  tensor(0.0145, device='cuda:1')
# current epoch is:  94250
# current loss is:  tensor(-78.5606, device='cuda:1')
# current relative error is:  tensor(0.0171, device='cuda:1')
# current epoch is:  94300
# current loss is:  tensor(-69.6110, device='cuda:1')
# current relative error is:  tensor(0.0135, device='cuda:1')
# current epoch is:  94350
# current loss is:  tensor(-81.8760, device='cuda:1')
# current relative error is:  tensor(0.0157, device='cuda:1')
# current epoch is:  94400
# current loss is:  tensor(-83.4624, device='cuda:1')
# current relative error is:  tensor(0.0237, device='cuda:1')
# current epoch is:  94450
# current loss is:  tensor(-72.2672, device='cuda:1')
# current relative error is:  tensor(0.0144, device='cuda:1')
# current epoch is:  94500
# current loss is:  tensor(-79.1466, device='cuda:1')
# current relative error is:  tensor(0.0231, device='cuda:1')
# current epoch is:  94550
# current loss is:  tensor(-75.8451, device='cuda:1')
# current relative error is:  tensor(0.0217, device='cuda:1')
# current epoch is:  94600
# current loss is:  tensor(-74.0497, device='cuda:1')
# current relative error is:  tensor(0.0207, device='cuda:1')
# current epoch is:  94650
# current loss is:  tensor(-76.7044, device='cuda:1')
# current relative error is:  tensor(0.0281, device='cuda:1')
# current epoch is:  94700
# current loss is:  tensor(-77.7230, device='cuda:1')
# current relative error is:  tensor(0.0286, device='cuda:1')
# current epoch is:  94750
# current loss is:  tensor(-77.0657, device='cuda:1')
# current relative error is:  tensor(0.0179, device='cuda:1')
# current epoch is:  94800
# current loss is:  tensor(-78.4804, device='cuda:1')
# current relative error is:  tensor(0.0278, device='cuda:1')
# current epoch is:  94850
# current loss is:  tensor(-77.7540, device='cuda:1')
# current relative error is:  tensor(0.0238, device='cuda:1')
# current epoch is:  94900
# current loss is:  tensor(-77.0528, device='cuda:1')
# current relative error is:  tensor(0.0263, device='cuda:1')
# current epoch is:  94950
# current loss is:  tensor(-77.5176, device='cuda:1')
# current relative error is:  tensor(0.0326, device='cuda:1')
# current epoch is:  95000
# current loss is:  tensor(-80.1095, device='cuda:1')
# current relative error is:  tensor(0.0215, device='cuda:1')
# current epoch is:  95050
# current loss is:  tensor(-78.8413, device='cuda:1')
# current relative error is:  tensor(0.0182, device='cuda:1')
# current epoch is:  95100
# current loss is:  tensor(-78.8614, device='cuda:1')
# current relative error is:  tensor(0.0155, device='cuda:1')
# current epoch is:  95150
# current loss is:  tensor(-78.3787, device='cuda:1')
# current relative error is:  tensor(0.0133, device='cuda:1')
# current epoch is:  95200
# current loss is:  tensor(-72.5383, device='cuda:1')
# current relative error is:  tensor(0.0519, device='cuda:1')
# current epoch is:  95250
# current loss is:  tensor(-79.7180, device='cuda:1')
# current relative error is:  tensor(0.0192, device='cuda:1')
# current epoch is:  95300
# current loss is:  tensor(-75.8916, device='cuda:1')
# current relative error is:  tensor(0.0314, device='cuda:1')
# current epoch is:  95350
# current loss is:  tensor(-79.8240, device='cuda:1')
# current relative error is:  tensor(0.0196, device='cuda:1')
# current epoch is:  95400
# current loss is:  tensor(-81.3209, device='cuda:1')
# current relative error is:  tensor(0.0221, device='cuda:1')
# current epoch is:  95450
# current loss is:  tensor(-80.9649, device='cuda:1')
# current relative error is:  tensor(0.0133, device='cuda:1')
# current epoch is:  95500
# current loss is:  tensor(-71.2675, device='cuda:1')
# current relative error is:  tensor(0.0204, device='cuda:1')
# current epoch is:  95550
# current loss is:  tensor(-79.1064, device='cuda:1')
# current relative error is:  tensor(0.0185, device='cuda:1')
# current epoch is:  95600
# current loss is:  tensor(-79.4206, device='cuda:1')
# current relative error is:  tensor(0.0242, device='cuda:1')
# current epoch is:  95650
# current loss is:  tensor(-78.0081, device='cuda:1')
# current relative error is:  tensor(0.0336, device='cuda:1')
# current epoch is:  95700
# current loss is:  tensor(-72.3597, device='cuda:1')
# current relative error is:  tensor(0.0162, device='cuda:1')
# current epoch is:  95750
# current loss is:  tensor(-75.6897, device='cuda:1')
# current relative error is:  tensor(0.0361, device='cuda:1')
# current epoch is:  95800
# current loss is:  tensor(-88.9674, device='cuda:1')
# current relative error is:  tensor(0.0152, device='cuda:1')
# current epoch is:  95850
# current loss is:  tensor(-78.7205, device='cuda:1')
# current relative error is:  tensor(0.0155, device='cuda:1')
# current epoch is:  95900
# current loss is:  tensor(-83.3776, device='cuda:1')
# current relative error is:  tensor(0.0240, device='cuda:1')
# current epoch is:  95950
# current loss is:  tensor(-76.3147, device='cuda:1')
# current relative error is:  tensor(0.0409, device='cuda:1')
# current epoch is:  96000
# current loss is:  tensor(-72.2087, device='cuda:1')
# current relative error is:  tensor(0.0364, device='cuda:1')
# current epoch is:  96050
# current loss is:  tensor(-81.3832, device='cuda:1')
# current relative error is:  tensor(0.0169, device='cuda:1')
# current epoch is:  96100
# current loss is:  tensor(-79.1277, device='cuda:1')
# current relative error is:  tensor(0.0199, device='cuda:1')
# current epoch is:  96150
# current loss is:  tensor(-78.6537, device='cuda:1')
# current relative error is:  tensor(0.0172, device='cuda:1')
# current epoch is:  96200
# current loss is:  tensor(-82.9152, device='cuda:1')
# current relative error is:  tensor(0.0406, device='cuda:1')
# current epoch is:  96250
# current loss is:  tensor(-78.8580, device='cuda:1')
# current relative error is:  tensor(0.0200, device='cuda:1')
# current epoch is:  96300
# current loss is:  tensor(-79.8413, device='cuda:1')
# current relative error is:  tensor(0.0404, device='cuda:1')
# current epoch is:  96350
# current loss is:  tensor(-79.6255, device='cuda:1')
# current relative error is:  tensor(0.0263, device='cuda:1')
# current epoch is:  96400
# current loss is:  tensor(-81.4838, device='cuda:1')
# current relative error is:  tensor(0.0240, device='cuda:1')
# current epoch is:  96450
# current loss is:  tensor(-74.2925, device='cuda:1')
# current relative error is:  tensor(0.0384, device='cuda:1')
# current epoch is:  96500
# current loss is:  tensor(-81.6942, device='cuda:1')
# current relative error is:  tensor(0.0232, device='cuda:1')
# current epoch is:  96550
# current loss is:  tensor(-80.5371, device='cuda:1')
# current relative error is:  tensor(0.0164, device='cuda:1')
# current epoch is:  96600
# current loss is:  tensor(-76.3876, device='cuda:1')
# current relative error is:  tensor(0.0318, device='cuda:1')
# current epoch is:  96650
# current loss is:  tensor(-79.2108, device='cuda:1')
# current relative error is:  tensor(0.0179, device='cuda:1')
# current epoch is:  96700
# current loss is:  tensor(-78.8253, device='cuda:1')
# current relative error is:  tensor(0.0173, device='cuda:1')
# current epoch is:  96750
# current loss is:  tensor(-79.1680, device='cuda:1')
# current relative error is:  tensor(0.0225, device='cuda:1')
# current epoch is:  96800
# current loss is:  tensor(-75.2840, device='cuda:1')
# current relative error is:  tensor(0.0205, device='cuda:1')
# current epoch is:  96850
# current loss is:  tensor(-80.9979, device='cuda:1')
# current relative error is:  tensor(0.0322, device='cuda:1')
# current epoch is:  96900
# current loss is:  tensor(-74.6291, device='cuda:1')
# current relative error is:  tensor(0.0147, device='cuda:1')
# current epoch is:  96950
# current loss is:  tensor(-78.5512, device='cuda:1')
# current relative error is:  tensor(0.0406, device='cuda:1')
# current epoch is:  97000
# current loss is:  tensor(-83.6714, device='cuda:1')
# current relative error is:  tensor(0.0262, device='cuda:1')
# current epoch is:  97050
# current loss is:  tensor(-85.2519, device='cuda:1')
# current relative error is:  tensor(0.0230, device='cuda:1')
# current epoch is:  97100
# current loss is:  tensor(-86.0400, device='cuda:1')
# current relative error is:  tensor(0.0170, device='cuda:1')
# current epoch is:  97150
# current loss is:  tensor(-77.7012, device='cuda:1')
# current relative error is:  tensor(0.0344, device='cuda:1')
# current epoch is:  97200
# current loss is:  tensor(-75.4438, device='cuda:1')
# current relative error is:  tensor(0.0234, device='cuda:1')
# current epoch is:  97250
# current loss is:  tensor(-73.7178, device='cuda:1')
# current relative error is:  tensor(0.0526, device='cuda:1')
# current epoch is:  97300
# current loss is:  tensor(-73.4957, device='cuda:1')
# current relative error is:  tensor(0.0217, device='cuda:1')
# current epoch is:  97350
# current loss is:  tensor(-82.3154, device='cuda:1')
# current relative error is:  tensor(0.0272, device='cuda:1')
# current epoch is:  97400
# current loss is:  tensor(-77.4180, device='cuda:1')
# current relative error is:  tensor(0.0198, device='cuda:1')
# current epoch is:  97450
# current loss is:  tensor(-76.5989, device='cuda:1')
# current relative error is:  tensor(0.0171, device='cuda:1')
# current epoch is:  97500
# current loss is:  tensor(-83.0137, device='cuda:1')
# current relative error is:  tensor(0.0131, device='cuda:1')
# current epoch is:  97550
# current loss is:  tensor(-80.2527, device='cuda:1')
# current relative error is:  tensor(0.0381, device='cuda:1')
# current epoch is:  97600
# current loss is:  tensor(-77.5976, device='cuda:1')
# current relative error is:  tensor(0.0188, device='cuda:1')
# current epoch is:  97650
# current loss is:  tensor(-82.3518, device='cuda:1')
# current relative error is:  tensor(0.0170, device='cuda:1')
# current epoch is:  97700
# current loss is:  tensor(-77.8929, device='cuda:1')
# current relative error is:  tensor(0.0327, device='cuda:1')
# current epoch is:  97750
# current loss is:  tensor(-78.9804, device='cuda:1')
# current relative error is:  tensor(0.0224, device='cuda:1')
# current epoch is:  97800
# current loss is:  tensor(-71.7850, device='cuda:1')
# current relative error is:  tensor(0.0166, device='cuda:1')
# current epoch is:  97850
# current loss is:  tensor(-75.8287, device='cuda:1')
# current relative error is:  tensor(0.0245, device='cuda:1')
# current epoch is:  97900
# current loss is:  tensor(-77.7493, device='cuda:1')
# current relative error is:  tensor(0.0155, device='cuda:1')
# current epoch is:  97950
# current loss is:  tensor(-76.7866, device='cuda:1')
# current relative error is:  tensor(0.0260, device='cuda:1')
# current epoch is:  98000
# current loss is:  tensor(-81.9541, device='cuda:1')
# current relative error is:  tensor(0.0156, device='cuda:1')
# current epoch is:  98050
# current loss is:  tensor(-71.1769, device='cuda:1')
# current relative error is:  tensor(0.0278, device='cuda:1')
# current epoch is:  98100
# current loss is:  tensor(-85.4087, device='cuda:1')
# current relative error is:  tensor(0.0204, device='cuda:1')
# current epoch is:  98150
# current loss is:  tensor(-78.8752, device='cuda:1')
# current relative error is:  tensor(0.0144, device='cuda:1')
# current epoch is:  98200
# current loss is:  tensor(-73.6354, device='cuda:1')
# current relative error is:  tensor(0.0336, device='cuda:1')
# current epoch is:  98250
# current loss is:  tensor(-71.6556, device='cuda:1')
# current relative error is:  tensor(0.0158, device='cuda:1')
# current epoch is:  98300
# current loss is:  tensor(-81.4527, device='cuda:1')
# current relative error is:  tensor(0.0275, device='cuda:1')
# current epoch is:  98350
# current loss is:  tensor(-80.5204, device='cuda:1')
# current relative error is:  tensor(0.0212, device='cuda:1')
# current epoch is:  98400
# current loss is:  tensor(-75.1580, device='cuda:1')
# current relative error is:  tensor(0.0392, device='cuda:1')
# current epoch is:  98450
# current loss is:  tensor(-78.6125, device='cuda:1')
# current relative error is:  tensor(0.0157, device='cuda:1')
# current epoch is:  98500
# current loss is:  tensor(-77.6602, device='cuda:1')
# current relative error is:  tensor(0.0243, device='cuda:1')
# current epoch is:  98550
# current loss is:  tensor(-67.6045, device='cuda:1')
# current relative error is:  tensor(0.0476, device='cuda:1')
# current epoch is:  98600
# current loss is:  tensor(-80.1546, device='cuda:1')
# current relative error is:  tensor(0.0237, device='cuda:1')
# current epoch is:  98650
# current loss is:  tensor(-78.1426, device='cuda:1')
# current relative error is:  tensor(0.0176, device='cuda:1')
# current epoch is:  98700
# current loss is:  tensor(-71.4736, device='cuda:1')
# current relative error is:  tensor(0.0146, device='cuda:1')
# current epoch is:  98750
# current loss is:  tensor(-76.4545, device='cuda:1')
# current relative error is:  tensor(0.0177, device='cuda:1')
# current epoch is:  98800
# current loss is:  tensor(-73.0660, device='cuda:1')
# current relative error is:  tensor(0.0197, device='cuda:1')
# current epoch is:  98850
# current loss is:  tensor(-73.0363, device='cuda:1')
# current relative error is:  tensor(0.0186, device='cuda:1')
# current epoch is:  98900
# current loss is:  tensor(-79.9825, device='cuda:1')
# current relative error is:  tensor(0.0431, device='cuda:1')
# current epoch is:  98950
# current loss is:  tensor(-78.0768, device='cuda:1')
# current relative error is:  tensor(0.0293, device='cuda:1')
# current epoch is:  99000
# current loss is:  tensor(-76.7803, device='cuda:1')
# current relative error is:  tensor(0.0150, device='cuda:1')
# current epoch is:  99050
# current loss is:  tensor(-81.9190, device='cuda:1')
# current relative error is:  tensor(0.0143, device='cuda:1')
# current epoch is:  99100
# current loss is:  tensor(-80.9829, device='cuda:1')
# current relative error is:  tensor(0.0445, device='cuda:1')
# current epoch is:  99150
# current loss is:  tensor(-78.7412, device='cuda:1')
# current relative error is:  tensor(0.0234, device='cuda:1')
# current epoch is:  99200
# current loss is:  tensor(-70.1669, device='cuda:1')
# current relative error is:  tensor(0.0245, device='cuda:1')
# current epoch is:  99250
# current loss is:  tensor(-74.1040, device='cuda:1')
# current relative error is:  tensor(0.0382, device='cuda:1')
# current epoch is:  99300
# current loss is:  tensor(-77.1744, device='cuda:1')
# current relative error is:  tensor(0.0179, device='cuda:1')
# current epoch is:  99350
# current loss is:  tensor(-73.3542, device='cuda:1')
# current relative error is:  tensor(0.0148, device='cuda:1')
# current epoch is:  99400
# current loss is:  tensor(-80.1964, device='cuda:1')
# current relative error is:  tensor(0.0135, device='cuda:1')
# current epoch is:  99450
# current loss is:  tensor(-73.3646, device='cuda:1')
# current relative error is:  tensor(0.0274, device='cuda:1')
# current epoch is:  99500
# current loss is:  tensor(-75.3144, device='cuda:1')
# current relative error is:  tensor(0.0259, device='cuda:1')
# current epoch is:  99550
# current loss is:  tensor(-74.5480, device='cuda:1')
# current relative error is:  tensor(0.0202, device='cuda:1')
# current epoch is:  99600
# current loss is:  tensor(-74.4599, device='cuda:1')
# current relative error is:  tensor(0.0212, device='cuda:1')
# current epoch is:  99650
# current loss is:  tensor(-80.4498, device='cuda:1')
# current relative error is:  tensor(0.0136, device='cuda:1')
# current epoch is:  99700
# current loss is:  tensor(-77.5315, device='cuda:1')
# current relative error is:  tensor(0.0288, device='cuda:1')
# current epoch is:  99750
# current loss is:  tensor(-82.4637, device='cuda:1')
# current relative error is:  tensor(0.0146, device='cuda:1')
# current epoch is:  99800
# current loss is:  tensor(-78.7608, device='cuda:1')
# current relative error is:  tensor(0.0140, device='cuda:1')
# current epoch is:  99850
# current loss is:  tensor(-79.6411, device='cuda:1')
# current relative error is:  tensor(0.0339, device='cuda:1')
# current epoch is:  99900
# current loss is:  tensor(-78.5855, device='cuda:1')
# current relative error is:  tensor(0.0145, device='cuda:1')
# current epoch is:  99950
# current loss is:  tensor(-73.2540, device='cuda:1')
# current relative error is:  tensor(0.0224, device='cuda:1')
# total time is:  24077.48997592926 seconds
