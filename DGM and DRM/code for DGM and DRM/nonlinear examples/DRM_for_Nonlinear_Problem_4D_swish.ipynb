# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
from math import *
import time

# %%
torch.cuda.set_device(0)

# %%
torch.set_default_tensor_type('torch.DoubleTensor')

# %%
# defination of activation function
def activation(x):
    return x * torch.sigmoid(x)

# %%
# Build ResNet with three blocks
class net(torch.nn.Module):
    def __init__(self,input_width,layer_width):
        super(net,self).__init__()
        self.layer_in = torch.nn.Linear(input_width, layer_width)
        self.layer1 = torch.nn.Linear(layer_width, layer_width)
        self.layer2 = torch.nn.Linear(layer_width, layer_width)
        self.layer3 = torch.nn.Linear(layer_width, layer_width)
        self.layer4 = torch.nn.Linear(layer_width, layer_width)
        self.layer5 = torch.nn.Linear(layer_width, layer_width)
        self.layer6 = torch.nn.Linear(layer_width, layer_width)
        self.layer_out = torch.nn.Linear(layer_width, 1)
    def forward(self,x):
        y = self.layer_in(x)
        y = y + activation(self.layer2(activation(self.layer1(y)))) # residual block 1
        y = y + activation(self.layer4(activation(self.layer3(y)))) # residual block 2
        y = y + activation(self.layer6(activation(self.layer5(y)))) # residual block 3
        output = self.layer_out(y)
        return output

# %%
dimension = 4

# %%
# Defination of exact solution
def u_ex(x):  
    x_norm = torch.norm(x, dim = 1) # compute norm of x; dim = 1 - > sum by row
    u_x = torch.sin(pi/2*(1-x_norm)).reshape([x.size()[0],1])
    return u_x

# %%
# Defination of f(x)
def f(x):
    x_norm = torch.norm(x, dim = 1)
    u_temp = u_ex(x)
    f_temp = 1/4*pi**2*torch.sin(pi/2*(1-x_norm)) + 1/2*pi*(dimension-1)/x_norm*torch.cos(pi/2*(1-x_norm))  
    return f_temp.reshape([x.size()[0],1])+ u_temp**3

# %%
# Generate points by random
data_size = 1000
def generate_data():
    i = 0
    x = torch.tensor([])
    while x.size()[0] < data_size:
        temp_x = 2*torch.rand(data_size, dimension) - 1
        index = torch.where(torch.norm(temp_x, dim = 1) < 1)
        temp_x = temp_x[index]
        x = torch.cat((x,temp_x),0)
    x = x[1:data_size, :]
    return x.cuda()

# %%
# Defination of loss function for DRM
def loss_function(x):
    u_hat = model(x)
    ux = torch.zeros(x.size()[0], dimension).cuda()
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension).cuda()
        dx[:, i] = torch.ones(x.size()[0])
        ux[:, i] = (model(x+step_size*dx) - model(x-step_size*dx))[:,0]/step_size/2
    uxsq = (torch.sum(ux**2, dim = 1)).reshape([x.size()[0], 1]) 
    f_temp = f(x)
    part_1 = torch.sum(1/2*uxsq + 1/4*u_hat**4 - f_temp*u_hat)/x.size()[0]
    
    Nb = 200
    y = (2*torch.rand(Nb, dimension)-1).cuda()
    y_norm = torch.norm(y, dim = 1).cuda()
    for i in range(dimension):
        y[:, i] = y[:, i] / y_norm
    part_2 = (torch.sum((model(y)-u_ex(y))**2)/y.size()[0])
    
    lambda1 = 100.0
    return part_1 + lambda1 * part_2

# %%
# Parameters initialization by normal distribution for neural networks
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = net(dimension, 8)
model = initparam(model, 0.5)

# %%
device = torch.device("cuda:0" )
model.to(device)
# Out:
# net(
#   (layer_in): Linear(in_features=4, out_features=8, bias=True)
#   (layer1): Linear(in_features=8, out_features=8, bias=True)
#   (layer2): Linear(in_features=8, out_features=8, bias=True)
#   (layer3): Linear(in_features=8, out_features=8, bias=True)
#   (layer4): Linear(in_features=8, out_features=8, bias=True)
#   (layer5): Linear(in_features=8, out_features=8, bias=True)
#   (layer6): Linear(in_features=8, out_features=8, bias=True)
#   (layer_out): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
# Defination of relative error
def relative_error():
    x = generate_data()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
traintime = 10000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = generate_data()
    x.requires_grad = True
    loss = loss_function(x)
    loss.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", loss.detach())
        print("current relative error is: ", error.detach())
        np.save("DRM_relative_error_4D_Dirichlet_nonlinear_swish.npy", error_save)
np.save("DRM_relative_error_4D_Dirichlet_nonlinear_swish.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(13.8213, device='cuda:0')
# current relative error is:  tensor(1.4881, device='cuda:0')
# current epoch is:  50
# current loss is:  tensor(0.7156, device='cuda:0')
# current relative error is:  tensor(0.9757, device='cuda:0')
# current epoch is:  100
# current loss is:  tensor(0.2721, device='cuda:0')
# current relative error is:  tensor(0.9002, device='cuda:0')
# current epoch is:  150
# current loss is:  tensor(0.0859, device='cuda:0')
# current relative error is:  tensor(0.8848, device='cuda:0')
# current epoch is:  200
# current loss is:  tensor(0.0399, device='cuda:0')
# current relative error is:  tensor(0.8967, device='cuda:0')
# current epoch is:  250
# current loss is:  tensor(-0.0198, device='cuda:0')
# current relative error is:  tensor(0.8870, device='cuda:0')
# current epoch is:  300
# current loss is:  tensor(-0.0880, device='cuda:0')
# current relative error is:  tensor(0.8794, device='cuda:0')
# current epoch is:  350
# current loss is:  tensor(-0.0899, device='cuda:0')
# current relative error is:  tensor(0.8875, device='cuda:0')
# current epoch is:  400
# current loss is:  tensor(-0.0994, device='cuda:0')
# current relative error is:  tensor(0.8721, device='cuda:0')
# current epoch is:  450
# current loss is:  tensor(-0.1355, device='cuda:0')
# current relative error is:  tensor(0.8644, device='cuda:0')
# current epoch is:  500
# current loss is:  tensor(-0.1702, device='cuda:0')
# current relative error is:  tensor(0.8643, device='cuda:0')
# current epoch is:  550
# current loss is:  tensor(-0.1752, device='cuda:0')
# current relative error is:  tensor(0.8510, device='cuda:0')
# current epoch is:  600
# current loss is:  tensor(-0.2346, device='cuda:0')
# current relative error is:  tensor(0.8544, device='cuda:0')
# current epoch is:  650
# current loss is:  tensor(-0.2476, device='cuda:0')
# current relative error is:  tensor(0.8308, device='cuda:0')
# current epoch is:  700
# current loss is:  tensor(-0.2371, device='cuda:0')
# current relative error is:  tensor(0.8157, device='cuda:0')
# current epoch is:  750
# current loss is:  tensor(-0.2931, device='cuda:0')
# current relative error is:  tensor(0.8065, device='cuda:0')
# current epoch is:  800
# current loss is:  tensor(-0.2790, device='cuda:0')
# current relative error is:  tensor(0.7882, device='cuda:0')
# current epoch is:  850
# current loss is:  tensor(-0.3808, device='cuda:0')
# current relative error is:  tensor(0.7576, device='cuda:0')
# current epoch is:  900
# current loss is:  tensor(-0.4208, device='cuda:0')
# current relative error is:  tensor(0.7229, device='cuda:0')
# current epoch is:  950
# current loss is:  tensor(-0.5269, device='cuda:0')
# current relative error is:  tensor(0.6472, device='cuda:0')
# current epoch is:  1000
# current loss is:  tensor(-0.6973, device='cuda:0')
# current relative error is:  tensor(0.5642, device='cuda:0')
# current epoch is:  1050
# current loss is:  tensor(-0.7842, device='cuda:0')
# current relative error is:  tensor(0.4306, device='cuda:0')
# current epoch is:  1100
# current loss is:  tensor(-0.8788, device='cuda:0')
# current relative error is:  tensor(0.3090, device='cuda:0')
# current epoch is:  1150
# current loss is:  tensor(-0.9496, device='cuda:0')
# current relative error is:  tensor(0.2330, device='cuda:0')
# current epoch is:  1200
# current loss is:  tensor(-0.9930, device='cuda:0')
# current relative error is:  tensor(0.1750, device='cuda:0')
# current epoch is:  1250
# current loss is:  tensor(-1.0750, device='cuda:0')
# current relative error is:  tensor(0.1296, device='cuda:0')
# current epoch is:  1300
# current loss is:  tensor(-1.1265, device='cuda:0')
# current relative error is:  tensor(0.1163, device='cuda:0')
# current epoch is:  1350
# current loss is:  tensor(-1.1155, device='cuda:0')
# current relative error is:  tensor(0.1057, device='cuda:0')
# current epoch is:  1400
# current loss is:  tensor(-1.1514, device='cuda:0')
# current relative error is:  tensor(0.0991, device='cuda:0')
# current epoch is:  1450
# current loss is:  tensor(-1.1906, device='cuda:0')
# current relative error is:  tensor(0.1116, device='cuda:0')
# current epoch is:  1500
# current loss is:  tensor(-1.2086, device='cuda:0')
# current relative error is:  tensor(0.0903, device='cuda:0')
# current epoch is:  1550
# current loss is:  tensor(-1.1325, device='cuda:0')
# current relative error is:  tensor(0.0962, device='cuda:0')
# current epoch is:  1600
# current loss is:  tensor(-1.1111, device='cuda:0')
# current relative error is:  tensor(0.0981, device='cuda:0')
# current epoch is:  1650
# current loss is:  tensor(-1.1613, device='cuda:0')
# current relative error is:  tensor(0.1089, device='cuda:0')
# current epoch is:  1700
# current loss is:  tensor(-1.2042, device='cuda:0')
# current relative error is:  tensor(0.1058, device='cuda:0')
# current epoch is:  1750
# current loss is:  tensor(-1.2504, device='cuda:0')
# current relative error is:  tensor(0.1077, device='cuda:0')
# current epoch is:  1800
# current loss is:  tensor(-1.1089, device='cuda:0')
# current relative error is:  tensor(0.0864, device='cuda:0')
# current epoch is:  1850
# current loss is:  tensor(-1.2303, device='cuda:0')
# current relative error is:  tensor(0.0891, device='cuda:0')
# current epoch is:  1900
# current loss is:  tensor(-1.1724, device='cuda:0')
# current relative error is:  tensor(0.0846, device='cuda:0')
# current epoch is:  1950
# current loss is:  tensor(-1.1459, device='cuda:0')
# current relative error is:  tensor(0.1133, device='cuda:0')
# current epoch is:  2000
# current loss is:  tensor(-1.2241, device='cuda:0')
# current relative error is:  tensor(0.1002, device='cuda:0')
# current epoch is:  2050
# current loss is:  tensor(-1.2733, device='cuda:0')
# current relative error is:  tensor(0.0846, device='cuda:0')
# current epoch is:  2100
# current loss is:  tensor(-1.2005, device='cuda:0')
# current relative error is:  tensor(0.0878, device='cuda:0')
# current epoch is:  2150
# current loss is:  tensor(-1.0870, device='cuda:0')
# current relative error is:  tensor(0.0890, device='cuda:0')
# current epoch is:  2200
# current loss is:  tensor(-1.2010, device='cuda:0')
# current relative error is:  tensor(0.0927, device='cuda:0')
# current epoch is:  2250
# current loss is:  tensor(-1.3064, device='cuda:0')
# current relative error is:  tensor(0.1043, device='cuda:0')
# current epoch is:  2300
# current loss is:  tensor(-1.1703, device='cuda:0')
# current relative error is:  tensor(0.0714, device='cuda:0')
# current epoch is:  2350
# current loss is:  tensor(-1.1209, device='cuda:0')
# current relative error is:  tensor(0.1057, device='cuda:0')
# current epoch is:  2400
# current loss is:  tensor(-1.2452, device='cuda:0')
# current relative error is:  tensor(0.0928, device='cuda:0')
# current epoch is:  2450
# current loss is:  tensor(-1.2317, device='cuda:0')
# current relative error is:  tensor(0.0807, device='cuda:0')
# current epoch is:  2500
# current loss is:  tensor(-1.0933, device='cuda:0')
# current relative error is:  tensor(0.0883, device='cuda:0')
# current epoch is:  2550
# current loss is:  tensor(-1.1955, device='cuda:0')
# current relative error is:  tensor(0.1181, device='cuda:0')
# current epoch is:  2600
# current loss is:  tensor(-1.2217, device='cuda:0')
# current relative error is:  tensor(0.1080, device='cuda:0')
# current epoch is:  2650
# current loss is:  tensor(-1.2238, device='cuda:0')
# current relative error is:  tensor(0.0949, device='cuda:0')
# current epoch is:  2700
# current loss is:  tensor(-1.1266, device='cuda:0')
# current relative error is:  tensor(0.0826, device='cuda:0')
# current epoch is:  2750
# current loss is:  tensor(-1.2557, device='cuda:0')
# current relative error is:  tensor(0.1108, device='cuda:0')
# current epoch is:  2800
# current loss is:  tensor(-1.1527, device='cuda:0')
# current relative error is:  tensor(0.0929, device='cuda:0')
# current epoch is:  2850
# current loss is:  tensor(-1.1299, device='cuda:0')
# current relative error is:  tensor(0.1042, device='cuda:0')
# current epoch is:  2900
# current loss is:  tensor(-1.2881, device='cuda:0')
# current relative error is:  tensor(0.1132, device='cuda:0')
# current epoch is:  2950
# current loss is:  tensor(-1.1662, device='cuda:0')
# current relative error is:  tensor(0.1052, device='cuda:0')
# current epoch is:  3000
# current loss is:  tensor(-1.0596, device='cuda:0')
# current relative error is:  tensor(0.0808, device='cuda:0')
# current epoch is:  3050
# current loss is:  tensor(-1.3576, device='cuda:0')
# current relative error is:  tensor(0.0889, device='cuda:0')
# current epoch is:  3100
# current loss is:  tensor(-1.2046, device='cuda:0')
# current relative error is:  tensor(0.0844, device='cuda:0')
# current epoch is:  3150
# current loss is:  tensor(-1.1950, device='cuda:0')
# current relative error is:  tensor(0.0988, device='cuda:0')
# current epoch is:  3200
# current loss is:  tensor(-1.1407, device='cuda:0')
# current relative error is:  tensor(0.1020, device='cuda:0')
# current epoch is:  3250
# current loss is:  tensor(-1.2188, device='cuda:0')
# current relative error is:  tensor(0.0963, device='cuda:0')
# current epoch is:  3300
# current loss is:  tensor(-1.1849, device='cuda:0')
# current relative error is:  tensor(0.0997, device='cuda:0')
# current epoch is:  3350
# current loss is:  tensor(-0.9837, device='cuda:0')
# current relative error is:  tensor(0.0872, device='cuda:0')
# current epoch is:  3400
# current loss is:  tensor(-1.0573, device='cuda:0')
# current relative error is:  tensor(0.0895, device='cuda:0')
# current epoch is:  3450
# current loss is:  tensor(-1.1020, device='cuda:0')
# current relative error is:  tensor(0.0954, device='cuda:0')
# current epoch is:  3500
# current loss is:  tensor(-1.1721, device='cuda:0')
# current relative error is:  tensor(0.1013, device='cuda:0')
# current epoch is:  3550
# current loss is:  tensor(-1.1989, device='cuda:0')
# current relative error is:  tensor(0.0918, device='cuda:0')
# current epoch is:  3600
# current loss is:  tensor(-1.2850, device='cuda:0')
# current relative error is:  tensor(0.0840, device='cuda:0')
# current epoch is:  3650
# current loss is:  tensor(-1.1083, device='cuda:0')
# current relative error is:  tensor(0.0970, device='cuda:0')
# current epoch is:  3700
# current loss is:  tensor(-1.2355, device='cuda:0')
# current relative error is:  tensor(0.1069, device='cuda:0')
# current epoch is:  3750
# current loss is:  tensor(-1.1299, device='cuda:0')
# current relative error is:  tensor(0.1018, device='cuda:0')
# current epoch is:  3800
# current loss is:  tensor(-1.2661, device='cuda:0')
# current relative error is:  tensor(0.1035, device='cuda:0')
# current epoch is:  3850
# current loss is:  tensor(-1.2074, device='cuda:0')
# current relative error is:  tensor(0.0973, device='cuda:0')
# current epoch is:  3900
# current loss is:  tensor(-1.1998, device='cuda:0')
# current relative error is:  tensor(0.0900, device='cuda:0')
# current epoch is:  3950
# current loss is:  tensor(-1.2294, device='cuda:0')
# current relative error is:  tensor(0.0971, device='cuda:0')
# current epoch is:  4000
# current loss is:  tensor(-1.1436, device='cuda:0')
# current relative error is:  tensor(0.1160, device='cuda:0')
# current epoch is:  4050
# current loss is:  tensor(-1.1957, device='cuda:0')
# current relative error is:  tensor(0.0906, device='cuda:0')
# current epoch is:  4100
# current loss is:  tensor(-1.2301, device='cuda:0')
# current relative error is:  tensor(0.0912, device='cuda:0')
# current epoch is:  4150
# current loss is:  tensor(-1.2955, device='cuda:0')
# current relative error is:  tensor(0.0957, device='cuda:0')
# current epoch is:  4200
# current loss is:  tensor(-1.1060, device='cuda:0')
# current relative error is:  tensor(0.1110, device='cuda:0')
# current epoch is:  4250
# current loss is:  tensor(-1.3406, device='cuda:0')
# current relative error is:  tensor(0.1047, device='cuda:0')
# current epoch is:  4300
# current loss is:  tensor(-1.1890, device='cuda:0')
# current relative error is:  tensor(0.0838, device='cuda:0')
# current epoch is:  4350
# current loss is:  tensor(-1.2777, device='cuda:0')
# current relative error is:  tensor(0.0953, device='cuda:0')
# current epoch is:  4400
# current loss is:  tensor(-1.2259, device='cuda:0')
# current relative error is:  tensor(0.1153, device='cuda:0')
# current epoch is:  4450
# current loss is:  tensor(-1.1808, device='cuda:0')
# current relative error is:  tensor(0.1067, device='cuda:0')
# current epoch is:  4500
# current loss is:  tensor(-1.2024, device='cuda:0')
# current relative error is:  tensor(0.0967, device='cuda:0')
# current epoch is:  4550
# current loss is:  tensor(-1.1402, device='cuda:0')
# current relative error is:  tensor(0.1053, device='cuda:0')
# current epoch is:  4600
# current loss is:  tensor(-1.3445, device='cuda:0')
# current relative error is:  tensor(0.1029, device='cuda:0')
# current epoch is:  4650
# current loss is:  tensor(-1.1067, device='cuda:0')
# current relative error is:  tensor(0.0955, device='cuda:0')
# current epoch is:  4700
# current loss is:  tensor(-1.1086, device='cuda:0')
# current relative error is:  tensor(0.1007, device='cuda:0')
# current epoch is:  4750
# current loss is:  tensor(-1.2539, device='cuda:0')
# current relative error is:  tensor(0.0897, device='cuda:0')
# current epoch is:  4800
# current loss is:  tensor(-1.2979, device='cuda:0')
# current relative error is:  tensor(0.0971, device='cuda:0')
# current epoch is:  4850
# current loss is:  tensor(-1.3006, device='cuda:0')
# current relative error is:  tensor(0.1111, device='cuda:0')
# current epoch is:  4900
# current loss is:  tensor(-1.2835, device='cuda:0')
# current relative error is:  tensor(0.1071, device='cuda:0')
# current epoch is:  4950
# current loss is:  tensor(-1.2072, device='cuda:0')
# current relative error is:  tensor(0.0963, device='cuda:0')
# current epoch is:  5000
# current loss is:  tensor(-1.3690, device='cuda:0')
# current relative error is:  tensor(0.1049, device='cuda:0')
# current epoch is:  5050
# current loss is:  tensor(-1.2260, device='cuda:0')
# current relative error is:  tensor(0.1018, device='cuda:0')
# current epoch is:  5100
# current loss is:  tensor(-1.1873, device='cuda:0')
# current relative error is:  tensor(0.1006, device='cuda:0')
# current epoch is:  5150
# current loss is:  tensor(-1.2475, device='cuda:0')
# current relative error is:  tensor(0.0929, device='cuda:0')
# current epoch is:  5200
# current loss is:  tensor(-1.1448, device='cuda:0')
# current relative error is:  tensor(0.0926, device='cuda:0')
# current epoch is:  5250
# current loss is:  tensor(-1.2944, device='cuda:0')
# current relative error is:  tensor(0.0938, device='cuda:0')
# current epoch is:  5300
# current loss is:  tensor(-1.1176, device='cuda:0')
# current relative error is:  tensor(0.0987, device='cuda:0')
# current epoch is:  5350
# current loss is:  tensor(-1.2968, device='cuda:0')
# current relative error is:  tensor(0.0900, device='cuda:0')
# current epoch is:  5400
# current loss is:  tensor(-1.2945, device='cuda:0')
# current relative error is:  tensor(0.1147, device='cuda:0')
# current epoch is:  5450
# current loss is:  tensor(-1.0239, device='cuda:0')
# current relative error is:  tensor(0.1074, device='cuda:0')
# current epoch is:  5500
# current loss is:  tensor(-1.0493, device='cuda:0')
# current relative error is:  tensor(0.1011, device='cuda:0')
# current epoch is:  5550
# current loss is:  tensor(-1.2387, device='cuda:0')
# current relative error is:  tensor(0.1104, device='cuda:0')
# current epoch is:  5600
# current loss is:  tensor(-1.2029, device='cuda:0')
# current relative error is:  tensor(0.1033, device='cuda:0')
# current epoch is:  5650
# current loss is:  tensor(-1.1146, device='cuda:0')
# current relative error is:  tensor(0.1016, device='cuda:0')
# current epoch is:  5700
# current loss is:  tensor(-1.2288, device='cuda:0')
# current relative error is:  tensor(0.1048, device='cuda:0')
# current epoch is:  5750
# current loss is:  tensor(-1.1231, device='cuda:0')
# current relative error is:  tensor(0.0894, device='cuda:0')
# current epoch is:  5800
# current loss is:  tensor(-1.3005, device='cuda:0')
# current relative error is:  tensor(0.1022, device='cuda:0')
# current epoch is:  5850
# current loss is:  tensor(-1.2035, device='cuda:0')
# current relative error is:  tensor(0.1051, device='cuda:0')
# current epoch is:  5900
# current loss is:  tensor(-1.2623, device='cuda:0')
# current relative error is:  tensor(0.1046, device='cuda:0')
# current epoch is:  5950
# current loss is:  tensor(-1.2758, device='cuda:0')
# current relative error is:  tensor(0.0856, device='cuda:0')
# current epoch is:  6000
# current loss is:  tensor(-1.1404, device='cuda:0')
# current relative error is:  tensor(0.0935, device='cuda:0')
# current epoch is:  6050
# current loss is:  tensor(-1.2976, device='cuda:0')
# current relative error is:  tensor(0.0907, device='cuda:0')
# current epoch is:  6100
# current loss is:  tensor(-1.3450, device='cuda:0')
# current relative error is:  tensor(0.1100, device='cuda:0')
# current epoch is:  6150
# current loss is:  tensor(-1.1569, device='cuda:0')
# current relative error is:  tensor(0.0961, device='cuda:0')
# current epoch is:  6200
# current loss is:  tensor(-1.2516, device='cuda:0')
# current relative error is:  tensor(0.0957, device='cuda:0')
# current epoch is:  6250
# current loss is:  tensor(-1.1842, device='cuda:0')
# current relative error is:  tensor(0.1002, device='cuda:0')
# current epoch is:  6300
# current loss is:  tensor(-1.0973, device='cuda:0')
# current relative error is:  tensor(0.1136, device='cuda:0')
# current epoch is:  6350
# current loss is:  tensor(-1.1454, device='cuda:0')
# current relative error is:  tensor(0.0938, device='cuda:0')
# current epoch is:  6400
# current loss is:  tensor(-1.2981, device='cuda:0')
# current relative error is:  tensor(0.1153, device='cuda:0')
# current epoch is:  6450
# current loss is:  tensor(-1.1401, device='cuda:0')
# current relative error is:  tensor(0.0918, device='cuda:0')
# current epoch is:  6500
# current loss is:  tensor(-1.0887, device='cuda:0')
# current relative error is:  tensor(0.1027, device='cuda:0')
# current epoch is:  6550
# current loss is:  tensor(-1.2200, device='cuda:0')
# current relative error is:  tensor(0.1097, device='cuda:0')
# current epoch is:  6600
# current loss is:  tensor(-1.2243, device='cuda:0')
# current relative error is:  tensor(0.1008, device='cuda:0')
# current epoch is:  6650
# current loss is:  tensor(-1.1236, device='cuda:0')
# current relative error is:  tensor(0.1010, device='cuda:0')
# current epoch is:  6700
# current loss is:  tensor(-1.1891, device='cuda:0')
# current relative error is:  tensor(0.1141, device='cuda:0')
# current epoch is:  6750
# current loss is:  tensor(-1.1422, device='cuda:0')
# current relative error is:  tensor(0.1073, device='cuda:0')
# current epoch is:  6800
# current loss is:  tensor(-1.0658, device='cuda:0')
# current relative error is:  tensor(0.0947, device='cuda:0')
# current epoch is:  6850
# current loss is:  tensor(-1.1144, device='cuda:0')
# current relative error is:  tensor(0.1128, device='cuda:0')
# current epoch is:  6900
# current loss is:  tensor(-1.3287, device='cuda:0')
# current relative error is:  tensor(0.0994, device='cuda:0')
# current epoch is:  6950
# current loss is:  tensor(-1.2715, device='cuda:0')
# current relative error is:  tensor(0.1181, device='cuda:0')
# current epoch is:  7000
# current loss is:  tensor(-1.1770, device='cuda:0')
# current relative error is:  tensor(0.0959, device='cuda:0')
# current epoch is:  7050
# current loss is:  tensor(-1.2571, device='cuda:0')
# current relative error is:  tensor(0.0986, device='cuda:0')
# current epoch is:  7100
# current loss is:  tensor(-1.0413, device='cuda:0')
# current relative error is:  tensor(0.1020, device='cuda:0')
# current epoch is:  7150
# current loss is:  tensor(-1.2938, device='cuda:0')
# current relative error is:  tensor(0.0959, device='cuda:0')
# current epoch is:  7200
# current loss is:  tensor(-1.3068, device='cuda:0')
# current relative error is:  tensor(0.1030, device='cuda:0')
# current epoch is:  7250
# current loss is:  tensor(-1.1670, device='cuda:0')
# current relative error is:  tensor(0.0754, device='cuda:0')
# current epoch is:  7300
# current loss is:  tensor(-1.2803, device='cuda:0')
# current relative error is:  tensor(0.1117, device='cuda:0')
# current epoch is:  7350
# current loss is:  tensor(-1.1694, device='cuda:0')
# current relative error is:  tensor(0.1005, device='cuda:0')
# current epoch is:  7400
# current loss is:  tensor(-1.2415, device='cuda:0')
# current relative error is:  tensor(0.1006, device='cuda:0')
# current epoch is:  7450
# current loss is:  tensor(-1.1559, device='cuda:0')
# current relative error is:  tensor(0.1067, device='cuda:0')
# current epoch is:  7500
# current loss is:  tensor(-1.1692, device='cuda:0')
# current relative error is:  tensor(0.1085, device='cuda:0')
# current epoch is:  7550
# current loss is:  tensor(-1.2305, device='cuda:0')
# current relative error is:  tensor(0.0885, device='cuda:0')
# current epoch is:  7600
# current loss is:  tensor(-1.1740, device='cuda:0')
# current relative error is:  tensor(0.1041, device='cuda:0')
# current epoch is:  7650
# current loss is:  tensor(-1.1802, device='cuda:0')
# current relative error is:  tensor(0.1007, device='cuda:0')
# current epoch is:  7700
# current loss is:  tensor(-1.0852, device='cuda:0')
# current relative error is:  tensor(0.0990, device='cuda:0')
# current epoch is:  7750
# current loss is:  tensor(-1.1289, device='cuda:0')
# current relative error is:  tensor(0.1053, device='cuda:0')
# current epoch is:  7800
# current loss is:  tensor(-1.1952, device='cuda:0')
# current relative error is:  tensor(0.1082, device='cuda:0')
# current epoch is:  7850
# current loss is:  tensor(-1.2236, device='cuda:0')
# current relative error is:  tensor(0.1226, device='cuda:0')
# current epoch is:  7900
# current loss is:  tensor(-1.2398, device='cuda:0')
# current relative error is:  tensor(0.0742, device='cuda:0')
# current epoch is:  7950
# current loss is:  tensor(-1.2293, device='cuda:0')
# current relative error is:  tensor(0.1148, device='cuda:0')
# current epoch is:  8000
# current loss is:  tensor(-1.2900, device='cuda:0')
# current relative error is:  tensor(0.1038, device='cuda:0')
# current epoch is:  8050
# current loss is:  tensor(-1.2120, device='cuda:0')
# current relative error is:  tensor(0.1092, device='cuda:0')
# current epoch is:  8100
# current loss is:  tensor(-1.2759, device='cuda:0')
# current relative error is:  tensor(0.1044, device='cuda:0')
# current epoch is:  8150
# current loss is:  tensor(-1.3123, device='cuda:0')
# current relative error is:  tensor(0.0961, device='cuda:0')
# current epoch is:  8200
# current loss is:  tensor(-1.2239, device='cuda:0')
# current relative error is:  tensor(0.1102, device='cuda:0')
# current epoch is:  8250
# current loss is:  tensor(-1.2489, device='cuda:0')
# current relative error is:  tensor(0.1029, device='cuda:0')
# current epoch is:  8300
# current loss is:  tensor(-1.2289, device='cuda:0')
# current relative error is:  tensor(0.1072, device='cuda:0')
# current epoch is:  8350
# current loss is:  tensor(-1.1497, device='cuda:0')
# current relative error is:  tensor(0.1079, device='cuda:0')
# current epoch is:  8400
# current loss is:  tensor(-1.2739, device='cuda:0')
# current relative error is:  tensor(0.1125, device='cuda:0')
# current epoch is:  8450
# current loss is:  tensor(-1.1283, device='cuda:0')
# current relative error is:  tensor(0.1129, device='cuda:0')
# current epoch is:  8500
# current loss is:  tensor(-1.2244, device='cuda:0')
# current relative error is:  tensor(0.1110, device='cuda:0')
# current epoch is:  8550
# current loss is:  tensor(-1.2111, device='cuda:0')
# current relative error is:  tensor(0.0997, device='cuda:0')
# current epoch is:  8600
# current loss is:  tensor(-1.2719, device='cuda:0')
# current relative error is:  tensor(0.0970, device='cuda:0')
# current epoch is:  8650
# current loss is:  tensor(-1.2069, device='cuda:0')
# current relative error is:  tensor(0.1081, device='cuda:0')
# current epoch is:  8700
# current loss is:  tensor(-1.1804, device='cuda:0')
# current relative error is:  tensor(0.1058, device='cuda:0')
# current epoch is:  8750
# current loss is:  tensor(-1.2126, device='cuda:0')
# current relative error is:  tensor(0.1011, device='cuda:0')
# current epoch is:  8800
# current loss is:  tensor(-1.1706, device='cuda:0')
# current relative error is:  tensor(0.1167, device='cuda:0')
# current epoch is:  8850
# current loss is:  tensor(-1.1005, device='cuda:0')
# current relative error is:  tensor(0.1004, device='cuda:0')
# current epoch is:  8900
# current loss is:  tensor(-1.2010, device='cuda:0')
# current relative error is:  tensor(0.1064, device='cuda:0')
# current epoch is:  8950
# current loss is:  tensor(-1.3701, device='cuda:0')
# current relative error is:  tensor(0.1031, device='cuda:0')
# current epoch is:  9000
# current loss is:  tensor(-1.1827, device='cuda:0')
# current relative error is:  tensor(0.0967, device='cuda:0')
# current epoch is:  9050
# current loss is:  tensor(-1.1818, device='cuda:0')
# current relative error is:  tensor(0.1017, device='cuda:0')
# current epoch is:  9100
# current loss is:  tensor(-1.2282, device='cuda:0')
# current relative error is:  tensor(0.0925, device='cuda:0')
# current epoch is:  9150
# current loss is:  tensor(-1.0992, device='cuda:0')
# current relative error is:  tensor(0.0915, device='cuda:0')
# current epoch is:  9200
# current loss is:  tensor(-1.1800, device='cuda:0')
# current relative error is:  tensor(0.1196, device='cuda:0')
# current epoch is:  9250
# current loss is:  tensor(-1.1195, device='cuda:0')
# current relative error is:  tensor(0.0966, device='cuda:0')
# current epoch is:  9300
# current loss is:  tensor(-1.2554, device='cuda:0')
# current relative error is:  tensor(0.1023, device='cuda:0')
# current epoch is:  9350
# current loss is:  tensor(-1.1552, device='cuda:0')
# current relative error is:  tensor(0.0927, device='cuda:0')
# current epoch is:  9400
# current loss is:  tensor(-1.1166, device='cuda:0')
# current relative error is:  tensor(0.1088, device='cuda:0')
# current epoch is:  9450
# current loss is:  tensor(-1.2053, device='cuda:0')
# current relative error is:  tensor(0.0976, device='cuda:0')
# current epoch is:  9500
# current loss is:  tensor(-1.1418, device='cuda:0')
# current relative error is:  tensor(0.1036, device='cuda:0')
# current epoch is:  9550
# current loss is:  tensor(-1.2942, device='cuda:0')
# current relative error is:  tensor(0.1098, device='cuda:0')
# current epoch is:  9600
# current loss is:  tensor(-1.2511, device='cuda:0')
# current relative error is:  tensor(0.1079, device='cuda:0')
# current epoch is:  9650
# current loss is:  tensor(-1.1338, device='cuda:0')
# current relative error is:  tensor(0.0956, device='cuda:0')
# current epoch is:  9700
# current loss is:  tensor(-1.1509, device='cuda:0')
# current relative error is:  tensor(0.1196, device='cuda:0')
# current epoch is:  9750
# current loss is:  tensor(-1.2264, device='cuda:0')
# current relative error is:  tensor(0.1177, device='cuda:0')
# current epoch is:  9800
# current loss is:  tensor(-1.2274, device='cuda:0')
# current relative error is:  tensor(0.0970, device='cuda:0')
# current epoch is:  9850
# current loss is:  tensor(-1.2530, device='cuda:0')
# current relative error is:  tensor(0.0917, device='cuda:0')
# current epoch is:  9900
# current loss is:  tensor(-1.0878, device='cuda:0')
# current relative error is:  tensor(0.0777, device='cuda:0')
# current epoch is:  9950
# current loss is:  tensor(-1.2707, device='cuda:0')
# current relative error is:  tensor(0.0954, device='cuda:0')
# total time is:  1229.3201987743378 seconds
