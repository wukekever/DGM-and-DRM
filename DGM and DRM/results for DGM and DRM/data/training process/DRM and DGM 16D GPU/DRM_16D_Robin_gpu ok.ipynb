# %%
import torch
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import torch.nn as nn
from math import *

# %%
torch.cuda.set_device(1)

# %%
torch.set_default_tensor_type('torch.DoubleTensor') # 设置浮点类型为 torch.float64

# %%
# 定义激活函数: swish(x)
def acti(x):
    return x*torch.sigmoid(x)

# %%
# 定义网络结构
class DeepRitzNet(torch.nn.Module):
    def __init__(self, input_width, layer_width):
        super(DeepRitzNet, self).__init__()
        self.linear_in = torch.nn.Linear(input_width, layer_width)
        self.linear1 = torch.nn.Linear(layer_width, layer_width)
        self.linear2 = torch.nn.Linear(layer_width, layer_width)
        self.linear3 = torch.nn.Linear(layer_width, layer_width)
        self.linear4 = torch.nn.Linear(layer_width, layer_width)
        self.linear5 = torch.nn.Linear(layer_width, layer_width)
        self.linear6 = torch.nn.Linear(layer_width, layer_width)
        self.linear_out = torch.nn.Linear(layer_width, 1)

    def forward(self, x):
        y = self.linear_in(x) # fully connect layer
        y = y + acti(self.linear2(acti(self.linear1(y)))) # residual block 1
        y = y + acti(self.linear4(acti(self.linear3(y)))) # residual block 2
        y = y + acti(self.linear6(acti(self.linear5(y)))) # residual block 3
        output = self.linear_out(y) # fully connect layer
        return output

# %%
dimension = 16

# %%
# exact solution
def u_ex(x):  
    x_temp = torch.cos(pi*x)
    u_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return u_x

# %%
def f(x):
    x_temp = torch.cos(pi*x)
    f_x = 2*pi**2*(x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return f_x

# %%
def g(x):  
    x_temp = torch.cos(pi*x)
    g_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return g_x

# %%
# Deep Ritz Method
def DRM(x):
    u_hat = model(x)
    ux = torch.zeros(x.size()[0], dimension).cuda()
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension).cuda()
        dx[:, i] = torch.ones(x.size()[0])
        ux[:, i] = (model(x+step_size*dx) - model(x-step_size*dx))[:,0]/step_size/2
    uxsq = (torch.sum(ux**2, dim = 1)).reshape([x.size()[0], 1]) # dim = 1 按行求和
    f_temp = f(x)
    part_1 = torch.sum(0.5 * uxsq + 0.5*pi**2*u_hat**2 - f_temp*u_hat)/x.size()[0]
    
    Nb = 100
    xa1 = torch.rand(Nb, dimension).cuda()  
    xa1[:, 0] = torch.zeros(Nb)
    xa2 = torch.rand(Nb, dimension).cuda()  
    xa2[:, 0] = torch.ones(Nb)
    xb1 = torch.rand(Nb, dimension).cuda() 
    xb1[:, 1] = torch.zeros(Nb)
    xb2 = torch.rand(Nb, dimension).cuda() 
    xb2[:, 1] = torch.ones(Nb)
    xc1 = torch.rand(Nb, dimension).cuda() 
    xc1[:, 2] = torch.zeros(Nb)
    xc2 = torch.rand(Nb, dimension).cuda() 
    xc2[:, 2] = torch.ones(Nb)
    xd1 = torch.rand(Nb, dimension).cuda() 
    xd1[:, 3] = torch.zeros(Nb)
    xd2 = torch.rand(Nb, dimension).cuda() 
    xd2[:, 3] = torch.ones(Nb)
    xe1 = torch.rand(Nb, dimension).cuda()  
    xe1[:, 4] = torch.zeros(Nb)
    xe2 = torch.rand(Nb, dimension).cuda()  
    xe2[:, 4] = torch.ones(Nb)
    xf1 = torch.rand(Nb, dimension).cuda() 
    xf1[:, 5] = torch.zeros(Nb)
    xf2 = torch.rand(Nb, dimension).cuda() 
    xf2[:, 5] = torch.ones(Nb)
    xg1 = torch.rand(Nb, dimension).cuda() 
    xg1[:, 6] = torch.zeros(Nb)
    xg2 = torch.rand(Nb, dimension).cuda() 
    xg2[:, 6] = torch.ones(Nb)
    xh1 = torch.rand(Nb, dimension).cuda() 
    xh1[:, 7] = torch.zeros(Nb)
    xh2 = torch.rand(Nb, dimension).cuda() 
    xh2[:, 7] = torch.ones(Nb)
    xi1 = torch.rand(Nb, dimension).cuda()  
    xi1[:, 8] = torch.zeros(Nb)
    xi2 = torch.rand(Nb, dimension).cuda()  
    xi2[:, 8] = torch.ones(Nb)
    xj1 = torch.rand(Nb, dimension).cuda() 
    xj1[:, 9] = torch.zeros(Nb)
    xj2 = torch.rand(Nb, dimension).cuda() 
    xj2[:, 9] = torch.ones(Nb)
    xk1 = torch.rand(Nb, dimension).cuda() 
    xk1[:, 10] = torch.zeros(Nb)
    xk2 = torch.rand(Nb, dimension).cuda() 
    xk2[:, 10] = torch.ones(Nb)
    xl1 = torch.rand(Nb, dimension).cuda() 
    xl1[:, 11] = torch.zeros(Nb)
    xl2 = torch.rand(Nb, dimension).cuda() 
    xl2[:, 11] = torch.ones(Nb)
    xm1 = torch.rand(Nb, dimension).cuda()  
    xm1[:, 12] = torch.zeros(Nb)
    xm2 = torch.rand(Nb, dimension).cuda()  
    xm2[:, 12] = torch.ones(Nb)
    xn1 = torch.rand(Nb, dimension).cuda() 
    xn1[:, 13] = torch.zeros(Nb)
    xn2 = torch.rand(Nb, dimension).cuda() 
    xn2[:, 13] = torch.ones(Nb)
    xo1 = torch.rand(Nb, dimension).cuda() 
    xo1[:, 14] = torch.zeros(Nb)
    xo2 = torch.rand(Nb, dimension).cuda() 
    xo2[:, 14] = torch.ones(Nb)
    xp1 = torch.rand(Nb, dimension).cuda() 
    xp1[:, 15] = torch.zeros(Nb)
    xp2 = torch.rand(Nb, dimension).cuda() 
    xp2[:, 15] = torch.ones(Nb)
    
    dx1 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx1[:, 0] = torch.ones(xb1.size()[0])
    dx2 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx2[:, 1] = torch.ones(xb1.size()[0])
    dx3 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx3[:, 2] = torch.ones(xb1.size()[0])
    dx4 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx4[:, 3] = torch.ones(xb1.size()[0])
    dx5 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx5[:, 4] = torch.ones(xb1.size()[0])
    dx6 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx6[:, 5] = torch.ones(xb1.size()[0])
    dx7 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx7[:, 6] = torch.ones(xb1.size()[0])
    dx8 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx8[:, 7] = torch.ones(xb1.size()[0])
    dx9 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx9[:, 8] = torch.ones(xb1.size()[0])
    dx10 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx10[:, 9] = torch.ones(xb1.size()[0])
    dx11 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx11[:, 10] = torch.ones(xb1.size()[0])
    dx12 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx12[:, 11] = torch.ones(xb1.size()[0])
    dx13 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx13[:, 12] = torch.ones(xb1.size()[0])
    dx14 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx14[:, 13] = torch.ones(xb1.size()[0])
    dx15 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx15[:, 14] = torch.ones(xb1.size()[0])
    dx16 = torch.zeros(xb1.size()[0], dimension).cuda() 
    dx16[:, 15] = torch.ones(xb1.size()[0])
    
    uxa1 = (((model(xa1+step_size*dx1) - model(xa1-step_size*dx1))/step_size/2 * (1.0) + model(xa1) - g(xa1))**2).cuda()
    uxa2 = (((model(xa2+step_size*dx1) - model(xa2-step_size*dx1))/step_size/2 * (-1.0) + model(xa2) - g(xa2))**2).cuda()
    uxb1 = (((model(xb1+step_size*dx2) - model(xb1-step_size*dx2))/step_size/2 * (1.0) + model(xb1) - g(xb1))**2).cuda()
    uxb2 = (((model(xb2+step_size*dx2) - model(xb2-step_size*dx2))/step_size/2 * (-1.0) + model(xb2) - g(xb2))**2).cuda()
    uxc1 = (((model(xc1+step_size*dx3) - model(xc1-step_size*dx3))/step_size/2 * (1.0) + model(xc1) - g(xc1))**2).cuda()
    uxc2 = (((model(xc2+step_size*dx3) - model(xc2-step_size*dx3))/step_size/2 * (-1.0) + model(xc2) - g(xc2))**2).cuda()
    uxd1 = (((model(xd1+step_size*dx4) - model(xd1-step_size*dx4))/step_size/2 * (1.0) + model(xd1) - g(xd1))**2).cuda()
    uxd2 = (((model(xd2+step_size*dx4) - model(xd2-step_size*dx4))/step_size/2 * (-1.0) + model(xd2) - g(xd2))**2).cuda()
    uxe1 = (((model(xe1+step_size*dx5) - model(xe1-step_size*dx5))/step_size/2 * (1.0) + model(xe1) - g(xe1))**2).cuda()
    uxe2 = (((model(xe2+step_size*dx5) - model(xe2-step_size*dx5))/step_size/2 * (-1.0) + model(xe2) - g(xe2))**2).cuda()
    uxf1 = (((model(xf1+step_size*dx6) - model(xf1-step_size*dx6))/step_size/2 * (1.0) + model(xf1) - g(xf1))**2).cuda()
    uxf2 = (((model(xf2+step_size*dx6) - model(xf2-step_size*dx6))/step_size/2 * (-1.0) + model(xf2) - g(xf2))**2).cuda()
    uxg1 = (((model(xg1+step_size*dx7) - model(xg1-step_size*dx7))/step_size/2 * (1.0) + model(xg1) - g(xg1))**2).cuda()
    uxg2 = (((model(xg2+step_size*dx7) - model(xg2-step_size*dx7))/step_size/2 * (-1.0) + model(xg2) - g(xg2))**2).cuda()
    uxh1 = (((model(xh1+step_size*dx8) - model(xh1-step_size*dx8))/step_size/2 * (1.0) + model(xh1) - g(xh1))**2).cuda()
    uxh2 = (((model(xh2+step_size*dx8) - model(xh2-step_size*dx8))/step_size/2 * (-1.0) + model(xh2) - g(xh2))**2).cuda()
    uxi1 = (((model(xi1+step_size*dx9) - model(xi1-step_size*dx1))/step_size/2 * (1.0) + model(xi1) - g(xi1))**2).cuda()
    uxi2 = (((model(xi2+step_size*dx9) - model(xi2-step_size*dx1))/step_size/2 * (-1.0) + model(xi2) - g(xi2))**2).cuda()
    uxj1 = (((model(xj1+step_size*dx10) - model(xj1-step_size*dx9))/step_size/2 * (1.0) + model(xj1) - g(xj1))**2).cuda()
    uxj2 = (((model(xj2+step_size*dx10) - model(xj2-step_size*dx9))/step_size/2 * (-1.0) + model(xj2) - g(xj2))**2).cuda()
    uxk1 = (((model(xk1+step_size*dx11) - model(xk1-step_size*dx10))/step_size/2 * (1.0) + model(xk1) - g(xk1))**2).cuda()
    uxk2 = (((model(xk2+step_size*dx11) - model(xk2-step_size*dx10))/step_size/2 * (-1.0) + model(xk2) - g(xk2))**2).cuda()
    uxl1 = (((model(xl1+step_size*dx12) - model(xl1-step_size*dx11))/step_size/2 * (1.0) + model(xl1) - g(xl1))**2).cuda()
    uxl2 = (((model(xl2+step_size*dx12) - model(xl2-step_size*dx11))/step_size/2 * (-1.0) + model(xl2) - g(xl2))**2).cuda()
    uxm1 = (((model(xm1+step_size*dx13) - model(xm1-step_size*dx12))/step_size/2 * (1.0) + model(xm1) - g(xm1))**2).cuda()
    uxm2 = (((model(xm2+step_size*dx13) - model(xm2-step_size*dx12))/step_size/2 * (-1.0) + model(xm2) - g(xm2))**2).cuda()
    uxn1 = (((model(xn1+step_size*dx14) - model(xn1-step_size*dx13))/step_size/2 * (1.0) + model(xn1) - g(xn1))**2).cuda()
    uxn2 = (((model(xn2+step_size*dx14) - model(xn2-step_size*dx13))/step_size/2 * (-1.0) + model(xn2) - g(xn2))**2).cuda()
    uxo1 = (((model(xo1+step_size*dx15) - model(xo1-step_size*dx14))/step_size/2 * (1.0) + model(xo1) - g(xo1))**2).cuda()
    uxo2 = (((model(xo2+step_size*dx15) - model(xo2-step_size*dx14))/step_size/2 * (-1.0) + model(xo2) - g(xo2))**2).cuda()
    uxp1 = (((model(xp1+step_size*dx16) - model(xp1-step_size*dx15))/step_size/2 * (1.0) + model(xp1) - g(xp1))**2).cuda()
    uxp2 = (((model(xp2+step_size*dx16) - model(xp2-step_size*dx15))/step_size/2 * (-1.0) + model(xp2) - g(xp2))**2).cuda()
    
    part_2 = torch.sum((uxa1 + uxa2 + uxb1 + uxb2 + uxc1 + uxc2 + uxd1 + uxd2 + uxe1 + uxe2 + uxf1 + uxf2 + uxg1 + uxg2 + uxh1 + uxh2 + uxi1 + uxi2 + uxj1 + uxj2 + uxk1 + uxk2 + uxl1 + uxl2 + uxm1 + uxm2 + uxn1 + uxn2 + uxo1 + uxo2 + uxp1 + uxp2)[:,0])/xa1.size()[0]
    lambda1 = 10.0
    return part_1 + lambda1 * part_2 / 32

# %%
Data_size = 2000
def Gendata():
    x = torch.rand(Data_size, dimension)
    return x.cuda()

# %%
# 正态分布初始化参数
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = DeepRitzNet(dimension, 32)
model = initparam(model, 0.5)

# %%
device = torch.device("cuda:1" )
model.to(device)
# Out:
# DeepRitzNet(
#   (linear_in): Linear(in_features=16, out_features=32, bias=True)
#   (linear1): Linear(in_features=32, out_features=32, bias=True)
#   (linear2): Linear(in_features=32, out_features=32, bias=True)
#   (linear3): Linear(in_features=32, out_features=32, bias=True)
#   (linear4): Linear(in_features=32, out_features=32, bias=True)
#   (linear5): Linear(in_features=32, out_features=32, bias=True)
#   (linear6): Linear(in_features=32, out_features=32, bias=True)
#   (linear_out): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
import torch.optim as optim
import torch.nn as nn
import time

# %%
def relative_error():
    x = Gendata()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact)**2))/torch.sqrt(torch.sum((exact)**2))
    return value

# %%
traintime = 100000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = Gendata()
    x.requires_grad = True
    losses = DRM(x)
    losses.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", losses.detach())
        print("current relative error is: ", error.detach())
        np.save("DRM_relative_error_16D_Robin.npy", error_save)
np.save("DRM_relative_error_16D_Robin.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(142379.6540, device='cuda:1')
# current relative error is:  tensor(19.4845, device='cuda:1')
# current epoch is:  50
# current loss is:  tensor(4414.4439, device='cuda:1')
# current relative error is:  tensor(3.8381, device='cuda:1')
# current epoch is:  100
# current loss is:  tensor(1754.9447, device='cuda:1')
# current relative error is:  tensor(2.3756, device='cuda:1')
# current epoch is:  150
# current loss is:  tensor(918.4895, device='cuda:1')
# current relative error is:  tensor(1.8036, device='cuda:1')
# current epoch is:  200
# current loss is:  tensor(601.0700, device='cuda:1')
# current relative error is:  tensor(1.4626, device='cuda:1')
# current epoch is:  250
# current loss is:  tensor(425.3095, device='cuda:1')
# current relative error is:  tensor(1.2698, device='cuda:1')
# current epoch is:  300
# current loss is:  tensor(322.9326, device='cuda:1')
# current relative error is:  tensor(1.1007, device='cuda:1')
# current epoch is:  350
# current loss is:  tensor(239.8364, device='cuda:1')
# current relative error is:  tensor(1.0259, device='cuda:1')
# current epoch is:  400
# current loss is:  tensor(202.5196, device='cuda:1')
# current relative error is:  tensor(0.9569, device='cuda:1')
# current epoch is:  450
# current loss is:  tensor(166.7302, device='cuda:1')
# current relative error is:  tensor(0.8645, device='cuda:1')
# current epoch is:  500
# current loss is:  tensor(122.1430, device='cuda:1')
# current relative error is:  tensor(0.8120, device='cuda:1')
# current epoch is:  550
# current loss is:  tensor(91.2490, device='cuda:1')
# current relative error is:  tensor(0.7407, device='cuda:1')
# current epoch is:  600
# current loss is:  tensor(68.2198, device='cuda:1')
# current relative error is:  tensor(0.6673, device='cuda:1')
# current epoch is:  650
# current loss is:  tensor(47.1387, device='cuda:1')
# current relative error is:  tensor(0.6232, device='cuda:1')
# current epoch is:  700
# current loss is:  tensor(38.1613, device='cuda:1')
# current relative error is:  tensor(0.5883, device='cuda:1')
# current epoch is:  750
# current loss is:  tensor(35.1792, device='cuda:1')
# current relative error is:  tensor(0.5368, device='cuda:1')
# current epoch is:  800
# current loss is:  tensor(16.0824, device='cuda:1')
# current relative error is:  tensor(0.5181, device='cuda:1')
# current epoch is:  850
# current loss is:  tensor(20.2216, device='cuda:1')
# current relative error is:  tensor(0.4991, device='cuda:1')
# current epoch is:  900
# current loss is:  tensor(12.2043, device='cuda:1')
# current relative error is:  tensor(0.4633, device='cuda:1')
# current epoch is:  950
# current loss is:  tensor(6.6728, device='cuda:1')
# current relative error is:  tensor(0.4618, device='cuda:1')
# current epoch is:  1000
# current loss is:  tensor(-1.1380, device='cuda:1')
# current relative error is:  tensor(0.4414, device='cuda:1')
# current epoch is:  1050
# current loss is:  tensor(4.4126, device='cuda:1')
# current relative error is:  tensor(0.4380, device='cuda:1')
# current epoch is:  1100
# current loss is:  tensor(-7.3383, device='cuda:1')
# current relative error is:  tensor(0.3999, device='cuda:1')
# current epoch is:  1150
# current loss is:  tensor(-11.7223, device='cuda:1')
# current relative error is:  tensor(0.3888, device='cuda:1')
# current epoch is:  1200
# current loss is:  tensor(-10.2891, device='cuda:1')
# current relative error is:  tensor(0.3683, device='cuda:1')
# current epoch is:  1250
# current loss is:  tensor(-14.7782, device='cuda:1')
# current relative error is:  tensor(0.3620, device='cuda:1')
# current epoch is:  1300
# current loss is:  tensor(-14.2801, device='cuda:1')
# current relative error is:  tensor(0.3600, device='cuda:1')
# current epoch is:  1350
# current loss is:  tensor(-14.7095, device='cuda:1')
# current relative error is:  tensor(0.3603, device='cuda:1')
# current epoch is:  1400
# current loss is:  tensor(-19.7402, device='cuda:1')
# current relative error is:  tensor(0.3530, device='cuda:1')
# current epoch is:  1450
# current loss is:  tensor(-14.0104, device='cuda:1')
# current relative error is:  tensor(0.3258, device='cuda:1')
# current epoch is:  1500
# current loss is:  tensor(-19.0496, device='cuda:1')
# current relative error is:  tensor(0.3319, device='cuda:1')
# current epoch is:  1550
# current loss is:  tensor(-22.0671, device='cuda:1')
# current relative error is:  tensor(0.3694, device='cuda:1')
# current epoch is:  1600
# current loss is:  tensor(-25.9168, device='cuda:1')
# current relative error is:  tensor(0.3225, device='cuda:1')
# current epoch is:  1650
# current loss is:  tensor(-11.9301, device='cuda:1')
# current relative error is:  tensor(0.3292, device='cuda:1')
# current epoch is:  1700
# current loss is:  tensor(-20.8869, device='cuda:1')
# current relative error is:  tensor(0.3149, device='cuda:1')
# current epoch is:  1750
# current loss is:  tensor(-22.1876, device='cuda:1')
# current relative error is:  tensor(0.3460, device='cuda:1')
# current epoch is:  1800
# current loss is:  tensor(-22.9334, device='cuda:1')
# current relative error is:  tensor(0.3219, device='cuda:1')
# current epoch is:  1850
# current loss is:  tensor(-23.9853, device='cuda:1')
# current relative error is:  tensor(0.3032, device='cuda:1')
# current epoch is:  1900
# current loss is:  tensor(-24.9629, device='cuda:1')
# current relative error is:  tensor(0.2956, device='cuda:1')
# current epoch is:  1950
# current loss is:  tensor(-21.4832, device='cuda:1')
# current relative error is:  tensor(0.2997, device='cuda:1')
# current epoch is:  2000
# current loss is:  tensor(-23.2910, device='cuda:1')
# current relative error is:  tensor(0.3014, device='cuda:1')
# current epoch is:  2050
# current loss is:  tensor(-22.0270, device='cuda:1')
# current relative error is:  tensor(0.3127, device='cuda:1')
# current epoch is:  2100
# current loss is:  tensor(-18.1498, device='cuda:1')
# current relative error is:  tensor(0.3419, device='cuda:1')
# current epoch is:  2150
# current loss is:  tensor(-26.5023, device='cuda:1')
# current relative error is:  tensor(0.4084, device='cuda:1')
# current epoch is:  2200
# current loss is:  tensor(22.9387, device='cuda:1')
# current relative error is:  tensor(0.7525, device='cuda:1')
# current epoch is:  2250
# current loss is:  tensor(-12.8530, device='cuda:1')
# current relative error is:  tensor(0.3162, device='cuda:1')
# current epoch is:  2300
# current loss is:  tensor(-16.3249, device='cuda:1')
# current relative error is:  tensor(0.4582, device='cuda:1')
# current epoch is:  2350
# current loss is:  tensor(0.3587, device='cuda:1')
# current relative error is:  tensor(0.5664, device='cuda:1')
# current epoch is:  2400
# current loss is:  tensor(-23.7750, device='cuda:1')
# current relative error is:  tensor(0.2987, device='cuda:1')
# current epoch is:  2450
# current loss is:  tensor(-24.0075, device='cuda:1')
# current relative error is:  tensor(0.3502, device='cuda:1')
# current epoch is:  2500
# current loss is:  tensor(-24.5954, device='cuda:1')
# current relative error is:  tensor(0.3149, device='cuda:1')
# current epoch is:  2550
# current loss is:  tensor(-23.9066, device='cuda:1')
# current relative error is:  tensor(0.2779, device='cuda:1')
# current epoch is:  2600
# current loss is:  tensor(-25.4688, device='cuda:1')
# current relative error is:  tensor(0.2843, device='cuda:1')
# current epoch is:  2650
# current loss is:  tensor(-13.6813, device='cuda:1')
# current relative error is:  tensor(0.3539, device='cuda:1')
# current epoch is:  2700
# current loss is:  tensor(-6.4078, device='cuda:1')
# current relative error is:  tensor(0.4695, device='cuda:1')
# current epoch is:  2750
# current loss is:  tensor(-21.5545, device='cuda:1')
# current relative error is:  tensor(0.3266, device='cuda:1')
# current epoch is:  2800
# current loss is:  tensor(-27.9353, device='cuda:1')
# current relative error is:  tensor(0.3011, device='cuda:1')
# current epoch is:  2850
# current loss is:  tensor(-26.8883, device='cuda:1')
# current relative error is:  tensor(0.2933, device='cuda:1')
# current epoch is:  2900
# current loss is:  tensor(-25.2718, device='cuda:1')
# current relative error is:  tensor(0.2740, device='cuda:1')
# current epoch is:  2950
# current loss is:  tensor(-26.4488, device='cuda:1')
# current relative error is:  tensor(0.2944, device='cuda:1')
# current epoch is:  3000
# current loss is:  tensor(-3.5480, device='cuda:1')
# current relative error is:  tensor(0.6485, device='cuda:1')
# current epoch is:  3050
# current loss is:  tensor(-27.8057, device='cuda:1')
# current relative error is:  tensor(0.3354, device='cuda:1')
# current epoch is:  3100
# current loss is:  tensor(-22.5156, device='cuda:1')
# current relative error is:  tensor(0.3270, device='cuda:1')
# current epoch is:  3150
# current loss is:  tensor(-25.0321, device='cuda:1')
# current relative error is:  tensor(0.3272, device='cuda:1')
# current epoch is:  3200
# current loss is:  tensor(-34.8313, device='cuda:1')
# current relative error is:  tensor(0.3224, device='cuda:1')
# current epoch is:  3250
# current loss is:  tensor(-27.9577, device='cuda:1')
# current relative error is:  tensor(0.4737, device='cuda:1')
# current epoch is:  3300
# current loss is:  tensor(-27.8078, device='cuda:1')
# current relative error is:  tensor(0.2766, device='cuda:1')
# current epoch is:  3350
# current loss is:  tensor(-27.5774, device='cuda:1')
# current relative error is:  tensor(0.2882, device='cuda:1')
# current epoch is:  3400
# current loss is:  tensor(3.9606, device='cuda:1')
# current relative error is:  tensor(0.5591, device='cuda:1')
# current epoch is:  3450
# current loss is:  tensor(-30.3830, device='cuda:1')
# current relative error is:  tensor(0.2760, device='cuda:1')
# current epoch is:  3500
# current loss is:  tensor(-27.4189, device='cuda:1')
# current relative error is:  tensor(0.2756, device='cuda:1')
# current epoch is:  3550
# current loss is:  tensor(-30.7525, device='cuda:1')
# current relative error is:  tensor(0.3002, device='cuda:1')
# current epoch is:  3600
# current loss is:  tensor(-19.3706, device='cuda:1')
# current relative error is:  tensor(0.4245, device='cuda:1')
# current epoch is:  3650
# current loss is:  tensor(-23.2891, device='cuda:1')
# current relative error is:  tensor(0.3395, device='cuda:1')
# current epoch is:  3700
# current loss is:  tensor(-30.3687, device='cuda:1')
# current relative error is:  tensor(0.3209, device='cuda:1')
# current epoch is:  3750
# current loss is:  tensor(-19.9987, device='cuda:1')
# current relative error is:  tensor(0.3480, device='cuda:1')
# current epoch is:  3800
# current loss is:  tensor(-31.0585, device='cuda:1')
# current relative error is:  tensor(0.2871, device='cuda:1')
# current epoch is:  3850
# current loss is:  tensor(-28.0931, device='cuda:1')
# current relative error is:  tensor(0.3199, device='cuda:1')
# current epoch is:  3900
# current loss is:  tensor(-21.2147, device='cuda:1')
# current relative error is:  tensor(0.3619, device='cuda:1')
# current epoch is:  3950
# current loss is:  tensor(-26.8987, device='cuda:1')
# current relative error is:  tensor(0.2846, device='cuda:1')
# current epoch is:  4000
# current loss is:  tensor(-30.5983, device='cuda:1')
# current relative error is:  tensor(0.2719, device='cuda:1')
# current epoch is:  4050
# current loss is:  tensor(-3.9968, device='cuda:1')
# current relative error is:  tensor(0.5455, device='cuda:1')
# current epoch is:  4100
# current loss is:  tensor(-22.9022, device='cuda:1')
# current relative error is:  tensor(0.4362, device='cuda:1')
# current epoch is:  4150
# current loss is:  tensor(-25.2851, device='cuda:1')
# current relative error is:  tensor(0.2747, device='cuda:1')
# current epoch is:  4200
# current loss is:  tensor(-28.4595, device='cuda:1')
# current relative error is:  tensor(0.2685, device='cuda:1')
# current epoch is:  4250
# current loss is:  tensor(-26.6097, device='cuda:1')
# current relative error is:  tensor(0.3167, device='cuda:1')
# current epoch is:  4300
# current loss is:  tensor(-26.9286, device='cuda:1')
# current relative error is:  tensor(0.2766, device='cuda:1')
# current epoch is:  4350
# current loss is:  tensor(-32.4034, device='cuda:1')
# current relative error is:  tensor(0.2697, device='cuda:1')
# current epoch is:  4400
# current loss is:  tensor(-31.8635, device='cuda:1')
# current relative error is:  tensor(0.3011, device='cuda:1')
# current epoch is:  4450
# current loss is:  tensor(-29.0157, device='cuda:1')
# current relative error is:  tensor(0.2724, device='cuda:1')
# current epoch is:  4500
# current loss is:  tensor(-28.7902, device='cuda:1')
# current relative error is:  tensor(0.3652, device='cuda:1')
# current epoch is:  4550
# current loss is:  tensor(-22.7188, device='cuda:1')
# current relative error is:  tensor(0.2847, device='cuda:1')
# current epoch is:  4600
# current loss is:  tensor(-29.1515, device='cuda:1')
# current relative error is:  tensor(0.3195, device='cuda:1')
# current epoch is:  4650
# current loss is:  tensor(-30.2482, device='cuda:1')
# current relative error is:  tensor(0.2848, device='cuda:1')
# current epoch is:  4700
# current loss is:  tensor(-24.5216, device='cuda:1')
# current relative error is:  tensor(0.3883, device='cuda:1')
# current epoch is:  4750
# current loss is:  tensor(-21.6381, device='cuda:1')
# current relative error is:  tensor(0.2815, device='cuda:1')
# current epoch is:  4800
# current loss is:  tensor(-33.4646, device='cuda:1')
# current relative error is:  tensor(0.2645, device='cuda:1')
# current epoch is:  4850
# current loss is:  tensor(-12.0650, device='cuda:1')
# current relative error is:  tensor(0.3331, device='cuda:1')
# current epoch is:  4900
# current loss is:  tensor(-29.5617, device='cuda:1')
# current relative error is:  tensor(0.3771, device='cuda:1')
# current epoch is:  4950
# current loss is:  tensor(-21.7520, device='cuda:1')
# current relative error is:  tensor(0.3348, device='cuda:1')
# current epoch is:  5000
# current loss is:  tensor(-29.9102, device='cuda:1')
# current relative error is:  tensor(0.2568, device='cuda:1')
# current epoch is:  5050
# current loss is:  tensor(-25.5785, device='cuda:1')
# current relative error is:  tensor(0.3959, device='cuda:1')
# current epoch is:  5100
# current loss is:  tensor(-36.5228, device='cuda:1')
# current relative error is:  tensor(0.2803, device='cuda:1')
# current epoch is:  5150
# current loss is:  tensor(-24.8873, device='cuda:1')
# current relative error is:  tensor(0.2689, device='cuda:1')
# current epoch is:  5200
# current loss is:  tensor(-34.6006, device='cuda:1')
# current relative error is:  tensor(0.2754, device='cuda:1')
# current epoch is:  5250
# current loss is:  tensor(-26.4707, device='cuda:1')
# current relative error is:  tensor(0.2626, device='cuda:1')
# current epoch is:  5300
# current loss is:  tensor(-22.3235, device='cuda:1')
# current relative error is:  tensor(0.4123, device='cuda:1')
# current epoch is:  5350
# current loss is:  tensor(-32.3716, device='cuda:1')
# current relative error is:  tensor(0.2595, device='cuda:1')
# current epoch is:  5400
# current loss is:  tensor(-32.4183, device='cuda:1')
# current relative error is:  tensor(0.2960, device='cuda:1')
# current epoch is:  5450
# current loss is:  tensor(-25.5427, device='cuda:1')
# current relative error is:  tensor(0.2618, device='cuda:1')
# current epoch is:  5500
# current loss is:  tensor(-32.2166, device='cuda:1')
# current relative error is:  tensor(0.2791, device='cuda:1')
# current epoch is:  5550
# current loss is:  tensor(-28.5995, device='cuda:1')
# current relative error is:  tensor(0.2620, device='cuda:1')
# current epoch is:  5600
# current loss is:  tensor(-30.0584, device='cuda:1')
# current relative error is:  tensor(0.2712, device='cuda:1')
# current epoch is:  5650
# current loss is:  tensor(-30.0815, device='cuda:1')
# current relative error is:  tensor(0.3582, device='cuda:1')
# current epoch is:  5700
# current loss is:  tensor(-19.0145, device='cuda:1')
# current relative error is:  tensor(0.3391, device='cuda:1')
# current epoch is:  5750
# current loss is:  tensor(-30.0115, device='cuda:1')
# current relative error is:  tensor(0.2792, device='cuda:1')
# current epoch is:  5800
# current loss is:  tensor(-30.2109, device='cuda:1')
# current relative error is:  tensor(0.3554, device='cuda:1')
# current epoch is:  5850
# current loss is:  tensor(-28.8838, device='cuda:1')
# current relative error is:  tensor(0.2842, device='cuda:1')
# current epoch is:  5900
# current loss is:  tensor(-29.2082, device='cuda:1')
# current relative error is:  tensor(0.2771, device='cuda:1')
# current epoch is:  5950
# current loss is:  tensor(-28.3090, device='cuda:1')
# current relative error is:  tensor(0.3819, device='cuda:1')
# current epoch is:  6000
# current loss is:  tensor(-32.5999, device='cuda:1')
# current relative error is:  tensor(0.2524, device='cuda:1')
# current epoch is:  6050
# current loss is:  tensor(-27.1571, device='cuda:1')
# current relative error is:  tensor(0.3690, device='cuda:1')
# current epoch is:  6100
# current loss is:  tensor(-31.9468, device='cuda:1')
# current relative error is:  tensor(0.2530, device='cuda:1')
# current epoch is:  6150
# current loss is:  tensor(-29.4423, device='cuda:1')
# current relative error is:  tensor(0.2801, device='cuda:1')
# current epoch is:  6200
# current loss is:  tensor(-7.4138, device='cuda:1')
# current relative error is:  tensor(0.4345, device='cuda:1')
# current epoch is:  6250
# current loss is:  tensor(-36.8712, device='cuda:1')
# current relative error is:  tensor(0.2657, device='cuda:1')
# current epoch is:  6300
# current loss is:  tensor(-33.9217, device='cuda:1')
# current relative error is:  tensor(0.2870, device='cuda:1')
# current epoch is:  6350
# current loss is:  tensor(-4.5651, device='cuda:1')
# current relative error is:  tensor(0.5159, device='cuda:1')
# current epoch is:  6400
# current loss is:  tensor(-32.2480, device='cuda:1')
# current relative error is:  tensor(0.2690, device='cuda:1')
# current epoch is:  6450
# current loss is:  tensor(-28.6565, device='cuda:1')
# current relative error is:  tensor(0.3175, device='cuda:1')
# current epoch is:  6500
# current loss is:  tensor(-38.1585, device='cuda:1')
# current relative error is:  tensor(0.2608, device='cuda:1')
# current epoch is:  6550
# current loss is:  tensor(-29.9332, device='cuda:1')
# current relative error is:  tensor(0.2563, device='cuda:1')
# current epoch is:  6600
# current loss is:  tensor(-33.7910, device='cuda:1')
# current relative error is:  tensor(0.2665, device='cuda:1')
# current epoch is:  6650
# current loss is:  tensor(-43.3908, device='cuda:1')
# current relative error is:  tensor(0.2512, device='cuda:1')
# current epoch is:  6700
# current loss is:  tensor(-27.6583, device='cuda:1')
# current relative error is:  tensor(0.3388, device='cuda:1')
# current epoch is:  6750
# current loss is:  tensor(-29.0583, device='cuda:1')
# current relative error is:  tensor(0.2583, device='cuda:1')
# current epoch is:  6800
# current loss is:  tensor(-38.8193, device='cuda:1')
# current relative error is:  tensor(0.2592, device='cuda:1')
# current epoch is:  6850
# current loss is:  tensor(-34.1174, device='cuda:1')
# current relative error is:  tensor(0.2554, device='cuda:1')
# current epoch is:  6900
# current loss is:  tensor(-41.0386, device='cuda:1')
# current relative error is:  tensor(0.2968, device='cuda:1')
# current epoch is:  6950
# current loss is:  tensor(-33.8218, device='cuda:1')
# current relative error is:  tensor(0.2649, device='cuda:1')
# current epoch is:  7000
# current loss is:  tensor(-38.6104, device='cuda:1')
# current relative error is:  tensor(0.2500, device='cuda:1')
# current epoch is:  7050
# current loss is:  tensor(-32.0669, device='cuda:1')
# current relative error is:  tensor(0.3573, device='cuda:1')
# current epoch is:  7100
# current loss is:  tensor(-35.3497, device='cuda:1')
# current relative error is:  tensor(0.2757, device='cuda:1')
# current epoch is:  7150
# current loss is:  tensor(-35.0293, device='cuda:1')
# current relative error is:  tensor(0.2628, device='cuda:1')
# current epoch is:  7200
# current loss is:  tensor(-39.4969, device='cuda:1')
# current relative error is:  tensor(0.2697, device='cuda:1')
# current epoch is:  7250
# current loss is:  tensor(-30.6028, device='cuda:1')
# current relative error is:  tensor(0.3802, device='cuda:1')
# current epoch is:  7300
# current loss is:  tensor(-30.4326, device='cuda:1')
# current relative error is:  tensor(0.2876, device='cuda:1')
# current epoch is:  7350
# current loss is:  tensor(-37.2898, device='cuda:1')
# current relative error is:  tensor(0.2532, device='cuda:1')
# current epoch is:  7400
# current loss is:  tensor(-39.0166, device='cuda:1')
# current relative error is:  tensor(0.2970, device='cuda:1')
# current epoch is:  7450
# current loss is:  tensor(-37.6712, device='cuda:1')
# current relative error is:  tensor(0.2524, device='cuda:1')
# current epoch is:  7500
# current loss is:  tensor(-34.5442, device='cuda:1')
# current relative error is:  tensor(0.2518, device='cuda:1')
# current epoch is:  7550
# current loss is:  tensor(-29.0000, device='cuda:1')
# current relative error is:  tensor(0.3926, device='cuda:1')
# current epoch is:  7600
# current loss is:  tensor(-39.3950, device='cuda:1')
# current relative error is:  tensor(0.2459, device='cuda:1')
# current epoch is:  7650
# current loss is:  tensor(-25.4711, device='cuda:1')
# current relative error is:  tensor(0.3601, device='cuda:1')
# current epoch is:  7700
# current loss is:  tensor(-38.1019, device='cuda:1')
# current relative error is:  tensor(0.2828, device='cuda:1')
# current epoch is:  7750
# current loss is:  tensor(-31.8784, device='cuda:1')
# current relative error is:  tensor(0.2578, device='cuda:1')
# current epoch is:  7800
# current loss is:  tensor(-40.0424, device='cuda:1')
# current relative error is:  tensor(0.2717, device='cuda:1')
# current epoch is:  7850
# current loss is:  tensor(-39.7234, device='cuda:1')
# current relative error is:  tensor(0.4072, device='cuda:1')
# current epoch is:  7900
# current loss is:  tensor(-31.7434, device='cuda:1')
# current relative error is:  tensor(0.3049, device='cuda:1')
# current epoch is:  7950
# current loss is:  tensor(-45.9941, device='cuda:1')
# current relative error is:  tensor(0.2671, device='cuda:1')
# current epoch is:  8000
# current loss is:  tensor(-33.3350, device='cuda:1')
# current relative error is:  tensor(0.4142, device='cuda:1')
# current epoch is:  8050
# current loss is:  tensor(-39.9464, device='cuda:1')
# current relative error is:  tensor(0.2833, device='cuda:1')
# current epoch is:  8100
# current loss is:  tensor(-44.9362, device='cuda:1')
# current relative error is:  tensor(0.2552, device='cuda:1')
# current epoch is:  8150
# current loss is:  tensor(-39.8435, device='cuda:1')
# current relative error is:  tensor(0.2746, device='cuda:1')
# current epoch is:  8200
# current loss is:  tensor(-42.5321, device='cuda:1')
# current relative error is:  tensor(0.2485, device='cuda:1')
# current epoch is:  8250
# current loss is:  tensor(-32.2895, device='cuda:1')
# current relative error is:  tensor(0.3781, device='cuda:1')
# current epoch is:  8300
# current loss is:  tensor(-41.4433, device='cuda:1')
# current relative error is:  tensor(0.3353, device='cuda:1')
# current epoch is:  8350
# current loss is:  tensor(-44.5543, device='cuda:1')
# current relative error is:  tensor(0.2778, device='cuda:1')
# current epoch is:  8400
# current loss is:  tensor(-28.7620, device='cuda:1')
# current relative error is:  tensor(0.4310, device='cuda:1')
# current epoch is:  8450
# current loss is:  tensor(-40.6347, device='cuda:1')
# current relative error is:  tensor(0.2662, device='cuda:1')
# current epoch is:  8500
# current loss is:  tensor(-41.5746, device='cuda:1')
# current relative error is:  tensor(0.3387, device='cuda:1')
# current epoch is:  8550
# current loss is:  tensor(-43.5136, device='cuda:1')
# current relative error is:  tensor(0.2492, device='cuda:1')
# current epoch is:  8600
# current loss is:  tensor(-41.5210, device='cuda:1')
# current relative error is:  tensor(0.2592, device='cuda:1')
# current epoch is:  8650
# current loss is:  tensor(-39.8606, device='cuda:1')
# current relative error is:  tensor(0.2452, device='cuda:1')
# current epoch is:  8700
# current loss is:  tensor(-43.8587, device='cuda:1')
# current relative error is:  tensor(0.3577, device='cuda:1')
# current epoch is:  8750
# current loss is:  tensor(-39.8001, device='cuda:1')
# current relative error is:  tensor(0.3951, device='cuda:1')
# current epoch is:  8800
# current loss is:  tensor(-42.3037, device='cuda:1')
# current relative error is:  tensor(0.2470, device='cuda:1')
# current epoch is:  8850
# current loss is:  tensor(-38.7544, device='cuda:1')
# current relative error is:  tensor(0.4706, device='cuda:1')
# current epoch is:  8900
# current loss is:  tensor(-37.1403, device='cuda:1')
# current relative error is:  tensor(0.2719, device='cuda:1')
# current epoch is:  8950
# current loss is:  tensor(-45.0008, device='cuda:1')
# current relative error is:  tensor(0.2506, device='cuda:1')
# current epoch is:  9000
# current loss is:  tensor(-50.2892, device='cuda:1')
# current relative error is:  tensor(0.2491, device='cuda:1')
# current epoch is:  9050
# current loss is:  tensor(-45.6225, device='cuda:1')
# current relative error is:  tensor(0.2462, device='cuda:1')
# current epoch is:  9100
# current loss is:  tensor(-44.0672, device='cuda:1')
# current relative error is:  tensor(0.2743, device='cuda:1')
# current epoch is:  9150
# current loss is:  tensor(-44.4891, device='cuda:1')
# current relative error is:  tensor(0.2629, device='cuda:1')
# current epoch is:  9200
# current loss is:  tensor(-40.1515, device='cuda:1')
# current relative error is:  tensor(0.2592, device='cuda:1')
# current epoch is:  9250
# current loss is:  tensor(-48.1303, device='cuda:1')
# current relative error is:  tensor(0.2432, device='cuda:1')
# current epoch is:  9300
# current loss is:  tensor(-47.8410, device='cuda:1')
# current relative error is:  tensor(0.2847, device='cuda:1')
# current epoch is:  9350
# current loss is:  tensor(-31.8264, device='cuda:1')
# current relative error is:  tensor(0.2717, device='cuda:1')
# current epoch is:  9400
# current loss is:  tensor(-47.0995, device='cuda:1')
# current relative error is:  tensor(0.2272, device='cuda:1')
# current epoch is:  9450
# current loss is:  tensor(-49.1862, device='cuda:1')
# current relative error is:  tensor(0.2464, device='cuda:1')
# current epoch is:  9500
# current loss is:  tensor(-48.2372, device='cuda:1')
# current relative error is:  tensor(0.3212, device='cuda:1')
# current epoch is:  9550
# current loss is:  tensor(-47.5232, device='cuda:1')
# current relative error is:  tensor(0.2351, device='cuda:1')
# current epoch is:  9600
# current loss is:  tensor(-49.0126, device='cuda:1')
# current relative error is:  tensor(0.2626, device='cuda:1')
# current epoch is:  9650
# current loss is:  tensor(-43.3361, device='cuda:1')
# current relative error is:  tensor(0.2248, device='cuda:1')
# current epoch is:  9700
# current loss is:  tensor(-48.5183, device='cuda:1')
# current relative error is:  tensor(0.2507, device='cuda:1')
# current epoch is:  9750
# current loss is:  tensor(-39.4231, device='cuda:1')
# current relative error is:  tensor(0.2858, device='cuda:1')
# current epoch is:  9800
# current loss is:  tensor(-48.9908, device='cuda:1')
# current relative error is:  tensor(0.2207, device='cuda:1')
# current epoch is:  9850
# current loss is:  tensor(-50.5286, device='cuda:1')
# current relative error is:  tensor(0.2312, device='cuda:1')
# current epoch is:  9900
# current loss is:  tensor(-44.5763, device='cuda:1')
# current relative error is:  tensor(0.2671, device='cuda:1')
# current epoch is:  9950
# current loss is:  tensor(-43.7837, device='cuda:1')
# current relative error is:  tensor(0.2278, device='cuda:1')
# current epoch is:  10000
# current loss is:  tensor(-41.4613, device='cuda:1')
# current relative error is:  tensor(0.3568, device='cuda:1')
# current epoch is:  10050
# current loss is:  tensor(-49.9882, device='cuda:1')
# current relative error is:  tensor(0.2399, device='cuda:1')
# current epoch is:  10100
# current loss is:  tensor(-46.6953, device='cuda:1')
# current relative error is:  tensor(0.2159, device='cuda:1')
# current epoch is:  10150
# current loss is:  tensor(-42.4927, device='cuda:1')
# current relative error is:  tensor(0.2228, device='cuda:1')
# current epoch is:  10200
# current loss is:  tensor(-44.6462, device='cuda:1')
# current relative error is:  tensor(0.3138, device='cuda:1')
# current epoch is:  10250
# current loss is:  tensor(-53.3248, device='cuda:1')
# current relative error is:  tensor(0.2410, device='cuda:1')
# current epoch is:  10300
# current loss is:  tensor(-49.8190, device='cuda:1')
# current relative error is:  tensor(0.2882, device='cuda:1')
# current epoch is:  10350
# current loss is:  tensor(-44.2490, device='cuda:1')
# current relative error is:  tensor(0.2911, device='cuda:1')
# current epoch is:  10400
# current loss is:  tensor(-44.2297, device='cuda:1')
# current relative error is:  tensor(0.2349, device='cuda:1')
# current epoch is:  10450
# current loss is:  tensor(-44.3809, device='cuda:1')
# current relative error is:  tensor(0.2596, device='cuda:1')
# current epoch is:  10500
# current loss is:  tensor(-45.9372, device='cuda:1')
# current relative error is:  tensor(0.2638, device='cuda:1')
# current epoch is:  10550
# current loss is:  tensor(-53.7666, device='cuda:1')
# current relative error is:  tensor(0.2318, device='cuda:1')
# current epoch is:  10600
# current loss is:  tensor(-49.0125, device='cuda:1')
# current relative error is:  tensor(0.4236, device='cuda:1')
# current epoch is:  10650
# current loss is:  tensor(-45.3124, device='cuda:1')
# current relative error is:  tensor(0.2467, device='cuda:1')
# current epoch is:  10700
# current loss is:  tensor(-51.5693, device='cuda:1')
# current relative error is:  tensor(0.2088, device='cuda:1')
# current epoch is:  10750
# current loss is:  tensor(-48.3846, device='cuda:1')
# current relative error is:  tensor(0.2856, device='cuda:1')
# current epoch is:  10800
# current loss is:  tensor(-48.7333, device='cuda:1')
# current relative error is:  tensor(0.1968, device='cuda:1')
# current epoch is:  10850
# current loss is:  tensor(-52.2255, device='cuda:1')
# current relative error is:  tensor(0.2876, device='cuda:1')
# current epoch is:  10900
# current loss is:  tensor(-48.0224, device='cuda:1')
# current relative error is:  tensor(0.2087, device='cuda:1')
# current epoch is:  10950
# current loss is:  tensor(-59.7673, device='cuda:1')
# current relative error is:  tensor(0.3040, device='cuda:1')
# current epoch is:  11000
# current loss is:  tensor(-45.0675, device='cuda:1')
# current relative error is:  tensor(0.2118, device='cuda:1')
# current epoch is:  11050
# current loss is:  tensor(-52.2490, device='cuda:1')
# current relative error is:  tensor(0.2196, device='cuda:1')
# current epoch is:  11100
# current loss is:  tensor(-63.5593, device='cuda:1')
# current relative error is:  tensor(0.2143, device='cuda:1')
# current epoch is:  11150
# current loss is:  tensor(-56.8700, device='cuda:1')
# current relative error is:  tensor(0.2013, device='cuda:1')
# current epoch is:  11200
# current loss is:  tensor(-54.1272, device='cuda:1')
# current relative error is:  tensor(0.2509, device='cuda:1')
# current epoch is:  11250
# current loss is:  tensor(-50.5580, device='cuda:1')
# current relative error is:  tensor(0.1914, device='cuda:1')
# current epoch is:  11300
# current loss is:  tensor(-56.8388, device='cuda:1')
# current relative error is:  tensor(0.3217, device='cuda:1')
# current epoch is:  11350
# current loss is:  tensor(-55.5268, device='cuda:1')
# current relative error is:  tensor(0.1916, device='cuda:1')
# current epoch is:  11400
# current loss is:  tensor(-55.7784, device='cuda:1')
# current relative error is:  tensor(0.2284, device='cuda:1')
# current epoch is:  11450
# current loss is:  tensor(-58.3902, device='cuda:1')
# current relative error is:  tensor(0.2448, device='cuda:1')
# current epoch is:  11500
# current loss is:  tensor(-57.4170, device='cuda:1')
# current relative error is:  tensor(0.2127, device='cuda:1')
# current epoch is:  11550
# current loss is:  tensor(-47.4874, device='cuda:1')
# current relative error is:  tensor(0.2500, device='cuda:1')
# current epoch is:  11600
# current loss is:  tensor(-50.9949, device='cuda:1')
# current relative error is:  tensor(0.1837, device='cuda:1')
# current epoch is:  11650
# current loss is:  tensor(-52.7653, device='cuda:1')
# current relative error is:  tensor(0.4397, device='cuda:1')
# current epoch is:  11700
# current loss is:  tensor(-58.8216, device='cuda:1')
# current relative error is:  tensor(0.1855, device='cuda:1')
# current epoch is:  11750
# current loss is:  tensor(-52.0359, device='cuda:1')
# current relative error is:  tensor(0.4011, device='cuda:1')
# current epoch is:  11800
# current loss is:  tensor(-51.3435, device='cuda:1')
# current relative error is:  tensor(0.2101, device='cuda:1')
# current epoch is:  11850
# current loss is:  tensor(-52.7558, device='cuda:1')
# current relative error is:  tensor(0.1889, device='cuda:1')
# current epoch is:  11900
# current loss is:  tensor(-58.4584, device='cuda:1')
# current relative error is:  tensor(0.3382, device='cuda:1')
# current epoch is:  11950
# current loss is:  tensor(-52.7505, device='cuda:1')
# current relative error is:  tensor(0.1861, device='cuda:1')
# current epoch is:  12000
# current loss is:  tensor(-62.6380, device='cuda:1')
# current relative error is:  tensor(0.2434, device='cuda:1')
# current epoch is:  12050
# current loss is:  tensor(-47.4708, device='cuda:1')
# current relative error is:  tensor(0.2836, device='cuda:1')
# current epoch is:  12100
# current loss is:  tensor(-57.2797, device='cuda:1')
# current relative error is:  tensor(0.2210, device='cuda:1')
# current epoch is:  12150
# current loss is:  tensor(-64.9641, device='cuda:1')
# current relative error is:  tensor(0.1902, device='cuda:1')
# current epoch is:  12200
# current loss is:  tensor(-57.8859, device='cuda:1')
# current relative error is:  tensor(0.4127, device='cuda:1')
# current epoch is:  12250
# current loss is:  tensor(-55.6731, device='cuda:1')
# current relative error is:  tensor(0.2141, device='cuda:1')
# current epoch is:  12300
# current loss is:  tensor(-54.8995, device='cuda:1')
# current relative error is:  tensor(0.2511, device='cuda:1')
# current epoch is:  12350
# current loss is:  tensor(-61.1443, device='cuda:1')
# current relative error is:  tensor(0.2459, device='cuda:1')
# current epoch is:  12400
# current loss is:  tensor(-50.5388, device='cuda:1')
# current relative error is:  tensor(0.1689, device='cuda:1')
# current epoch is:  12450
# current loss is:  tensor(-61.1326, device='cuda:1')
# current relative error is:  tensor(0.1769, device='cuda:1')
# current epoch is:  12500
# current loss is:  tensor(-56.5242, device='cuda:1')
# current relative error is:  tensor(0.2243, device='cuda:1')
# current epoch is:  12550
# current loss is:  tensor(-54.0248, device='cuda:1')
# current relative error is:  tensor(0.2068, device='cuda:1')
# current epoch is:  12600
# current loss is:  tensor(-59.1428, device='cuda:1')
# current relative error is:  tensor(0.3003, device='cuda:1')
# current epoch is:  12650
# current loss is:  tensor(-43.4209, device='cuda:1')
# current relative error is:  tensor(0.5558, device='cuda:1')
# current epoch is:  12700
# current loss is:  tensor(-52.3577, device='cuda:1')
# current relative error is:  tensor(0.3273, device='cuda:1')
# current epoch is:  12750
# current loss is:  tensor(-63.1779, device='cuda:1')
# current relative error is:  tensor(0.1887, device='cuda:1')
# current epoch is:  12800
# current loss is:  tensor(-66.1047, device='cuda:1')
# current relative error is:  tensor(0.1599, device='cuda:1')
# current epoch is:  12850
# current loss is:  tensor(-60.1623, device='cuda:1')
# current relative error is:  tensor(0.3440, device='cuda:1')
# current epoch is:  12900
# current loss is:  tensor(-58.3993, device='cuda:1')
# current relative error is:  tensor(0.3722, device='cuda:1')
# current epoch is:  12950
# current loss is:  tensor(-61.9128, device='cuda:1')
# current relative error is:  tensor(0.2433, device='cuda:1')
# current epoch is:  13000
# current loss is:  tensor(-62.5740, device='cuda:1')
# current relative error is:  tensor(0.2949, device='cuda:1')
# current epoch is:  13050
# current loss is:  tensor(-61.7617, device='cuda:1')
# current relative error is:  tensor(0.2666, device='cuda:1')
# current epoch is:  13100
# current loss is:  tensor(-62.4829, device='cuda:1')
# current relative error is:  tensor(0.1432, device='cuda:1')
# current epoch is:  13150
# current loss is:  tensor(-61.4755, device='cuda:1')
# current relative error is:  tensor(0.3181, device='cuda:1')
# current epoch is:  13200
# current loss is:  tensor(-64.5597, device='cuda:1')
# current relative error is:  tensor(0.2779, device='cuda:1')
# current epoch is:  13250
# current loss is:  tensor(-67.6999, device='cuda:1')
# current relative error is:  tensor(0.1734, device='cuda:1')
# current epoch is:  13300
# current loss is:  tensor(-62.6432, device='cuda:1')
# current relative error is:  tensor(0.3651, device='cuda:1')
# current epoch is:  13350
# current loss is:  tensor(-62.6608, device='cuda:1')
# current relative error is:  tensor(0.1470, device='cuda:1')
# current epoch is:  13400
# current loss is:  tensor(-51.6475, device='cuda:1')
# current relative error is:  tensor(0.1970, device='cuda:1')
# current epoch is:  13450
# current loss is:  tensor(-64.9906, device='cuda:1')
# current relative error is:  tensor(0.1390, device='cuda:1')
# current epoch is:  13500
# current loss is:  tensor(-61.5957, device='cuda:1')
# current relative error is:  tensor(0.3018, device='cuda:1')
# current epoch is:  13550
# current loss is:  tensor(-70.7568, device='cuda:1')
# current relative error is:  tensor(0.1959, device='cuda:1')
# current epoch is:  13600
# current loss is:  tensor(-58.9305, device='cuda:1')
# current relative error is:  tensor(0.1611, device='cuda:1')
# current epoch is:  13650
# current loss is:  tensor(-62.1294, device='cuda:1')
# current relative error is:  tensor(0.3984, device='cuda:1')
# current epoch is:  13700
# current loss is:  tensor(-62.1985, device='cuda:1')
# current relative error is:  tensor(0.1295, device='cuda:1')
# current epoch is:  13750
# current loss is:  tensor(-66.3794, device='cuda:1')
# current relative error is:  tensor(0.2559, device='cuda:1')
# current epoch is:  13800
# current loss is:  tensor(-61.0045, device='cuda:1')
# current relative error is:  tensor(0.1626, device='cuda:1')
# current epoch is:  13850
# current loss is:  tensor(-60.7457, device='cuda:1')
# current relative error is:  tensor(0.1339, device='cuda:1')
# current epoch is:  13900
# current loss is:  tensor(-65.9651, device='cuda:1')
# current relative error is:  tensor(0.1934, device='cuda:1')
# current epoch is:  13950
# current loss is:  tensor(-61.1789, device='cuda:1')
# current relative error is:  tensor(0.3735, device='cuda:1')
# current epoch is:  14000
# current loss is:  tensor(-69.4324, device='cuda:1')
# current relative error is:  tensor(0.3646, device='cuda:1')
# current epoch is:  14050
# current loss is:  tensor(-68.0239, device='cuda:1')
# current relative error is:  tensor(0.1461, device='cuda:1')
# current epoch is:  14100
# current loss is:  tensor(-63.6505, device='cuda:1')
# current relative error is:  tensor(0.1947, device='cuda:1')
# current epoch is:  14150
# current loss is:  tensor(-62.4553, device='cuda:1')
# current relative error is:  tensor(0.1373, device='cuda:1')
# current epoch is:  14200
# current loss is:  tensor(-66.6030, device='cuda:1')
# current relative error is:  tensor(0.2722, device='cuda:1')
# current epoch is:  14250
# current loss is:  tensor(-62.3178, device='cuda:1')
# current relative error is:  tensor(0.3279, device='cuda:1')
# current epoch is:  14300
# current loss is:  tensor(-57.8319, device='cuda:1')
# current relative error is:  tensor(0.2938, device='cuda:1')
# current epoch is:  14350
# current loss is:  tensor(-65.6362, device='cuda:1')
# current relative error is:  tensor(0.2778, device='cuda:1')
# current epoch is:  14400
# current loss is:  tensor(-66.7879, device='cuda:1')
# current relative error is:  tensor(0.1865, device='cuda:1')
# current epoch is:  14450
# current loss is:  tensor(-66.9505, device='cuda:1')
# current relative error is:  tensor(0.1333, device='cuda:1')
# current epoch is:  14500
# current loss is:  tensor(-61.6195, device='cuda:1')
# current relative error is:  tensor(0.1706, device='cuda:1')
# current epoch is:  14550
# current loss is:  tensor(-61.2198, device='cuda:1')
# current relative error is:  tensor(0.1210, device='cuda:1')
# current epoch is:  14600
# current loss is:  tensor(-60.1994, device='cuda:1')
# current relative error is:  tensor(0.1297, device='cuda:1')
# current epoch is:  14650
# current loss is:  tensor(-66.6590, device='cuda:1')
# current relative error is:  tensor(0.1550, device='cuda:1')
# current epoch is:  14700
# current loss is:  tensor(-61.8869, device='cuda:1')
# current relative error is:  tensor(0.1569, device='cuda:1')
# current epoch is:  14750
# current loss is:  tensor(-62.1856, device='cuda:1')
# current relative error is:  tensor(0.2258, device='cuda:1')
# current epoch is:  14800
# current loss is:  tensor(-55.9358, device='cuda:1')
# current relative error is:  tensor(0.1370, device='cuda:1')
# current epoch is:  14850
# current loss is:  tensor(-67.7455, device='cuda:1')
# current relative error is:  tensor(0.1524, device='cuda:1')
# current epoch is:  14900
# current loss is:  tensor(-65.9299, device='cuda:1')
# current relative error is:  tensor(0.1320, device='cuda:1')
# current epoch is:  14950
# current loss is:  tensor(-60.4088, device='cuda:1')
# current relative error is:  tensor(0.2347, device='cuda:1')
# current epoch is:  15000
# current loss is:  tensor(-62.7593, device='cuda:1')
# current relative error is:  tensor(0.1701, device='cuda:1')
# current epoch is:  15050
# current loss is:  tensor(-68.6681, device='cuda:1')
# current relative error is:  tensor(0.2072, device='cuda:1')
# current epoch is:  15100
# current loss is:  tensor(-69.6666, device='cuda:1')
# current relative error is:  tensor(0.3460, device='cuda:1')
# current epoch is:  15150
# current loss is:  tensor(-66.5809, device='cuda:1')
# current relative error is:  tensor(0.2129, device='cuda:1')
# current epoch is:  15200
# current loss is:  tensor(-60.0780, device='cuda:1')
# current relative error is:  tensor(0.1517, device='cuda:1')
# current epoch is:  15250
# current loss is:  tensor(-61.8701, device='cuda:1')
# current relative error is:  tensor(0.2654, device='cuda:1')
# current epoch is:  15300
# current loss is:  tensor(-59.0411, device='cuda:1')
# current relative error is:  tensor(0.1169, device='cuda:1')
# current epoch is:  15350
# current loss is:  tensor(-70.0231, device='cuda:1')
# current relative error is:  tensor(0.1681, device='cuda:1')
# current epoch is:  15400
# current loss is:  tensor(-63.9992, device='cuda:1')
# current relative error is:  tensor(0.3151, device='cuda:1')
# current epoch is:  15450
# current loss is:  tensor(-61.7520, device='cuda:1')
# current relative error is:  tensor(0.1292, device='cuda:1')
# current epoch is:  15500
# current loss is:  tensor(-69.9057, device='cuda:1')
# current relative error is:  tensor(0.1234, device='cuda:1')
# current epoch is:  15550
# current loss is:  tensor(-67.1905, device='cuda:1')
# current relative error is:  tensor(0.2901, device='cuda:1')
# current epoch is:  15600
# current loss is:  tensor(-71.3223, device='cuda:1')
# current relative error is:  tensor(0.1917, device='cuda:1')
# current epoch is:  15650
# current loss is:  tensor(-65.6622, device='cuda:1')
# current relative error is:  tensor(0.1563, device='cuda:1')
# current epoch is:  15700
# current loss is:  tensor(-67.3743, device='cuda:1')
# current relative error is:  tensor(0.1174, device='cuda:1')
# current epoch is:  15750
# current loss is:  tensor(-59.9160, device='cuda:1')
# current relative error is:  tensor(0.2148, device='cuda:1')
# current epoch is:  15800
# current loss is:  tensor(-66.7064, device='cuda:1')
# current relative error is:  tensor(0.4206, device='cuda:1')
# current epoch is:  15850
# current loss is:  tensor(-61.4145, device='cuda:1')
# current relative error is:  tensor(0.2472, device='cuda:1')
# current epoch is:  15900
# current loss is:  tensor(-61.3718, device='cuda:1')
# current relative error is:  tensor(0.2669, device='cuda:1')
# current epoch is:  15950
# current loss is:  tensor(-71.1005, device='cuda:1')
# current relative error is:  tensor(0.1953, device='cuda:1')
# current epoch is:  16000
# current loss is:  tensor(-70.7003, device='cuda:1')
# current relative error is:  tensor(0.1292, device='cuda:1')
# current epoch is:  16050
# current loss is:  tensor(-61.6136, device='cuda:1')
# current relative error is:  tensor(0.1808, device='cuda:1')
# current epoch is:  16100
# current loss is:  tensor(-60.0986, device='cuda:1')
# current relative error is:  tensor(0.1326, device='cuda:1')
# current epoch is:  16150
# current loss is:  tensor(-61.8624, device='cuda:1')
# current relative error is:  tensor(0.2759, device='cuda:1')
# current epoch is:  16200
# current loss is:  tensor(-75.2534, device='cuda:1')
# current relative error is:  tensor(0.1054, device='cuda:1')
# current epoch is:  16250
# current loss is:  tensor(-63.5361, device='cuda:1')
# current relative error is:  tensor(0.1165, device='cuda:1')
# current epoch is:  16300
# current loss is:  tensor(-65.0947, device='cuda:1')
# current relative error is:  tensor(0.1795, device='cuda:1')
# current epoch is:  16350
# current loss is:  tensor(-67.8279, device='cuda:1')
# current relative error is:  tensor(0.2012, device='cuda:1')
# current epoch is:  16400
# current loss is:  tensor(-69.4962, device='cuda:1')
# current relative error is:  tensor(0.1251, device='cuda:1')
# current epoch is:  16450
# current loss is:  tensor(-61.9230, device='cuda:1')
# current relative error is:  tensor(0.1211, device='cuda:1')
# current epoch is:  16500
# current loss is:  tensor(-69.1021, device='cuda:1')
# current relative error is:  tensor(0.1367, device='cuda:1')
# current epoch is:  16550
# current loss is:  tensor(-70.5549, device='cuda:1')
# current relative error is:  tensor(0.1129, device='cuda:1')
# current epoch is:  16600
# current loss is:  tensor(-75.0835, device='cuda:1')
# current relative error is:  tensor(0.2273, device='cuda:1')
# current epoch is:  16650
# current loss is:  tensor(-71.4541, device='cuda:1')
# current relative error is:  tensor(0.1841, device='cuda:1')
# current epoch is:  16700
# current loss is:  tensor(-73.6236, device='cuda:1')
# current relative error is:  tensor(0.1053, device='cuda:1')
# current epoch is:  16750
# current loss is:  tensor(-76.0759, device='cuda:1')
# current relative error is:  tensor(0.1481, device='cuda:1')
# current epoch is:  16800
# current loss is:  tensor(-72.5995, device='cuda:1')
# current relative error is:  tensor(0.2253, device='cuda:1')
# current epoch is:  16850
# current loss is:  tensor(-60.5074, device='cuda:1')
# current relative error is:  tensor(0.2365, device='cuda:1')
# current epoch is:  16900
# current loss is:  tensor(-73.0622, device='cuda:1')
# current relative error is:  tensor(0.2623, device='cuda:1')
# current epoch is:  16950
# current loss is:  tensor(-70.6030, device='cuda:1')
# current relative error is:  tensor(0.2834, device='cuda:1')
# current epoch is:  17000
# current loss is:  tensor(-68.4409, device='cuda:1')
# current relative error is:  tensor(0.3102, device='cuda:1')
# current epoch is:  17050
# current loss is:  tensor(-63.5799, device='cuda:1')
# current relative error is:  tensor(0.1158, device='cuda:1')
# current epoch is:  17100
# current loss is:  tensor(-75.2194, device='cuda:1')
# current relative error is:  tensor(0.2084, device='cuda:1')
# current epoch is:  17150
# current loss is:  tensor(-75.4802, device='cuda:1')
# current relative error is:  tensor(0.1007, device='cuda:1')
# current epoch is:  17200
# current loss is:  tensor(-70.7653, device='cuda:1')
# current relative error is:  tensor(0.0991, device='cuda:1')
# current epoch is:  17250
# current loss is:  tensor(-70.6729, device='cuda:1')
# current relative error is:  tensor(0.1363, device='cuda:1')
# current epoch is:  17300
# current loss is:  tensor(-70.2868, device='cuda:1')
# current relative error is:  tensor(0.1127, device='cuda:1')
# current epoch is:  17350
# current loss is:  tensor(-65.6432, device='cuda:1')
# current relative error is:  tensor(0.1473, device='cuda:1')
# current epoch is:  17400
# current loss is:  tensor(-72.9686, device='cuda:1')
# current relative error is:  tensor(0.1443, device='cuda:1')
# current epoch is:  17450
# current loss is:  tensor(-64.8772, device='cuda:1')
# current relative error is:  tensor(0.2885, device='cuda:1')
# current epoch is:  17500
# current loss is:  tensor(-72.0171, device='cuda:1')
# current relative error is:  tensor(0.1575, device='cuda:1')
# current epoch is:  17550
# current loss is:  tensor(-75.7673, device='cuda:1')
# current relative error is:  tensor(0.1616, device='cuda:1')
# ...
# current relative error is:  tensor(0.0298, device='cuda:1')
# current epoch is:  94200
# current loss is:  tensor(-73.8701, device='cuda:1')
# current relative error is:  tensor(0.0758, device='cuda:1')
# current epoch is:  94250
# current loss is:  tensor(-79.4416, device='cuda:1')
# current relative error is:  tensor(0.0408, device='cuda:1')
# current epoch is:  94300
# current loss is:  tensor(-76.7785, device='cuda:1')
# current relative error is:  tensor(0.0341, device='cuda:1')
# current epoch is:  94350
# current loss is:  tensor(-75.5201, device='cuda:1')
# current relative error is:  tensor(0.0419, device='cuda:1')
# current epoch is:  94400
# current loss is:  tensor(-80.9623, device='cuda:1')
# current relative error is:  tensor(0.0446, device='cuda:1')
# current epoch is:  94450
# current loss is:  tensor(-71.9601, device='cuda:1')
# current relative error is:  tensor(0.0328, device='cuda:1')
# current epoch is:  94500
# current loss is:  tensor(-76.3942, device='cuda:1')
# current relative error is:  tensor(0.0511, device='cuda:1')
# current epoch is:  94550
# current loss is:  tensor(-82.2491, device='cuda:1')
# current relative error is:  tensor(0.0396, device='cuda:1')
# current epoch is:  94600
# current loss is:  tensor(-82.2639, device='cuda:1')
# current relative error is:  tensor(0.0306, device='cuda:1')
# current epoch is:  94650
# current loss is:  tensor(-71.7810, device='cuda:1')
# current relative error is:  tensor(0.0361, device='cuda:1')
# current epoch is:  94700
# current loss is:  tensor(-75.0658, device='cuda:1')
# current relative error is:  tensor(0.0732, device='cuda:1')
# current epoch is:  94750
# current loss is:  tensor(-80.1562, device='cuda:1')
# current relative error is:  tensor(0.0404, device='cuda:1')
# current epoch is:  94800
# current loss is:  tensor(-77.7946, device='cuda:1')
# current relative error is:  tensor(0.0316, device='cuda:1')
# current epoch is:  94850
# current loss is:  tensor(-78.6144, device='cuda:1')
# current relative error is:  tensor(0.0461, device='cuda:1')
# current epoch is:  94900
# current loss is:  tensor(-78.5101, device='cuda:1')
# current relative error is:  tensor(0.0488, device='cuda:1')
# current epoch is:  94950
# current loss is:  tensor(-80.8168, device='cuda:1')
# current relative error is:  tensor(0.0303, device='cuda:1')
# current epoch is:  95000
# current loss is:  tensor(-78.1708, device='cuda:1')
# current relative error is:  tensor(0.0304, device='cuda:1')
# current epoch is:  95050
# current loss is:  tensor(-77.2772, device='cuda:1')
# current relative error is:  tensor(0.0434, device='cuda:1')
# current epoch is:  95100
# current loss is:  tensor(-76.0303, device='cuda:1')
# current relative error is:  tensor(0.0300, device='cuda:1')
# current epoch is:  95150
# current loss is:  tensor(-75.6574, device='cuda:1')
# current relative error is:  tensor(0.0425, device='cuda:1')
# current epoch is:  95200
# current loss is:  tensor(-83.7607, device='cuda:1')
# current relative error is:  tensor(0.0442, device='cuda:1')
# current epoch is:  95250
# current loss is:  tensor(-81.1069, device='cuda:1')
# current relative error is:  tensor(0.0659, device='cuda:1')
# current epoch is:  95300
# current loss is:  tensor(-82.1324, device='cuda:1')
# current relative error is:  tensor(0.0361, device='cuda:1')
# current epoch is:  95350
# current loss is:  tensor(-82.7354, device='cuda:1')
# current relative error is:  tensor(0.0298, device='cuda:1')
# current epoch is:  95400
# current loss is:  tensor(-74.7999, device='cuda:1')
# current relative error is:  tensor(0.0368, device='cuda:1')
# current epoch is:  95450
# current loss is:  tensor(-78.4766, device='cuda:1')
# current relative error is:  tensor(0.0331, device='cuda:1')
# current epoch is:  95500
# current loss is:  tensor(-76.3475, device='cuda:1')
# current relative error is:  tensor(0.0509, device='cuda:1')
# current epoch is:  95550
# current loss is:  tensor(-75.2949, device='cuda:1')
# current relative error is:  tensor(0.0342, device='cuda:1')
# current epoch is:  95600
# current loss is:  tensor(-72.0409, device='cuda:1')
# current relative error is:  tensor(0.0459, device='cuda:1')
# current epoch is:  95650
# current loss is:  tensor(-77.0689, device='cuda:1')
# current relative error is:  tensor(0.0268, device='cuda:1')
# current epoch is:  95700
# current loss is:  tensor(-83.1078, device='cuda:1')
# current relative error is:  tensor(0.0442, device='cuda:1')
# current epoch is:  95750
# current loss is:  tensor(-72.3205, device='cuda:1')
# current relative error is:  tensor(0.0532, device='cuda:1')
# current epoch is:  95800
# current loss is:  tensor(-80.2077, device='cuda:1')
# current relative error is:  tensor(0.0293, device='cuda:1')
# current epoch is:  95850
# current loss is:  tensor(-79.7306, device='cuda:1')
# current relative error is:  tensor(0.0386, device='cuda:1')
# current epoch is:  95900
# current loss is:  tensor(-81.2113, device='cuda:1')
# current relative error is:  tensor(0.0353, device='cuda:1')
# current epoch is:  95950
# current loss is:  tensor(-73.0181, device='cuda:1')
# current relative error is:  tensor(0.0412, device='cuda:1')
# current epoch is:  96000
# current loss is:  tensor(-79.9399, device='cuda:1')
# current relative error is:  tensor(0.0415, device='cuda:1')
# current epoch is:  96050
# current loss is:  tensor(-79.0586, device='cuda:1')
# current relative error is:  tensor(0.0343, device='cuda:1')
# current epoch is:  96100
# current loss is:  tensor(-77.3650, device='cuda:1')
# current relative error is:  tensor(0.0293, device='cuda:1')
# current epoch is:  96150
# current loss is:  tensor(-76.8330, device='cuda:1')
# current relative error is:  tensor(0.0290, device='cuda:1')
# current epoch is:  96200
# current loss is:  tensor(-71.0970, device='cuda:1')
# current relative error is:  tensor(0.0534, device='cuda:1')
# current epoch is:  96250
# current loss is:  tensor(-77.6606, device='cuda:1')
# current relative error is:  tensor(0.0263, device='cuda:1')
# current epoch is:  96300
# current loss is:  tensor(-81.2292, device='cuda:1')
# current relative error is:  tensor(0.0403, device='cuda:1')
# current epoch is:  96350
# current loss is:  tensor(-80.0940, device='cuda:1')
# current relative error is:  tensor(0.0290, device='cuda:1')
# current epoch is:  96400
# current loss is:  tensor(-78.4580, device='cuda:1')
# current relative error is:  tensor(0.0307, device='cuda:1')
# current epoch is:  96450
# current loss is:  tensor(-74.2570, device='cuda:1')
# current relative error is:  tensor(0.0317, device='cuda:1')
# current epoch is:  96500
# current loss is:  tensor(-87.2091, device='cuda:1')
# current relative error is:  tensor(0.0284, device='cuda:1')
# current epoch is:  96550
# current loss is:  tensor(-77.6075, device='cuda:1')
# current relative error is:  tensor(0.0435, device='cuda:1')
# current epoch is:  96600
# current loss is:  tensor(-78.5410, device='cuda:1')
# current relative error is:  tensor(0.0287, device='cuda:1')
# current epoch is:  96650
# current loss is:  tensor(-73.9519, device='cuda:1')
# current relative error is:  tensor(0.0398, device='cuda:1')
# current epoch is:  96700
# current loss is:  tensor(-78.3308, device='cuda:1')
# current relative error is:  tensor(0.0310, device='cuda:1')
# current epoch is:  96750
# current loss is:  tensor(-75.4980, device='cuda:1')
# current relative error is:  tensor(0.0795, device='cuda:1')
# current epoch is:  96800
# current loss is:  tensor(-74.3895, device='cuda:1')
# current relative error is:  tensor(0.0313, device='cuda:1')
# current epoch is:  96850
# current loss is:  tensor(-82.1172, device='cuda:1')
# current relative error is:  tensor(0.0315, device='cuda:1')
# current epoch is:  96900
# current loss is:  tensor(-82.3295, device='cuda:1')
# current relative error is:  tensor(0.0518, device='cuda:1')
# current epoch is:  96950
# current loss is:  tensor(-76.4552, device='cuda:1')
# current relative error is:  tensor(0.0553, device='cuda:1')
# current epoch is:  97000
# current loss is:  tensor(-77.4484, device='cuda:1')
# current relative error is:  tensor(0.0384, device='cuda:1')
# current epoch is:  97050
# current loss is:  tensor(-75.1792, device='cuda:1')
# current relative error is:  tensor(0.0295, device='cuda:1')
# current epoch is:  97100
# current loss is:  tensor(-78.9440, device='cuda:1')
# current relative error is:  tensor(0.0421, device='cuda:1')
# current epoch is:  97150
# current loss is:  tensor(-73.4379, device='cuda:1')
# current relative error is:  tensor(0.0538, device='cuda:1')
# current epoch is:  97200
# current loss is:  tensor(-76.4328, device='cuda:1')
# current relative error is:  tensor(0.0285, device='cuda:1')
# current epoch is:  97250
# current loss is:  tensor(-74.4990, device='cuda:1')
# current relative error is:  tensor(0.0326, device='cuda:1')
# current epoch is:  97300
# current loss is:  tensor(-80.5732, device='cuda:1')
# current relative error is:  tensor(0.0284, device='cuda:1')
# current epoch is:  97350
# current loss is:  tensor(-81.7691, device='cuda:1')
# current relative error is:  tensor(0.0298, device='cuda:1')
# current epoch is:  97400
# current loss is:  tensor(-74.7408, device='cuda:1')
# current relative error is:  tensor(0.0391, device='cuda:1')
# current epoch is:  97450
# current loss is:  tensor(-81.3540, device='cuda:1')
# current relative error is:  tensor(0.0503, device='cuda:1')
# current epoch is:  97500
# current loss is:  tensor(-77.3156, device='cuda:1')
# current relative error is:  tensor(0.0651, device='cuda:1')
# current epoch is:  97550
# current loss is:  tensor(-85.1468, device='cuda:1')
# current relative error is:  tensor(0.0292, device='cuda:1')
# current epoch is:  97600
# current loss is:  tensor(-78.6693, device='cuda:1')
# current relative error is:  tensor(0.0314, device='cuda:1')
# current epoch is:  97650
# current loss is:  tensor(-75.0177, device='cuda:1')
# current relative error is:  tensor(0.0341, device='cuda:1')
# current epoch is:  97700
# current loss is:  tensor(-75.0153, device='cuda:1')
# current relative error is:  tensor(0.0344, device='cuda:1')
# current epoch is:  97750
# current loss is:  tensor(-80.3984, device='cuda:1')
# current relative error is:  tensor(0.0285, device='cuda:1')
# current epoch is:  97800
# current loss is:  tensor(-76.5106, device='cuda:1')
# current relative error is:  tensor(0.0521, device='cuda:1')
# current epoch is:  97850
# current loss is:  tensor(-80.6954, device='cuda:1')
# current relative error is:  tensor(0.0305, device='cuda:1')
# current epoch is:  97900
# current loss is:  tensor(-78.1138, device='cuda:1')
# current relative error is:  tensor(0.0327, device='cuda:1')
# current epoch is:  97950
# current loss is:  tensor(-70.0841, device='cuda:1')
# current relative error is:  tensor(0.0517, device='cuda:1')
# current epoch is:  98000
# current loss is:  tensor(-72.0538, device='cuda:1')
# current relative error is:  tensor(0.0746, device='cuda:1')
# current epoch is:  98050
# current loss is:  tensor(-81.2362, device='cuda:1')
# current relative error is:  tensor(0.0927, device='cuda:1')
# current epoch is:  98100
# current loss is:  tensor(-75.5331, device='cuda:1')
# current relative error is:  tensor(0.0406, device='cuda:1')
# current epoch is:  98150
# current loss is:  tensor(-67.2090, device='cuda:1')
# current relative error is:  tensor(0.0344, device='cuda:1')
# current epoch is:  98200
# current loss is:  tensor(-80.6618, device='cuda:1')
# current relative error is:  tensor(0.0293, device='cuda:1')
# current epoch is:  98250
# current loss is:  tensor(-71.3796, device='cuda:1')
# current relative error is:  tensor(0.0322, device='cuda:1')
# current epoch is:  98300
# current loss is:  tensor(-74.2687, device='cuda:1')
# current relative error is:  tensor(0.0294, device='cuda:1')
# current epoch is:  98350
# current loss is:  tensor(-76.6290, device='cuda:1')
# current relative error is:  tensor(0.0307, device='cuda:1')
# current epoch is:  98400
# current loss is:  tensor(-76.3907, device='cuda:1')
# current relative error is:  tensor(0.0514, device='cuda:1')
# current epoch is:  98450
# current loss is:  tensor(-75.5892, device='cuda:1')
# current relative error is:  tensor(0.0608, device='cuda:1')
# current epoch is:  98500
# current loss is:  tensor(-80.4548, device='cuda:1')
# current relative error is:  tensor(0.0369, device='cuda:1')
# current epoch is:  98550
# current loss is:  tensor(-79.4439, device='cuda:1')
# current relative error is:  tensor(0.0444, device='cuda:1')
# current epoch is:  98600
# current loss is:  tensor(-69.5641, device='cuda:1')
# current relative error is:  tensor(0.0870, device='cuda:1')
# current epoch is:  98650
# current loss is:  tensor(-76.8074, device='cuda:1')
# current relative error is:  tensor(0.0313, device='cuda:1')
# current epoch is:  98700
# current loss is:  tensor(-76.4662, device='cuda:1')
# current relative error is:  tensor(0.0270, device='cuda:1')
# current epoch is:  98750
# current loss is:  tensor(-77.2545, device='cuda:1')
# current relative error is:  tensor(0.0328, device='cuda:1')
# current epoch is:  98800
# current loss is:  tensor(-75.5220, device='cuda:1')
# current relative error is:  tensor(0.0305, device='cuda:1')
# current epoch is:  98850
# current loss is:  tensor(-75.4465, device='cuda:1')
# current relative error is:  tensor(0.0305, device='cuda:1')
# current epoch is:  98900
# current loss is:  tensor(-78.3395, device='cuda:1')
# current relative error is:  tensor(0.0400, device='cuda:1')
# current epoch is:  98950
# current loss is:  tensor(-72.5689, device='cuda:1')
# current relative error is:  tensor(0.0357, device='cuda:1')
# current epoch is:  99000
# current loss is:  tensor(-77.8895, device='cuda:1')
# current relative error is:  tensor(0.0307, device='cuda:1')
# current epoch is:  99050
# current loss is:  tensor(-77.6280, device='cuda:1')
# current relative error is:  tensor(0.0264, device='cuda:1')
# current epoch is:  99100
# current loss is:  tensor(-79.6158, device='cuda:1')
# current relative error is:  tensor(0.0287, device='cuda:1')
# current epoch is:  99150
# current loss is:  tensor(-71.0270, device='cuda:1')
# current relative error is:  tensor(0.0316, device='cuda:1')
# current epoch is:  99200
# current loss is:  tensor(-76.4539, device='cuda:1')
# current relative error is:  tensor(0.0866, device='cuda:1')
# current epoch is:  99250
# current loss is:  tensor(-79.8900, device='cuda:1')
# current relative error is:  tensor(0.0912, device='cuda:1')
# current epoch is:  99300
# current loss is:  tensor(-76.7330, device='cuda:1')
# current relative error is:  tensor(0.0331, device='cuda:1')
# current epoch is:  99350
# current loss is:  tensor(-71.6732, device='cuda:1')
# current relative error is:  tensor(0.0295, device='cuda:1')
# current epoch is:  99400
# current loss is:  tensor(-80.0026, device='cuda:1')
# current relative error is:  tensor(0.0388, device='cuda:1')
# current epoch is:  99450
# current loss is:  tensor(-74.2113, device='cuda:1')
# current relative error is:  tensor(0.0289, device='cuda:1')
# current epoch is:  99500
# current loss is:  tensor(-73.5778, device='cuda:1')
# current relative error is:  tensor(0.0593, device='cuda:1')
# current epoch is:  99550
# current loss is:  tensor(-79.0262, device='cuda:1')
# current relative error is:  tensor(0.0423, device='cuda:1')
# current epoch is:  99600
# current loss is:  tensor(-79.4949, device='cuda:1')
# current relative error is:  tensor(0.0504, device='cuda:1')
# current epoch is:  99650
# current loss is:  tensor(-79.5585, device='cuda:1')
# current relative error is:  tensor(0.0526, device='cuda:1')
# current epoch is:  99700
# current loss is:  tensor(-73.5462, device='cuda:1')
# current relative error is:  tensor(0.0329, device='cuda:1')
# current epoch is:  99750
# current loss is:  tensor(-72.4113, device='cuda:1')
# current relative error is:  tensor(0.0340, device='cuda:1')
# current epoch is:  99800
# current loss is:  tensor(-80.6622, device='cuda:1')
# current relative error is:  tensor(0.0605, device='cuda:1')
# current epoch is:  99850
# current loss is:  tensor(-74.5849, device='cuda:1')
# current relative error is:  tensor(0.0436, device='cuda:1')
# current epoch is:  99900
# current loss is:  tensor(-80.4277, device='cuda:1')
# current relative error is:  tensor(0.0533, device='cuda:1')
# current epoch is:  99950
# current loss is:  tensor(-80.3670, device='cuda:1')
# current relative error is:  tensor(0.0379, device='cuda:1')
# total time is:  46406.09994792938 seconds
