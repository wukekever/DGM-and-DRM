# %%
import torch
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import torch.nn as nn
from math import *

# %%
torch.set_default_tensor_type('torch.DoubleTensor') # 设置浮点类型为 torch.float64

# %%
# 定义激活函数: swish(x)
def acti(x):
    return x*torch.sigmoid(x)

# %%
# 定义网络结构
class DeepRitzNet(torch.nn.Module):
    def __init__(self, input_width, layer_width):
        super(DeepRitzNet, self).__init__()
        self.linear_in = torch.nn.Linear(input_width, layer_width)
        self.linear1 = torch.nn.Linear(layer_width, layer_width)
        self.linear2 = torch.nn.Linear(layer_width, layer_width)
        self.linear3 = torch.nn.Linear(layer_width, layer_width)
        self.linear4 = torch.nn.Linear(layer_width, layer_width)
        self.linear5 = torch.nn.Linear(layer_width, layer_width)
        self.linear6 = torch.nn.Linear(layer_width, layer_width)
        self.linear_out = torch.nn.Linear(layer_width, 1)

    def forward(self, x):
        y = self.linear_in(x) # fully connect layer
        y = y + acti(self.linear2(acti(self.linear1(y)))) # residual block 1
        y = y + acti(self.linear4(acti(self.linear3(y)))) # residual block 2
        y = y + acti(self.linear6(acti(self.linear5(y)))) # residual block 3
        output = self.linear_out(y) # fully connect layer
        return output

# %%
dimension = 2

# %%
# exact solution
def u_ex(x):  
    x_temp = torch.cos(pi*x)
    u_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return u_x

# %%
def f(x):
    x_temp = torch.cos(pi*x)
    f_x = 2*pi**2*(x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return f_x

# %%
def g(x):  
    x_temp = torch.cos(pi*x)
    g_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return g_x

# %%
# Deep Ritz Method
def DRM(x):
    u_hat = model(x)
    # v = torch.ones(u_hat.shape)
    # ux = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = v, create_graph = True)[0]
    
    uxx = torch.zeros(x.size()[0], dimension)
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension)
        dx[:, i] = torch.ones(x.size()[0])
        uxx[:, i] = (model(x+step_size*dx) - 2*model(x) + model(x-step_size*dx))[:,0]/step_size**2
    laplace_u = (torch.sum(uxx, dim = 1)).reshape([x.size()[0], 1]) # dim = 1 按行求和
    f_temp = f(x)
    part_1 = torch.sum((-laplace_u + pi**2*u_hat - f_temp)**2)/x.size()[0]
    
    Nb = 100
    xb1 = torch.rand(Nb, dimension)
    xb1[:, 0] = torch.zeros(Nb)
    xb2 = torch.rand(Nb, dimension)
    xb2[:, 0] = torch.ones(Nb)
    xb3 = torch.rand(Nb, dimension)
    xb3[:, 1] = torch.zeros(Nb)
    xb4 = torch.rand(Nb, dimension)
    xb4[:, 1] = torch.ones(Nb)
    dx1 = torch.zeros(xb1.size()[0], dimension)
    dx1[:, 0] = torch.ones(xb1.size()[0])
    uxb1 = (((model(xb1+step_size*dx1) - model(xb1-step_size*dx1))/step_size/2 * (1.0) - 0) + model(xb1) - g(xb1))**2
    uxb2 = (((model(xb2+step_size*dx1) - model(xb2-step_size*dx1))/step_size/2 * (-1.0) - 0) + model(xb2) - g(xb2))**2
    dx2 = torch.zeros(xb1.size()[0], dimension)
    dx2[:, 1] = torch.ones(xb1.size()[0])
    uxb3 = (((model(xb3+step_size*dx2) - model(xb3-step_size*dx2))/step_size/2 * (1.0) - 0) + model(xb3) - g(xb3))**2
    uxb4 = (((model(xb4+step_size*dx2) - model(xb4-step_size*dx2))/step_size/2 * (-1.0) - 0) + model(xb4) - g(xb4))**2
    part_2 = torch.sum((uxb1 + uxb2 + uxb3 + uxb4)[:,0])/xb1.size()[0]
    lambda1 = 100.0
    return part_1 + lambda1 * part_2 / 4

# %%
Data_size = 2000
def Gendata():
    x = torch.rand(Data_size, dimension)
    return x

# %%
# 正态分布初始化参数
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = DeepRitzNet(dimension, 4)
model = initparam(model, 0.5)

# %%
import torch.optim as optim
import torch.nn as nn
import time

# %%
def relative_error():
    x = Gendata()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact )**2))/torch.sqrt(torch.sum((exact )**2))
    return value

# %%
traintime = 10000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = Gendata()
    x.requires_grad = True
    losses = DRM(x)
    losses.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", losses.detach())
        print("current relative error is: ", error.detach())
        np.save("DGM_relative_error_2D_Robin.npy", error_save)
np.save("DGM_relative_error_2D_Robin.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(523.7870)
# current relative error is:  tensor(0.8994)
# current epoch is:  50
# current loss is:  tensor(499.7490)
# current relative error is:  tensor(0.7968)
# current epoch is:  100
# current loss is:  tensor(484.1863)
# current relative error is:  tensor(0.6679)
# current epoch is:  150
# current loss is:  tensor(431.4923)
# current relative error is:  tensor(0.4761)
# current epoch is:  200
# current loss is:  tensor(269.0971)
# current relative error is:  tensor(0.4696)
# current epoch is:  250
# current loss is:  tensor(197.6837)
# current relative error is:  tensor(0.6319)
# current epoch is:  300
# current loss is:  tensor(181.6787)
# current relative error is:  tensor(0.6579)
# current epoch is:  350
# current loss is:  tensor(174.5711)
# current relative error is:  tensor(0.7174)
# current epoch is:  400
# current loss is:  tensor(158.0403)
# current relative error is:  tensor(0.7791)
# current epoch is:  450
# current loss is:  tensor(143.6257)
# current relative error is:  tensor(0.8238)
# current epoch is:  500
# current loss is:  tensor(95.5749)
# current relative error is:  tensor(0.8370)
# current epoch is:  550
# current loss is:  tensor(48.0551)
# current relative error is:  tensor(0.6284)
# current epoch is:  600
# current loss is:  tensor(31.0014)
# current relative error is:  tensor(0.5483)
# current epoch is:  650
# current loss is:  tensor(21.8215)
# current relative error is:  tensor(0.4823)
# current epoch is:  700
# current loss is:  tensor(16.5947)
# current relative error is:  tensor(0.4360)
# current epoch is:  750
# current loss is:  tensor(12.1747)
# current relative error is:  tensor(0.3730)
# current epoch is:  800
# current loss is:  tensor(9.9255)
# current relative error is:  tensor(0.3215)
# current epoch is:  850
# current loss is:  tensor(7.2548)
# current relative error is:  tensor(0.2631)
# current epoch is:  900
# current loss is:  tensor(5.8925)
# current relative error is:  tensor(0.2215)
# current epoch is:  950
# current loss is:  tensor(4.7020)
# current relative error is:  tensor(0.1825)
# current epoch is:  1000
# current loss is:  tensor(3.9256)
# current relative error is:  tensor(0.1572)
# current epoch is:  1050
# current loss is:  tensor(3.0904)
# current relative error is:  tensor(0.1249)
# current epoch is:  1100
# current loss is:  tensor(2.6730)
# current relative error is:  tensor(0.1089)
# current epoch is:  1150
# current loss is:  tensor(2.4414)
# current relative error is:  tensor(0.0923)
# current epoch is:  1200
# current loss is:  tensor(2.1863)
# current relative error is:  tensor(0.0789)
# current epoch is:  1250
# current loss is:  tensor(1.9785)
# current relative error is:  tensor(0.0664)
# current epoch is:  1300
# current loss is:  tensor(1.8607)
# current relative error is:  tensor(0.0628)
# current epoch is:  1350
# current loss is:  tensor(1.7043)
# current relative error is:  tensor(0.0547)
# current epoch is:  1400
# current loss is:  tensor(1.6027)
# current relative error is:  tensor(0.0451)
# current epoch is:  1450
# current loss is:  tensor(1.4113)
# current relative error is:  tensor(0.0439)
# current epoch is:  1500
# current loss is:  tensor(1.3321)
# current relative error is:  tensor(0.0380)
# current epoch is:  1550
# current loss is:  tensor(1.1084)
# current relative error is:  tensor(0.0397)
# current epoch is:  1600
# current loss is:  tensor(1.1744)
# current relative error is:  tensor(0.0374)
# current epoch is:  1650
# current loss is:  tensor(1.0159)
# current relative error is:  tensor(0.0321)
# current epoch is:  1700
# current loss is:  tensor(1.0182)
# current relative error is:  tensor(0.0360)
# current epoch is:  1750
# current loss is:  tensor(0.9445)
# current relative error is:  tensor(0.0260)
# current epoch is:  1800
# current loss is:  tensor(0.9326)
# current relative error is:  tensor(0.0310)
# current epoch is:  1850
# current loss is:  tensor(0.7762)
# current relative error is:  tensor(0.0295)
# current epoch is:  1900
# current loss is:  tensor(0.7578)
# current relative error is:  tensor(0.0263)
# current epoch is:  1950
# current loss is:  tensor(0.7043)
# current relative error is:  tensor(0.0251)
# current epoch is:  2000
# current loss is:  tensor(0.6728)
# current relative error is:  tensor(0.0248)
# current epoch is:  2050
# current loss is:  tensor(0.6294)
# current relative error is:  tensor(0.0248)
# current epoch is:  2100
# current loss is:  tensor(0.6037)
# current relative error is:  tensor(0.0190)
# current epoch is:  2150
# current loss is:  tensor(0.5387)
# current relative error is:  tensor(0.0193)
# current epoch is:  2200
# current epoch is:  5400
# current loss is:  tensor(0.0557)
# current relative error is:  tensor(0.0024)
# current epoch is:  5450
# current loss is:  tensor(0.0552)
# current relative error is:  tensor(0.0017)
# current epoch is:  5500
# current loss is:  tensor(0.0548)
# current relative error is:  tensor(0.0021)
# current epoch is:  5550
# current loss is:  tensor(0.0532)
# current relative error is:  tensor(0.0030)
# current epoch is:  5600
# current loss is:  tensor(0.0505)
# current relative error is:  tensor(0.0020)
# current epoch is:  5650
# current loss is:  tensor(0.0507)
# current relative error is:  tensor(0.0029)
# current epoch is:  5700
# current loss is:  tensor(0.0495)
# current relative error is:  tensor(0.0014)
# current epoch is:  5750
# current loss is:  tensor(0.0480)
# current relative error is:  tensor(0.0016)
# current epoch is:  5800
# current loss is:  tensor(0.0538)
# current relative error is:  tensor(0.0017)
# current epoch is:  5850
# current loss is:  tensor(0.0508)
# current relative error is:  tensor(0.0023)
# current epoch is:  5900
# current loss is:  tensor(0.0490)
# current relative error is:  tensor(0.0019)
# current epoch is:  5950
# current loss is:  tensor(0.0424)
# current relative error is:  tensor(0.0046)
# current epoch is:  6000
# current loss is:  tensor(0.0442)
# current relative error is:  tensor(0.0027)
# current epoch is:  6050
# current loss is:  tensor(0.0423)
# current relative error is:  tensor(0.0016)
# current epoch is:  6100
# current loss is:  tensor(0.0401)
# current relative error is:  tensor(0.0039)
# current epoch is:  6150
# current loss is:  tensor(0.0417)
# current relative error is:  tensor(0.0020)
# current epoch is:  6200
# current loss is:  tensor(0.0434)
# current relative error is:  tensor(0.0018)
# current epoch is:  6250
# current loss is:  tensor(0.0417)
# current relative error is:  tensor(0.0016)
# current epoch is:  6300
# current loss is:  tensor(0.0374)
# current relative error is:  tensor(0.0014)
# current epoch is:  6350
# current loss is:  tensor(0.0364)
# current relative error is:  tensor(0.0025)
# current epoch is:  6400
# current loss is:  tensor(0.0400)
# current relative error is:  tensor(0.0020)
# current epoch is:  6450
# current loss is:  tensor(0.0377)
# current relative error is:  tensor(0.0025)
# current epoch is:  6500
# current loss is:  tensor(0.0328)
# current relative error is:  tensor(0.0021)
# current epoch is:  6550
# current loss is:  tensor(0.0361)
# current relative error is:  tensor(0.0030)
# current epoch is:  6600
# current loss is:  tensor(0.0336)
# current relative error is:  tensor(0.0014)
# current epoch is:  6650
# current loss is:  tensor(0.0355)
# current relative error is:  tensor(0.0013)
# current epoch is:  6700
# current loss is:  tensor(0.0346)
# current relative error is:  tensor(0.0014)
# current epoch is:  6750
# current loss is:  tensor(0.0317)
# current relative error is:  tensor(0.0017)
# current epoch is:  6800
# current loss is:  tensor(0.0326)
# current relative error is:  tensor(0.0018)
# current epoch is:  6850
# current loss is:  tensor(0.0283)
# current relative error is:  tensor(0.0029)
# current epoch is:  6900
# current loss is:  tensor(0.0291)
# current relative error is:  tensor(0.0022)
# current epoch is:  6950
# current loss is:  tensor(0.0315)
# current relative error is:  tensor(0.0012)
# current epoch is:  7000
# current loss is:  tensor(0.0338)
# current relative error is:  tensor(0.0011)
# current epoch is:  7050
# current loss is:  tensor(0.0275)
# current relative error is:  tensor(0.0019)
# current epoch is:  7100
# current loss is:  tensor(0.0270)
# current relative error is:  tensor(0.0018)
# current epoch is:  7150
# current loss is:  tensor(0.0248)
# current relative error is:  tensor(0.0013)
# current epoch is:  7200
# current loss is:  tensor(0.0350)
# current relative error is:  tensor(0.0031)
# current epoch is:  7250
# current loss is:  tensor(0.0271)
# current relative error is:  tensor(0.0016)
# current epoch is:  7300
# current loss is:  tensor(0.0277)
# current relative error is:  tensor(0.0026)
# current epoch is:  7350
# current loss is:  tensor(0.0260)
# current relative error is:  tensor(0.0022)
# current epoch is:  7400
# current loss is:  tensor(0.0258)
# current relative error is:  tensor(0.0019)
# current epoch is:  7450
# current loss is:  tensor(0.0265)
# current relative error is:  tensor(0.0012)
# current epoch is:  7500
# current loss is:  tensor(0.0219)
# current relative error is:  tensor(0.0013)
# current epoch is:  7550
# current loss is:  tensor(0.0265)
# current relative error is:  tensor(0.0011)
# current epoch is:  7600
# current loss is:  tensor(0.0266)
# current relative error is:  tensor(0.0029)
# current epoch is:  7650
# current loss is:  tensor(0.0224)
# current relative error is:  tensor(0.0011)
# current epoch is:  7700
# current loss is:  tensor(0.0243)
# current relative error is:  tensor(0.0020)
# current epoch is:  7750
# current loss is:  tensor(0.0202)
# current relative error is:  tensor(0.0022)
# current epoch is:  7800
# current loss is:  tensor(0.0227)
# current relative error is:  tensor(0.0010)
# current epoch is:  7850
# current loss is:  tensor(0.0213)
# current relative error is:  tensor(0.0011)
# current epoch is:  7900
# current loss is:  tensor(0.0193)
# current relative error is:  tensor(0.0032)
# current epoch is:  7950
# current loss is:  tensor(0.0199)
# current relative error is:  tensor(0.0021)
# current epoch is:  8000
# current loss is:  tensor(0.0197)
# current relative error is:  tensor(0.0014)
# current epoch is:  8050
# current loss is:  tensor(0.0187)
# current relative error is:  tensor(0.0017)
# current epoch is:  8100
# current loss is:  tensor(0.0241)
# current relative error is:  tensor(0.0011)
# current epoch is:  8150
# current loss is:  tensor(0.0197)
# current relative error is:  tensor(0.0012)
# current epoch is:  8200
# current loss is:  tensor(0.0185)
# current relative error is:  tensor(0.0012)
# current epoch is:  8250
# current loss is:  tensor(0.0190)
# current relative error is:  tensor(0.0013)
# current epoch is:  8300
# current loss is:  tensor(0.0211)
# current relative error is:  tensor(0.0033)
# current epoch is:  8350
# current loss is:  tensor(0.0175)
# current relative error is:  tensor(0.0011)
# current epoch is:  8400
# current loss is:  tensor(0.0194)
# current relative error is:  tensor(0.0014)
# current epoch is:  8450
# current loss is:  tensor(0.0187)
# current relative error is:  tensor(0.0012)
# current epoch is:  8500
# current loss is:  tensor(0.0166)
# current relative error is:  tensor(0.0013)
# current epoch is:  8550
# current loss is:  tensor(0.0150)
# current relative error is:  tensor(0.0010)
# current epoch is:  8600
# current loss is:  tensor(0.0171)
# current relative error is:  tensor(0.0012)
# current epoch is:  8650
# current loss is:  tensor(0.0166)
# current relative error is:  tensor(0.0015)
# current epoch is:  8700
# current loss is:  tensor(0.0164)
# current relative error is:  tensor(0.0011)
# current epoch is:  8750
# current loss is:  tensor(0.0149)
# current relative error is:  tensor(0.0011)
# current epoch is:  8800
# current loss is:  tensor(0.0139)
# current relative error is:  tensor(0.0017)
# current epoch is:  8850
# current loss is:  tensor(0.0183)
# current relative error is:  tensor(0.0032)
# current epoch is:  8900
# current loss is:  tensor(0.0176)
# current relative error is:  tensor(0.0016)
# current epoch is:  8950
# current loss is:  tensor(0.0149)
# current relative error is:  tensor(0.0011)
# current epoch is:  9000
# current loss is:  tensor(0.0199)
# current relative error is:  tensor(0.0030)
# current epoch is:  9050
# current loss is:  tensor(0.0144)
# current relative error is:  tensor(0.0042)
# current epoch is:  9100
# current loss is:  tensor(0.0138)
# current relative error is:  tensor(0.0027)
# current epoch is:  9150
# current loss is:  tensor(0.0134)
# current relative error is:  tensor(0.0020)
# current epoch is:  9200
# current loss is:  tensor(0.0142)
# current relative error is:  tensor(0.0022)
# current epoch is:  9250
# current loss is:  tensor(0.0142)
# current relative error is:  tensor(0.0024)
# current epoch is:  9300
# current loss is:  tensor(0.0136)
# current relative error is:  tensor(0.0022)
# current epoch is:  9350
# current loss is:  tensor(0.0170)
# current relative error is:  tensor(0.0013)
# current epoch is:  9400
# current loss is:  tensor(0.0143)
# current relative error is:  tensor(0.0010)
# current epoch is:  9450
# current loss is:  tensor(0.0125)
# current relative error is:  tensor(0.0010)
# current epoch is:  9500
# current loss is:  tensor(0.0143)
# current relative error is:  tensor(0.0010)
# current epoch is:  9550
# current loss is:  tensor(0.0134)
# current relative error is:  tensor(0.0022)
# current epoch is:  9600
# current loss is:  tensor(0.0123)
# current relative error is:  tensor(0.0011)
# current epoch is:  9650
# current loss is:  tensor(0.0140)
# current relative error is:  tensor(0.0012)
# current epoch is:  9700
# current loss is:  tensor(0.0145)
# current relative error is:  tensor(0.0035)
# current epoch is:  9750
# current loss is:  tensor(0.0185)
# current relative error is:  tensor(0.0020)
# current epoch is:  9800
# current loss is:  tensor(0.0146)
# current relative error is:  tensor(0.0016)
# current epoch is:  9850
# current loss is:  tensor(0.0146)
# current relative error is:  tensor(0.0013)
# current epoch is:  9900
# current loss is:  tensor(0.0144)
# current relative error is:  tensor(0.0010)
# current epoch is:  9950
# current loss is:  tensor(0.0131)
# current relative error is:  tensor(0.0006)
# total time is:  1164.4093599319458 seconds

# %%
x_test = torch.rand(2, 10)
torch.abs(model(x) - u_ex(x))
# Out:
# tensor([[2.5813e-04],
#         [6.8091e-06],
#         [1.3897e-03],
#         ...,
#         [8.5505e-06],
#         [4.3867e-04],
#         [3.0858e-03]], grad_fn=<AbsBackward>)
