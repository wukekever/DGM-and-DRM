# %%
import torch
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR, MultiStepLR
import numpy as np
import torch.nn as nn
from math import *

# %%
torch.set_default_tensor_type('torch.DoubleTensor') # 设置浮点类型为 torch.float64

# %%
# 定义激活函数: swish(x)
def acti(x):
    return x*torch.sigmoid(x)

# %%
# 定义网络结构
class DeepRitzNet(torch.nn.Module):
    def __init__(self, input_width, layer_width):
        super(DeepRitzNet, self).__init__()
        self.linear_in = torch.nn.Linear(input_width, layer_width)
        self.linear1 = torch.nn.Linear(layer_width, layer_width)
        self.linear2 = torch.nn.Linear(layer_width, layer_width)
        self.linear3 = torch.nn.Linear(layer_width, layer_width)
        self.linear4 = torch.nn.Linear(layer_width, layer_width)
        self.linear5 = torch.nn.Linear(layer_width, layer_width)
        self.linear6 = torch.nn.Linear(layer_width, layer_width)
        self.linear_out = torch.nn.Linear(layer_width, 1)

    def forward(self, x):
        y = self.linear_in(x) # fully connect layer
        y = y + acti(self.linear2(acti(self.linear1(y)))) # residual block 1
        y = y + acti(self.linear4(acti(self.linear3(y)))) # residual block 2
        y = y + acti(self.linear6(acti(self.linear5(y)))) # residual block 3
        output = self.linear_out(y) # fully connect layer
        return output

# %%
dimension = 2

# %%
# exact solution
def u_ex(x):  
    x_temp = torch.cos(pi*x)
    u_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return u_x

# %%
def f(x):
    x_temp = torch.cos(pi*x)
    f_x = 2*pi**2*(x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return f_x

# %%
def g(x):  
    x_temp = torch.cos(pi*x)
    g_x = (x_temp.sum(1)).reshape([x.size()[0], 1]) # x_temp.sum(1) 按行求和
    return g_x

# %%
# Deep Ritz Method
def DRM(x):
    u_hat = model(x)
    # v = torch.ones(u_hat.shape)
    # ux = torch.autograd.grad(outputs = u_hat, inputs = x, grad_outputs = v, create_graph = True)[0]
    
    ux = torch.zeros(x.size()[0], dimension)
    step_size = 0.0001
    for i in range(dimension):
        dx = torch.zeros(x.size()[0], dimension)
        dx[:, i] = torch.ones(x.size()[0])
        ux[:, i] = (model(x+step_size*dx) - model(x-step_size*dx))[:,0]/step_size/2
    uxsq = (torch.sum(ux**2, dim = 1)).reshape([x.size()[0], 1]) # dim = 1 按行求和
    f_temp = f(x)
    part_1 = torch.sum(0.5 * uxsq + 0.5*pi**2*u_hat**2 - f_temp*u_hat)/x.size()[0]
    
    Nb = 100
    xb1 = torch.rand(Nb, dimension)
    xb1[:, 0] = torch.zeros(Nb)
    xb2 = torch.rand(Nb, dimension)
    xb2[:, 0] = torch.ones(Nb)
    xb3 = torch.rand(Nb, dimension)
    xb3[:, 1] = torch.zeros(Nb)
    xb4 = torch.rand(Nb, dimension)
    xb4[:, 1] = torch.ones(Nb)
    dx1 = torch.zeros(xb1.size()[0], dimension)
    dx1[:, 0] = torch.ones(xb1.size()[0])
    uxb1 = (((model(xb1+step_size*dx1) - model(xb1-step_size*dx1))/step_size/2 * (1.0) - 0) + model(xb1) - g(xb1))**2
    uxb2 = (((model(xb2+step_size*dx1) - model(xb2-step_size*dx1))/step_size/2 * (-1.0) - 0) + model(xb2) - g(xb2))**2
    dx2 = torch.zeros(xb1.size()[0], dimension)
    dx2[:, 1] = torch.ones(xb1.size()[0])
    uxb3 = (((model(xb3+step_size*dx2) - model(xb3-step_size*dx2))/step_size/2 * (1.0) - 0) + model(xb3) - g(xb3))**2
    uxb4 = (((model(xb4+step_size*dx2) - model(xb4-step_size*dx2))/step_size/2 * (-1.0) - 0) + model(xb4) - g(xb4))**2
    part_2 = torch.sum((uxb1 + uxb2 + uxb3 + uxb4)[:,0])/xb1.size()[0]
    lambda1 = 100.0
    return part_1 + lambda1 * part_2 / 4

# %%
Data_size = 2000
def Gendata():
    x = torch.rand(Data_size, dimension)
    return x

# %%
# 正态分布初始化参数
def initparam(model, sigma):
    for m in model.modules():
        if isinstance(m, nn.Linear):
            m.weight.data.normal_(0, sigma)
    return model

# %%
model = DeepRitzNet(dimension, 4)
model = initparam(model, 0.5)

# %%
import torch.optim as optim
import torch.nn as nn
import time

# %%
def relative_error():
    x = Gendata()
    predict = model(x)
    exact = u_ex(x)
    value = torch.sqrt(torch.sum((predict - exact )**2))/torch.sqrt(torch.sum((exact )**2))
    return value

# %%
traintime = 10000
error_save = np.zeros(traintime)
optimizer = optim.Adam(model.parameters())

# %%
time_start = time.time()
for i in range(traintime):
    optimizer.zero_grad()
    x = Gendata()
    x.requires_grad = True
    losses = DRM(x)
    losses.backward()
    optimizer.step()
    error = relative_error()
    error_save[i] = float(error)
    
    if i % 50 == 0:
        print("current epoch is: ", i)
        print("current loss is: ", losses.detach())
        print("current relative error is: ", error.detach())
        np.save("DRM_relative_error_2D_Robin.npy", error_save)
np.save("DRM_relative_error_2D_Robin.npy", error_save)
time_end = time.time()
print('total time is: ', time_end-time_start, 'seconds')
# Out:
# current epoch is:  0
# current loss is:  tensor(294.4655)
# current relative error is:  tensor(1.5818)
# current epoch is:  50
# current loss is:  tensor(166.3707)
# current relative error is:  tensor(1.1375)
# current epoch is:  100
# current loss is:  tensor(166.9143)
# current relative error is:  tensor(1.0457)
# current epoch is:  150
# current loss is:  tensor(151.6691)
# current relative error is:  tensor(1.0489)
# current epoch is:  200
# current loss is:  tensor(138.2976)
# current relative error is:  tensor(1.1266)
# current epoch is:  250
# current loss is:  tensor(122.2466)
# current relative error is:  tensor(1.1860)
# current epoch is:  300
# current loss is:  tensor(99.9108)
# current relative error is:  tensor(1.2641)
# current epoch is:  350
# current loss is:  tensor(72.4750)
# current relative error is:  tensor(1.2932)
# current epoch is:  400
# current loss is:  tensor(54.8875)
# current relative error is:  tensor(1.3405)
# current epoch is:  450
# current loss is:  tensor(42.2825)
# current relative error is:  tensor(1.3161)
# current epoch is:  500
# current loss is:  tensor(32.3305)
# current relative error is:  tensor(1.3224)
# current epoch is:  550
# current loss is:  tensor(15.3684)
# current relative error is:  tensor(1.2723)
# current epoch is:  600
# current loss is:  tensor(7.9216)
# current relative error is:  tensor(1.2059)
# current epoch is:  650
# current loss is:  tensor(6.1230)
# current relative error is:  tensor(1.1809)
# current epoch is:  700
# current loss is:  tensor(5.8623)
# current relative error is:  tensor(1.1809)
# current epoch is:  750
# current loss is:  tensor(5.8334)
# current relative error is:  tensor(1.1695)
# current epoch is:  800
# current loss is:  tensor(6.5511)
# current relative error is:  tensor(1.1575)
# current epoch is:  850
# current loss is:  tensor(5.6429)
# current relative error is:  tensor(1.1433)
# current epoch is:  900
# current loss is:  tensor(5.4240)
# current relative error is:  tensor(1.1451)
# current epoch is:  950
# current loss is:  tensor(4.7098)
# current relative error is:  tensor(1.1233)
# current epoch is:  1000
# current loss is:  tensor(4.4550)
# current relative error is:  tensor(1.1295)
# current epoch is:  1050
# current loss is:  tensor(4.2249)
# current relative error is:  tensor(1.1081)
# current epoch is:  1100
# current loss is:  tensor(4.0555)
# current relative error is:  tensor(1.0990)
# current epoch is:  1150
# current loss is:  tensor(3.3892)
# current relative error is:  tensor(1.0689)
# current epoch is:  1200
# current loss is:  tensor(2.1093)
# current relative error is:  tensor(1.0618)
# current epoch is:  1250
# current loss is:  tensor(0.8248)
# current relative error is:  tensor(1.0341)
# current epoch is:  1300
# current loss is:  tensor(-0.3373)
# current relative error is:  tensor(0.9567)
# current epoch is:  1350
# current loss is:  tensor(-1.8695)
# current relative error is:  tensor(0.8789)
# current epoch is:  1400
# current loss is:  tensor(-3.3846)
# current relative error is:  tensor(0.7844)
# current epoch is:  1450
# current loss is:  tensor(-3.8916)
# current relative error is:  tensor(0.6991)
# current epoch is:  1500
# current loss is:  tensor(-4.9139)
# current relative error is:  tensor(0.6411)
# current epoch is:  1550
# current loss is:  tensor(-5.5156)
# current relative error is:  tensor(0.5679)
# current epoch is:  1600
# current loss is:  tensor(-6.8130)
# current relative error is:  tensor(0.4858)
# current epoch is:  1650
# current loss is:  tensor(-7.9442)
# current relative error is:  tensor(0.3968)
# current epoch is:  1700
# current loss is:  tensor(-8.1239)
# current relative error is:  tensor(0.3016)
# current epoch is:  1750
# current loss is:  tensor(-9.2562)
# current relative error is:  tensor(0.2307)
# current epoch is:  1800
# current loss is:  tensor(-9.2145)
# current relative error is:  tensor(0.1756)
# current epoch is:  1850
# current loss is:  tensor(-9.2991)
# current relative error is:  tensor(0.1388)
# current epoch is:  1900
# current loss is:  tensor(-9.8301)
# current relative error is:  tensor(0.1153)
# current epoch is:  1950
# current loss is:  tensor(-10.1535)
# current relative error is:  tensor(0.0997)
# current epoch is:  2000
# current loss is:  tensor(-9.9857)
# current relative error is:  tensor(0.0810)
# current epoch is:  2050
# current loss is:  tensor(-9.6355)
# current relative error is:  tensor(0.0749)
# current epoch is:  2100
# current loss is:  tensor(-9.5815)
# current relative error is:  tensor(0.0694)
# current epoch is:  2150
# current loss is:  tensor(-9.6104)
# current relative error is:  tensor(0.0634)
# current epoch is:  2200
# current loss is:  tensor(-10.0658)
# current relative error is:  tensor(0.0558)
# current epoch is:  2250
# current loss is:  tensor(-9.1711)
# current relative error is:  tensor(0.0520)
# current epoch is:  2300
# current loss is:  tensor(-9.4730)
# current relative error is:  tensor(0.0487)
# current epoch is:  2350
# current loss is:  tensor(-10.4932)
# current relative error is:  tensor(0.0466)
# current epoch is:  2400
# current loss is:  tensor(-9.7840)
# current relative error is:  tensor(0.0461)
# current epoch is:  2450
# current loss is:  tensor(-10.0689)
# current relative error is:  tensor(0.0443)
# current epoch is:  2500
# current loss is:  tensor(-9.8674)
# current relative error is:  tensor(0.0414)
# current epoch is:  2550
# current loss is:  tensor(-9.0248)
# current relative error is:  tensor(0.0381)
# current epoch is:  2600
# current loss is:  tensor(-10.2599)
# current relative error is:  tensor(0.0375)
# current epoch is:  2650
# current loss is:  tensor(-9.8664)
# current relative error is:  tensor(0.0362)
# current epoch is:  2700
# current loss is:  tensor(-9.3730)
# current relative error is:  tensor(0.0342)
# current epoch is:  2750
# current loss is:  tensor(-9.9026)
# current relative error is:  tensor(0.0341)
# current epoch is:  2800
# current loss is:  tensor(-9.3702)
# current relative error is:  tensor(0.0327)
# current epoch is:  2850
# current loss is:  tensor(-9.5366)
# current relative error is:  tensor(0.0342)
# current epoch is:  2900
# current loss is:  tensor(-10.1338)
# current relative error is:  tensor(0.0328)
# current epoch is:  2950
# current loss is:  tensor(-10.1194)
# current relative error is:  tensor(0.0313)
# current epoch is:  3000
# current loss is:  tensor(-9.5578)
# current relative error is:  tensor(0.0305)
# current epoch is:  3050
# current loss is:  tensor(-9.6618)
# current relative error is:  tensor(0.0301)
# current epoch is:  3100
# current loss is:  tensor(-9.8494)
# current relative error is:  tensor(0.0300)
# current epoch is:  3150
# current loss is:  tensor(-9.2881)
# current relative error is:  tensor(0.0281)
# current epoch is:  3200
# current loss is:  tensor(-9.7696)
# current relative error is:  tensor(0.0288)
# current epoch is:  3250
# current loss is:  tensor(-9.8625)
# current relative error is:  tensor(0.0265)
# current epoch is:  3300
# current loss is:  tensor(-9.9001)
# current relative error is:  tensor(0.0259)
# current epoch is:  3350
# current loss is:  tensor(-9.0667)
# current relative error is:  tensor(0.0271)
# current epoch is:  3400
# current loss is:  tensor(-10.6515)
# current relative error is:  tensor(0.0267)
# current epoch is:  3450
# current loss is:  tensor(-9.2925)
# current relative error is:  tensor(0.0274)
# current epoch is:  3500
# current loss is:  tensor(-10.4364)
# current relative error is:  tensor(0.0246)
# current epoch is:  3550
# current loss is:  tensor(-10.6556)
# current relative error is:  tensor(0.0241)
# current epoch is:  3600
# current loss is:  tensor(-9.9179)
# current relative error is:  tensor(0.0240)
# current epoch is:  3650
# current loss is:  tensor(-10.2543)
# current relative error is:  tensor(0.0250)
# current epoch is:  3700
# current loss is:  tensor(-10.4758)
# current relative error is:  tensor(0.0253)
# current epoch is:  3750
# current loss is:  tensor(-10.2650)
# current relative error is:  tensor(0.0229)
# current epoch is:  3800
# current loss is:  tensor(-10.1469)
# current relative error is:  tensor(0.0207)
# current epoch is:  3850
# current loss is:  tensor(-10.6130)
# current relative error is:  tensor(0.0196)
# current epoch is:  3900
# current loss is:  tensor(-9.8789)
# current relative error is:  tensor(0.0207)
# current epoch is:  3950
# current loss is:  tensor(-10.2827)
# current relative error is:  tensor(0.0242)
# current epoch is:  4000
# current loss is:  tensor(-10.0004)
# current relative error is:  tensor(0.0254)
# current epoch is:  4050
# current loss is:  tensor(-9.9972)
# current relative error is:  tensor(0.0217)
# current epoch is:  4100
# current loss is:  tensor(-10.2492)
# current relative error is:  tensor(0.0245)
# current epoch is:  4150
# current loss is:  tensor(-9.8470)
# current relative error is:  tensor(0.0232)
# current epoch is:  4200
# current loss is:  tensor(-10.3407)
# current relative error is:  tensor(0.0205)
# current epoch is:  4250
# current loss is:  tensor(-9.5533)
# current relative error is:  tensor(0.0231)
# current epoch is:  4300
# current loss is:  tensor(-9.8434)
# current relative error is:  tensor(0.0193)
# current epoch is:  4350
# current loss is:  tensor(-10.1492)
# current relative error is:  tensor(0.0209)
# current epoch is:  4400
# current loss is:  tensor(-9.9300)
# current relative error is:  tensor(0.0180)
# current epoch is:  4450
# current loss is:  tensor(-9.7774)
# current relative error is:  tensor(0.0174)
# current epoch is:  4500
# current loss is:  tensor(-9.5975)
# current relative error is:  tensor(0.0180)
# current epoch is:  4550
# current loss is:  tensor(-9.5927)
# current relative error is:  tensor(0.0189)
# current epoch is:  4600
# current loss is:  tensor(-9.9529)
# current relative error is:  tensor(0.0174)
# current epoch is:  4650
# current loss is:  tensor(-9.7834)
# current relative error is:  tensor(0.0167)
# current epoch is:  4700
# current loss is:  tensor(-9.3399)
# current relative error is:  tensor(0.0175)
# current epoch is:  4750
# current loss is:  tensor(-9.8105)
# current relative error is:  tensor(0.0170)
# current epoch is:  4800
# current loss is:  tensor(-9.2993)
# current relative error is:  tensor(0.0146)
# current epoch is:  4850
# current loss is:  tensor(-9.2284)
# current relative error is:  tensor(0.0159)
# current epoch is:  4900
# current loss is:  tensor(-9.8536)
# current relative error is:  tensor(0.0155)
# current epoch is:  4950
# current loss is:  tensor(-9.5895)
# current relative error is:  tensor(0.0166)
# current epoch is:  5000
# current loss is:  tensor(-9.7337)
# current relative error is:  tensor(0.0139)
# current epoch is:  5050
# current loss is:  tensor(-9.9902)
# current relative error is:  tensor(0.0153)
# current epoch is:  5100
# current loss is:  tensor(-9.3269)
# current relative error is:  tensor(0.0138)
# current epoch is:  5150
# current loss is:  tensor(-9.6121)
# current relative error is:  tensor(0.0145)
# current epoch is:  5200
# current loss is:  tensor(-10.3283)
# current relative error is:  tensor(0.0149)
# current epoch is:  5250
# current loss is:  tensor(-9.3417)
# current relative error is:  tensor(0.0134)
# current epoch is:  5300
# current loss is:  tensor(-9.5378)
# current relative error is:  tensor(0.0140)
# current epoch is:  5350
# current loss is:  tensor(-10.2768)
# current relative error is:  tensor(0.0126)
# current epoch is:  5400
# current loss is:  tensor(-9.8554)
# current relative error is:  tensor(0.0131)
# current epoch is:  5450
# current loss is:  tensor(-9.9253)
# current relative error is:  tensor(0.0176)
# current epoch is:  5500
# current loss is:  tensor(-8.9937)
# current relative error is:  tensor(0.0144)
# current epoch is:  5550
# current loss is:  tensor(-10.3388)
# current relative error is:  tensor(0.0128)
# current epoch is:  5600
# current loss is:  tensor(-11.4365)
# current relative error is:  tensor(0.0147)
# current epoch is:  5650
# current loss is:  tensor(-9.1148)
# current relative error is:  tensor(0.0148)
# current epoch is:  5700
# current loss is:  tensor(-9.9215)
# current relative error is:  tensor(0.0132)
# current epoch is:  5750
# current loss is:  tensor(-9.9147)
# current relative error is:  tensor(0.0117)
# current epoch is:  5800
# current loss is:  tensor(-9.9605)
# current relative error is:  tensor(0.0140)
# current epoch is:  5850
# current loss is:  tensor(-9.9308)
# current relative error is:  tensor(0.0132)
# current epoch is:  5900
# current loss is:  tensor(-9.9856)
# current relative error is:  tensor(0.0172)
# current epoch is:  5950
# current loss is:  tensor(-10.1758)
# current relative error is:  tensor(0.0131)
# current epoch is:  6000
# current loss is:  tensor(-9.9254)
# current relative error is:  tensor(0.0122)
# current epoch is:  6050
# current loss is:  tensor(-9.6187)
# current relative error is:  tensor(0.0114)
# current epoch is:  6100
# current loss is:  tensor(-9.9232)
# current relative error is:  tensor(0.0125)
# current epoch is:  6150
# current loss is:  tensor(-9.8351)
# current relative error is:  tensor(0.0116)
# current epoch is:  6200
# current loss is:  tensor(-10.1525)
# current relative error is:  tensor(0.0135)
# current epoch is:  6250
# current loss is:  tensor(-10.8939)
# current relative error is:  tensor(0.0111)
# current epoch is:  6300
# current loss is:  tensor(-9.5852)
# current relative error is:  tensor(0.0165)
# current epoch is:  6350
# current loss is:  tensor(-9.4038)
# current relative error is:  tensor(0.0108)
# current epoch is:  6400
# current loss is:  tensor(-10.0392)
# current relative error is:  tensor(0.0116)
# current epoch is:  6450
# current loss is:  tensor(-10.0874)
# current relative error is:  tensor(0.0104)
# current epoch is:  6500
# current loss is:  tensor(-10.0283)
# current relative error is:  tensor(0.0102)
# current epoch is:  6550
# current loss is:  tensor(-9.9796)
# current relative error is:  tensor(0.0103)
# current epoch is:  6600
# current loss is:  tensor(-9.4950)
# current relative error is:  tensor(0.0161)
# current epoch is:  6650
# current loss is:  tensor(-10.0133)
# current relative error is:  tensor(0.0133)
# current epoch is:  6700
# current loss is:  tensor(-9.7454)
# current relative error is:  tensor(0.0132)
# current epoch is:  6750
# current loss is:  tensor(-10.3319)
# current relative error is:  tensor(0.0100)
# current epoch is:  6800
# current loss is:  tensor(-9.6483)
# current relative error is:  tensor(0.0102)
# current epoch is:  6850
# current loss is:  tensor(-10.1298)
# current relative error is:  tensor(0.0166)
# current epoch is:  6900
# current loss is:  tensor(-9.2964)
# current relative error is:  tensor(0.0108)
# current epoch is:  6950
# current loss is:  tensor(-9.8134)
# current relative error is:  tensor(0.0097)
# current epoch is:  7000
# current loss is:  tensor(-9.0676)
# current relative error is:  tensor(0.0100)
# current epoch is:  7050
# current loss is:  tensor(-9.7075)
# current relative error is:  tensor(0.0094)
# current epoch is:  7100
# current loss is:  tensor(-9.5726)
# current relative error is:  tensor(0.0095)
# current epoch is:  7150
# current loss is:  tensor(-9.5448)
# current relative error is:  tensor(0.0090)
# current epoch is:  7200
# current loss is:  tensor(-9.7165)
# current relative error is:  tensor(0.0103)
# current epoch is:  7250
# current loss is:  tensor(-9.7612)
# current relative error is:  tensor(0.0101)
# current epoch is:  7300
# current loss is:  tensor(-9.1102)
# current relative error is:  tensor(0.0087)
# current epoch is:  7350
# current loss is:  tensor(-9.3220)
# current relative error is:  tensor(0.0093)
# current epoch is:  7400
# current loss is:  tensor(-10.4896)
# current relative error is:  tensor(0.0088)
# current epoch is:  7450
# current loss is:  tensor(-10.1028)
# current relative error is:  tensor(0.0090)
# current epoch is:  7500
# current loss is:  tensor(-9.3477)
# current relative error is:  tensor(0.0091)
# current epoch is:  7550
# current loss is:  tensor(-10.2399)
# current relative error is:  tensor(0.0083)
# current epoch is:  7600
# current loss is:  tensor(-9.9645)
# current relative error is:  tensor(0.0084)
# current epoch is:  7650
# current loss is:  tensor(-9.8581)
# current relative error is:  tensor(0.0100)
# current epoch is:  7700
# current loss is:  tensor(-9.3980)
# current relative error is:  tensor(0.0083)
# current epoch is:  7750
# current loss is:  tensor(-10.0006)
# current relative error is:  tensor(0.0088)
# current epoch is:  7800
# current loss is:  tensor(-10.4551)
# current relative error is:  tensor(0.0093)
# current epoch is:  7850
# current loss is:  tensor(-10.1120)
# current relative error is:  tensor(0.0082)
# current epoch is:  7900
# current loss is:  tensor(-9.0095)
# current relative error is:  tensor(0.0082)
# current epoch is:  7950
# current loss is:  tensor(-9.5448)
# current relative error is:  tensor(0.0083)
# current epoch is:  8000
# current loss is:  tensor(-9.5136)
# current relative error is:  tensor(0.0087)
# current epoch is:  8050
# current loss is:  tensor(-9.8900)
# current relative error is:  tensor(0.0077)
# current epoch is:  8100
# current loss is:  tensor(-9.8500)
# current relative error is:  tensor(0.0090)
# current epoch is:  8150
# current loss is:  tensor(-9.2755)
# current relative error is:  tensor(0.0090)
# current epoch is:  8200
# current loss is:  tensor(-9.2649)
# current relative error is:  tensor(0.0072)
# current epoch is:  8250
# current loss is:  tensor(-9.3414)
# current relative error is:  tensor(0.0086)
# current epoch is:  8300
# current loss is:  tensor(-10.2948)
# current relative error is:  tensor(0.0135)
# current epoch is:  8350
# current loss is:  tensor(-9.4386)
# current relative error is:  tensor(0.0093)
# current epoch is:  8400
# current loss is:  tensor(-9.4537)
# current relative error is:  tensor(0.0075)
# current epoch is:  8450
# current loss is:  tensor(-10.5228)
# current relative error is:  tensor(0.0078)
# current epoch is:  8500
# current loss is:  tensor(-9.8165)
# current relative error is:  tensor(0.0091)
# current epoch is:  8550
# current loss is:  tensor(-10.3568)
# current relative error is:  tensor(0.0076)
# current epoch is:  8600
# current loss is:  tensor(-9.5532)
# current relative error is:  tensor(0.0080)
# current epoch is:  8650
# current loss is:  tensor(-10.2553)
# current relative error is:  tensor(0.0080)
# current epoch is:  8700
# current loss is:  tensor(-9.7666)
# current relative error is:  tensor(0.0075)
# current epoch is:  8750
# current loss is:  tensor(-9.8452)
# current relative error is:  tensor(0.0078)
# current epoch is:  8800
# current loss is:  tensor(-9.5249)
# current relative error is:  tensor(0.0078)
# current epoch is:  8850
# current loss is:  tensor(-9.8784)
# current relative error is:  tensor(0.0086)
# current epoch is:  8900
# current loss is:  tensor(-9.6195)
# current relative error is:  tensor(0.0102)
# current epoch is:  8950
# current loss is:  tensor(-10.4240)
# current relative error is:  tensor(0.0065)
# current epoch is:  9000
# current loss is:  tensor(-10.4394)
# current relative error is:  tensor(0.0067)
# current epoch is:  9050
# current loss is:  tensor(-9.4751)
# current relative error is:  tensor(0.0074)
# current epoch is:  9100
# current loss is:  tensor(-10.0630)
# current relative error is:  tensor(0.0137)
# current epoch is:  9150
# current loss is:  tensor(-9.5466)
# current relative error is:  tensor(0.0073)
# current epoch is:  9200
# current loss is:  tensor(-10.0187)
# current relative error is:  tensor(0.0085)
# current epoch is:  9250
# current loss is:  tensor(-10.0845)
# current relative error is:  tensor(0.0071)
# current epoch is:  9300
# current loss is:  tensor(-9.7330)
# current relative error is:  tensor(0.0077)
# current epoch is:  9350
# current loss is:  tensor(-9.9911)
# current relative error is:  tensor(0.0068)
# current epoch is:  9400
# current loss is:  tensor(-9.5217)
# current relative error is:  tensor(0.0066)
# current epoch is:  9450
# current loss is:  tensor(-10.2754)
# current relative error is:  tensor(0.0071)
# current epoch is:  9500
# current loss is:  tensor(-9.7364)
# current relative error is:  tensor(0.0067)
# current epoch is:  9550
# current loss is:  tensor(-9.2504)
# current relative error is:  tensor(0.0101)
# current epoch is:  9600
# current loss is:  tensor(-9.7971)
# current relative error is:  tensor(0.0085)
# current epoch is:  9650
# current loss is:  tensor(-9.8168)
# current relative error is:  tensor(0.0072)
# current epoch is:  9700
# current loss is:  tensor(-9.6107)
# current relative error is:  tensor(0.0070)
# current epoch is:  9750
# current loss is:  tensor(-10.2104)
# current relative error is:  tensor(0.0064)
# current epoch is:  9800
# current loss is:  tensor(-10.0022)
# current relative error is:  tensor(0.0087)
# current epoch is:  9850
# current loss is:  tensor(-11.1388)
# current relative error is:  tensor(0.0086)
# current epoch is:  9900
# current loss is:  tensor(-10.1157)
# current relative error is:  tensor(0.0119)
# current epoch is:  9950
# current loss is:  tensor(-9.6863)
# current relative error is:  tensor(0.0065)
# total time is:  993.2191143035889 seconds

# %%
x_test = torch.rand(2, 10)
torch.abs(model(x) - u_ex(x))
# Out:
# tensor([[0.0068],
#         [0.0098],
#         [0.0187],
#         ...,
#         [0.0056],
#         [0.0037],
#         [0.0015]], grad_fn=<AbsBackward>)
